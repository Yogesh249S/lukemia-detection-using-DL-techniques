# %% [markdown]
# # Solve the problem leveraging ResNet-50 architecture
# In this notebook, we will use the ResNet-50 architecture for our classification problem.
#
# First, we'll try a simple **feature extraction**. Since the architecture was trained on a different dataset, we do not expect very good performance, but we can use these results as a baseline for the next step: **fine-tuning**.

# %% [markdown]
# ## Import Libraries
# First of all, let's import all the libraries we will need later.

# %%
from google.colab import drive
import os
import shutil

import numpy as np
import random as rn
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from keras.models import Model
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from keras.applications.resnet_v2 import preprocess_input, decode_predictions

# %% [markdown]
# ## Load dataset from Google Drive
# The dataset is stored in Google Drive in a zip file, we unzip it locally for better performance.

# %%
drive.mount('/content/drive', force_remount=True)
# !unzip -q "/content/drive/My Drive/SplittedDataset.zip" -d "/content"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Set Parameters

# %%
DATASET_PATH = "/content/SplittedDataset"
TRAINING_PATH = DATASET_PATH + '/training_set'
TRAINING_ALL_PATH = TRAINING_PATH + '/all'
TRAINING_HEM_PATH = TRAINING_PATH + '/hem'
VALIDATION_PATH = DATASET_PATH + '/validation_set'
TEST_PATH = DATASET_PATH + '/test_set'

LOCAL_MODELS_FOLDER = "/content/models"
if not os.path.exists(LOCAL_MODELS_FOLDER):
  os.makedirs(LOCAL_MODELS_FOLDER)
GLOBAL_MODELS_FOLDER = "/content/drive/My Drive/Baldi_Cioffo/models/resnet-101"
if not os.path.exists(GLOBAL_MODELS_FOLDER):
  os.makedirs(GLOBAL_MODELS_FOLDER)

# Default values to load the dataset
BATCH_SIZE = 32
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224

# %% [markdown]
# ## Utility Functions

# %%
def set_seed ():
  '''
  set_seed is used to obtain reproducible results using keras during the development phase
  '''
  seed = 24
  # The below is necessary for reproducible results of certain Python hash-based operations.
  os.environ["PYTHONHASHSEED"]="0"
  # The below is necessary for starting Numpy generated random numbers in a well-defined initial state.
  np.random.seed(seed)
  # The below is necessary for starting core Python generated random numbers in a well-defined state.
  rn.seed(seed)
  # The below tf.random.set_seed will make random number generation in TensorFlow have a well-defined initial state.
  tf.random.set_seed(seed)

def show_training_and_validation_performance(history):
  '''
  show_training_and_validation_performance is used to plot the performances during the training phase
  :param history: object in which are recorded all the events
  '''
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'bo', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

def load_training_set (image_height, image_width, batch_size):
  '''
  load_training_set loads the training set from the "training_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return: the training set
  '''
  return image_dataset_from_directory(
    TRAINING_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def load_validation_set (image_height, image_width, batch_size):
  '''
  load_validation_set loads the validation set from the "validation_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return: the validation set
  '''
  return image_dataset_from_directory(
    VALIDATION_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def load_test_set (image_height, image_width, batch_size):
  '''
  load_test_set loads the test set from the "test_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return: the test set
  '''
  return image_dataset_from_directory(
    TEST_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    shuffle = False,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def compile_model (model, optimizer='adam', learning_rate = 0.001):
  '''
  compile_model is used to compile the current model
  :param model: model to compile
  :param optimizer: optimizer to be used
  :param learning_rate: learning rate parameter for the optimizer
  '''
  if optimizer == 'adam':
    model.compile(loss="binary_crossentropy",
      optimizer=optimizers.Adam(learning_rate=learning_rate),
      metrics=["accuracy"])
  elif optimizer == 'rmsprop':
    model.compile(loss="binary_crossentropy",
                  optimizer = optimizers.RMSprop(learning_rate=learning_rate),
                  metrics=['accuracy'])
  model.summary()

def run_model (model, model_name, epochs = 20, patience=5, monitor='val_loss'):
  '''
  run_model is used to run the current mode
  :param model: model to run
  :param model_name: name given to save the model
  :param epochs: how many epochs to do
  :param patience: patience value for Early Stopping
  :param monitor: what to monitor for Early Stopping and Model Checkpoint
  '''
  # local save path for the models
  save_path = LOCAL_MODELS_FOLDER + '/' + model_name + '.h5'
  callbacks_list = [
                  keras.callbacks.EarlyStopping(monitor=monitor, patience=patience),
                  keras.callbacks.ModelCheckpoint(
                      filepath = save_path,
                      monitor=monitor,
                      verbose=1,
                      save_best_only=True)
                  ]
  history = model.fit(train_dataset,
                    epochs=epochs,
                    validation_data=validation_dataset,
                    callbacks=callbacks_list)
  # save on Drive only the best model
  shutil.copy(save_path, GLOBAL_MODELS_FOLDER + '/' + model_name + '.h5')
  show_training_and_validation_performance(history)

def evaluate_model (model):
  '''
  evaluate_model is used to plot some statistics about the performance on the test set
  :param model: model to consider
  '''
  y_score = model.predict(test_dataset)
  y_pred = np.rint(y_score) # to have 0 or 1
  y_true = tf.concat([labels_batch for data_batch, labels_batch in test_dataset], axis = 0)
  print("Classification report: ")
  print(metrics.classification_report(y_true,y_pred,digits = 4))
  metrics.ConfusionMatrixDisplay.from_predictions(y_true, y_pred)

  # ROC curve
  fpr,tpr,th = metrics.roc_curve(y_true,y_score)
  roc_auc = metrics.roc_auc_score(y_true,y_score)

  plt.figure()
  plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
  plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.0])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('ROC curve')
  plt.legend(loc="lower right")
  plt.show()

# %% [markdown]
# ## Load Dataset
# The dataset, properly preprocessed, is now located in the local machine.

# %%
set_seed()

# %%
train_dataset = load_training_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
validation_dataset = load_validation_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
test_dataset = load_test_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
# Out:
# Found 6396 files belonging to 2 classes.
# Found 2132 files belonging to 2 classes.
# Found 2133 files belonging to 2 classes.

# %% [markdown]
# ## Feature extraction
# Firstly, we use the pretrained network to extract feature and we define our classifiers to classify the images.

# %%
conv_base = tf.keras.applications.ResNet101V2(include_top = False, weights='imagenet', input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 [==============================] - 1s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "resnet101v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (Ba  (None, 56, 56, 64)           256       ['pool1_pool[0][0]']
#  tchNormalization)
#
#  conv2_block1_preact_relu (  (None, 56, 56, 64)           0         ['conv2_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4096      ['conv2_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block1_1_relu[0][0]']
#  dding2D)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block1_2_pad[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block1_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_out (Add)      (None, 56, 56, 256)          0         ['conv2_block1_0_conv[0][0]',
#                                                                      'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (Ba  (None, 56, 56, 256)          1024      ['conv2_block1_out[0][0]']
#  tchNormalization)
#
#  conv2_block2_preact_relu (  (None, 56, 56, 256)          0         ['conv2_block2_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           16384     ['conv2_block2_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_relu[0][0]']
#  dding2D)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_2_pad[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_out (Add)      (None, 56, 56, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (Ba  (None, 56, 56, 256)          1024      ['conv2_block2_out[0][0]']
#  tchNormalization)
#
#  conv2_block3_preact_relu (  (None, 56, 56, 256)          0         ['conv2_block3_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           16384     ['conv2_block3_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_relu[0][0]']
#  dding2D)
#
#  conv2_block3_2_conv (Conv2  (None, 28, 28, 64)           36864     ['conv2_block3_2_pad[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 28, 28, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 28, 28, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  max_pooling2d (MaxPooling2  (None, 28, 28, 256)          0         ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_3_conv (Conv2  (None, 28, 28, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_out (Add)      (None, 28, 28, 256)          0         ['max_pooling2d[0][0]',
#                                                                      'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (Ba  (None, 28, 28, 256)          1024      ['conv2_block3_out[0][0]']
#  tchNormalization)
#
#  conv3_block1_preact_relu (  (None, 28, 28, 256)          0         ['conv3_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block1_1_relu[0][0]']
#  dding2D)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block1_2_pad[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 512)          131584    ['conv3_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block1_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_out (Add)      (None, 28, 28, 512)          0         ['conv3_block1_0_conv[0][0]',
#                                                                      'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (Ba  (None, 28, 28, 512)          2048      ['conv3_block1_out[0][0]']
#  tchNormalization)
#
#  conv3_block2_preact_relu (  (None, 28, 28, 512)          0         ['conv3_block2_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          65536     ['conv3_block2_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_relu[0][0]']
#  dding2D)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_2_pad[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_out (Add)      (None, 28, 28, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (Ba  (None, 28, 28, 512)          2048      ['conv3_block2_out[0][0]']
#  tchNormalization)
#
#  conv3_block3_preact_relu (  (None, 28, 28, 512)          0         ['conv3_block3_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          65536     ['conv3_block3_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_relu[0][0]']
#  dding2D)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_2_pad[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_out (Add)      (None, 28, 28, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (Ba  (None, 28, 28, 512)          2048      ['conv3_block3_out[0][0]']
#  tchNormalization)
#
#  conv3_block4_preact_relu (  (None, 28, 28, 512)          0         ['conv3_block4_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          65536     ['conv3_block4_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_relu[0][0]']
#  dding2D)
#
#  conv3_block4_2_conv (Conv2  (None, 14, 14, 128)          147456    ['conv3_block4_2_pad[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 512)          0         ['conv3_block3_out[0][0]']
#  g2D)
#
#  conv3_block4_3_conv (Conv2  (None, 14, 14, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_out (Add)      (None, 14, 14, 512)          0         ['max_pooling2d_1[0][0]',
#                                                                      'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (Ba  (None, 14, 14, 512)          2048      ['conv3_block4_out[0][0]']
#  tchNormalization)
#
#  conv4_block1_preact_relu (  (None, 14, 14, 512)          0         ['conv4_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 256)          131072    ['conv4_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block1_1_relu[0][0]']
#  dding2D)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block1_2_pad[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 1024)         525312    ['conv4_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block1_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_0_conv[0][0]',
#                                                                      'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block1_out[0][0]']
#  tchNormalization)
#
#  conv4_block2_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block2_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block2_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_relu[0][0]']
#  dding2D)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_2_pad[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block2_out[0][0]']
#  tchNormalization)
#
#  conv4_block3_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block3_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block3_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_relu[0][0]']
#  dding2D)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_2_pad[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block3_out[0][0]']
#  tchNormalization)
#
#  conv4_block4_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block4_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block4_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_relu[0][0]']
#  dding2D)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_2_pad[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block4_out[0][0]']
#  tchNormalization)
#
#  conv4_block5_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block5_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block5_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_relu[0][0]']
#  dding2D)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_2_pad[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block5_out[0][0]']
#  tchNormalization)
#
#  conv4_block6_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block6_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block6_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_relu[0][0]']
#  dding2D)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_2_pad[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_conv[0][0]']
#
#  conv4_block7_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block6_out[0][0]']
#  tchNormalization)
#
#  conv4_block7_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block7_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block7_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block7_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block7_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block7_1_conv[0][0]']
#  rmalization)
#
#  conv4_block7_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block7_1_bn[0][0]']
#  ation)
#
#  conv4_block7_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block7_1_relu[0][0]']
#  dding2D)
#
#  conv4_block7_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block7_2_pad[0][0]']
#  D)
#
#  conv4_block7_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block7_2_conv[0][0]']
#  rmalization)
#
#  conv4_block7_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block7_2_bn[0][0]']
#  ation)
#
# ...
#  conv4_block22_2_conv (Conv  (None, 14, 14, 256)          589824    ['conv4_block22_2_pad[0][0]']
#  2D)
#
#  conv4_block22_2_bn (BatchN  (None, 14, 14, 256)          1024      ['conv4_block22_2_conv[0][0]']
#  ormalization)
#
#  conv4_block22_2_relu (Acti  (None, 14, 14, 256)          0         ['conv4_block22_2_bn[0][0]']
#  vation)
#
#  conv4_block22_3_conv (Conv  (None, 14, 14, 1024)         263168    ['conv4_block22_2_relu[0][0]']
#  2D)
#
#  conv4_block22_out (Add)     (None, 14, 14, 1024)         0         ['conv4_block21_out[0][0]',
#                                                                      'conv4_block22_3_conv[0][0]']
#
#  conv4_block23_preact_bn (B  (None, 14, 14, 1024)         4096      ['conv4_block22_out[0][0]']
#  atchNormalization)
#
#  conv4_block23_preact_relu   (None, 14, 14, 1024)         0         ['conv4_block23_preact_bn[0][0
#  (Activation)                                                       ]']
#
#  conv4_block23_1_conv (Conv  (None, 14, 14, 256)          262144    ['conv4_block23_preact_relu[0]
#  2D)                                                                [0]']
#
#  conv4_block23_1_bn (BatchN  (None, 14, 14, 256)          1024      ['conv4_block23_1_conv[0][0]']
#  ormalization)
#
#  conv4_block23_1_relu (Acti  (None, 14, 14, 256)          0         ['conv4_block23_1_bn[0][0]']
#  vation)
#
#  conv4_block23_2_pad (ZeroP  (None, 16, 16, 256)          0         ['conv4_block23_1_relu[0][0]']
#  adding2D)
#
#  conv4_block23_2_conv (Conv  (None, 7, 7, 256)            589824    ['conv4_block23_2_pad[0][0]']
#  2D)
#
#  conv4_block23_2_bn (BatchN  (None, 7, 7, 256)            1024      ['conv4_block23_2_conv[0][0]']
#  ormalization)
#
#  conv4_block23_2_relu (Acti  (None, 7, 7, 256)            0         ['conv4_block23_2_bn[0][0]']
#  vation)
#
#  max_pooling2d_2 (MaxPoolin  (None, 7, 7, 1024)           0         ['conv4_block22_out[0][0]']
#  g2D)
#
#  conv4_block23_3_conv (Conv  (None, 7, 7, 1024)           263168    ['conv4_block23_2_relu[0][0]']
#  2D)
#
#  conv4_block23_out (Add)     (None, 7, 7, 1024)           0         ['max_pooling2d_2[0][0]',
#                                                                      'conv4_block23_3_conv[0][0]']
#
#  conv5_block1_preact_bn (Ba  (None, 7, 7, 1024)           4096      ['conv4_block23_out[0][0]']
#  tchNormalization)
#
#  conv5_block1_preact_relu (  (None, 7, 7, 1024)           0         ['conv5_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv5_block1_1_conv (Conv2  (None, 7, 7, 512)            524288    ['conv5_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv5_block1_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block1_1_relu[0][0]']
#  dding2D)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block1_2_pad[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 2048)           2099200   ['conv5_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv5_block1_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_out (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_0_conv[0][0]',
#                                                                      'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (Ba  (None, 7, 7, 2048)           8192      ['conv5_block1_out[0][0]']
#  tchNormalization)
#
#  conv5_block2_preact_relu (  (None, 7, 7, 2048)           0         ['conv5_block2_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            1048576   ['conv5_block2_preact_relu[0][
#  D)                                                                 0]']
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block2_1_relu[0][0]']
#  dding2D)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block2_2_pad[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_out (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (Ba  (None, 7, 7, 2048)           8192      ['conv5_block2_out[0][0]']
#  tchNormalization)
#
#  conv5_block3_preact_relu (  (None, 7, 7, 2048)           0         ['conv5_block3_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            1048576   ['conv5_block3_preact_relu[0][
#  D)                                                                 0]']
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_pad (ZeroPa  (None, 9, 9, 512)            0         ['conv5_block3_1_relu[0][0]']
#  dding2D)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359296   ['conv5_block3_2_pad[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_out (Add)      (None, 7, 7, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalizatio  (None, 7, 7, 2048)           8192      ['conv5_block3_out[0][0]']
#  n)
#
#  post_relu (Activation)      (None, 7, 7, 2048)           0         ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 42626560 (162.61 MB)
# Trainable params: 42528896 (162.23 MB)
# Non-trainable params: 97664 (381.50 KB)
# __________________________________________________________________________________________________

# %%
conv_base.trainable = False

# %% [markdown]
# ### Experiment 1: one dense layer with 64 neurons
# In this first experiment we try a simple configuration with a single dense layer before the output layer.

# %%
from keras.applications.densenet import preprocess_input
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet_v2.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu') (x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model1 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv (TFOpLambd  (None, 224, 224, 3)       0
#  a)
#
#  tf.math.subtract (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  resnet101v2 (Functional)    (None, 7, 7, 2048)        42626560
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 64)                6422592
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 49049217 (187.11 MB)
# Trainable params: 6422657 (24.50 MB)
# Non-trainable params: 42626560 (162.61 MB)
# _________________________________________________________________

# %%
run_model(model1, 'experiment1_feature_extraction', epochs = 30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 1.4497 - accuracy: 0.6961
# Epoch 1: val_loss improved from inf to 1.34021, saving model to /content/models/experiment1_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 65s 267ms/step - loss: 1.4497 - accuracy: 0.6961 - val_loss: 1.3402 - val_accuracy: 0.6459
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.8419
# Epoch 2: val_loss improved from 1.34021 to 0.91484, saving model to /content/models/experiment1_feature_extraction.h5
# 200/200 [==============================] - 46s 229ms/step - loss: 0.4857 - accuracy: 0.8419 - val_loss: 0.9148 - val_accuracy: 0.7326
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2638 - accuracy: 0.8987
# Epoch 3: val_loss improved from 0.91484 to 0.85323, saving model to /content/models/experiment1_feature_extraction.h5
# 200/200 [==============================] - 47s 233ms/step - loss: 0.2638 - accuracy: 0.8987 - val_loss: 0.8532 - val_accuracy: 0.7364
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9375
# Epoch 4: val_loss improved from 0.85323 to 0.62239, saving model to /content/models/experiment1_feature_extraction.h5
# 200/200 [==============================] - 47s 235ms/step - loss: 0.1535 - accuracy: 0.9375 - val_loss: 0.6224 - val_accuracy: 0.8293
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.9675
# Epoch 5: val_loss did not improve from 0.62239
# 200/200 [==============================] - 45s 222ms/step - loss: 0.0896 - accuracy: 0.9675 - val_loss: 0.8438 - val_accuracy: 0.7613
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.9705
# Epoch 6: val_loss did not improve from 0.62239
# 200/200 [==============================] - 45s 227ms/step - loss: 0.0788 - accuracy: 0.9705 - val_loss: 1.2511 - val_accuracy: 0.6942
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9908
# Epoch 7: val_loss did not improve from 0.62239
# 200/200 [==============================] - 45s 224ms/step - loss: 0.0371 - accuracy: 0.9908 - val_loss: 0.7732 - val_accuracy: 0.7908
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9994
# Epoch 8: val_loss did not improve from 0.62239
# 200/200 [==============================] - 55s 274ms/step - loss: 0.0151 - accuracy: 0.9994 - val_loss: 0.6928 - val_accuracy: 0.8077
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 9: val_loss did not improve from 0.62239
# 200/200 [==============================] - 45s 224ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.7047 - val_accuracy: 0.8063

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment1_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 15s 185ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6974    0.7615    0.7280       696
#            1     0.8791    0.8399    0.8591      1437
#
#     accuracy                         0.8143      2133
#    macro avg     0.7882    0.8007    0.7935      2133
# weighted avg     0.8198    0.8143    0.8163      2133

# %% [markdown]
# ### Experiment 2: one dense layer with 32 neurons
# We tried to lower the number of neurons, to fight overfitting

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet_v2.preprocess_input(inputs)

x = conv_base(x) # feature extraction
x = layers.Flatten()(x)
x = layers.Dense(32, activation='relu') (x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model2 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model2)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_1 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_1 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  resnet101v2 (Functional)    (None, 7, 7, 2048)        42626560
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  dense_2 (Dense)             (None, 32)                3211296
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 45837889 (174.86 MB)
# Trainable params: 3211329 (12.25 MB)
# Non-trainable params: 42626560 (162.61 MB)
# _________________________________________________________________

# %%
run_model(model2, 'experiment2_feature_extraction', epochs = 30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9692
# Epoch 1: val_loss improved from inf to 0.72206, saving model to /content/models/experiment2_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0985 - accuracy: 0.9692 - val_loss: 0.7221 - val_accuracy: 0.8063
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9844
# Epoch 2: val_loss did not improve from 0.72206
# 200/200 [==============================] - 54s 270ms/step - loss: 0.0672 - accuracy: 0.9844 - val_loss: 0.8433 - val_accuracy: 0.7871
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9873
# Epoch 3: val_loss did not improve from 0.72206
# 200/200 [==============================] - 45s 226ms/step - loss: 0.0561 - accuracy: 0.9873 - val_loss: 0.8729 - val_accuracy: 0.8072
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9875
# Epoch 4: val_loss did not improve from 0.72206
# 200/200 [==============================] - 45s 225ms/step - loss: 0.0545 - accuracy: 0.9875 - val_loss: 0.9877 - val_accuracy: 0.7795
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0427 - accuracy: 0.9909
# Epoch 5: val_loss did not improve from 0.72206
# 200/200 [==============================] - 44s 217ms/step - loss: 0.0427 - accuracy: 0.9909 - val_loss: 0.7463 - val_accuracy: 0.8372
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9897
# Epoch 6: val_loss did not improve from 0.72206
# 200/200 [==============================] - 52s 261ms/step - loss: 0.0488 - accuracy: 0.9897 - val_loss: 0.8638 - val_accuracy: 0.8175

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment2_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 13s 161ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6985    0.7457    0.7213       696
#            1     0.8727    0.8441    0.8582      1437
#
#     accuracy                         0.8120      2133
#    macro avg     0.7856    0.7949    0.7897      2133
# weighted avg     0.8158    0.8120    0.8135      2133

# %% [markdown]
# ### Experiment 3: one dense layer with 64 neurons and dropout
# Lowering the capacity of the networks leads us to underfitting, we could try to use Dropout instead.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet_v2.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu') (x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model3 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model3)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_2 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_2 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  resnet101v2 (Functional)    (None, 7, 7, 2048)        42626560
#
#  flatten_2 (Flatten)         (None, 100352)            0
#
#  dense_4 (Dense)             (None, 64)                6422592
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 49049217 (187.11 MB)
# Trainable params: 6422657 (24.50 MB)
# Non-trainable params: 42626560 (162.61 MB)
# _________________________________________________________________

# %%
run_model(model3, 'experiment3_feature_extraction', epochs = 50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 1.3155 - accuracy: 0.6693
# Epoch 1: val_loss improved from inf to 0.51521, saving model to /content/models/experiment3_feature_extraction.h5
# 200/200 [==============================] - 64s 283ms/step - loss: 1.3155 - accuracy: 0.6693 - val_loss: 0.5152 - val_accuracy: 0.7847
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4835 - accuracy: 0.7436
# Epoch 2: val_loss did not improve from 0.51521
# 200/200 [==============================] - 44s 217ms/step - loss: 0.4835 - accuracy: 0.7436 - val_loss: 0.5632 - val_accuracy: 0.7767
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4346 - accuracy: 0.7708
# Epoch 3: val_loss improved from 0.51521 to 0.38663, saving model to /content/models/experiment3_feature_extraction.h5
# 200/200 [==============================] - 45s 222ms/step - loss: 0.4346 - accuracy: 0.7708 - val_loss: 0.3866 - val_accuracy: 0.8330
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3671 - accuracy: 0.8025
# Epoch 4: val_loss did not improve from 0.38663
# 200/200 [==============================] - 53s 262ms/step - loss: 0.3671 - accuracy: 0.8025 - val_loss: 0.4916 - val_accuracy: 0.7983
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3310 - accuracy: 0.8227
# Epoch 5: val_loss did not improve from 0.38663
# 200/200 [==============================] - 46s 229ms/step - loss: 0.3310 - accuracy: 0.8227 - val_loss: 0.5753 - val_accuracy: 0.7913
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3007 - accuracy: 0.8291
# Epoch 6: val_loss did not improve from 0.38663
# 200/200 [==============================] - 45s 223ms/step - loss: 0.3007 - accuracy: 0.8291 - val_loss: 0.5646 - val_accuracy: 0.7917
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.2715 - accuracy: 0.8499
# Epoch 7: val_loss did not improve from 0.38663
# 200/200 [==============================] - 55s 272ms/step - loss: 0.2715 - accuracy: 0.8499 - val_loss: 0.4692 - val_accuracy: 0.8133
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.2294 - accuracy: 0.8626
# Epoch 8: val_loss did not improve from 0.38663
# 200/200 [==============================] - 46s 228ms/step - loss: 0.2294 - accuracy: 0.8626 - val_loss: 0.4537 - val_accuracy: 0.8335

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment3_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 13s 162ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8709    0.5718    0.6904       696
#            1     0.8222    0.9589    0.8853      1437
#
#     accuracy                         0.8326      2133
#    macro avg     0.8465    0.7654    0.7878      2133
# weighted avg     0.8381    0.8326    0.8217      2133

# %% [markdown]
# ### Experiment 4: global average pooling
# Try GlobalAveragePooling instead of fully connected layers, to lower the number of parameters.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet_v2.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.GlobalAveragePooling2D() (x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model4 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model4)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_3 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_3 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  resnet101v2 (Functional)    (None, 7, 7, 2048)        42626560
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 42628609 (162.62 MB)
# Trainable params: 2049 (8.00 KB)
# Non-trainable params: 42626560 (162.61 MB)
# _________________________________________________________________

# %%
run_model(model4, "experiment4_feature_extraction", epochs=20)
# Out:
# Epoch 1/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5845 - accuracy: 0.7001
# Epoch 1: val_loss improved from inf to 0.58828, saving model to /content/models/experiment4_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 57s 241ms/step - loss: 0.5845 - accuracy: 0.7001 - val_loss: 0.5883 - val_accuracy: 0.6796
# Epoch 2/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5222 - accuracy: 0.7389
# Epoch 2: val_loss improved from 0.58828 to 0.52130, saving model to /content/models/experiment4_feature_extraction.h5
# 200/200 [==============================] - 47s 232ms/step - loss: 0.5222 - accuracy: 0.7389 - val_loss: 0.5213 - val_accuracy: 0.7425
# Epoch 3/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4903 - accuracy: 0.7703
# Epoch 3: val_loss improved from 0.52130 to 0.44993, saving model to /content/models/experiment4_feature_extraction.h5
# 200/200 [==============================] - 55s 275ms/step - loss: 0.4903 - accuracy: 0.7703 - val_loss: 0.4499 - val_accuracy: 0.8063
# Epoch 4/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4722 - accuracy: 0.7752
# Epoch 4: val_loss did not improve from 0.44993
# 200/200 [==============================] - 55s 274ms/step - loss: 0.4722 - accuracy: 0.7752 - val_loss: 0.4600 - val_accuracy: 0.7960
# Epoch 5/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4576 - accuracy: 0.7858
# Epoch 5: val_loss did not improve from 0.44993
# 200/200 [==============================] - 46s 227ms/step - loss: 0.4576 - accuracy: 0.7858 - val_loss: 0.4555 - val_accuracy: 0.7932
# Epoch 6/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4458 - accuracy: 0.7996
# Epoch 6: val_loss did not improve from 0.44993
# 200/200 [==============================] - 44s 221ms/step - loss: 0.4458 - accuracy: 0.7996 - val_loss: 0.4630 - val_accuracy: 0.7800
# Epoch 7/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4390 - accuracy: 0.7975
# Epoch 7: val_loss improved from 0.44993 to 0.41036, saving model to /content/models/experiment4_feature_extraction.h5
# 200/200 [==============================] - 47s 233ms/step - loss: 0.4390 - accuracy: 0.7975 - val_loss: 0.4104 - val_accuracy: 0.8307
# Epoch 8/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4314 - accuracy: 0.8044
# Epoch 8: val_loss did not improve from 0.41036
# 200/200 [==============================] - 44s 221ms/step - loss: 0.4314 - accuracy: 0.8044 - val_loss: 0.4123 - val_accuracy: 0.8279
# Epoch 9/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4241 - accuracy: 0.8052
# Epoch 9: val_loss improved from 0.41036 to 0.40988, saving model to /content/models/experiment4_feature_extraction.h5
# 200/200 [==============================] - 46s 229ms/step - loss: 0.4241 - accuracy: 0.8052 - val_loss: 0.4099 - val_accuracy: 0.8265
# Epoch 10/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4214 - accuracy: 0.8089
# Epoch 10: val_loss did not improve from 0.40988
# 200/200 [==============================] - 45s 224ms/step - loss: 0.4214 - accuracy: 0.8089 - val_loss: 0.4381 - val_accuracy: 0.8021
# Epoch 11/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4121 - accuracy: 0.8124
# Epoch 11: val_loss did not improve from 0.40988
# 200/200 [==============================] - 46s 229ms/step - loss: 0.4121 - accuracy: 0.8124 - val_loss: 0.4579 - val_accuracy: 0.7842
# Epoch 12/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4080 - accuracy: 0.8166
# Epoch 12: val_loss did not improve from 0.40988
# 200/200 [==============================] - 44s 221ms/step - loss: 0.4080 - accuracy: 0.8166 - val_loss: 0.4539 - val_accuracy: 0.7838
# Epoch 13/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4045 - accuracy: 0.8204
# Epoch 13: val_loss improved from 0.40988 to 0.40786, saving model to /content/models/experiment4_feature_extraction.h5
# 200/200 [==============================] - 47s 232ms/step - loss: 0.4045 - accuracy: 0.8204 - val_loss: 0.4079 - val_accuracy: 0.8218
# Epoch 14/20
# 200/200 [==============================] - ETA: 0s - loss: 0.3984 - accuracy: 0.8211
# Epoch 14: val_loss did not improve from 0.40786
# 200/200 [==============================] - 54s 269ms/step - loss: 0.3984 - accuracy: 0.8211 - val_loss: 0.4192 - val_accuracy: 0.8119
# Epoch 15/20
# 200/200 [==============================] - ETA: 0s - loss: 0.3942 - accuracy: 0.8238
# Epoch 15: val_loss did not improve from 0.40786
# 200/200 [==============================] - 46s 229ms/step - loss: 0.3942 - accuracy: 0.8238 - val_loss: 0.4564 - val_accuracy: 0.7791
# Epoch 16/20
# 200/200 [==============================] - ETA: 0s - loss: 0.3897 - accuracy: 0.8272
# Epoch 16: val_loss did not improve from 0.40786
# 200/200 [==============================] - 44s 221ms/step - loss: 0.3897 - accuracy: 0.8272 - val_loss: 0.4199 - val_accuracy: 0.8086
# Epoch 17/20
# 200/200 [==============================] - ETA: 0s - loss: 0.3858 - accuracy: 0.8299
# Epoch 17: val_loss improved from 0.40786 to 0.39996, saving model to /content/models/experiment4_feature_extraction.h5
# 200/200 [==============================] - 55s 276ms/step - loss: 0.3858 - accuracy: 0.8299 - val_loss: 0.4000 - val_accuracy: 0.8250
# Epoch 18/20
# 200/200 [==============================] - ETA: 0s - loss: 0.3820 - accuracy: 0.8332
# Epoch 18: val_loss improved from 0.39996 to 0.39761, saving model to /content/models/experiment4_feature_extraction.h5
# 200/200 [==============================] - 46s 229ms/step - loss: 0.3820 - accuracy: 0.8332 - val_loss: 0.3976 - val_accuracy: 0.8269
# Epoch 19/20
# 200/200 [==============================] - ETA: 0s - loss: 0.3786 - accuracy: 0.8336
# Epoch 19: val_loss did not improve from 0.39761
# 200/200 [==============================] - 46s 228ms/step - loss: 0.3786 - accuracy: 0.8336 - val_loss: 0.4006 - val_accuracy: 0.8227
# Epoch 20/20
# 200/200 [==============================] - ETA: 0s - loss: 0.3767 - accuracy: 0.8335
# Epoch 20: val_loss did not improve from 0.39761
# 200/200 [==============================] - 44s 221ms/step - loss: 0.3767 - accuracy: 0.8335 - val_loss: 0.4834 - val_accuracy: 0.7683

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment4_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 13s 165ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7065    0.7471    0.7263       696
#            1     0.8740    0.8497    0.8617      1437
#
#     accuracy                         0.8162      2133
#    macro avg     0.7903    0.7984    0.7940      2133
# weighted avg     0.8194    0.8162    0.8175      2133

# %% [markdown]
# ### Experiment 5: global average pooling and two dense layers

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet_v2.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model5 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model5, optimizer='rmsprop')
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_4 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_4 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  resnet101v2 (Functional)    (None, 7, 7, 2048)        42626560
#
#  global_average_pooling2d_1  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_7 (Dense)             (None, 512)               1049088
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  dense_9 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 43938817 (167.61 MB)
# Trainable params: 1312257 (5.01 MB)
# Non-trainable params: 42626560 (162.61 MB)
# _________________________________________________________________

# %%
run_model(model5, 'Experiment5_feature_extraction', epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.6393 - accuracy: 0.6782
# Epoch 1: val_loss improved from inf to 0.77345, saving model to /content/models/Experiment5_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 56s 244ms/step - loss: 0.6393 - accuracy: 0.6782 - val_loss: 0.7735 - val_accuracy: 0.6196
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5204 - accuracy: 0.7459
# Epoch 2: val_loss improved from 0.77345 to 0.47807, saving model to /content/models/Experiment5_feature_extraction.h5
# 200/200 [==============================] - 46s 226ms/step - loss: 0.5204 - accuracy: 0.7459 - val_loss: 0.4781 - val_accuracy: 0.8002
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4816 - accuracy: 0.7659
# Epoch 3: val_loss improved from 0.47807 to 0.41616, saving model to /content/models/Experiment5_feature_extraction.h5
# 200/200 [==============================] - 46s 231ms/step - loss: 0.4816 - accuracy: 0.7659 - val_loss: 0.4162 - val_accuracy: 0.8110
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4526 - accuracy: 0.7822
# Epoch 4: val_loss improved from 0.41616 to 0.40411, saving model to /content/models/Experiment5_feature_extraction.h5
# 200/200 [==============================] - 47s 234ms/step - loss: 0.4526 - accuracy: 0.7822 - val_loss: 0.4041 - val_accuracy: 0.8236
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4167 - accuracy: 0.8041
# Epoch 5: val_loss did not improve from 0.40411
# 200/200 [==============================] - 45s 222ms/step - loss: 0.4167 - accuracy: 0.8041 - val_loss: 0.4275 - val_accuracy: 0.8227
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4077 - accuracy: 0.8158
# Epoch 6: val_loss did not improve from 0.40411
# 200/200 [==============================] - 46s 228ms/step - loss: 0.4077 - accuracy: 0.8158 - val_loss: 0.4798 - val_accuracy: 0.7838
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3719 - accuracy: 0.8351
# Epoch 7: val_loss did not improve from 0.40411
# 200/200 [==============================] - 46s 229ms/step - loss: 0.3719 - accuracy: 0.8351 - val_loss: 0.4610 - val_accuracy: 0.8171
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3536 - accuracy: 0.8440
# Epoch 8: val_loss did not improve from 0.40411
# 200/200 [==============================] - 54s 269ms/step - loss: 0.3536 - accuracy: 0.8440 - val_loss: 0.4180 - val_accuracy: 0.8316
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3353 - accuracy: 0.8437
# Epoch 9: val_loss did not improve from 0.40411
# 200/200 [==============================] - 46s 230ms/step - loss: 0.3353 - accuracy: 0.8437 - val_loss: 0.4647 - val_accuracy: 0.8180

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 13s 159ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8281    0.6020    0.6972       696
#            1     0.8297    0.9395    0.8812      1437
#
#     accuracy                         0.8293      2133
#    macro avg     0.8289    0.7707    0.7892      2133
# weighted avg     0.8292    0.8293    0.8212      2133

# %% [markdown]
# ## Fine-tuning

# %% [markdown]
# ### Experiment 1: one dense layer

# %%
model1 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment1_feature_extraction.h5')

set_trainable = False
for layer in model1.get_layer('resnet101v2').layers:
    if layer.name == 'conv5_block3_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(model1, learning_rate=1e-5)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv (TFOpLambd  (None, 224, 224, 3)       0
#  a)
#
#  tf.math.subtract (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  resnet101v2 (Functional)    (None, 7, 7, 2048)        42626560
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 64)                6422592
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 49049217 (187.11 MB)
# Trainable params: 10887297 (41.53 MB)
# Non-trainable params: 38161920 (145.58 MB)
# _________________________________________________________________

# %%
run_model(model1, "experiment1_fine_tuning", epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5549 - accuracy: 0.8386
# Epoch 1: val_loss improved from inf to 0.96799, saving model to /content/models/experiment1_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 60s 259ms/step - loss: 0.5549 - accuracy: 0.8386 - val_loss: 0.9680 - val_accuracy: 0.7397
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9417
# Epoch 2: val_loss improved from 0.96799 to 0.87291, saving model to /content/models/experiment1_fine_tuning.h5
# 200/200 [==============================] - 59s 295ms/step - loss: 0.1510 - accuracy: 0.9417 - val_loss: 0.8729 - val_accuracy: 0.7725
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0722 - accuracy: 0.9801
# Epoch 3: val_loss improved from 0.87291 to 0.87041, saving model to /content/models/experiment1_fine_tuning.h5
# 200/200 [==============================] - 51s 252ms/step - loss: 0.0722 - accuracy: 0.9801 - val_loss: 0.8704 - val_accuracy: 0.7777
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9931
# Epoch 4: val_loss improved from 0.87041 to 0.86960, saving model to /content/models/experiment1_fine_tuning.h5
# 200/200 [==============================] - 58s 292ms/step - loss: 0.0374 - accuracy: 0.9931 - val_loss: 0.8696 - val_accuracy: 0.7805
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9975
# Epoch 5: val_loss did not improve from 0.86960
# 200/200 [==============================] - 47s 235ms/step - loss: 0.0238 - accuracy: 0.9975 - val_loss: 0.8734 - val_accuracy: 0.7800
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9991
# Epoch 6: val_loss improved from 0.86960 to 0.84470, saving model to /content/models/experiment1_fine_tuning.h5
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0159 - accuracy: 0.9991 - val_loss: 0.8447 - val_accuracy: 0.7960
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9992
# Epoch 7: val_loss did not improve from 0.84470
# 200/200 [==============================] - 49s 244ms/step - loss: 0.0129 - accuracy: 0.9992 - val_loss: 0.8692 - val_accuracy: 0.7894
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9994
# Epoch 8: val_loss did not improve from 0.84470
# 200/200 [==============================] - 47s 233ms/step - loss: 0.0100 - accuracy: 0.9994 - val_loss: 0.8844 - val_accuracy: 0.7866
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9998
# Epoch 9: val_loss did not improve from 0.84470
# 200/200 [==============================] - 49s 243ms/step - loss: 0.0076 - accuracy: 0.9998 - val_loss: 0.8645 - val_accuracy: 0.7997
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 10: val_loss did not improve from 0.84470
# 200/200 [==============================] - 47s 234ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.8983 - val_accuracy: 0.7885
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 11: val_loss did not improve from 0.84470
# 200/200 [==============================] - 57s 285ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.8860 - val_accuracy: 0.7932

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment1_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 12s 161ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6261    0.7845    0.6964       696
#            1     0.8810    0.7731    0.8236      1437
#
#     accuracy                         0.7768      2133
#    macro avg     0.7536    0.7788    0.7600      2133
# weighted avg     0.7979    0.7768    0.7821      2133

# %% [markdown]
# ### Experiment 2: global average pooling

# %%
model4 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment4_feature_extraction.h5')

set_trainable = False
# fine-tune the last three elements
for layer in model4.get_layer('resnet101v2').layers:
    if layer.name == 'conv5_block3_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(model4, learning_rate=1e-5)

# %%
run_model(model4, "Experiment2_fine_tuning")

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_fine_tuning.h5'))

# %% [markdown]
# ### Experiment 3: global average pooling and two dense layers

# %%
model5 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_feature_extraction.h5')

set_trainable = False
for layer in model5.get_layer('resnet50').layers:
    if layer.name == 'conv5_block3_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(model5, optimizer='rmsprop', learning_rate=1e-5)

# %%
run_model(model5, "Experiment3_fine_tuning", epochs=50)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment3_fine_tuning.h5'))

# %% [markdown]
# ## Remove final block (5-th block)
# Due to Colab's limitations we only took part of the original dataset, so now our dataset is small and very different from the one the pre-trained network was trained on. In this case it may be good to try to remove some of the final layers of the pre-trained network whose filters deal with finding detailed features. We will use less specific features that we find in previous levels.

# %%
def get_index_by_layer_name(model, layer_name):
  '''
  get_index_by_layer_name is used to retrieve the index of a specific layer
  :param model: model to check
  :param layer_name: name of the layer we want to get the index of
  :return: the index of the layer named as defined in layer_name
  '''
  for index, layer in enumerate(model.layers):
      if layer.name == layer_name:
          return index

# %%
conv_base = keras.applications.ResNet101V2(include_top = False, weights='imagenet', input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,3))

# %% [markdown]
# Remove the last convolutionary block of ResNet50.

# %%
base = Model(conv_base.input, conv_base.layers[get_index_by_layer_name(conv_base, 'conv4_block6_out')].output, name='base')
base.trainable = False
base.summary()
# Out:
# Model: "base"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_13[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (Ba  (None, 56, 56, 64)           256       ['pool1_pool[0][0]']
#  tchNormalization)
#
#  conv2_block1_preact_relu (  (None, 56, 56, 64)           0         ['conv2_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4096      ['conv2_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block1_1_relu[0][0]']
#  dding2D)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block1_2_pad[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block1_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_out (Add)      (None, 56, 56, 256)          0         ['conv2_block1_0_conv[0][0]',
#                                                                      'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (Ba  (None, 56, 56, 256)          1024      ['conv2_block1_out[0][0]']
#  tchNormalization)
#
#  conv2_block2_preact_relu (  (None, 56, 56, 256)          0         ['conv2_block2_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           16384     ['conv2_block2_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block2_1_relu[0][0]']
#  dding2D)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36864     ['conv2_block2_2_pad[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_out (Add)      (None, 56, 56, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (Ba  (None, 56, 56, 256)          1024      ['conv2_block2_out[0][0]']
#  tchNormalization)
#
#  conv2_block3_preact_relu (  (None, 56, 56, 256)          0         ['conv2_block3_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           16384     ['conv2_block3_preact_relu[0][
#  D)                                                                 0]']
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_pad (ZeroPa  (None, 58, 58, 64)           0         ['conv2_block3_1_relu[0][0]']
#  dding2D)
#
#  conv2_block3_2_conv (Conv2  (None, 28, 28, 64)           36864     ['conv2_block3_2_pad[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 28, 28, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 28, 28, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  max_pooling2d_3 (MaxPoolin  (None, 28, 28, 256)          0         ['conv2_block2_out[0][0]']
#  g2D)
#
#  conv2_block3_3_conv (Conv2  (None, 28, 28, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_out (Add)      (None, 28, 28, 256)          0         ['max_pooling2d_3[0][0]',
#                                                                      'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (Ba  (None, 28, 28, 256)          1024      ['conv2_block3_out[0][0]']
#  tchNormalization)
#
#  conv3_block1_preact_relu (  (None, 28, 28, 256)          0         ['conv3_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          32768     ['conv3_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block1_1_relu[0][0]']
#  dding2D)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block1_2_pad[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 512)          131584    ['conv3_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block1_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_out (Add)      (None, 28, 28, 512)          0         ['conv3_block1_0_conv[0][0]',
#                                                                      'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (Ba  (None, 28, 28, 512)          2048      ['conv3_block1_out[0][0]']
#  tchNormalization)
#
#  conv3_block2_preact_relu (  (None, 28, 28, 512)          0         ['conv3_block2_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          65536     ['conv3_block2_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block2_1_relu[0][0]']
#  dding2D)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block2_2_pad[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_out (Add)      (None, 28, 28, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (Ba  (None, 28, 28, 512)          2048      ['conv3_block2_out[0][0]']
#  tchNormalization)
#
#  conv3_block3_preact_relu (  (None, 28, 28, 512)          0         ['conv3_block3_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          65536     ['conv3_block3_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block3_1_relu[0][0]']
#  dding2D)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147456    ['conv3_block3_2_pad[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_out (Add)      (None, 28, 28, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (Ba  (None, 28, 28, 512)          2048      ['conv3_block3_out[0][0]']
#  tchNormalization)
#
#  conv3_block4_preact_relu (  (None, 28, 28, 512)          0         ['conv3_block4_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          65536     ['conv3_block4_preact_relu[0][
#  D)                                                                 0]']
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_pad (ZeroPa  (None, 30, 30, 128)          0         ['conv3_block4_1_relu[0][0]']
#  dding2D)
#
#  conv3_block4_2_conv (Conv2  (None, 14, 14, 128)          147456    ['conv3_block4_2_pad[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 512)          0         ['conv3_block3_out[0][0]']
#  g2D)
#
#  conv3_block4_3_conv (Conv2  (None, 14, 14, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_out (Add)      (None, 14, 14, 512)          0         ['max_pooling2d_4[0][0]',
#                                                                      'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (Ba  (None, 14, 14, 512)          2048      ['conv3_block4_out[0][0]']
#  tchNormalization)
#
#  conv4_block1_preact_relu (  (None, 14, 14, 512)          0         ['conv4_block1_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 256)          131072    ['conv4_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block1_1_relu[0][0]']
#  dding2D)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block1_2_pad[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 1024)         525312    ['conv4_block1_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block1_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_0_conv[0][0]',
#                                                                      'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block1_out[0][0]']
#  tchNormalization)
#
#  conv4_block2_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block2_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block2_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block2_1_relu[0][0]']
#  dding2D)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block2_2_pad[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block2_out[0][0]']
#  tchNormalization)
#
#  conv4_block3_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block3_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block3_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block3_1_relu[0][0]']
#  dding2D)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block3_2_pad[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block3_out[0][0]']
#  tchNormalization)
#
#  conv4_block4_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block4_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block4_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block4_1_relu[0][0]']
#  dding2D)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block4_2_pad[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block4_out[0][0]']
#  tchNormalization)
#
#  conv4_block5_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block5_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block5_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block5_1_relu[0][0]']
#  dding2D)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block5_2_pad[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (Ba  (None, 14, 14, 1024)         4096      ['conv4_block5_out[0][0]']
#  tchNormalization)
#
#  conv4_block6_preact_relu (  (None, 14, 14, 1024)         0         ['conv4_block6_preact_bn[0][0]
#  Activation)                                                        ']
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          262144    ['conv4_block6_preact_relu[0][
#  D)                                                                 0]']
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_pad (ZeroPa  (None, 16, 16, 256)          0         ['conv4_block6_1_relu[0][0]']
#  dding2D)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          589824    ['conv4_block6_2_pad[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_out (Add)      (None, 14, 14, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_conv[0][0]']
#
# ==================================================================================================
# Total params: 8573440 (32.71 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 8573440 (32.71 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Feature extraction
# Firstly, we will try to use the new base network to extract the features; we will put a classifier on top of the base network. We couldn't afford to use the Flatten, the output of the base network is 14x14x1024, too much. So we decided to use the GlobalAveragePooling2D.

# %% [markdown]
# #### Experiment 1: one dense layer with 256 neurons
# In this first example we use just a Dense layer before the output layer.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet_v2.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(256)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model1 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model1)
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_7 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_7 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  base (Functional)           (None, 14, 14, 1024)      8573440
#
#  global_average_pooling2d_2  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_10 (Dense)            (None, 256)               262400
#
#  dense_11 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8836097 (33.71 MB)
# Trainable params: 262657 (1.00 MB)
# Non-trainable params: 8573440 (32.71 MB)
# _________________________________________________________________

# %%
run_model(model1, "Experiment1_remove_blocks_feature_extraction", epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.6033 - accuracy: 0.6950
# Epoch 1: val_loss improved from inf to 0.47775, saving model to /content/models/Experiment1_remove_blocks_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 31s 141ms/step - loss: 0.6033 - accuracy: 0.6950 - val_loss: 0.4778 - val_accuracy: 0.7753
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.5118 - accuracy: 0.7550
# Epoch 2: val_loss improved from 0.47775 to 0.45019, saving model to /content/models/Experiment1_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.5118 - accuracy: 0.7550 - val_loss: 0.4502 - val_accuracy: 0.7974
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4880 - accuracy: 0.7645
# Epoch 3: val_loss did not improve from 0.45019
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4880 - accuracy: 0.7645 - val_loss: 0.4840 - val_accuracy: 0.7575
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4780 - accuracy: 0.7716
# Epoch 4: val_loss improved from 0.45019 to 0.39319, saving model to /content/models/Experiment1_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 112ms/step - loss: 0.4780 - accuracy: 0.7716 - val_loss: 0.3932 - val_accuracy: 0.8466
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4791 - accuracy: 0.7750
# Epoch 5: val_loss did not improve from 0.39319
# 200/200 [==============================] - 27s 133ms/step - loss: 0.4791 - accuracy: 0.7750 - val_loss: 0.4633 - val_accuracy: 0.7744
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4679 - accuracy: 0.7810
# Epoch 6: val_loss did not improve from 0.39319
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4679 - accuracy: 0.7810 - val_loss: 0.4446 - val_accuracy: 0.7969
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4442 - accuracy: 0.7947
# Epoch 7: val_loss did not improve from 0.39319
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4442 - accuracy: 0.7947 - val_loss: 0.3940 - val_accuracy: 0.8457
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4412 - accuracy: 0.7986
# Epoch 8: val_loss improved from 0.39319 to 0.38493, saving model to /content/models/Experiment1_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4412 - accuracy: 0.7986 - val_loss: 0.3849 - val_accuracy: 0.8471
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4578 - accuracy: 0.7872
# Epoch 9: val_loss did not improve from 0.38493
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4578 - accuracy: 0.7872 - val_loss: 0.6230 - val_accuracy: 0.6520
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4564 - accuracy: 0.7883
# Epoch 10: val_loss did not improve from 0.38493
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4564 - accuracy: 0.7883 - val_loss: 0.3897 - val_accuracy: 0.8476
# Epoch 11/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4403 - accuracy: 0.8008
# Epoch 11: val_loss did not improve from 0.38493
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4403 - accuracy: 0.8008 - val_loss: 0.5095 - val_accuracy: 0.7406
# Epoch 12/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4388 - accuracy: 0.8035
# Epoch 12: val_loss did not improve from 0.38493
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4388 - accuracy: 0.8035 - val_loss: 0.4041 - val_accuracy: 0.8265
# Epoch 13/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4313 - accuracy: 0.8043
# Epoch 13: val_loss did not improve from 0.38493
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4313 - accuracy: 0.8043 - val_loss: 0.3943 - val_accuracy: 0.8386

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment1_remove_blocks_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 6s 82ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7373    0.7701    0.7533       696
#            1     0.8862    0.8671    0.8765      1437
#
#     accuracy                         0.8354      2133
#    macro avg     0.8117    0.8186    0.8149      2133
# weighted avg     0.8376    0.8354    0.8363      2133

# %% [markdown]
# #### Experiment 2: one dense layer with 256 neurons and dropout
# Try to use Dropout.

# %%
# define the classifier
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet_v2.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model2 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model2)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_8 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_8 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  base (Functional)           (None, 14, 14, 1024)      8573440
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8836097 (33.71 MB)
# Trainable params: 262657 (1.00 MB)
# Non-trainable params: 8573440 (32.71 MB)
# _________________________________________________________________

# %%
run_model(model2, "Experiment2_remove_blocks_feature_extraction")
# Out:
# Epoch 1/20
# 200/200 [==============================] - ETA: 0s - loss: 0.6479 - accuracy: 0.6731
# Epoch 1: val_loss improved from inf to 0.44530, saving model to /content/models/Experiment2_remove_blocks_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 27s 114ms/step - loss: 0.6479 - accuracy: 0.6731 - val_loss: 0.4453 - val_accuracy: 0.8194
# Epoch 2/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5403 - accuracy: 0.7387
# Epoch 2: val_loss improved from 0.44530 to 0.43366, saving model to /content/models/Experiment2_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 112ms/step - loss: 0.5403 - accuracy: 0.7387 - val_loss: 0.4337 - val_accuracy: 0.8133
# Epoch 3/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5189 - accuracy: 0.7509
# Epoch 3: val_loss did not improve from 0.43366
# 200/200 [==============================] - 22s 110ms/step - loss: 0.5189 - accuracy: 0.7509 - val_loss: 0.6812 - val_accuracy: 0.6159
# Epoch 4/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5071 - accuracy: 0.7550
# Epoch 4: val_loss improved from 0.43366 to 0.42372, saving model to /content/models/Experiment2_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 112ms/step - loss: 0.5071 - accuracy: 0.7550 - val_loss: 0.4237 - val_accuracy: 0.8227
# Epoch 5/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5019 - accuracy: 0.7622
# Epoch 5: val_loss improved from 0.42372 to 0.40806, saving model to /content/models/Experiment2_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 22s 109ms/step - loss: 0.5019 - accuracy: 0.7622 - val_loss: 0.4081 - val_accuracy: 0.8330
# Epoch 6/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4916 - accuracy: 0.7691
# Epoch 6: val_loss did not improve from 0.40806
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4916 - accuracy: 0.7691 - val_loss: 0.5711 - val_accuracy: 0.6867
# Epoch 7/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.7770
# Epoch 7: val_loss improved from 0.40806 to 0.40589, saving model to /content/models/Experiment2_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4803 - accuracy: 0.7770 - val_loss: 0.4059 - val_accuracy: 0.8335
# Epoch 8/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4768 - accuracy: 0.7772
# Epoch 8: val_loss did not improve from 0.40589
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4768 - accuracy: 0.7772 - val_loss: 0.4480 - val_accuracy: 0.7932
# Epoch 9/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4715 - accuracy: 0.7802
# Epoch 9: val_loss did not improve from 0.40589
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4715 - accuracy: 0.7802 - val_loss: 0.4150 - val_accuracy: 0.8265
# Epoch 10/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.7802
# Epoch 10: val_loss did not improve from 0.40589
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4726 - accuracy: 0.7802 - val_loss: 0.4845 - val_accuracy: 0.7570
# Epoch 11/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4664 - accuracy: 0.7831
# Epoch 11: val_loss did not improve from 0.40589
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4664 - accuracy: 0.7831 - val_loss: 0.4120 - val_accuracy: 0.8260
# Epoch 12/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4681 - accuracy: 0.7841
# Epoch 12: val_loss improved from 0.40589 to 0.38002, saving model to /content/models/Experiment2_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 27s 133ms/step - loss: 0.4681 - accuracy: 0.7841 - val_loss: 0.3800 - val_accuracy: 0.8518
# Epoch 13/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.7844
# Epoch 13: val_loss did not improve from 0.38002
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4591 - accuracy: 0.7844 - val_loss: 0.3926 - val_accuracy: 0.8419
# Epoch 14/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4642 - accuracy: 0.7911
# Epoch 14: val_loss did not improve from 0.38002
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4642 - accuracy: 0.7911 - val_loss: 0.5119 - val_accuracy: 0.7350
# Epoch 15/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4605 - accuracy: 0.7871
# Epoch 15: val_loss did not improve from 0.38002
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4605 - accuracy: 0.7871 - val_loss: 0.3912 - val_accuracy: 0.8405
# Epoch 16/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4542 - accuracy: 0.7903
# Epoch 16: val_loss did not improve from 0.38002
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4542 - accuracy: 0.7903 - val_loss: 0.5113 - val_accuracy: 0.7345
# Epoch 17/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4610 - accuracy: 0.7880
# Epoch 17: val_loss did not improve from 0.38002
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4610 - accuracy: 0.7880 - val_loss: 0.4170 - val_accuracy: 0.8246

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 6s 77ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8090    0.6940    0.7471       696
#            1     0.8613    0.9207    0.8900      1437
#
#     accuracy                         0.8467      2133
#    macro avg     0.8352    0.8073    0.8186      2133
# weighted avg     0.8443    0.8467    0.8434      2133

# %% [markdown]
# #### Experiment 3: two dense layers, 256-128 neurons
# Try to make a more complex network, increasing the dense layers.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet_v2.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(256)(x)
x = layers.Dense(128)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model3 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model3)
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_9 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_9 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  base (Functional)           (None, 14, 14, 1024)      8573440
#
#  global_average_pooling2d_4  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_14 (Dense)            (None, 256)               262400
#
#  dense_15 (Dense)            (None, 128)               32896
#
#  dense_16 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 8868865 (33.83 MB)
# Trainable params: 295425 (1.13 MB)
# Non-trainable params: 8573440 (32.71 MB)
# _________________________________________________________________

# %%
run_model(model3, "Experiment3_remove_blocks_feature_extraction")
# Out:
# Epoch 1/20
# 200/200 [==============================] - ETA: 0s - loss: 0.6042 - accuracy: 0.6992
# Epoch 1: val_loss improved from inf to 0.61245, saving model to /content/models/Experiment3_remove_blocks_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 27s 117ms/step - loss: 0.6042 - accuracy: 0.6992 - val_loss: 0.6124 - val_accuracy: 0.6360
# Epoch 2/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4906 - accuracy: 0.7728
# Epoch 2: val_loss did not improve from 0.61245
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4906 - accuracy: 0.7728 - val_loss: 0.9706 - val_accuracy: 0.4231
# Epoch 3/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5024 - accuracy: 0.7534
# Epoch 3: val_loss improved from 0.61245 to 0.49581, saving model to /content/models/Experiment3_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 27s 134ms/step - loss: 0.5024 - accuracy: 0.7534 - val_loss: 0.4958 - val_accuracy: 0.7439
# Epoch 4/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.7738
# Epoch 4: val_loss improved from 0.49581 to 0.44036, saving model to /content/models/Experiment3_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 112ms/step - loss: 0.4759 - accuracy: 0.7738 - val_loss: 0.4404 - val_accuracy: 0.8063
# Epoch 5/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4705 - accuracy: 0.7778
# Epoch 5: val_loss improved from 0.44036 to 0.38488, saving model to /content/models/Experiment3_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4705 - accuracy: 0.7778 - val_loss: 0.3849 - val_accuracy: 0.8490
# Epoch 6/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.7881
# Epoch 6: val_loss did not improve from 0.38488
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4621 - accuracy: 0.7881 - val_loss: 0.4631 - val_accuracy: 0.7767
# Epoch 7/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4543 - accuracy: 0.7899
# Epoch 7: val_loss did not improve from 0.38488
# 200/200 [==============================] - 27s 133ms/step - loss: 0.4543 - accuracy: 0.7899 - val_loss: 0.4345 - val_accuracy: 0.8199
# Epoch 8/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4519 - accuracy: 0.7913
# Epoch 8: val_loss improved from 0.38488 to 0.37383, saving model to /content/models/Experiment3_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4519 - accuracy: 0.7913 - val_loss: 0.3738 - val_accuracy: 0.8546
# Epoch 9/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4505 - accuracy: 0.7914
# Epoch 9: val_loss did not improve from 0.37383
# 200/200 [==============================] - 22s 112ms/step - loss: 0.4505 - accuracy: 0.7914 - val_loss: 0.4168 - val_accuracy: 0.8152
# Epoch 10/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4562 - accuracy: 0.7886
# Epoch 10: val_loss did not improve from 0.37383
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4562 - accuracy: 0.7886 - val_loss: 0.7536 - val_accuracy: 0.5464
# Epoch 11/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4480 - accuracy: 0.7917
# Epoch 11: val_loss did not improve from 0.37383
# 200/200 [==============================] - 27s 133ms/step - loss: 0.4480 - accuracy: 0.7917 - val_loss: 0.4965 - val_accuracy: 0.7519
# Epoch 12/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4479 - accuracy: 0.7944
# Epoch 12: val_loss improved from 0.37383 to 0.36891, saving model to /content/models/Experiment3_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4479 - accuracy: 0.7944 - val_loss: 0.3689 - val_accuracy: 0.8574
# Epoch 13/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4496 - accuracy: 0.7921
# Epoch 13: val_loss did not improve from 0.36891
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4496 - accuracy: 0.7921 - val_loss: 0.4385 - val_accuracy: 0.8030
# Epoch 14/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4481 - accuracy: 0.7917
# Epoch 14: val_loss did not improve from 0.36891
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4481 - accuracy: 0.7917 - val_loss: 0.4070 - val_accuracy: 0.8194
# Epoch 15/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4324 - accuracy: 0.8068
# Epoch 15: val_loss did not improve from 0.36891
# 200/200 [==============================] - 27s 132ms/step - loss: 0.4324 - accuracy: 0.8068 - val_loss: 0.4869 - val_accuracy: 0.7542
# Epoch 16/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4327 - accuracy: 0.8043
# Epoch 16: val_loss did not improve from 0.36891
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4327 - accuracy: 0.8043 - val_loss: 0.4972 - val_accuracy: 0.7477
# Epoch 17/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4371 - accuracy: 0.8030
# Epoch 17: val_loss did not improve from 0.36891
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4371 - accuracy: 0.8030 - val_loss: 0.5303 - val_accuracy: 0.7275

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment3_remove_blocks_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 6s 81ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7897    0.7284    0.7578       696
#            1     0.8732    0.9061    0.8893      1437
#
#     accuracy                         0.8481      2133
#    macro avg     0.8315    0.8173    0.8236      2133
# weighted avg     0.8460    0.8481    0.8464      2133

# %% [markdown]
# #### Experiment 4: one dense layer with 512 neurons
# Try to make a more complex networks increasing the neurons of a single Dense layer. We use RMSprop that in this case give us a smoother learning curve.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet_v2.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(512)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model4 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model4, optimizer='rmsprop', learning_rate=5e-5)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_10 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  tf.math.subtract_10 (TFOpL  (None, 224, 224, 3)       0
#  ambda)
#
#  base (Functional)           (None, 14, 14, 1024)      8573440
#
#  global_average_pooling2d_5  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_17 (Dense)            (None, 512)               524800
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9098753 (34.71 MB)
# Trainable params: 525313 (2.00 MB)
# Non-trainable params: 8573440 (32.71 MB)
# _________________________________________________________________

# %%
run_model(model4, "Experiment4_remove_blocks_feature_extraction", epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.6232 - accuracy: 0.6628
# Epoch 1: val_loss improved from inf to 0.59793, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 26s 115ms/step - loss: 0.6232 - accuracy: 0.6628 - val_loss: 0.5979 - val_accuracy: 0.6773
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5616 - accuracy: 0.7189
# Epoch 2: val_loss did not improve from 0.59793
# 200/200 [==============================] - 22s 108ms/step - loss: 0.5616 - accuracy: 0.7189 - val_loss: 0.6585 - val_accuracy: 0.5896
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5376 - accuracy: 0.7408
# Epoch 3: val_loss improved from 0.59793 to 0.49502, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 27s 136ms/step - loss: 0.5376 - accuracy: 0.7408 - val_loss: 0.4950 - val_accuracy: 0.7749
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5214 - accuracy: 0.7489
# Epoch 4: val_loss did not improve from 0.49502
# 200/200 [==============================] - 22s 109ms/step - loss: 0.5214 - accuracy: 0.7489 - val_loss: 0.5067 - val_accuracy: 0.7542
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5075 - accuracy: 0.7589
# Epoch 5: val_loss did not improve from 0.49502
# 200/200 [==============================] - 22s 108ms/step - loss: 0.5075 - accuracy: 0.7589 - val_loss: 0.5240 - val_accuracy: 0.7298
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5012 - accuracy: 0.7628
# Epoch 6: val_loss improved from 0.49502 to 0.46550, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 113ms/step - loss: 0.5012 - accuracy: 0.7628 - val_loss: 0.4655 - val_accuracy: 0.7880
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4938 - accuracy: 0.7666
# Epoch 7: val_loss did not improve from 0.46550
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4938 - accuracy: 0.7666 - val_loss: 0.5273 - val_accuracy: 0.7237
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4859 - accuracy: 0.7680
# Epoch 8: val_loss did not improve from 0.46550
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4859 - accuracy: 0.7680 - val_loss: 0.4660 - val_accuracy: 0.7871
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4804 - accuracy: 0.7766
# Epoch 9: val_loss did not improve from 0.46550
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4804 - accuracy: 0.7766 - val_loss: 0.4789 - val_accuracy: 0.7664
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4758 - accuracy: 0.7816
# Epoch 10: val_loss improved from 0.46550 to 0.45451, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4758 - accuracy: 0.7816 - val_loss: 0.4545 - val_accuracy: 0.7946
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4738 - accuracy: 0.7781
# Epoch 11: val_loss did not improve from 0.45451
# 200/200 [==============================] - 27s 132ms/step - loss: 0.4738 - accuracy: 0.7781 - val_loss: 0.4999 - val_accuracy: 0.7444
# Epoch 12/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4700 - accuracy: 0.7786
# Epoch 12: val_loss improved from 0.45451 to 0.40656, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4700 - accuracy: 0.7786 - val_loss: 0.4066 - val_accuracy: 0.8419
# Epoch 13/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4650 - accuracy: 0.7813
# Epoch 13: val_loss did not improve from 0.40656
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4650 - accuracy: 0.7813 - val_loss: 0.5421 - val_accuracy: 0.7078
# Epoch 14/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4633 - accuracy: 0.7896
# Epoch 14: val_loss improved from 0.40656 to 0.40647, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4633 - accuracy: 0.7896 - val_loss: 0.4065 - val_accuracy: 0.8391
# Epoch 15/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4643 - accuracy: 0.7847
# Epoch 15: val_loss did not improve from 0.40647
# 200/200 [==============================] - 22s 107ms/step - loss: 0.4643 - accuracy: 0.7847 - val_loss: 0.4180 - val_accuracy: 0.8269
# Epoch 16/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4579 - accuracy: 0.7899
# Epoch 16: val_loss improved from 0.40647 to 0.40433, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4579 - accuracy: 0.7899 - val_loss: 0.4043 - val_accuracy: 0.8391
# Epoch 17/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4574 - accuracy: 0.7855
# Epoch 17: val_loss did not improve from 0.40433
# 200/200 [==============================] - 22s 111ms/step - loss: 0.4574 - accuracy: 0.7855 - val_loss: 0.4338 - val_accuracy: 0.8119
# Epoch 18/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4566 - accuracy: 0.7888
# Epoch 18: val_loss did not improve from 0.40433
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4566 - accuracy: 0.7888 - val_loss: 0.4395 - val_accuracy: 0.8025
# Epoch 19/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4539 - accuracy: 0.7921
# Epoch 19: val_loss did not improve from 0.40433
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4539 - accuracy: 0.7921 - val_loss: 0.4443 - val_accuracy: 0.7969
# Epoch 20/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4533 - accuracy: 0.7916
# Epoch 20: val_loss did not improve from 0.40433
# 200/200 [==============================] - 22s 112ms/step - loss: 0.4533 - accuracy: 0.7916 - val_loss: 0.4308 - val_accuracy: 0.8147
# Epoch 21/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4518 - accuracy: 0.7942
# Epoch 21: val_loss did not improve from 0.40433
# 200/200 [==============================] - 27s 133ms/step - loss: 0.4518 - accuracy: 0.7942 - val_loss: 0.4451 - val_accuracy: 0.7969

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 6s 79ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7486    0.7443    0.7464       696
#            1     0.8765    0.8789    0.8777      1437
#
#     accuracy                         0.8350      2133
#    macro avg     0.8125    0.8116    0.8120      2133
# weighted avg     0.8347    0.8350    0.8349      2133

# %% [markdown]
# #### Experiment 5: two dense layers of 512 neurons
# Try to make a more complex networks with two fully-connected dense layer of 512 neurons. We use RMSprop that in this case give us a smoother learning curve.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet_v2.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model5 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model5, optimizer='rmsprop')
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_11 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  tf.math.subtract_11 (TFOpL  (None, 224, 224, 3)       0
#  ambda)
#
#  base (Functional)           (None, 14, 14, 1024)      8573440
#
#  global_average_pooling2d_6  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_19 (Dense)            (None, 512)               524800
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dense_21 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9361409 (35.71 MB)
# Trainable params: 787969 (3.01 MB)
# Non-trainable params: 8573440 (32.71 MB)
# _________________________________________________________________

# %%
run_model(model5, "Experiment5_remove_blocks_feature_extraction", epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.6473 - accuracy: 0.6467
# Epoch 1: val_loss improved from inf to 0.56564, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 26s 115ms/step - loss: 0.6473 - accuracy: 0.6467 - val_loss: 0.5656 - val_accuracy: 0.6754
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5563 - accuracy: 0.7167
# Epoch 2: val_loss improved from 0.56564 to 0.47368, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 112ms/step - loss: 0.5563 - accuracy: 0.7167 - val_loss: 0.4737 - val_accuracy: 0.8096
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5239 - accuracy: 0.7403
# Epoch 3: val_loss improved from 0.47368 to 0.44343, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 112ms/step - loss: 0.5239 - accuracy: 0.7403 - val_loss: 0.4434 - val_accuracy: 0.8204
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5082 - accuracy: 0.7561
# Epoch 4: val_loss did not improve from 0.44343
# 200/200 [==============================] - 27s 132ms/step - loss: 0.5082 - accuracy: 0.7561 - val_loss: 0.4511 - val_accuracy: 0.8222
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4884 - accuracy: 0.7641
# Epoch 5: val_loss did not improve from 0.44343
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4884 - accuracy: 0.7641 - val_loss: 0.7218 - val_accuracy: 0.6656
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4754 - accuracy: 0.7730
# Epoch 6: val_loss improved from 0.44343 to 0.39708, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4754 - accuracy: 0.7730 - val_loss: 0.3971 - val_accuracy: 0.8344
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4712 - accuracy: 0.7736
# Epoch 7: val_loss did not improve from 0.39708
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4712 - accuracy: 0.7736 - val_loss: 0.4517 - val_accuracy: 0.8462
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4682 - accuracy: 0.7756
# Epoch 8: val_loss did not improve from 0.39708
# 200/200 [==============================] - 22s 110ms/step - loss: 0.4682 - accuracy: 0.7756 - val_loss: 0.4215 - val_accuracy: 0.8447
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.7755
# Epoch 9: val_loss did not improve from 0.39708
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4675 - accuracy: 0.7755 - val_loss: 0.4722 - val_accuracy: 0.7871
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4574 - accuracy: 0.7813
# Epoch 10: val_loss did not improve from 0.39708
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4574 - accuracy: 0.7813 - val_loss: 0.5216 - val_accuracy: 0.7828
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4504 - accuracy: 0.7813
# Epoch 11: val_loss did not improve from 0.39708
# 200/200 [==============================] - 22s 109ms/step - loss: 0.4504 - accuracy: 0.7813 - val_loss: 0.4387 - val_accuracy: 0.8166

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_remove_blocks_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 7s 84ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8852    0.5761    0.6980       696
#            1     0.8244    0.9638    0.8887      1437
#
#     accuracy                         0.8373      2133
#    macro avg     0.8548    0.7700    0.7933      2133
# weighted avg     0.8442    0.8373    0.8265      2133

# %% [markdown]
# ### Fine tuning
# Now we can fine tune the best models of the previous experiments, unfreezing some of the last layers of the base network.

# %% [markdown]
# #### Unfreeze some layers
# Firstly, we try to unfreeze just some of the last layers of the fourth block.

# %% [markdown]
# ##### Experiment 1: one dense layer with 256 neurons and dropout

# %%
model1 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5')

set_trainable = False
# set trainable from "conv4_block6_1_conv"
for layer in model1.get_layer('base').layers:
    if layer.name == 'conv4_block6_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
model1.summary()

# %%
compile_model(model1, learning_rate=1e-5)

# %%
run_model(model1, 'Experiment1_remove_blocks_fine_tuning', epochs=30)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment1_remove_blocks_fine_tuning.h5'))

# %% [markdown]
# ##### Experiment 2: one dense layer with 512 neurons

# %%
model2 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5')
set_trainable = False
# set trainable from "conv4_block6_1_conv"
for layer in model2.get_layer('base').layers:
    if layer.name == 'conv4_block6_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
model1.summary()

# %%
compile_model(model2, optimizer='rmsprop', learning_rate=1e-5)

# %%
run_model(model2, 'Experiment2_remove_blocks_fine_tuning', epochs=30)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_fine_tuning.h5'))

# %% [markdown]
# #### Unfreeze all the 4-th block
# We try to unfreeze more layers, more precisely all the fourth block (that is the last block of our base network).

# %% [markdown]
# ##### Experiment 3: one dense layer with 256 neurons and dropout

# %%
model3 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5')

set_trainable = False
# set trainable all conv4 section
for layer in model3.get_layer('base').layers:
    if layer.name == 'conv4_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
compile_model(model3, learning_rate=1e-5)

# %%
run_model(model3, 'Experiment3_remove_blocks_fine_tuning', epochs=30)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment3_remove_blocks_fine_tuning.h5'))

# %% [markdown]
# ##### Experiment 4: one dense layer with 512 neurons

# %%
model4 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5')
set_trainable = False
for layer in model4.get_layer('base').layers:
    if layer.name == 'conv4_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model4, optimizer='rmsprop', learning_rate=1e-5)

# %%
run_model(model4, 'Experiment4_remove_blocks_fine_tuning', epochs=30)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_fine_tuning.h5'))

# %% [markdown]
# ##### Experiment 5: two dense layers of 512 neurons

# %%
model5 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_remove_blocks_feature_extraction.h5')
set_trainable = False
for layer in model5.get_layer('base').layers:
    if layer.name == 'conv4_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model5, optimizer='rmsprop', learning_rate=1e-5)

# %%
run_model(model5, 'Experiment5_remove_blocks_fine_tuning', epochs=30)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_remove_blocks_fine_tuning.h5'))

# %% [markdown]
# #### Unfreeze also the third block
# We saw an improvement of our models, so we keep to unfreeze more layers. Now we unfreeze also the third block of our base network.

# %% [markdown]
# ##### Experiment 6: one dense layer with 256 neurons and dropout

# %%
model6 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5')

set_trainable = False
for layer in model6.get_layer('base').layers:
    if layer.name == 'conv3_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model6, learning_rate=1e-5)

# %%
run_model(model6, 'Experiment6_remove_blocks_fine_tuning', epochs=30)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment6_remove_blocks_fine_tuning.h5'))

# %% [markdown]
# ##### Experiment 7: one dense layer with 512 neurons

# %%
model7 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5')

set_trainable = False
for layer in model7.get_layer('base').layers:
    if layer.name == 'conv3_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model7, optimizer='rmsprop', learning_rate=1e-5)

# %%
run_model(model7, 'Experiment7_remove_blocks_fine_tuning', epochs=30)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment7_remove_blocks_fine_tuning.h5'))

# %% [markdown]
# #### Unfreeze also the second block
# We try to unfreeze also the entire second block

# %% [markdown]
# ##### Experiment 8: one dense layer with 256 neurons and dropout

# %%
model8 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5')

set_trainable = False
for layer in model8.get_layer('base').layers:
    if layer.name == 'conv2_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model8, learning_rate=1e-5)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_8 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_8 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  base (Functional)           (None, 14, 14, 1024)      8573440
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8836097 (33.71 MB)
# Trainable params: 8801537 (33.58 MB)
# Non-trainable params: 34560 (135.00 KB)
# _________________________________________________________________

# %%
run_model(model8, 'Experiment8_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4952 - accuracy: 0.7842
# Epoch 1: val_loss improved from inf to 0.35527, saving model to /content/models/Experiment8_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 79s 284ms/step - loss: 0.4952 - accuracy: 0.7842 - val_loss: 0.3553 - val_accuracy: 0.8490
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3542 - accuracy: 0.8466
# Epoch 2: val_loss improved from 0.35527 to 0.29101, saving model to /content/models/Experiment8_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 53s 263ms/step - loss: 0.3542 - accuracy: 0.8466 - val_loss: 0.2910 - val_accuracy: 0.8790
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2900 - accuracy: 0.8759
# Epoch 3: val_loss improved from 0.29101 to 0.25577, saving model to /content/models/Experiment8_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 54s 270ms/step - loss: 0.2900 - accuracy: 0.8759 - val_loss: 0.2558 - val_accuracy: 0.8963
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2488 - accuracy: 0.8959
# Epoch 4: val_loss improved from 0.25577 to 0.24690, saving model to /content/models/Experiment8_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 57s 285ms/step - loss: 0.2488 - accuracy: 0.8959 - val_loss: 0.2469 - val_accuracy: 0.8996
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1994 - accuracy: 0.9164
# Epoch 5: val_loss improved from 0.24690 to 0.21665, saving model to /content/models/Experiment8_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 54s 272ms/step - loss: 0.1994 - accuracy: 0.9164 - val_loss: 0.2166 - val_accuracy: 0.9137
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9448
# Epoch 6: val_loss did not improve from 0.21665
# 200/200 [==============================] - 54s 266ms/step - loss: 0.1486 - accuracy: 0.9448 - val_loss: 0.3445 - val_accuracy: 0.8560
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9573
# Epoch 7: val_loss improved from 0.21665 to 0.20626, saving model to /content/models/Experiment8_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 54s 269ms/step - loss: 0.1148 - accuracy: 0.9573 - val_loss: 0.2063 - val_accuracy: 0.9268
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9767
# Epoch 8: val_loss did not improve from 0.20626
# 200/200 [==============================] - 52s 259ms/step - loss: 0.0714 - accuracy: 0.9767 - val_loss: 0.2649 - val_accuracy: 0.9048
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9830
# Epoch 9: val_loss did not improve from 0.20626
# 200/200 [==============================] - 53s 263ms/step - loss: 0.0547 - accuracy: 0.9830 - val_loss: 0.2523 - val_accuracy: 0.9193
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9870
# Epoch 10: val_loss did not improve from 0.20626
# 200/200 [==============================] - 59s 291ms/step - loss: 0.0417 - accuracy: 0.9870 - val_loss: 0.2317 - val_accuracy: 0.9311
# Epoch 11/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9912
# Epoch 11: val_loss did not improve from 0.20626
# 200/200 [==============================] - 53s 266ms/step - loss: 0.0278 - accuracy: 0.9912 - val_loss: 0.2606 - val_accuracy: 0.9250
# Epoch 12/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9945
# Epoch 12: val_loss did not improve from 0.20626
# 200/200 [==============================] - 52s 259ms/step - loss: 0.0211 - accuracy: 0.9945 - val_loss: 0.3031 - val_accuracy: 0.9137

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment8_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 6s 81ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8899    0.8707    0.8802       696
#            1     0.9380    0.9478    0.9429      1437
#
#     accuracy                         0.9226      2133
#    macro avg     0.9139    0.9092    0.9115      2133
# weighted avg     0.9223    0.9226    0.9224      2133

# %% [markdown]
# ##### Experiment 9: one dense layer with 512 neurons

# %%
model9 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5')

set_trainable = False
for layer in model9.get_layer('base').layers:
    if layer.name == 'conv2_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model9, learning_rate=1e-5)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_10 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  tf.math.subtract_10 (TFOpL  (None, 224, 224, 3)       0
#  ambda)
#
#  base (Functional)           (None, 14, 14, 1024)      8573440
#
#  global_average_pooling2d_5  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_17 (Dense)            (None, 512)               524800
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9098753 (34.71 MB)
# Trainable params: 9064193 (34.58 MB)
# Non-trainable params: 34560 (135.00 KB)
# _________________________________________________________________

# %%
run_model(model9, 'Experiment9_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4862 - accuracy: 0.7861
# Epoch 1: val_loss improved from inf to 0.36673, saving model to /content/models/Experiment9_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 73s 276ms/step - loss: 0.4862 - accuracy: 0.7861 - val_loss: 0.3667 - val_accuracy: 0.8457
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3493 - accuracy: 0.8480
# Epoch 2: val_loss improved from 0.36673 to 0.29370, saving model to /content/models/Experiment9_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 54s 269ms/step - loss: 0.3493 - accuracy: 0.8480 - val_loss: 0.2937 - val_accuracy: 0.8809
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2886 - accuracy: 0.8766
# Epoch 3: val_loss improved from 0.29370 to 0.27706, saving model to /content/models/Experiment9_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 52s 261ms/step - loss: 0.2886 - accuracy: 0.8766 - val_loss: 0.2771 - val_accuracy: 0.8917
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2405 - accuracy: 0.9051
# Epoch 4: val_loss improved from 0.27706 to 0.23642, saving model to /content/models/Experiment9_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 53s 267ms/step - loss: 0.2405 - accuracy: 0.9051 - val_loss: 0.2364 - val_accuracy: 0.9071
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9206
# Epoch 5: val_loss improved from 0.23642 to 0.22060, saving model to /content/models/Experiment9_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 53s 264ms/step - loss: 0.1991 - accuracy: 0.9206 - val_loss: 0.2206 - val_accuracy: 0.9118
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9426
# Epoch 6: val_loss improved from 0.22060 to 0.21726, saving model to /content/models/Experiment9_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 55s 272ms/step - loss: 0.1470 - accuracy: 0.9426 - val_loss: 0.2173 - val_accuracy: 0.9174
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1097 - accuracy: 0.9603
# Epoch 7: val_loss did not improve from 0.21726
# 200/200 [==============================] - 54s 267ms/step - loss: 0.1097 - accuracy: 0.9603 - val_loss: 0.2180 - val_accuracy: 0.9226
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0888 - accuracy: 0.9667
# Epoch 8: val_loss did not improve from 0.21726
# 200/200 [==============================] - 52s 259ms/step - loss: 0.0888 - accuracy: 0.9667 - val_loss: 0.2308 - val_accuracy: 0.9123
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9876
# Epoch 9: val_loss did not improve from 0.21726
# 200/200 [==============================] - 53s 264ms/step - loss: 0.0447 - accuracy: 0.9876 - val_loss: 0.2641 - val_accuracy: 0.9160
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9886
# Epoch 10: val_loss did not improve from 0.21726
# 200/200 [==============================] - 52s 262ms/step - loss: 0.0365 - accuracy: 0.9886 - val_loss: 0.2486 - val_accuracy: 0.9254
# Epoch 11/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9947
# Epoch 11: val_loss did not improve from 0.21726
# 200/200 [==============================] - 53s 262ms/step - loss: 0.0238 - accuracy: 0.9947 - val_loss: 0.2867 - val_accuracy: 0.9137

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment9_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 6s 81ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8228    0.9009    0.8601       696
#            1     0.9497    0.9061    0.9274      1437
#
#     accuracy                         0.9044      2133
#    macro avg     0.8863    0.9035    0.8937      2133
# weighted avg     0.9083    0.9044    0.9054      2133

# %% [markdown]
# #### Unfreeze all the base network
# Let's try to unfreeze all the layers of the base network

# %% [markdown]
# ##### Experiment 10: one dense layer with 256 neurons and dropout

# %%
model10 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5')
model10.trainable = True
compile_model(model10, learning_rate=1e-5)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_8 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_8 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  base (Functional)           (None, 14, 14, 1024)      8573440
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8836097 (33.71 MB)
# Trainable params: 8811137 (33.61 MB)
# Non-trainable params: 24960 (97.50 KB)
# _________________________________________________________________

# %%
run_model(model10, 'Experiment10_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment10_remove_blocks_fine_tuning.h5'))

# %% [markdown]
# ##### Experiment 11: one dense layer with 512 neurons

# %%
model11 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5')
model11.trainable = True
compile_model(model11, learning_rate=1e-5)

# %%
run_model(model11, 'Experiment11_remove_blocks_fine_tuning', epochs=30)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment11_remove_blocks_fine_tuning.h5'))

# %% [markdown]
# ##### Experiment 12: two dense layers of 512 neurons

# %%
model12 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_remove_blocks_feature_extraction.h5')
model12.trainable = True
compile_model(model12, learning_rate=1e-5)

# %%
run_model(model12, 'Experiment12_remove_blocks_fine_tuning', epochs=30)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment12_remove_blocks_fine_tuning.h5'))

# %% [markdown]
# # CLAHE
# We will try now to use the dataset in which the images are preprocesses with CLAHE. We will test the performance with the best network previuosly found and we will compare the results. Unfortunately, no significant improvements were found.

# %% [markdown]
# ## Load dataset from Google Drive
# The dataset is stored in Google Drive in a zip file, we unzip it locally for better performance.

# %%
drive.mount('/content/drive', force_remount=True)
# !unzip -q "/content/drive/My Drive/SplittedDataset_CLAHE.zip" -d "/content"

# %% [markdown]
# ## Set parameters

# %%
DATASET_PATH = "/content/SplittedDataset_CLAHE"
TRAINING_PATH = DATASET_PATH + '/training_set'
TRAINING_ALL_PATH = TRAINING_PATH + '/all'
TRAINING_HEM_PATH = TRAINING_PATH + '/hem'
VALIDATION_PATH = DATASET_PATH + '/validation_set'
TEST_PATH = DATASET_PATH + '/test_set'

# %% [markdown]
# ## Load dataset
# The dataset, properly preprocessed, is now located in the local machine.

# %%
set_seed()

train_dataset = load_training_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
validation_dataset = load_validation_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
test_dataset = load_test_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)

# %% [markdown]
# ## Remove final block
# As we did for the original dataset, here too we are going to remove the last block that deals with the high-level features of Imagenet

# %%
conv_base = keras.applications.resnet.ResNet50(include_top = False, weights='imagenet', input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,3))

# %%
base = Model(conv_base.input, conv_base.layers[get_index_by_layer_name(conv_base, 'conv4_block6_out')].output, name='base')
base.trainable = False
base.summary()

# %% [markdown]
# ## Feature extraction
# Firstly, we try the simplest approach in which we use the pretrained network to extract feature and we use our classifier to classify the images.

# %% [markdown]
# ### Experiment 1: one dense layer with 256 neurons and dropout
# This is the first best model found in the previous section with the standard dataset.

# %%
# define the classifier
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model1 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model1)

# %%
run_model(model1, "Experiment1_remove_blocks_feature_extraction_CLAHE", epochs=50)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment1_remove_blocks_feature_extraction_CLAHE.h5'))

# %% [markdown]
# ## Fine Tuning
# Now we can fine-tune the base network to adapt it to extract more useful features in our images.

# %% [markdown]
# ### Unfreeze up to the second block included
# We tried directly to unfreeze up to the second block included, just to compare with the previous results. We can easily see that unfortunately there are no significative improvements, indeed the results are less satisfactory than the same network on the original dataset.

# %% [markdown]
# #### Experiment 1: one dense layer with 256 neurons and dropout

# %%
model1 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment1_remove_blocks_feature_extraction_CLAHE.h5')

set_trainable = False
for layer in model1.get_layer('base').layers:
    if layer.name == 'conv2_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model1, learning_rate=1e-5)

# %%
run_model(model1, "Experiment1_remove_blocks_fine_tuning_CLAHE", epochs=50)

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment1_remove_blocks_fine_tuning_CLAHE.h5'))
