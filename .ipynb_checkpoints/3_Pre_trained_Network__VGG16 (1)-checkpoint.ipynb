# %% [markdown]
# # Solve the problem leveraging VGG16 architecture
# In this notebook, we will use the VGG16 architecture for our classification problem.
#
# First, we'll try a simple **feature extraction**. Since the architecture was trained on ImageNet we do not expect very good performance, but we can use these results as a baseline for the next step: **fine-tuning**.

# %% [markdown]
# ## Import Libraries
# First of all, let's import all the libraries we will need later.

# %%
from google.colab import drive
import os
import shutil
import numpy as np
import random as rn
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG16
import matplotlib.pyplot as plt
from sklearn import metrics

# %% [markdown]
# ## Load Dataset from Google Drive

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !unzip -q "/content/drive/My Drive/SplittedDataset.zip" -d "/content"

# %% [markdown]
# ## Set Parameters

# %%
DATASET_PATH = "/content/SplittedDataset"
TRAINING_PATH = DATASET_PATH + '/training_set'
TRAINING_ALL_PATH = TRAINING_PATH + '/all'
TRAINING_HEM_PATH = TRAINING_PATH + '/hem'
VALIDATION_PATH = DATASET_PATH + '/validation_set'
TEST_PATH = DATASET_PATH + '/test_set'

LOCAL_MODELS_FOLDER = "/content/models"
if not os.path.exists(LOCAL_MODELS_FOLDER):
  os.makedirs(LOCAL_MODELS_FOLDER)
GLOBAL_MODELS_FOLDER = "/content/drive/My Drive/Baldi_Cioffo/models/vgg16"
if not os.path.exists(GLOBAL_MODELS_FOLDER):
  os.makedirs(GLOBAL_MODELS_FOLDER)

# Default values to load the dataset
BATCH_SIZE = 32
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224

# %% [markdown]
# ## Utility Functions

# %%
def set_seed ():
  '''
  set_seed is used to obtain reproducible results using keras during the development phase
  '''
  seed = 24
  # The below is necessary for reproducible results of certain Python hash-based operations.
  os.environ["PYTHONHASHSEED"]="0"
  # The below is necessary for starting Numpy generated random numbers in a well-defined initial state.
  np.random.seed(seed)
  # The below is necessary for starting core Python generated random numbers in a well-defined state.
  rn.seed(seed)
  # The below tf.random.set_seed will make random number generation in TensorFlow have a well-defined initial state.
  tf.random.set_seed(seed)

def show_training_and_validation_performance(history):
  '''
  show_training_and_validation_performance is used to plot the performances during the training phase
  :param history: object in which are recorded all the events
  '''
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'bo', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

def load_training_set (image_height, image_width, batch_size):
  '''
  load_training_set loads the training set from the "training_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return the training set
  '''
  return image_dataset_from_directory(
    TRAINING_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def load_validation_set (image_height, image_width, batch_size):
  '''
  load_validation_set loads the validation set from the "validation_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return the validation set
  '''
  return image_dataset_from_directory(
    VALIDATION_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def load_test_set (image_height, image_width, batch_size):
  '''
  load_test_set loads the test set from the "test_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return the test set
  '''
  return image_dataset_from_directory(
    TEST_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    shuffle = False,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def compile_model (model, optimizer='adam', learning_rate = 0.001):
  '''
  compile_model is used to compile the current model
  :param model: model to compile
  :param optimizer: optimizer to be used
  :param learning_rate: learning rate parameter for the optimizer
  '''
  if optimizer == 'adam':
    model.compile(loss="binary_crossentropy",
      optimizer=optimizers.Adam(learning_rate=learning_rate),
      metrics=["accuracy"])
  elif optimizer == 'rmsprop':
    model.compile(loss="binary_crossentropy",
                  optimizer = optimizers.RMSprop(learning_rate=learning_rate),
                  metrics=['accuracy'])
  model.summary()

def run_model (model, model_name, epochs = 20, patience=5, monitor='val_loss'):
  '''
  run_model is used to run the current mode
  :param model: model to run
  :param model_name: name given to save the model
  :param epochs: how many epochs to do
  :param patience: patience value for Early Stopping
  :param monitor: what to monitor for Early Stopping and Model Checkpoint
  '''
  # local save path for the models
  save_path = LOCAL_MODELS_FOLDER + '/' + model_name + '.h5'
  callbacks_list = [
                  keras.callbacks.EarlyStopping(monitor=monitor, patience=patience),
                  keras.callbacks.ModelCheckpoint(
                      filepath = save_path,
                      monitor=monitor,
                      verbose=1,
                      save_best_only=True)
                  ]
  history = model.fit(train_dataset,
                    epochs=epochs,
                    validation_data=validation_dataset,
                    callbacks=callbacks_list)
  # save on Drive only the best model
  shutil.copy(save_path, GLOBAL_MODELS_FOLDER + '/' + model_name + '.h5')
  show_training_and_validation_performance(history)

def evaluate_model (model):
  '''
  evaluate_model is used to plot some statistics about the performance on the test set
  :param model: model to consider
  '''
  y_score = model.predict(test_dataset)
  y_pred = np.rint(y_score) # to have 0 or 1
  y_true = tf.concat([labels_batch for data_batch, labels_batch in test_dataset], axis = 0)
  print("Classification report: ")
  print(metrics.classification_report(y_true,y_pred,digits = 4))
  metrics.ConfusionMatrixDisplay.from_predictions(y_true, y_pred)

  # ROC curve
  fpr,tpr,th = metrics.roc_curve(y_true,y_score)
  roc_auc = metrics.roc_auc_score(y_true,y_score)

  plt.figure()
  plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
  plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.0])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('ROC curve')
  plt.legend(loc="lower right")
  plt.show()

# %% [markdown]
# ## Load Dataset
# The dataset, properly preprocessed, is now located in the local machine.

# %%
set_seed()

# %% [markdown]
# Below, we report the number of images for each of the two classes (normal vs cancer) in the training set and validation set.

# %%
num_all_tr = len(os.listdir(TRAINING_ALL_PATH))
num_hem_tr = len(os.listdir(TRAINING_HEM_PATH))

num_all_val = len(os.listdir(VALIDATION_PATH + "/all"))
num_hem_val = len(os.listdir(VALIDATION_PATH + "/hem"))

total_train = num_all_tr + num_hem_tr
total_val = num_all_val + num_hem_val

# %%
print('total training cancer cell images:', num_all_tr)
print('total training normal cell images:', num_hem_tr)

print('total validation cancer cell images:', num_all_val)
print('total validation normal cell images:', num_hem_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cancer cell images: 3198
# total training normal cell images: 3198
# total validation cancer cell images: 1403
# total validation normal cell images: 729
# --
# Total training images: 6396
# Total validation images: 2132

# %% [markdown]
# At this point we need to transform the images we have on disk into preprocessed tensors.
#
# We decided to use the size that VGG16 expects as input, which is 224x224, and to use batches of size 32.

# %%
train_dataset = load_training_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
validation_dataset = load_validation_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
test_dataset = load_test_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
# Out:
# Found 6396 files belonging to 2 classes.
# Found 2132 files belonging to 2 classes.
# Found 2133 files belonging to 2 classes.

# %% [markdown]
# ## Feature Extraction
# This first set of experiments is based on using the architecture of VGG16 simply as a feature extractor.

# %% [markdown]
# Let's instantiate the VGG16 model:

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Since we want to perform feature extraction only, we need to "freeze" the convolutional basis.

# %%
conv_base.trainable = False

# %% [markdown]
# At this point, we can concatenate a binary classifier to the frozen convolutional basis.
# ### Experiment 1: vanilla
# This first version is very simple since we connect directly to the convolutional basis a fully connected layer whose 256 neurons feed the output layer containing a single neuron with sigmoidal activation function.

# %%
inputs = keras.Input(shape=(224,224,3))
x = keras.applications.vgg16.preprocess_input(inputs)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
vanilla_vgg_model = keras.Model(inputs, outputs)
compile_model(vanilla_vgg_model)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (  (None, 224, 224, 3)       0
#  SlicingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda  (None, 224, 224, 3)       0
#  )
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 21137729 (80.63 MB)
# Trainable params: 6423041 (24.50 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
run_model(vanilla_vgg_model, 'experiment1_feature_extraction_vanilla', epochs = 100, patience=20, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 15.9790 - accuracy: 0.6787
# Epoch 1: val_loss improved from inf to 1.76155, saving model to /content/models/experiment1_feature_extraction_vanilla.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 55s 221ms/step - loss: 15.9790 - accuracy: 0.6787 - val_loss: 1.7615 - val_accuracy: 0.7387
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4990 - accuracy: 0.8497
# Epoch 2: val_loss improved from 1.76155 to 0.77878, saving model to /content/models/experiment1_feature_extraction_vanilla.h5
# 200/200 [==============================] - 35s 173ms/step - loss: 0.4990 - accuracy: 0.8497 - val_loss: 0.7788 - val_accuracy: 0.7017
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9096
# Epoch 3: val_loss improved from 0.77878 to 0.58561, saving model to /content/models/experiment1_feature_extraction_vanilla.h5
# 200/200 [==============================] - 36s 180ms/step - loss: 0.2240 - accuracy: 0.9096 - val_loss: 0.5856 - val_accuracy: 0.7950
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 0.9336
# Epoch 4: val_loss did not improve from 0.58561
# 200/200 [==============================] - 37s 183ms/step - loss: 0.1696 - accuracy: 0.9336 - val_loss: 1.3203 - val_accuracy: 0.6482
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1734 - accuracy: 0.9357
# Epoch 5: val_loss did not improve from 0.58561
# 200/200 [==============================] - 37s 182ms/step - loss: 0.1734 - accuracy: 0.9357 - val_loss: 1.2072 - val_accuracy: 0.7406
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9439
# Epoch 6: val_loss did not improve from 0.58561
# 200/200 [==============================] - 35s 176ms/step - loss: 0.1472 - accuracy: 0.9439 - val_loss: 1.3751 - val_accuracy: 0.7298
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1716 - accuracy: 0.9389
# Epoch 7: val_loss did not improve from 0.58561
# 200/200 [==============================] - 35s 175ms/step - loss: 0.1716 - accuracy: 0.9389 - val_loss: 0.9533 - val_accuracy: 0.7903
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9558
# Epoch 8: val_loss did not improve from 0.58561
# 200/200 [==============================] - 37s 182ms/step - loss: 0.1172 - accuracy: 0.9558 - val_loss: 1.4007 - val_accuracy: 0.7542
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2742 - accuracy: 0.9165
# Epoch 9: val_loss did not improve from 0.58561
# 200/200 [==============================] - 37s 182ms/step - loss: 0.2742 - accuracy: 0.9165 - val_loss: 0.8250 - val_accuracy: 0.7885
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9653
# Epoch 10: val_loss did not improve from 0.58561
# 200/200 [==============================] - 35s 176ms/step - loss: 0.0955 - accuracy: 0.9653 - val_loss: 1.8874 - val_accuracy: 0.7040
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1161 - accuracy: 0.9614
# Epoch 11: val_loss did not improve from 0.58561
# 200/200 [==============================] - 35s 175ms/step - loss: 0.1161 - accuracy: 0.9614 - val_loss: 1.4109 - val_accuracy: 0.7580
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1912 - accuracy: 0.9450
# Epoch 12: val_loss did not improve from 0.58561
# 200/200 [==============================] - 35s 176ms/step - loss: 0.1912 - accuracy: 0.9450 - val_loss: 1.1667 - val_accuracy: 0.7758
# Epoch 13/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9678
# Epoch 13: val_loss did not improve from 0.58561
# 200/200 [==============================] - 37s 183ms/step - loss: 0.1018 - accuracy: 0.9678 - val_loss: 1.9315 - val_accuracy: 0.7148
# Epoch 14/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9517
# Epoch 14: val_loss did not improve from 0.58561
# 200/200 [==============================] - 37s 184ms/step - loss: 0.1535 - accuracy: 0.9517 - val_loss: 1.3636 - val_accuracy: 0.7833
# Epoch 15/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9625
# Epoch 15: val_loss did not improve from 0.58561
# 200/200 [==============================] - 37s 185ms/step - loss: 0.1190 - accuracy: 0.9625 - val_loss: 1.7110 - val_accuracy: 0.7608
# Epoch 16/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1865 - accuracy: 0.9492
# Epoch 16: val_loss did not improve from 0.58561
# 200/200 [==============================] - 37s 185ms/step - loss: 0.1865 - accuracy: 0.9492 - val_loss: 1.0349 - val_accuracy: 0.7932
# Epoch 17/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1436 - accuracy: 0.9565
# Epoch 17: val_loss did not improve from 0.58561
# 200/200 [==============================] - 37s 185ms/step - loss: 0.1436 - accuracy: 0.9565 - val_loss: 2.5992 - val_accuracy: 0.6674
# Epoch 18/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9644
# Epoch 18: val_loss did not improve from 0.58561
# 200/200 [==============================] - 35s 174ms/step - loss: 0.1285 - accuracy: 0.9644 - val_loss: 2.0345 - val_accuracy: 0.7730
# Epoch 19/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1788 - accuracy: 0.9565
# Epoch 19: val_loss did not improve from 0.58561
# 200/200 [==============================] - 35s 176ms/step - loss: 0.1788 - accuracy: 0.9565 - val_loss: 2.9883 - val_accuracy: 0.6801
# Epoch 20/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9620
# Epoch 20: val_loss did not improve from 0.58561
# 200/200 [==============================] - 36s 177ms/step - loss: 0.1219 - accuracy: 0.9620 - val_loss: 3.3896 - val_accuracy: 0.6801
# Epoch 21/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9545
# Epoch 21: val_loss did not improve from 0.58561
# 200/200 [==============================] - 35s 175ms/step - loss: 0.1907 - accuracy: 0.9545 - val_loss: 3.0603 - val_accuracy: 0.7303
# Epoch 22/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2398 - accuracy: 0.9506
# Epoch 22: val_loss did not improve from 0.58561
# 200/200 [==============================] - 35s 174ms/step - loss: 0.2398 - accuracy: 0.9506 - val_loss: 3.4985 - val_accuracy: 0.6398
# Epoch 23/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2108 - accuracy: 0.9533
# Epoch 23: val_loss did not improve from 0.58561
# 200/200 [==============================] - 35s 176ms/step - loss: 0.2108 - accuracy: 0.9533 - val_loss: 2.7777 - val_accuracy: 0.7871

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment1_feature_extraction_vanilla.h5'))
# Out:
# 67/67 [==============================] - 13s 198ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6962    0.6652    0.6804       696
#            1     0.8413    0.8594    0.8503      1437
#
#     accuracy                         0.7961      2133
#    macro avg     0.7688    0.7623    0.7653      2133
# weighted avg     0.7940    0.7961    0.7948      2133

# %% [markdown]
# ### Experiment 2: adding dropout
# Not surprisingly, the vanilla model performs very poorly and suffers highly from overfitting. We try to solve this problem by adding dropout.

# %%
inputs = keras.Input(shape=(224,224,3))
x = keras.applications.vgg16.preprocess_input(inputs)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
dropout_vgg_model = keras.Model(inputs, outputs)
compile_model(dropout_vgg_model)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 256)               6422784
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 21137729 (80.63 MB)
# Trainable params: 6423041 (24.50 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
run_model(dropout_vgg_model, 'experiment2_feature_extraction_dropout', epochs = 100, patience=20, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 24.1219 - accuracy: 0.6745
# Epoch 1: val_loss improved from inf to 10.37217, saving model to /content/models/experiment2_feature_extraction_dropout.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 39s 182ms/step - loss: 24.1219 - accuracy: 0.6745 - val_loss: 10.3722 - val_accuracy: 0.7800
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 6.5078 - accuracy: 0.7695
# Epoch 2: val_loss improved from 10.37217 to 4.16263, saving model to /content/models/experiment2_feature_extraction_dropout.h5
# 200/200 [==============================] - 35s 175ms/step - loss: 6.5078 - accuracy: 0.7695 - val_loss: 4.1626 - val_accuracy: 0.7678
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 2.5332 - accuracy: 0.8155
# Epoch 3: val_loss improved from 4.16263 to 4.03773, saving model to /content/models/experiment2_feature_extraction_dropout.h5
# 200/200 [==============================] - 37s 184ms/step - loss: 2.5332 - accuracy: 0.8155 - val_loss: 4.0377 - val_accuracy: 0.6567
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.8652 - accuracy: 0.8676
# Epoch 4: val_loss improved from 4.03773 to 1.37065, saving model to /content/models/experiment2_feature_extraction_dropout.h5
# 200/200 [==============================] - 35s 176ms/step - loss: 0.8652 - accuracy: 0.8676 - val_loss: 1.3706 - val_accuracy: 0.7824
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4601 - accuracy: 0.8891
# Epoch 5: val_loss improved from 1.37065 to 0.98192, saving model to /content/models/experiment2_feature_extraction_dropout.h5
# 200/200 [==============================] - 36s 178ms/step - loss: 0.4601 - accuracy: 0.8891 - val_loss: 0.9819 - val_accuracy: 0.8002
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2839 - accuracy: 0.9054
# Epoch 6: val_loss improved from 0.98192 to 0.81930, saving model to /content/models/experiment2_feature_extraction_dropout.h5
# 200/200 [==============================] - 35s 176ms/step - loss: 0.2839 - accuracy: 0.9054 - val_loss: 0.8193 - val_accuracy: 0.8077
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2181 - accuracy: 0.9226
# Epoch 7: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 174ms/step - loss: 0.2181 - accuracy: 0.9226 - val_loss: 0.9359 - val_accuracy: 0.7716
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1799 - accuracy: 0.9336
# Epoch 8: val_loss did not improve from 0.81930
# 200/200 [==============================] - 37s 182ms/step - loss: 0.1799 - accuracy: 0.9336 - val_loss: 0.8339 - val_accuracy: 0.8039
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1942 - accuracy: 0.9329
# Epoch 9: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 174ms/step - loss: 0.1942 - accuracy: 0.9329 - val_loss: 1.4138 - val_accuracy: 0.7036
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9264
# Epoch 10: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 173ms/step - loss: 0.2109 - accuracy: 0.9264 - val_loss: 0.9544 - val_accuracy: 0.8016
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1774 - accuracy: 0.9400
# Epoch 11: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 174ms/step - loss: 0.1774 - accuracy: 0.9400 - val_loss: 1.6382 - val_accuracy: 0.7054
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2242 - accuracy: 0.9298
# Epoch 12: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 174ms/step - loss: 0.2242 - accuracy: 0.9298 - val_loss: 1.0975 - val_accuracy: 0.8152
# Epoch 13/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2688 - accuracy: 0.9203
# Epoch 13: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 175ms/step - loss: 0.2688 - accuracy: 0.9203 - val_loss: 1.3656 - val_accuracy: 0.7753
# Epoch 14/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3233 - accuracy: 0.9168
# Epoch 14: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 175ms/step - loss: 0.3233 - accuracy: 0.9168 - val_loss: 1.2536 - val_accuracy: 0.8072
# Epoch 15/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3442 - accuracy: 0.9174
# Epoch 15: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 174ms/step - loss: 0.3442 - accuracy: 0.9174 - val_loss: 1.4361 - val_accuracy: 0.7988
# Epoch 16/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4223 - accuracy: 0.9095
# Epoch 16: val_loss did not improve from 0.81930
# 200/200 [==============================] - 37s 182ms/step - loss: 0.4223 - accuracy: 0.9095 - val_loss: 1.8767 - val_accuracy: 0.7683
# Epoch 17/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.9040
# Epoch 17: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 174ms/step - loss: 0.4976 - accuracy: 0.9040 - val_loss: 1.7228 - val_accuracy: 0.8110
# Epoch 18/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5473 - accuracy: 0.9004
# Epoch 18: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 175ms/step - loss: 0.5473 - accuracy: 0.9004 - val_loss: 2.7575 - val_accuracy: 0.6937
# Epoch 19/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4728 - accuracy: 0.9065
# Epoch 19: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 175ms/step - loss: 0.4728 - accuracy: 0.9065 - val_loss: 1.7112 - val_accuracy: 0.8063
# Epoch 20/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4887 - accuracy: 0.9153
# Epoch 20: val_loss did not improve from 0.81930
# 200/200 [==============================] - 37s 182ms/step - loss: 0.4887 - accuracy: 0.9153 - val_loss: 2.0456 - val_accuracy: 0.7899
# Epoch 21/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5371 - accuracy: 0.9137
# Epoch 21: val_loss did not improve from 0.81930
# 200/200 [==============================] - 35s 175ms/step - loss: 0.5371 - accuracy: 0.9137 - val_loss: 3.4747 - val_accuracy: 0.7214

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment2_feature_extraction_dropout.h5'))
# Out:
# 67/67 [==============================] - 9s 126ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6869    0.7313    0.7084       696
#            1     0.8657    0.8386    0.8519      1437
#
#     accuracy                         0.8036      2133
#    macro avg     0.7763    0.7849    0.7802      2133
# weighted avg     0.8073    0.8036    0.8051      2133

# %% [markdown]
# ### Experiment 3: global average pooling

# %%
inputs = keras.Input(shape=(224,224,3))
x = keras.applications.vgg16.preprocess_input(inputs)
x = conv_base(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
global_average = keras.Model(inputs, outputs)
compile_model(global_average)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_2  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_2 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 14846273 (56.63 MB)
# Trainable params: 131585 (514.00 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
run_model(global_average, 'experiment3_feature_extraction_gap', epochs = 100, patience=20, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 1.2309 - accuracy: 0.6563
# Epoch 1: val_loss improved from inf to 1.00537, saving model to /content/models/experiment3_feature_extraction_gap.h5
# 200/200 [==============================] - 36s 175ms/step - loss: 1.2309 - accuracy: 0.6563 - val_loss: 1.0054 - val_accuracy: 0.5380
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - ETA: 0s - loss: 0.7810 - accuracy: 0.6865
# Epoch 2: val_loss did not improve from 1.00537
# 200/200 [==============================] - 35s 174ms/step - loss: 0.7810 - accuracy: 0.6865 - val_loss: 1.0058 - val_accuracy: 0.5136
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6246 - accuracy: 0.7179
# Epoch 3: val_loss improved from 1.00537 to 0.64938, saving model to /content/models/experiment3_feature_extraction_gap.h5
# 200/200 [==============================] - 35s 173ms/step - loss: 0.6246 - accuracy: 0.7179 - val_loss: 0.6494 - val_accuracy: 0.6515
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5468 - accuracy: 0.7391
# Epoch 4: val_loss improved from 0.64938 to 0.50171, saving model to /content/models/experiment3_feature_extraction_gap.h5
# 200/200 [==============================] - 36s 182ms/step - loss: 0.5468 - accuracy: 0.7391 - val_loss: 0.5017 - val_accuracy: 0.7509
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5275 - accuracy: 0.7425
# Epoch 5: val_loss did not improve from 0.50171
# 200/200 [==============================] - 35s 172ms/step - loss: 0.5275 - accuracy: 0.7425 - val_loss: 0.5229 - val_accuracy: 0.7411
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5072 - accuracy: 0.7533
# Epoch 6: val_loss improved from 0.50171 to 0.43621, saving model to /content/models/experiment3_feature_extraction_gap.h5
# 200/200 [==============================] - 35s 174ms/step - loss: 0.5072 - accuracy: 0.7533 - val_loss: 0.4362 - val_accuracy: 0.8110
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4965 - accuracy: 0.7594
# Epoch 7: val_loss did not improve from 0.43621
# 200/200 [==============================] - 35s 175ms/step - loss: 0.4965 - accuracy: 0.7594 - val_loss: 0.4362 - val_accuracy: 0.8096
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4939 - accuracy: 0.7570
# Epoch 8: val_loss did not improve from 0.43621
# 200/200 [==============================] - 36s 181ms/step - loss: 0.4939 - accuracy: 0.7570 - val_loss: 0.4599 - val_accuracy: 0.7908
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4888 - accuracy: 0.7616
# Epoch 9: val_loss did not improve from 0.43621
# 200/200 [==============================] - 35s 173ms/step - loss: 0.4888 - accuracy: 0.7616 - val_loss: 0.5720 - val_accuracy: 0.7017
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4838 - accuracy: 0.7653
# Epoch 10: val_loss did not improve from 0.43621
# 200/200 [==============================] - 35s 173ms/step - loss: 0.4838 - accuracy: 0.7653 - val_loss: 0.4887 - val_accuracy: 0.7725
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4831 - accuracy: 0.7586
# Epoch 11: val_loss did not improve from 0.43621
# 200/200 [==============================] - 35s 173ms/step - loss: 0.4831 - accuracy: 0.7586 - val_loss: 0.5096 - val_accuracy: 0.7491

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment3_feature_extraction_gap.h5'))
# Out:
# 67/67 [==============================] - 9s 126ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7556    0.5862    0.6602       696
#            1     0.8192    0.9081    0.8614      1437
#
#     accuracy                         0.8031      2133
#    macro avg     0.7874    0.7472    0.7608      2133
# weighted avg     0.7984    0.8031    0.7957      2133

# %% [markdown]
# ## Fine Tuning
# At this point, we try to unfreeze a few layers of the network and re-run the training to increase performance.

# %% [markdown]
# ### Experiment 4: last layer

# %%
vgg_ft_1_layer = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment2_feature_extraction_dropout.h5'))

for layer in vgg_ft_1_layer.get_layer('vgg16').layers:
    if layer.name in ('block5_conv3'):
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(vgg_ft_1_layer, learning_rate=1e-5)

for i, layer in enumerate(vgg_ft_1_layer.get_layer('vgg16').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 256)               6422784
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 21137729 (80.63 MB)
# Trainable params: 8782849 (33.50 MB)
# Non-trainable params: 12354880 (47.13 MB)
# _________________________________________________________________
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 False
# 16 block5_conv2 False
# 17 block5_conv3 True
# 18 block5_pool False

# %%
run_model(vgg_ft_1_layer, 'experiment4_finetuning_1_layer', epochs = 100, patience=20, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2141 - accuracy: 0.9218
# Epoch 1: val_loss improved from inf to 0.84410, saving model to /content/models/experiment4_finetuning_1_layer.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 39s 187ms/step - loss: 0.2141 - accuracy: 0.9218 - val_loss: 0.8441 - val_accuracy: 0.7908
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1292 - accuracy: 0.9489
# Epoch 2: val_loss did not improve from 0.84410
# 200/200 [==============================] - 36s 180ms/step - loss: 0.1292 - accuracy: 0.9489 - val_loss: 0.9957 - val_accuracy: 0.7645
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1002 - accuracy: 0.9583
# Epoch 3: val_loss did not improve from 0.84410
# 200/200 [==============================] - 36s 180ms/step - loss: 0.1002 - accuracy: 0.9583 - val_loss: 0.8787 - val_accuracy: 0.7941
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9720
# Epoch 4: val_loss improved from 0.84410 to 0.82429, saving model to /content/models/experiment4_finetuning_1_layer.h5
# 200/200 [==============================] - 37s 182ms/step - loss: 0.0796 - accuracy: 0.9720 - val_loss: 0.8243 - val_accuracy: 0.8082
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9823
# Epoch 5: val_loss did not improve from 0.82429
# 200/200 [==============================] - 36s 180ms/step - loss: 0.0496 - accuracy: 0.9823 - val_loss: 0.9756 - val_accuracy: 0.7702
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9872
# Epoch 6: val_loss did not improve from 0.82429
# 200/200 [==============================] - 36s 180ms/step - loss: 0.0417 - accuracy: 0.9872 - val_loss: 0.8539 - val_accuracy: 0.8082
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9903
# Epoch 7: val_loss did not improve from 0.82429
# 200/200 [==============================] - 38s 188ms/step - loss: 0.0314 - accuracy: 0.9903 - val_loss: 0.9113 - val_accuracy: 0.8030
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9936
# Epoch 8: val_loss did not improve from 0.82429
# 200/200 [==============================] - 38s 188ms/step - loss: 0.0270 - accuracy: 0.9936 - val_loss: 0.9041 - val_accuracy: 0.8044
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9947
# Epoch 9: val_loss did not improve from 0.82429
# 200/200 [==============================] - 36s 180ms/step - loss: 0.0214 - accuracy: 0.9947 - val_loss: 0.8596 - val_accuracy: 0.8180

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment4_finetuning_1_layer.h5'))
# Out:
# 67/67 [==============================] - 8s 125ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6631    0.7945    0.7229       696
#            1     0.8899    0.8045    0.8450      1437
#
#     accuracy                         0.8012      2133
#    macro avg     0.7765    0.7995    0.7840      2133
# weighted avg     0.8159    0.8012    0.8052      2133

# %% [markdown]
# ### Experiment 4bis: last layer

# %%
vgg_ft_1_layer = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment3_feature_extraction_gap.h5'))

for layer in vgg_ft_1_layer.get_layer('vgg16').layers:
    if layer.name in ('block5_conv3'):
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(vgg_ft_1_layer, learning_rate=1e-5)

for i, layer in enumerate(vgg_ft_1_layer.get_layer('vgg16').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_2  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_2 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 14846273 (56.63 MB)
# Trainable params: 2491393 (9.50 MB)
# Non-trainable params: 12354880 (47.13 MB)
# _________________________________________________________________
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 False
# 16 block5_conv2 False
# 17 block5_conv3 True
# 18 block5_pool False

# %%
run_model(vgg_ft_1_layer, 'experiment4bis_finetuning_1_layer', epochs = 100, patience=20, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4733 - accuracy: 0.7763
# Epoch 1: val_loss improved from inf to 0.42362, saving model to /content/models/experiment4bis_finetuning_1_layer.h5
# 200/200 [==============================] - 38s 183ms/step - loss: 0.4733 - accuracy: 0.7763 - val_loss: 0.4236 - val_accuracy: 0.8114
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - ETA: 0s - loss: 0.4347 - accuracy: 0.7967
# Epoch 2: val_loss improved from 0.42362 to 0.40456, saving model to /content/models/experiment4bis_finetuning_1_layer.h5
# 200/200 [==============================] - 38s 187ms/step - loss: 0.4347 - accuracy: 0.7967 - val_loss: 0.4046 - val_accuracy: 0.8321
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3999 - accuracy: 0.8166
# Epoch 3: val_loss did not improve from 0.40456
# 200/200 [==============================] - 36s 180ms/step - loss: 0.3999 - accuracy: 0.8166 - val_loss: 0.4754 - val_accuracy: 0.7636
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3720 - accuracy: 0.8358
# Epoch 4: val_loss did not improve from 0.40456
# 200/200 [==============================] - 37s 187ms/step - loss: 0.3720 - accuracy: 0.8358 - val_loss: 0.4234 - val_accuracy: 0.8086
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3462 - accuracy: 0.8488
# Epoch 5: val_loss did not improve from 0.40456
# 200/200 [==============================] - 36s 179ms/step - loss: 0.3462 - accuracy: 0.8488 - val_loss: 0.5126 - val_accuracy: 0.7430
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.8615
# Epoch 6: val_loss did not improve from 0.40456
# 200/200 [==============================] - 36s 179ms/step - loss: 0.3274 - accuracy: 0.8615 - val_loss: 0.4897 - val_accuracy: 0.7608
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3063 - accuracy: 0.8740
# Epoch 7: val_loss did not improve from 0.40456
# 200/200 [==============================] - 36s 179ms/step - loss: 0.3063 - accuracy: 0.8740 - val_loss: 0.4178 - val_accuracy: 0.8105

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment4bis_finetuning_1_layer.h5'))
# Out:
# 67/67 [==============================] - 9s 127ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7338    0.7011    0.7171       696
#            1     0.8583    0.8768    0.8675      1437
#
#     accuracy                         0.8195      2133
#    macro avg     0.7961    0.7890    0.7923      2133
# weighted avg     0.8177    0.8195    0.8184      2133

# %% [markdown]
# ### Experiment 5: last block

# %%
vgg16_ft_1_block = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment2_feature_extraction_dropout.h5'))

for layer in vgg16_ft_1_block.get_layer('vgg16').layers:
    if layer.name in ('block5_conv2', 'block5_conv3', 'block5_conv1'):
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(vgg16_ft_1_block, learning_rate=1e-5)

for i, layer in enumerate(vgg16_ft_1_block.get_layer('vgg16').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 256)               6422784
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 21137729 (80.63 MB)
# Trainable params: 13502465 (51.51 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool False

# %%
run_model(vgg16_ft_1_block, 'experiment5_finetuning_1_block', epochs = 100, patience=20, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2359 - accuracy: 0.9132
# Epoch 1: val_loss improved from inf to 0.94942, saving model to /content/models/experiment5_finetuning_1_block.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 43s 202ms/step - loss: 0.2359 - accuracy: 0.9132 - val_loss: 0.9494 - val_accuracy: 0.7552
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9484
# Epoch 2: val_loss improved from 0.94942 to 0.84400, saving model to /content/models/experiment5_finetuning_1_block.h5
# 200/200 [==============================] - 42s 207ms/step - loss: 0.1317 - accuracy: 0.9484 - val_loss: 0.8440 - val_accuracy: 0.7720
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9687
# Epoch 3: val_loss improved from 0.84400 to 0.81400, saving model to /content/models/experiment5_finetuning_1_block.h5
# 200/200 [==============================] - 40s 198ms/step - loss: 0.0828 - accuracy: 0.9687 - val_loss: 0.8140 - val_accuracy: 0.7917
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9825
# Epoch 4: val_loss did not improve from 0.81400
# 200/200 [==============================] - 39s 196ms/step - loss: 0.0521 - accuracy: 0.9825 - val_loss: 0.8231 - val_accuracy: 0.7992
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9856
# Epoch 5: val_loss did not improve from 0.81400
# 200/200 [==============================] - 39s 196ms/step - loss: 0.0421 - accuracy: 0.9856 - val_loss: 0.9190 - val_accuracy: 0.7894
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9916
# Epoch 6: val_loss did not improve from 0.81400
# 200/200 [==============================] - 39s 196ms/step - loss: 0.0278 - accuracy: 0.9916 - val_loss: 0.8916 - val_accuracy: 0.7941
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9959
# Epoch 7: val_loss did not improve from 0.81400
# 200/200 [==============================] - 39s 196ms/step - loss: 0.0171 - accuracy: 0.9959 - val_loss: 0.8333 - val_accuracy: 0.8100
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9967
# Epoch 8: val_loss did not improve from 0.81400
# 200/200 [==============================] - 39s 197ms/step - loss: 0.0134 - accuracy: 0.9967 - val_loss: 0.9958 - val_accuracy: 0.7763

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment5_finetuning_1_block.h5'))
# Out:
# 67/67 [==============================] - 9s 128ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6351    0.7902    0.7042       696
#            1     0.8848    0.7801    0.8291      1437
#
#     accuracy                         0.7834      2133
#    macro avg     0.7599    0.7852    0.7667      2133
# weighted avg     0.8033    0.7834    0.7884      2133

# %% [markdown]
# ### Experiment 5bis: last block (Global Average Pooling)

# %%
vgg16_ft_1_block = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment3_feature_extraction_gap.h5'))

for layer in vgg16_ft_1_block.get_layer('vgg16').layers:
    if layer.name in ('block5_conv2', 'block5_conv3', 'block5_conv1'):
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(vgg16_ft_1_block, learning_rate=1e-5)

for i, layer in enumerate(vgg16_ft_1_block.get_layer('vgg16').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_2  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_2 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 14846273 (56.63 MB)
# Trainable params: 7211009 (27.51 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool False

# %%
run_model(vgg16_ft_1_block, 'experiment5bis_finetuning_1_block', epochs = 100, patience=20, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4728 - accuracy: 0.7708
# Epoch 1: val_loss improved from inf to 0.42248, saving model to /content/models/experiment5bis_finetuning_1_block.h5
# 200/200 [==============================] - 41s 198ms/step - loss: 0.4728 - accuracy: 0.7708 - val_loss: 0.4225 - val_accuracy: 0.8194
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3751 - accuracy: 0.8271
# Epoch 2: val_loss improved from 0.42248 to 0.38965, saving model to /content/models/experiment5bis_finetuning_1_block.h5
# 200/200 [==============================] - 39s 196ms/step - loss: 0.3751 - accuracy: 0.8271 - val_loss: 0.3897 - val_accuracy: 0.8340
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3059 - accuracy: 0.8712
# Epoch 3: val_loss improved from 0.38965 to 0.36034, saving model to /content/models/experiment5bis_finetuning_1_block.h5
# 200/200 [==============================] - 41s 204ms/step - loss: 0.3059 - accuracy: 0.8712 - val_loss: 0.3603 - val_accuracy: 0.8457
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.9067
# Epoch 4: val_loss did not improve from 0.36034
# 200/200 [==============================] - 40s 197ms/step - loss: 0.2443 - accuracy: 0.9067 - val_loss: 0.3890 - val_accuracy: 0.8316
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9225
# Epoch 5: val_loss did not improve from 0.36034
# 200/200 [==============================] - 39s 195ms/step - loss: 0.2025 - accuracy: 0.9225 - val_loss: 0.4026 - val_accuracy: 0.8208
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1563 - accuracy: 0.9501
# Epoch 6: val_loss did not improve from 0.36034
# 200/200 [==============================] - 39s 194ms/step - loss: 0.1563 - accuracy: 0.9501 - val_loss: 0.3831 - val_accuracy: 0.8452
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9670
# Epoch 7: val_loss improved from 0.36034 to 0.35019, saving model to /content/models/experiment5bis_finetuning_1_block.h5
# 200/200 [==============================] - 40s 197ms/step - loss: 0.1172 - accuracy: 0.9670 - val_loss: 0.3502 - val_accuracy: 0.8593
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9669
# Epoch 8: val_loss improved from 0.35019 to 0.33970, saving model to /content/models/experiment5bis_finetuning_1_block.h5
# 200/200 [==============================] - 40s 197ms/step - loss: 0.1094 - accuracy: 0.9669 - val_loss: 0.3397 - val_accuracy: 0.8724
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9795
# Epoch 9: val_loss did not improve from 0.33970
# 200/200 [==============================] - 39s 196ms/step - loss: 0.0812 - accuracy: 0.9795 - val_loss: 0.3773 - val_accuracy: 0.8612
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9916
# Epoch 10: val_loss did not improve from 0.33970
# 200/200 [==============================] - 39s 196ms/step - loss: 0.0541 - accuracy: 0.9916 - val_loss: 0.3821 - val_accuracy: 0.8607
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9953
# Epoch 11: val_loss did not improve from 0.33970
# 200/200 [==============================] - 39s 196ms/step - loss: 0.0404 - accuracy: 0.9953 - val_loss: 0.3749 - val_accuracy: 0.8682
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9911
# Epoch 12: val_loss did not improve from 0.33970
# 200/200 [==============================] - 39s 196ms/step - loss: 0.0453 - accuracy: 0.9911 - val_loss: 0.4929 - val_accuracy: 0.8354
# Epoch 13/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9970
# Epoch 13: val_loss did not improve from 0.33970
# 200/200 [==============================] - 41s 204ms/step - loss: 0.0291 - accuracy: 0.9970 - val_loss: 0.3911 - val_accuracy: 0.8696

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment5bis_finetuning_1_block.h5'))
# Out:
# 67/67 [==============================] - 8s 124ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7834    0.8003    0.7918       696
#            1     0.9023    0.8928    0.8975      1437
#
#     accuracy                         0.8626      2133
#    macro avg     0.8428    0.8466    0.8446      2133
# weighted avg     0.8635    0.8626    0.8630      2133

# %% [markdown]
# ### Experiment 6: two blocks

# %%
vgg16_ft_2_blocks = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment2_feature_extraction_dropout.h5'))

for layer in vgg16_ft_2_blocks.get_layer('vgg16').layers:
    if layer.name in ('block5_conv2', 'block5_conv3', 'block5_conv1', 'block4_conv3', 'block4_conv2', 'block4_conv1'):
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(vgg16_ft_2_blocks, learning_rate=1e-5)

for i, layer in enumerate(vgg16_ft_2_blocks.get_layer('vgg16').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 256)               6422784
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 21137729 (80.63 MB)
# Trainable params: 19402241 (74.01 MB)
# Non-trainable params: 1735488 (6.62 MB)
# _________________________________________________________________
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 True
# 12 block4_conv2 True
# 13 block4_conv3 True
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool False

# %%
run_model(vgg16_ft_2_blocks, 'experiment6_finetuning_2_blocks', epochs = 100, patience=20, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3012 - accuracy: 0.8902
# Epoch 1: val_loss improved from inf to 0.75705, saving model to /content/models/experiment6_finetuning_2_blocks.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 58s 265ms/step - loss: 0.3012 - accuracy: 0.8902 - val_loss: 0.7571 - val_accuracy: 0.7523
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9420
# Epoch 2: val_loss improved from 0.75705 to 0.64937, saving model to /content/models/experiment6_finetuning_2_blocks.h5
# 200/200 [==============================] - 51s 252ms/step - loss: 0.1517 - accuracy: 0.9420 - val_loss: 0.6494 - val_accuracy: 0.8110
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9537
# Epoch 3: val_loss did not improve from 0.64937
# 200/200 [==============================] - 50s 248ms/step - loss: 0.1167 - accuracy: 0.9537 - val_loss: 0.7044 - val_accuracy: 0.7955
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9812
# Epoch 4: val_loss did not improve from 0.64937
# 200/200 [==============================] - 50s 248ms/step - loss: 0.0534 - accuracy: 0.9812 - val_loss: 0.7250 - val_accuracy: 0.8016
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9884
# Epoch 5: val_loss did not improve from 0.64937
# 200/200 [==============================] - 51s 256ms/step - loss: 0.0354 - accuracy: 0.9884 - val_loss: 0.7654 - val_accuracy: 0.8091
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9822
# Epoch 6: val_loss did not improve from 0.64937
# 200/200 [==============================] - 51s 255ms/step - loss: 0.0479 - accuracy: 0.9822 - val_loss: 0.6966 - val_accuracy: 0.8166
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9944
# Epoch 7: val_loss did not improve from 0.64937
# 200/200 [==============================] - 50s 250ms/step - loss: 0.0212 - accuracy: 0.9944 - val_loss: 0.8396 - val_accuracy: 0.7974

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment6_finetuning_2_blocks.h5'))
# Out:
# 67/67 [==============================] - 8s 124ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7017    0.7672    0.7330       696
#            1     0.8819    0.8420    0.8615      1437
#
#     accuracy                         0.8176      2133
#    macro avg     0.7918    0.8046    0.7973      2133
# weighted avg     0.8231    0.8176    0.8196      2133

# %% [markdown]
# ### Experiment 6bis: two blocks (Global Average Pooling)

# %%
vgg16_ft_2_blocks_gap = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment3_feature_extraction_gap.h5'))

for layer in vgg16_ft_2_blocks_gap.get_layer('vgg16').layers:
    if layer.name in ('block5_conv2', 'block5_conv3', 'block5_conv1', 'block4_conv3', 'block4_conv2', 'block4_conv1'):
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(vgg16_ft_2_blocks_gap, learning_rate=1e-5)

for i, layer in enumerate(vgg16_ft_2_blocks_gap.get_layer('vgg16').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_2  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_2 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 14846273 (56.63 MB)
# Trainable params: 13110785 (50.01 MB)
# Non-trainable params: 1735488 (6.62 MB)
# _________________________________________________________________
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 True
# 12 block4_conv2 True
# 13 block4_conv3 True
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool False

# %%
run_model(vgg16_ft_2_blocks_gap, 'experiment6bis_finetuning_2_blocks', epochs = 100, patience=20, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4662 - accuracy: 0.7720
# Epoch 1: val_loss improved from inf to 0.37295, saving model to /content/models/experiment6bis_finetuning_2_blocks.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 53s 252ms/step - loss: 0.4662 - accuracy: 0.7720 - val_loss: 0.3730 - val_accuracy: 0.8466
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3314 - accuracy: 0.8551
# Epoch 2: val_loss improved from 0.37295 to 0.33590, saving model to /content/models/experiment6bis_finetuning_2_blocks.h5
# 200/200 [==============================] - 51s 255ms/step - loss: 0.3314 - accuracy: 0.8551 - val_loss: 0.3359 - val_accuracy: 0.8612
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2535 - accuracy: 0.8932
# Epoch 3: val_loss improved from 0.33590 to 0.30502, saving model to /content/models/experiment6bis_finetuning_2_blocks.h5
# 200/200 [==============================] - 51s 251ms/step - loss: 0.2535 - accuracy: 0.8932 - val_loss: 0.3050 - val_accuracy: 0.8715
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1754 - accuracy: 0.9307
# Epoch 4: val_loss did not improve from 0.30502
# 200/200 [==============================] - 51s 256ms/step - loss: 0.1754 - accuracy: 0.9307 - val_loss: 0.3222 - val_accuracy: 0.8691
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 0.9512
# Epoch 5: val_loss did not improve from 0.30502
# 200/200 [==============================] - 50s 248ms/step - loss: 0.1316 - accuracy: 0.9512 - val_loss: 0.3370 - val_accuracy: 0.8621
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9767
# Epoch 6: val_loss did not improve from 0.30502
# 200/200 [==============================] - 49s 245ms/step - loss: 0.0806 - accuracy: 0.9767 - val_loss: 0.5594 - val_accuracy: 0.8002
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9784
# Epoch 7: val_loss did not improve from 0.30502
# 200/200 [==============================] - 50s 247ms/step - loss: 0.0672 - accuracy: 0.9784 - val_loss: 0.4113 - val_accuracy: 0.8579
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0452 - accuracy: 0.9870
# Epoch 8: val_loss did not improve from 0.30502
# 200/200 [==============================] - 50s 248ms/step - loss: 0.0452 - accuracy: 0.9870 - val_loss: 0.4126 - val_accuracy: 0.8659

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment6bis_finetuning_2_blocks.h5'))
# Out:
# 67/67 [==============================] - 8s 123ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8574    0.7256    0.7860       696
#            1     0.8763    0.9415    0.9077      1437
#
#     accuracy                         0.8711      2133
#    macro avg     0.8668    0.8336    0.8469      2133
# weighted avg     0.8701    0.8711    0.8680      2133

# %% [markdown]
# ## Remove Last Block
# Since our dataset is small and very different from ImageNet, we try to remove the last block. In fact, that block should be able to extract features more specific to the images in the original dataset, which therefore may not be suitable for our medical imaging dataset.
#
# We then repeat the same steps as before, gradually increasing the complexity of the network.

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# #### Experiment 7: one FC layer with dropout

# %%
model = Sequential()
for layer in conv_base.layers:
  if layer.name in ("block5_conv1"):
    break
  layer.trainable = False
  model.add(layer)

model.summary()
for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
# =================================================================
# Total params: 7635264 (29.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________
# 0 block1_conv1 False
# 1 block1_conv2 False
# 2 block1_pool False
# 3 block2_conv1 False
# 4 block2_conv2 False
# 5 block2_pool False
# 6 block3_conv1 False
# 7 block3_conv2 False
# 8 block3_conv3 False
# 9 block3_pool False
# 10 block4_conv1 False
# 11 block4_conv2 False
# 12 block4_conv3 False
# 13 block4_pool False

# %%
inputs = keras.Input(shape=(224,224,3))
x = keras.applications.vgg16.preprocess_input(inputs)
x = model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
vgg_cut_model = keras.Model(inputs, outputs)
compile_model(vgg_cut_model)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_3  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_3 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  sequential (Sequential)     (None, 14, 14, 512)       7635264
#
#  global_average_pooling2d_1  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 7766849 (29.63 MB)
# Trainable params: 131585 (514.00 KB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %%
run_model(vgg_cut_model, 'experiment7_cut_feature_extraction_dropout', epochs = 100, patience=20, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 11.8467 - accuracy: 0.6452
# Epoch 1: val_loss improved from inf to 3.78863, saving model to /content/models/experiment7_cut_feature_extraction_dropout.h5
# 200/200 [==============================] - 34s 164ms/step - loss: 11.8467 - accuracy: 0.6452 - val_loss: 3.7886 - val_accuracy: 0.7875
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - ETA: 0s - loss: 6.1467 - accuracy: 0.6829
# Epoch 2: val_loss improved from 3.78863 to 2.33974, saving model to /content/models/experiment7_cut_feature_extraction_dropout.h5
# 200/200 [==============================] - 32s 161ms/step - loss: 6.1467 - accuracy: 0.6829 - val_loss: 2.3397 - val_accuracy: 0.8246
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 3.6500 - accuracy: 0.7003
# Epoch 3: val_loss improved from 2.33974 to 2.32151, saving model to /content/models/experiment7_cut_feature_extraction_dropout.h5
# 200/200 [==============================] - 32s 159ms/step - loss: 3.6500 - accuracy: 0.7003 - val_loss: 2.3215 - val_accuracy: 0.7828
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 1.9866 - accuracy: 0.7169
# Epoch 4: val_loss improved from 2.32151 to 0.80325, saving model to /content/models/experiment7_cut_feature_extraction_dropout.h5
# 200/200 [==============================] - 35s 173ms/step - loss: 1.9866 - accuracy: 0.7169 - val_loss: 0.8032 - val_accuracy: 0.8424
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 1.2160 - accuracy: 0.7334
# Epoch 5: val_loss did not improve from 0.80325
# 200/200 [==============================] - 32s 159ms/step - loss: 1.2160 - accuracy: 0.7334 - val_loss: 0.9566 - val_accuracy: 0.6646
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6994 - accuracy: 0.7450
# Epoch 6: val_loss improved from 0.80325 to 0.51056, saving model to /content/models/experiment7_cut_feature_extraction_dropout.h5
# 200/200 [==============================] - 32s 161ms/step - loss: 0.6994 - accuracy: 0.7450 - val_loss: 0.5106 - val_accuracy: 0.7570
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5176 - accuracy: 0.7628
# Epoch 7: val_loss improved from 0.51056 to 0.37782, saving model to /content/models/experiment7_cut_feature_extraction_dropout.h5
# 200/200 [==============================] - 33s 162ms/step - loss: 0.5176 - accuracy: 0.7628 - val_loss: 0.3778 - val_accuracy: 0.8349
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4988 - accuracy: 0.7645
# Epoch 8: val_loss did not improve from 0.37782
# 200/200 [==============================] - 32s 161ms/step - loss: 0.4988 - accuracy: 0.7645 - val_loss: 0.4626 - val_accuracy: 0.7749
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5007 - accuracy: 0.7631
# Epoch 9: val_loss did not improve from 0.37782
# 200/200 [==============================] - 34s 170ms/step - loss: 0.5007 - accuracy: 0.7631 - val_loss: 0.4234 - val_accuracy: 0.8058
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4871 - accuracy: 0.7706
# Epoch 10: val_loss did not improve from 0.37782
# 200/200 [==============================] - 32s 161ms/step - loss: 0.4871 - accuracy: 0.7706 - val_loss: 0.4629 - val_accuracy: 0.7767
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4961 - accuracy: 0.7663
# Epoch 11: val_loss did not improve from 0.37782
# 200/200 [==============================] - 32s 161ms/step - loss: 0.4961 - accuracy: 0.7663 - val_loss: 0.5195 - val_accuracy: 0.7326
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4960 - accuracy: 0.7633
# Epoch 12: val_loss did not improve from 0.37782
# 200/200 [==============================] - 34s 171ms/step - loss: 0.4960 - accuracy: 0.7633 - val_loss: 0.5893 - val_accuracy: 0.7026

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment7_cut_feature_extraction_dropout.h5'))
# Out:
# 67/67 [==============================] - 8s 116ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7496    0.7486    0.7491       696
#            1     0.8783    0.8789    0.8786      1437
#
#     accuracy                         0.8364      2133
#    macro avg     0.8140    0.8137    0.8139      2133
# weighted avg     0.8363    0.8364    0.8364      2133

# %% [markdown]
# #### Experiment 8: RMSprop

# %%
inputs = keras.Input(shape=(224,224,3))
x = keras.applications.vgg16.preprocess_input(inputs)
x = model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
vgg_cut_model = keras.Model(inputs, outputs)
compile_model(vgg_cut_model, optimizer="rmsprop", learning_rate = 5e-5)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_4  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_4 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  sequential (Sequential)     (None, 14, 14, 512)       7635264
#
#  global_average_pooling2d_2  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 7766849 (29.63 MB)
# Trainable params: 131585 (514.00 KB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %%
run_model(vgg_cut_model, 'experiment8_cut_feature_extraction_dropout_rms', epochs = 100, patience=20, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 17.1174 - accuracy: 0.5525
# Epoch 1: val_loss improved from inf to 5.20289, saving model to /content/models/experiment8_cut_feature_extraction_dropout_rms.h5
# 200/200 [==============================] - 34s 163ms/step - loss: 17.1174 - accuracy: 0.5525 - val_loss: 5.2029 - val_accuracy: 0.6534
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 9.4483 - accuracy: 0.6276
# Epoch 2: val_loss did not improve from 5.20289
# 200/200 [==============================] - 34s 171ms/step - loss: 9.4483 - accuracy: 0.6276 - val_loss: 5.7032 - val_accuracy: 0.5929
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 5.8188 - accuracy: 0.6581
# Epoch 3: val_loss improved from 5.20289 to 2.06547, saving model to /content/models/experiment8_cut_feature_extraction_dropout_rms.h5
# 200/200 [==============================] - 33s 162ms/step - loss: 5.8188 - accuracy: 0.6581 - val_loss: 2.0655 - val_accuracy: 0.7800
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 4.7213 - accuracy: 0.6651
# Epoch 4: val_loss did not improve from 2.06547
# 200/200 [==============================] - 32s 161ms/step - loss: 4.7213 - accuracy: 0.6651 - val_loss: 3.1900 - val_accuracy: 0.6360
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 4.3492 - accuracy: 0.6645
# Epoch 5: val_loss did not improve from 2.06547
# 200/200 [==============================] - 34s 170ms/step - loss: 4.3492 - accuracy: 0.6645 - val_loss: 2.9266 - val_accuracy: 0.6468
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 4.2274 - accuracy: 0.6771
# Epoch 6: val_loss did not improve from 2.06547
# 200/200 [==============================] - 33s 162ms/step - loss: 4.2274 - accuracy: 0.6771 - val_loss: 2.0765 - val_accuracy: 0.7144
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 4.0158 - accuracy: 0.6776
# Epoch 7: val_loss did not improve from 2.06547
# 200/200 [==============================] - 32s 160ms/step - loss: 4.0158 - accuracy: 0.6776 - val_loss: 2.8621 - val_accuracy: 0.6346
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 3.7951 - accuracy: 0.6798
# Epoch 8: val_loss did not improve from 2.06547
# 200/200 [==============================] - 32s 159ms/step - loss: 3.7951 - accuracy: 0.6798 - val_loss: 2.0854 - val_accuracy: 0.8086

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment8_cut_feature_extraction_dropout_rms.h5'))
# Out:
# 67/67 [==============================] - 8s 116ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6983    0.6351    0.6652       696
#            1     0.8307    0.8671    0.8485      1437
#
#     accuracy                         0.7914      2133
#    macro avg     0.7645    0.7511    0.7568      2133
# weighted avg     0.7875    0.7914    0.7887      2133

# %% [markdown]
# ### Fine Tuning

# %% [markdown]
# #### Experiment 9: last layer

# %%
vgg_ft_1_layer = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment7_cut_feature_extraction_dropout.h5'))

for layer in vgg_ft_1_layer.get_layer("sequential_2").layers:
    if layer.name in ('block4_conv3'):
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(vgg_ft_1_layer, learning_rate=1e-5)

for i, layer in enumerate(vgg_ft_1_layer.get_layer('sequential_2').layers):
    print(i, layer.name, layer.trainable)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-c82aeefe5bb7> in <cell line: 3>()
#       1 vgg_ft_1_layer = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment7_cut_feature_extraction_dropout.h5'))
#       2
# ----> 3 for layer in vgg_ft_1_layer.get_layer("sequential_2").layers:
#       4     if layer.name in ('block4_conv3'):
#       5         layer.trainable = True
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in get_layer(self, name, index)
#    3565                 if layer.name == name:
#    3566                     return layer
# -> 3567             raise ValueError(
#    3568                 f"No such layer: {name}. Existing layers are: "
#    3569                 f"{list(layer.name for layer in self.layers)}."
#
# ValueError: No such layer: sequential_2. Existing layers are: ['input_5', 'tf.__operators__.getitem_3', 'tf.nn.bias_add_3', 'sequential', 'global_average_pooling2d_1', 'dense_6', 'dropout_2', 'dense_7'].

# %%
run_model(vgg_ft_1_layer, 'experiment9_cut_finetuning_1_layer', epochs = 100, patience=5, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5072 - accuracy: 0.7825
# Epoch 1: val_loss improved from inf to 0.41288, saving model to /content/models/experiment9_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 33s 163ms/step - loss: 0.5072 - accuracy: 0.7825 - val_loss: 0.4129 - val_accuracy: 0.8063
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4835 - accuracy: 0.7842
# Epoch 2: val_loss did not improve from 0.41288
# 200/200 [==============================] - 33s 162ms/step - loss: 0.4835 - accuracy: 0.7842 - val_loss: 0.7923 - val_accuracy: 0.6374
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4954 - accuracy: 0.7816
# Epoch 3: val_loss improved from 0.41288 to 0.39952, saving model to /content/models/experiment9_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 32s 160ms/step - loss: 0.4954 - accuracy: 0.7816 - val_loss: 0.3995 - val_accuracy: 0.8307
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4950 - accuracy: 0.7849
# Epoch 4: val_loss improved from 0.39952 to 0.34584, saving model to /content/models/experiment9_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 32s 162ms/step - loss: 0.4950 - accuracy: 0.7849 - val_loss: 0.3458 - val_accuracy: 0.8588
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4799 - accuracy: 0.7885
# Epoch 5: val_loss did not improve from 0.34584
# 200/200 [==============================] - 33s 162ms/step - loss: 0.4799 - accuracy: 0.7885 - val_loss: 0.5618 - val_accuracy: 0.7237
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4769 - accuracy: 0.7860
# Epoch 6: val_loss did not improve from 0.34584
# 200/200 [==============================] - 35s 172ms/step - loss: 0.4769 - accuracy: 0.7860 - val_loss: 0.3972 - val_accuracy: 0.8199
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4858 - accuracy: 0.7821
# Epoch 7: val_loss did not improve from 0.34584
# 200/200 [==============================] - 32s 161ms/step - loss: 0.4858 - accuracy: 0.7821 - val_loss: 0.3560 - val_accuracy: 0.8447
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4949 - accuracy: 0.7802
# Epoch 8: val_loss did not improve from 0.34584
# 200/200 [==============================] - 32s 162ms/step - loss: 0.4949 - accuracy: 0.7802 - val_loss: 0.3911 - val_accuracy: 0.8218
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4777 - accuracy: 0.7855
# Epoch 9: val_loss did not improve from 0.34584
# 200/200 [==============================] - 32s 160ms/step - loss: 0.4777 - accuracy: 0.7855 - val_loss: 0.3496 - val_accuracy: 0.8607

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment9_cut_finetuning_1_layer.h5'))
# Out:
# 67/67 [==============================] - 8s 116ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8243    0.6739    0.7415       696
#            1     0.8549    0.9304    0.8910      1437
#
#     accuracy                         0.8467      2133
#    macro avg     0.8396    0.8021    0.8163      2133
# weighted avg     0.8449    0.8467    0.8422      2133

# %% [markdown]
# #### Experiment 9bis: last layer

# %%
vgg_ft_1_layer = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment8_cut_feature_extraction_dropout_rms.h5'))

for layer in vgg_ft_1_layer.get_layer("sequential").layers:
    if layer.name in ('block4_conv3'):
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(vgg_ft_1_layer, learning_rate=1e-5)

for i, layer in enumerate(vgg_ft_1_layer.get_layer('sequential').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_4  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_4 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  sequential (Sequential)     (None, 14, 14, 512)       7635264
#
#  global_average_pooling2d_2  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 7766849 (29.63 MB)
# Trainable params: 2491393 (9.50 MB)
# Non-trainable params: 5275456 (20.12 MB)
# _________________________________________________________________
# 0 block1_conv1 False
# 1 block1_conv2 False
# 2 block1_pool False
# 3 block2_conv1 False
# 4 block2_conv2 False
# 5 block2_pool False
# 6 block3_conv1 False
# 7 block3_conv2 False
# 8 block3_conv3 False
# 9 block3_pool False
# 10 block4_conv1 False
# 11 block4_conv2 False
# 12 block4_conv3 True
# 13 block4_pool False

# %%
run_model(vgg_ft_1_layer, 'experiment9bis_cut_finetuning_1_layer', epochs = 100, patience=5, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 4.8536 - accuracy: 0.6628
# Epoch 1: val_loss improved from inf to 2.08044, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 37s 176ms/step - loss: 4.8536 - accuracy: 0.6628 - val_loss: 2.0804 - val_accuracy: 0.7289
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - ETA: 0s - loss: 4.0172 - accuracy: 0.6870
# Epoch 2: val_loss improved from 2.08044 to 1.80699, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 37s 185ms/step - loss: 4.0172 - accuracy: 0.6870 - val_loss: 1.8070 - val_accuracy: 0.7692
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 3.2772 - accuracy: 0.7043
# Epoch 3: val_loss improved from 1.80699 to 1.55195, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 35s 174ms/step - loss: 3.2772 - accuracy: 0.7043 - val_loss: 1.5520 - val_accuracy: 0.7711
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 3.0328 - accuracy: 0.7187
# Epoch 4: val_loss improved from 1.55195 to 1.17773, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 35s 175ms/step - loss: 3.0328 - accuracy: 0.7187 - val_loss: 1.1777 - val_accuracy: 0.8246
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 3.0073 - accuracy: 0.7167
# Epoch 5: val_loss did not improve from 1.17773
# 200/200 [==============================] - 34s 172ms/step - loss: 3.0073 - accuracy: 0.7167 - val_loss: 1.4539 - val_accuracy: 0.7674
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 2.5758 - accuracy: 0.7278
# Epoch 6: val_loss improved from 1.17773 to 1.08245, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 35s 176ms/step - loss: 2.5758 - accuracy: 0.7278 - val_loss: 1.0825 - val_accuracy: 0.8171
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 2.3596 - accuracy: 0.7392
# Epoch 7: val_loss improved from 1.08245 to 0.97614, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 37s 186ms/step - loss: 2.3596 - accuracy: 0.7392 - val_loss: 0.9761 - val_accuracy: 0.8302
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 2.1951 - accuracy: 0.7450
# Epoch 8: val_loss improved from 0.97614 to 0.97073, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 35s 174ms/step - loss: 2.1951 - accuracy: 0.7450 - val_loss: 0.9707 - val_accuracy: 0.8274
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 2.0418 - accuracy: 0.7553
# Epoch 9: val_loss did not improve from 0.97073
# 200/200 [==============================] - 35s 174ms/step - loss: 2.0418 - accuracy: 0.7553 - val_loss: 1.0821 - val_accuracy: 0.7936
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 1.9057 - accuracy: 0.7594
# Epoch 10: val_loss improved from 0.97073 to 0.90078, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 35s 174ms/step - loss: 1.9057 - accuracy: 0.7594 - val_loss: 0.9008 - val_accuracy: 0.8588
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 1.7994 - accuracy: 0.7645
# Epoch 11: val_loss improved from 0.90078 to 0.82427, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 35s 174ms/step - loss: 1.7994 - accuracy: 0.7645 - val_loss: 0.8243 - val_accuracy: 0.8344
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 1.7015 - accuracy: 0.7700
# Epoch 12: val_loss did not improve from 0.82427
# 200/200 [==============================] - 35s 173ms/step - loss: 1.7015 - accuracy: 0.7700 - val_loss: 1.0212 - val_accuracy: 0.8011
# Epoch 13/100
# 200/200 [==============================] - ETA: 0s - loss: 1.5950 - accuracy: 0.7775
# Epoch 13: val_loss improved from 0.82427 to 0.76302, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 35s 173ms/step - loss: 1.5950 - accuracy: 0.7775 - val_loss: 0.7630 - val_accuracy: 0.8396
# Epoch 14/100
# 200/200 [==============================] - ETA: 0s - loss: 1.4978 - accuracy: 0.7816
# Epoch 14: val_loss improved from 0.76302 to 0.71785, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 37s 185ms/step - loss: 1.4978 - accuracy: 0.7816 - val_loss: 0.7178 - val_accuracy: 0.8654
# Epoch 15/100
# 200/200 [==============================] - ETA: 0s - loss: 1.3689 - accuracy: 0.7939
# Epoch 15: val_loss improved from 0.71785 to 0.62344, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 37s 184ms/step - loss: 1.3689 - accuracy: 0.7939 - val_loss: 0.6234 - val_accuracy: 0.8729
# Epoch 16/100
# 200/200 [==============================] - ETA: 0s - loss: 1.3170 - accuracy: 0.7938
# Epoch 16: val_loss did not improve from 0.62344
# 200/200 [==============================] - 37s 184ms/step - loss: 1.3170 - accuracy: 0.7938 - val_loss: 1.0941 - val_accuracy: 0.7720
# Epoch 17/100
# 200/200 [==============================] - ETA: 0s - loss: 1.3607 - accuracy: 0.7963
# Epoch 17: val_loss did not improve from 0.62344
# 200/200 [==============================] - 35s 174ms/step - loss: 1.3607 - accuracy: 0.7963 - val_loss: 0.6332 - val_accuracy: 0.8612
# Epoch 18/100
# 200/200 [==============================] - ETA: 0s - loss: 1.1827 - accuracy: 0.8077
# Epoch 18: val_loss improved from 0.62344 to 0.58373, saving model to /content/models/experiment9bis_cut_finetuning_1_layer.h5
# 200/200 [==============================] - 35s 174ms/step - loss: 1.1827 - accuracy: 0.8077 - val_loss: 0.5837 - val_accuracy: 0.8748
# Epoch 19/100
# 200/200 [==============================] - ETA: 0s - loss: 1.1081 - accuracy: 0.8102
# Epoch 19: val_loss did not improve from 0.58373
# 200/200 [==============================] - 37s 184ms/step - loss: 1.1081 - accuracy: 0.8102 - val_loss: 1.2708 - val_accuracy: 0.7509
# Epoch 20/100
# 200/200 [==============================] - ETA: 0s - loss: 1.0675 - accuracy: 0.8118
# Epoch 20: val_loss did not improve from 0.58373
# 200/200 [==============================] - 35s 174ms/step - loss: 1.0675 - accuracy: 0.8118 - val_loss: 0.6033 - val_accuracy: 0.8579
# Epoch 21/100
# 200/200 [==============================] - ETA: 0s - loss: 0.9941 - accuracy: 0.8215
# Epoch 21: val_loss did not improve from 0.58373
# 200/200 [==============================] - 35s 174ms/step - loss: 0.9941 - accuracy: 0.8215 - val_loss: 0.8832 - val_accuracy: 0.7988
# Epoch 22/100
# 200/200 [==============================] - ETA: 0s - loss: 0.9413 - accuracy: 0.8249
# Epoch 22: val_loss did not improve from 0.58373
# 200/200 [==============================] - 37s 184ms/step - loss: 0.9413 - accuracy: 0.8249 - val_loss: 0.8508 - val_accuracy: 0.8016
# Epoch 23/100
# 200/200 [==============================] - ETA: 0s - loss: 0.8739 - accuracy: 0.8326
# Epoch 23: val_loss did not improve from 0.58373
# 200/200 [==============================] - 35s 173ms/step - loss: 0.8739 - accuracy: 0.8326 - val_loss: 1.0472 - val_accuracy: 0.7772

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment9bis_cut_finetuning_1_layer.h5'))
# Out:
# 67/67 [==============================] - 8s 117ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7913    0.7845    0.7879       696
#            1     0.8960    0.8998    0.8979      1437
#
#     accuracy                         0.8622      2133
#    macro avg     0.8437    0.8421    0.8429      2133
# weighted avg     0.8619    0.8622    0.8620      2133

# %% [markdown]
# #### Experiment 10: last block

# %%
vgg_ft_1_block = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment7_cut_feature_extraction_dropout.h5'))

for layer in vgg_ft_1_block.get_layer("sequential").layers:
    if layer.name in ('block4_conv3', 'block4_conv1', 'block4_conv2'):
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(vgg_ft_1_block, learning_rate=1e-5)

for i, layer in enumerate(vgg_ft_1_block.get_layer('sequential').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_3  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_3 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  sequential (Sequential)     (None, 14, 14, 512)       7635264
#
#  global_average_pooling2d_1  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 7766849 (29.63 MB)
# Trainable params: 6031361 (23.01 MB)
# Non-trainable params: 1735488 (6.62 MB)
# _________________________________________________________________
# 0 block1_conv1 False
# 1 block1_conv2 False
# 2 block1_pool False
# 3 block2_conv1 False
# 4 block2_conv2 False
# 5 block2_pool False
# 6 block3_conv1 False
# 7 block3_conv2 False
# 8 block3_conv3 False
# 9 block3_pool False
# 10 block4_conv1 True
# 11 block4_conv2 True
# 12 block4_conv3 True
# 13 block4_pool False

# %%
run_model(vgg_ft_1_block, 'eperiment10_cut_ft_1_block', epochs = 100, patience=5, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4901 - accuracy: 0.7663
# Epoch 1: val_loss improved from inf to 0.49520, saving model to /content/models/eperiment10_cut_ft_1_block.h5
# 200/200 [==============================] - 33s 163ms/step - loss: 0.4901 - accuracy: 0.7663 - val_loss: 0.4952 - val_accuracy: 0.7481
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - ETA: 0s - loss: 0.4816 - accuracy: 0.7710
# Epoch 2: val_loss improved from 0.49520 to 0.37173, saving model to /content/models/eperiment10_cut_ft_1_block.h5
# 200/200 [==============================] - 33s 162ms/step - loss: 0.4816 - accuracy: 0.7710 - val_loss: 0.3717 - val_accuracy: 0.8462
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4986 - accuracy: 0.7656
# Epoch 3: val_loss did not improve from 0.37173
# 200/200 [==============================] - 34s 170ms/step - loss: 0.4986 - accuracy: 0.7656 - val_loss: 0.6604 - val_accuracy: 0.6571
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4982 - accuracy: 0.7680
# Epoch 4: val_loss did not improve from 0.37173
# 200/200 [==============================] - 35s 173ms/step - loss: 0.4982 - accuracy: 0.7680 - val_loss: 0.3726 - val_accuracy: 0.8452
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5070 - accuracy: 0.7639
# Epoch 5: val_loss did not improve from 0.37173
# 200/200 [==============================] - 32s 160ms/step - loss: 0.5070 - accuracy: 0.7639 - val_loss: 0.3768 - val_accuracy: 0.8433
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5034 - accuracy: 0.7689
# Epoch 6: val_loss did not improve from 0.37173
# 200/200 [==============================] - 32s 161ms/step - loss: 0.5034 - accuracy: 0.7689 - val_loss: 0.3785 - val_accuracy: 0.8372
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5032 - accuracy: 0.7633
# Epoch 7: val_loss improved from 0.37173 to 0.37064, saving model to /content/models/eperiment10_cut_ft_1_block.h5
# 200/200 [==============================] - 34s 171ms/step - loss: 0.5032 - accuracy: 0.7633 - val_loss: 0.3706 - val_accuracy: 0.8499
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5219 - accuracy: 0.7531
# Epoch 8: val_loss did not improve from 0.37064
# 200/200 [==============================] - 32s 161ms/step - loss: 0.5219 - accuracy: 0.7531 - val_loss: 0.4152 - val_accuracy: 0.8152
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5152 - accuracy: 0.7605
# Epoch 9: val_loss did not improve from 0.37064
# 200/200 [==============================] - 32s 161ms/step - loss: 0.5152 - accuracy: 0.7605 - val_loss: 0.4194 - val_accuracy: 0.8129
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4965 - accuracy: 0.7634
# Epoch 10: val_loss did not improve from 0.37064
# 200/200 [==============================] - 32s 159ms/step - loss: 0.4965 - accuracy: 0.7634 - val_loss: 0.3891 - val_accuracy: 0.8236
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5123 - accuracy: 0.7595
# Epoch 11: val_loss did not improve from 0.37064
# 200/200 [==============================] - 32s 160ms/step - loss: 0.5123 - accuracy: 0.7595 - val_loss: 0.6588 - val_accuracy: 0.6646
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5133 - accuracy: 0.7589
# Epoch 12: val_loss did not improve from 0.37064
# 200/200 [==============================] - 34s 172ms/step - loss: 0.5133 - accuracy: 0.7589 - val_loss: 0.3709 - val_accuracy: 0.8401

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/eperiment10_cut_ft_1_block.h5'))
# Out:
# 67/67 [==============================] - 8s 113ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7883    0.6954    0.7389       696
#            1     0.8604    0.9095    0.8843      1437
#
#     accuracy                         0.8397      2133
#    macro avg     0.8244    0.8025    0.8116      2133
# weighted avg     0.8369    0.8397    0.8369      2133

# %% [markdown]
# #### Experiment 10bis: last block

# %%
vgg_ft_1_block = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment8_cut_feature_extraction_dropout_rms.h5'))

for layer in vgg_ft_1_block.get_layer("sequential").layers:
    if layer.name in ('block4_conv3', 'block4_conv1', 'block4_conv2'):
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(vgg_ft_1_block, optimizer="rms", learning_rate=1e-5)

for i, layer in enumerate(vgg_ft_1_block.get_layer('sequential').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_4  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_4 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  sequential (Sequential)     (None, 14, 14, 512)       7635264
#
#  global_average_pooling2d_2  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 7766849 (29.63 MB)
# Trainable params: 6031361 (23.01 MB)
# Non-trainable params: 1735488 (6.62 MB)
# _________________________________________________________________
# 0 block1_conv1 False
# 1 block1_conv2 False
# 2 block1_pool False
# 3 block2_conv1 False
# 4 block2_conv2 False
# 5 block2_pool False
# 6 block3_conv1 False
# 7 block3_conv2 False
# 8 block3_conv3 False
# 9 block3_pool False
# 10 block4_conv1 True
# 11 block4_conv2 True
# 12 block4_conv3 True
# 13 block4_pool False

# %%
run_model(vgg_ft_1_block, 'eperiment10bis_cut_ft_1_block', epochs = 100, patience=5, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 4.8412 - accuracy: 0.6617
# Epoch 1: val_loss improved from inf to 1.73762, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 34s 166ms/step - loss: 4.8412 - accuracy: 0.6617 - val_loss: 1.7376 - val_accuracy: 0.7730
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - ETA: 0s - loss: 4.4685 - accuracy: 0.6653
# Epoch 2: val_loss improved from 1.73762 to 1.72131, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 35s 173ms/step - loss: 4.4685 - accuracy: 0.6653 - val_loss: 1.7213 - val_accuracy: 0.7791
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 4.1124 - accuracy: 0.6762
# Epoch 3: val_loss improved from 1.72131 to 1.69559, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 32s 159ms/step - loss: 4.1124 - accuracy: 0.6762 - val_loss: 1.6956 - val_accuracy: 0.7434
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 3.8611 - accuracy: 0.6784
# Epoch 4: val_loss improved from 1.69559 to 1.46338, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 32s 162ms/step - loss: 3.8611 - accuracy: 0.6784 - val_loss: 1.4634 - val_accuracy: 0.8025
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 3.7301 - accuracy: 0.6840
# Epoch 5: val_loss did not improve from 1.46338
# 200/200 [==============================] - 32s 160ms/step - loss: 3.7301 - accuracy: 0.6840 - val_loss: 1.7822 - val_accuracy: 0.8180
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 3.4561 - accuracy: 0.6950
# Epoch 6: val_loss improved from 1.46338 to 1.45323, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 34s 171ms/step - loss: 3.4561 - accuracy: 0.6950 - val_loss: 1.4532 - val_accuracy: 0.8152
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 3.4250 - accuracy: 0.6867
# Epoch 7: val_loss improved from 1.45323 to 1.32848, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 32s 161ms/step - loss: 3.4250 - accuracy: 0.6867 - val_loss: 1.3285 - val_accuracy: 0.8044
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 3.3357 - accuracy: 0.7000
# Epoch 8: val_loss improved from 1.32848 to 1.28957, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 32s 161ms/step - loss: 3.3357 - accuracy: 0.7000 - val_loss: 1.2896 - val_accuracy: 0.7969
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 3.3838 - accuracy: 0.6853
# Epoch 9: val_loss did not improve from 1.28957
# 200/200 [==============================] - 34s 171ms/step - loss: 3.3838 - accuracy: 0.6853 - val_loss: 1.4594 - val_accuracy: 0.7706
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 3.0102 - accuracy: 0.7058
# Epoch 10: val_loss improved from 1.28957 to 1.19295, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 32s 161ms/step - loss: 3.0102 - accuracy: 0.7058 - val_loss: 1.1929 - val_accuracy: 0.8129
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 3.0203 - accuracy: 0.7023
# Epoch 11: val_loss did not improve from 1.19295
# 200/200 [==============================] - 32s 160ms/step - loss: 3.0203 - accuracy: 0.7023 - val_loss: 1.6535 - val_accuracy: 0.7256
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 3.0346 - accuracy: 0.6975
# Epoch 12: val_loss did not improve from 1.19295
# 200/200 [==============================] - 32s 162ms/step - loss: 3.0346 - accuracy: 0.6975 - val_loss: 1.7311 - val_accuracy: 0.7162
# Epoch 13/100
# 200/200 [==============================] - ETA: 0s - loss: 2.9445 - accuracy: 0.6961
# Epoch 13: val_loss improved from 1.19295 to 1.08850, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 32s 160ms/step - loss: 2.9445 - accuracy: 0.6961 - val_loss: 1.0885 - val_accuracy: 0.8077
# Epoch 14/100
# 200/200 [==============================] - ETA: 0s - loss: 2.7898 - accuracy: 0.7125
# Epoch 14: val_loss improved from 1.08850 to 1.05264, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 32s 161ms/step - loss: 2.7898 - accuracy: 0.7125 - val_loss: 1.0526 - val_accuracy: 0.8185
# Epoch 15/100
# 200/200 [==============================] - ETA: 0s - loss: 2.6948 - accuracy: 0.7123
# Epoch 15: val_loss did not improve from 1.05264
# 200/200 [==============================] - 32s 161ms/step - loss: 2.6948 - accuracy: 0.7123 - val_loss: 3.7511 - val_accuracy: 0.5385
# Epoch 16/100
# 200/200 [==============================] - ETA: 0s - loss: 2.6345 - accuracy: 0.7097
# Epoch 16: val_loss did not improve from 1.05264
# 200/200 [==============================] - 32s 159ms/step - loss: 2.6345 - accuracy: 0.7097 - val_loss: 1.2590 - val_accuracy: 0.7711
# Epoch 17/100
# 200/200 [==============================] - ETA: 0s - loss: 2.5746 - accuracy: 0.7043
# Epoch 17: val_loss did not improve from 1.05264
# 200/200 [==============================] - 32s 161ms/step - loss: 2.5746 - accuracy: 0.7043 - val_loss: 1.1564 - val_accuracy: 0.7847
# Epoch 18/100
# 200/200 [==============================] - ETA: 0s - loss: 2.5212 - accuracy: 0.7106
# Epoch 18: val_loss improved from 1.05264 to 0.96191, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 33s 162ms/step - loss: 2.5212 - accuracy: 0.7106 - val_loss: 0.9619 - val_accuracy: 0.8293
# Epoch 19/100
# 200/200 [==============================] - ETA: 0s - loss: 2.3141 - accuracy: 0.7201
# Epoch 19: val_loss did not improve from 0.96191
# 200/200 [==============================] - 35s 172ms/step - loss: 2.3141 - accuracy: 0.7201 - val_loss: 1.1590 - val_accuracy: 0.7767
# Epoch 20/100
# 200/200 [==============================] - ETA: 0s - loss: 2.3397 - accuracy: 0.7165
# Epoch 20: val_loss improved from 0.96191 to 0.89852, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 32s 161ms/step - loss: 2.3397 - accuracy: 0.7165 - val_loss: 0.8985 - val_accuracy: 0.8175
# Epoch 21/100
# 200/200 [==============================] - ETA: 0s - loss: 2.2213 - accuracy: 0.7228
# Epoch 21: val_loss did not improve from 0.89852
# 200/200 [==============================] - 35s 172ms/step - loss: 2.2213 - accuracy: 0.7228 - val_loss: 1.3624 - val_accuracy: 0.7359
# Epoch 22/100
# 200/200 [==============================] - ETA: 0s - loss: 2.1433 - accuracy: 0.7162
# Epoch 22: val_loss did not improve from 0.89852
# 200/200 [==============================] - 32s 161ms/step - loss: 2.1433 - accuracy: 0.7162 - val_loss: 1.0361 - val_accuracy: 0.7805
# Epoch 23/100
# 200/200 [==============================] - ETA: 0s - loss: 2.1239 - accuracy: 0.7240
# Epoch 23: val_loss did not improve from 0.89852
# 200/200 [==============================] - 34s 171ms/step - loss: 2.1239 - accuracy: 0.7240 - val_loss: 0.9919 - val_accuracy: 0.8433
# Epoch 24/100
# 200/200 [==============================] - ETA: 0s - loss: 2.0814 - accuracy: 0.7267
# Epoch 24: val_loss did not improve from 0.89852
# 200/200 [==============================] - 32s 161ms/step - loss: 2.0814 - accuracy: 0.7267 - val_loss: 1.0034 - val_accuracy: 0.7772
# Epoch 25/100
# 200/200 [==============================] - ETA: 0s - loss: 2.0085 - accuracy: 0.7231
# Epoch 25: val_loss improved from 0.89852 to 0.77664, saving model to /content/models/eperiment10bis_cut_ft_1_block.h5
# 200/200 [==============================] - 32s 161ms/step - loss: 2.0085 - accuracy: 0.7231 - val_loss: 0.7766 - val_accuracy: 0.8208
# Epoch 26/100
# 200/200 [==============================] - ETA: 0s - loss: 1.9975 - accuracy: 0.7189
# Epoch 26: val_loss did not improve from 0.77664
# 200/200 [==============================] - 32s 159ms/step - loss: 1.9975 - accuracy: 0.7189 - val_loss: 2.0816 - val_accuracy: 0.6356
# Epoch 27/100
# 200/200 [==============================] - ETA: 0s - loss: 1.9254 - accuracy: 0.7247
# Epoch 27: val_loss did not improve from 0.77664
# 200/200 [==============================] - 33s 161ms/step - loss: 1.9254 - accuracy: 0.7247 - val_loss: 1.1544 - val_accuracy: 0.7458
# Epoch 28/100
# 200/200 [==============================] - ETA: 0s - loss: 1.8802 - accuracy: 0.7262
# Epoch 28: val_loss did not improve from 0.77664
# 200/200 [==============================] - 32s 161ms/step - loss: 1.8802 - accuracy: 0.7262 - val_loss: 0.9780 - val_accuracy: 0.7800
# Epoch 29/100
# 200/200 [==============================] - ETA: 0s - loss: 1.7373 - accuracy: 0.7262
# Epoch 29: val_loss did not improve from 0.77664
# 200/200 [==============================] - 35s 173ms/step - loss: 1.7373 - accuracy: 0.7262 - val_loss: 1.1997 - val_accuracy: 0.7322
# Epoch 30/100
# 200/200 [==============================] - ETA: 0s - loss: 1.7907 - accuracy: 0.7311
# Epoch 30: val_loss did not improve from 0.77664
# 200/200 [==============================] - 32s 160ms/step - loss: 1.7907 - accuracy: 0.7311 - val_loss: 0.9449 - val_accuracy: 0.7749

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/eperiment10bis_cut_ft_1_block.h5'))
# Out:
# 67/67 [==============================] - 8s 119ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7096    0.7514    0.7299       696
#            1     0.8761    0.8511    0.8634      1437
#
#     accuracy                         0.8186      2133
#    macro avg     0.7929    0.8013    0.7967      2133
# weighted avg     0.8218    0.8186    0.8198      2133

# %% [markdown]
# #### Experiment 11: last two blocks

# %%
vgg_ft_2_blocks = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment7_cut_feature_extraction_dropout.h5'))

for layer in vgg_ft_2_blocks.get_layer("sequential").layers:
    if layer.name in ('block4_conv3', 'block4_conv1', 'block4_conv2', 'block3_conv3' , 'block3_conv2' , 'block3_conv1'):
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(vgg_ft_2_blocks, learning_rate=1e-5)

for i, layer in enumerate(vgg_ft_2_blocks.get_layer('sequential').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_3  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_3 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  sequential (Sequential)     (None, 14, 14, 512)       7635264
#
#  global_average_pooling2d_1  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 7766849 (29.63 MB)
# Trainable params: 7506689 (28.64 MB)
# Non-trainable params: 260160 (1016.25 KB)
# _________________________________________________________________
# 0 block1_conv1 False
# 1 block1_conv2 False
# 2 block1_pool False
# 3 block2_conv1 False
# 4 block2_conv2 False
# 5 block2_pool False
# 6 block3_conv1 True
# 7 block3_conv2 True
# 8 block3_conv3 True
# 9 block3_pool False
# 10 block4_conv1 True
# 11 block4_conv2 True
# 12 block4_conv3 True
# 13 block4_pool False

# %%
run_model(vgg_ft_2_blocks, 'eperiment11_cut_ft_2_blocks', epochs = 100, patience=5, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4867 - accuracy: 0.7710
# Epoch 1: val_loss improved from inf to 0.42407, saving model to /content/models/eperiment11_cut_ft_2_blocks.h5
# 200/200 [==============================] - 34s 163ms/step - loss: 0.4867 - accuracy: 0.7710 - val_loss: 0.4241 - val_accuracy: 0.7997
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - ETA: 0s - loss: 0.4936 - accuracy: 0.7694
# Epoch 2: val_loss improved from 0.42407 to 0.38286, saving model to /content/models/eperiment11_cut_ft_2_blocks.h5
# 200/200 [==============================] - 33s 166ms/step - loss: 0.4936 - accuracy: 0.7694 - val_loss: 0.3829 - val_accuracy: 0.8382
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4850 - accuracy: 0.7684
# Epoch 3: val_loss did not improve from 0.38286
# 200/200 [==============================] - 32s 159ms/step - loss: 0.4850 - accuracy: 0.7684 - val_loss: 0.3892 - val_accuracy: 0.8311
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4913 - accuracy: 0.7652
# Epoch 4: val_loss did not improve from 0.38286
# 200/200 [==============================] - 32s 161ms/step - loss: 0.4913 - accuracy: 0.7652 - val_loss: 0.4270 - val_accuracy: 0.7960
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5100 - accuracy: 0.7628
# Epoch 5: val_loss did not improve from 0.38286
# 200/200 [==============================] - 32s 161ms/step - loss: 0.5100 - accuracy: 0.7628 - val_loss: 0.4082 - val_accuracy: 0.8119
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5039 - accuracy: 0.7641
# Epoch 6: val_loss improved from 0.38286 to 0.36559, saving model to /content/models/eperiment11_cut_ft_2_blocks.h5
# 200/200 [==============================] - 33s 162ms/step - loss: 0.5039 - accuracy: 0.7641 - val_loss: 0.3656 - val_accuracy: 0.8527
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4989 - accuracy: 0.7677
# Epoch 7: val_loss did not improve from 0.36559
# 200/200 [==============================] - 32s 160ms/step - loss: 0.4989 - accuracy: 0.7677 - val_loss: 0.6500 - val_accuracy: 0.6524
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4980 - accuracy: 0.7659
# Epoch 8: val_loss did not improve from 0.36559
# 200/200 [==============================] - 32s 160ms/step - loss: 0.4980 - accuracy: 0.7659 - val_loss: 0.5839 - val_accuracy: 0.6904
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5152 - accuracy: 0.7606
# Epoch 9: val_loss did not improve from 0.36559
# 200/200 [==============================] - 32s 160ms/step - loss: 0.5152 - accuracy: 0.7606 - val_loss: 0.6383 - val_accuracy: 0.6609
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5218 - accuracy: 0.7602
# Epoch 10: val_loss did not improve from 0.36559
# 200/200 [==============================] - 32s 160ms/step - loss: 0.5218 - accuracy: 0.7602 - val_loss: 0.3882 - val_accuracy: 0.8260
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5133 - accuracy: 0.7638
# Epoch 11: val_loss did not improve from 0.36559
# 200/200 [==============================] - 32s 160ms/step - loss: 0.5133 - accuracy: 0.7638 - val_loss: 0.6749 - val_accuracy: 0.6398

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/eperiment11_cut_ft_2_blocks.h5'))
# Out:
# 67/67 [==============================] - 8s 117ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8251    0.6710    0.7401       696
#            1     0.8539    0.9311    0.8908      1437
#
#     accuracy                         0.8462      2133
#    macro avg     0.8395    0.8010    0.8155      2133
# weighted avg     0.8445    0.8462    0.8416      2133

# %% [markdown]
# #### Experiment 12: last three blocks

# %%
vgg_ft_3_blocks = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment7_cut_feature_extraction_dropout.h5'))

for layer in vgg_ft_3_blocks.get_layer("sequential").layers:
    if layer.name in ('block1_conv2', 'block1_conv1'):
        layer.trainable = False
    else:
        layer.trainable = True

compile_model(vgg_ft_3_blocks, learning_rate=1e-5)

for i, layer in enumerate(vgg_ft_3_blocks.get_layer('sequential').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_3  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_3 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  sequential (Sequential)     (None, 14, 14, 512)       7635264
#
#  global_average_pooling2d_1  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 7766849 (29.63 MB)
# Trainable params: 7728129 (29.48 MB)
# Non-trainable params: 38720 (151.25 KB)
# _________________________________________________________________
# 0 block1_conv1 False
# 1 block1_conv2 False
# 2 block1_pool True
# 3 block2_conv1 True
# 4 block2_conv2 True
# 5 block2_pool True
# 6 block3_conv1 True
# 7 block3_conv2 True
# 8 block3_conv3 True
# 9 block3_pool True
# 10 block4_conv1 True
# 11 block4_conv2 True
# 12 block4_conv3 True
# 13 block4_pool True

# %%
run_model(vgg_ft_3_blocks, 'eperiment12_cut_ft_3_blocks', epochs = 100, patience=5, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4745 - accuracy: 0.7803
# Epoch 1: val_loss improved from inf to 0.38146, saving model to /content/models/eperiment12_cut_ft_3_blocks.h5
# 200/200 [==============================] - 82s 363ms/step - loss: 0.4745 - accuracy: 0.7803 - val_loss: 0.3815 - val_accuracy: 0.8321
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - ETA: 0s - loss: 0.3864 - accuracy: 0.8222
# Epoch 2: val_loss improved from 0.38146 to 0.31240, saving model to /content/models/eperiment12_cut_ft_3_blocks.h5
# 200/200 [==============================] - 67s 334ms/step - loss: 0.3864 - accuracy: 0.8222 - val_loss: 0.3124 - val_accuracy: 0.8762
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3462 - accuracy: 0.8491
# Epoch 3: val_loss did not improve from 0.31240
# 200/200 [==============================] - 69s 345ms/step - loss: 0.3462 - accuracy: 0.8491 - val_loss: 0.3825 - val_accuracy: 0.8250
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3072 - accuracy: 0.8690
# Epoch 4: val_loss did not improve from 0.31240
# 200/200 [==============================] - 68s 337ms/step - loss: 0.3072 - accuracy: 0.8690 - val_loss: 0.3267 - val_accuracy: 0.8574
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2638 - accuracy: 0.8879
# Epoch 5: val_loss improved from 0.31240 to 0.27558, saving model to /content/models/eperiment12_cut_ft_3_blocks.h5
# 200/200 [==============================] - 67s 334ms/step - loss: 0.2638 - accuracy: 0.8879 - val_loss: 0.2756 - val_accuracy: 0.8841
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2368 - accuracy: 0.8998
# Epoch 6: val_loss improved from 0.27558 to 0.22393, saving model to /content/models/eperiment12_cut_ft_3_blocks.h5
# 200/200 [==============================] - 70s 349ms/step - loss: 0.2368 - accuracy: 0.8998 - val_loss: 0.2239 - val_accuracy: 0.9170
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2400 - accuracy: 0.9045
# Epoch 7: val_loss improved from 0.22393 to 0.20529, saving model to /content/models/eperiment12_cut_ft_3_blocks.h5
# 200/200 [==============================] - 68s 337ms/step - loss: 0.2400 - accuracy: 0.9045 - val_loss: 0.2053 - val_accuracy: 0.9203
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2036 - accuracy: 0.9201
# Epoch 8: val_loss did not improve from 0.20529
# 200/200 [==============================] - 67s 336ms/step - loss: 0.2036 - accuracy: 0.9201 - val_loss: 0.2062 - val_accuracy: 0.9174
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1828 - accuracy: 0.9285
# Epoch 9: val_loss improved from 0.20529 to 0.19546, saving model to /content/models/eperiment12_cut_ft_3_blocks.h5
# 200/200 [==============================] - 67s 334ms/step - loss: 0.1828 - accuracy: 0.9285 - val_loss: 0.1955 - val_accuracy: 0.9264
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9350
# Epoch 10: val_loss did not improve from 0.19546
# 200/200 [==============================] - 69s 344ms/step - loss: 0.1694 - accuracy: 0.9350 - val_loss: 0.2084 - val_accuracy: 0.9212
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1493 - accuracy: 0.9414
# Epoch 11: val_loss improved from 0.19546 to 0.18380, saving model to /content/models/eperiment12_cut_ft_3_blocks.h5
# 200/200 [==============================] - 67s 335ms/step - loss: 0.1493 - accuracy: 0.9414 - val_loss: 0.1838 - val_accuracy: 0.9287
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9500
# Epoch 12: val_loss did not improve from 0.18380
# 200/200 [==============================] - 67s 333ms/step - loss: 0.1375 - accuracy: 0.9500 - val_loss: 0.2006 - val_accuracy: 0.9179
# Epoch 13/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1319 - accuracy: 0.9479
# Epoch 13: val_loss did not improve from 0.18380
# 200/200 [==============================] - 67s 333ms/step - loss: 0.1319 - accuracy: 0.9479 - val_loss: 0.2521 - val_accuracy: 0.8963
# Epoch 14/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9539
# Epoch 14: val_loss did not improve from 0.18380
# 200/200 [==============================] - 69s 345ms/step - loss: 0.1164 - accuracy: 0.9539 - val_loss: 0.2217 - val_accuracy: 0.9067
# Epoch 15/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9590
# Epoch 15: val_loss did not improve from 0.18380
# 200/200 [==============================] - 68s 338ms/step - loss: 0.1132 - accuracy: 0.9590 - val_loss: 0.3235 - val_accuracy: 0.8630
# Epoch 16/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9579
# Epoch 16: val_loss improved from 0.18380 to 0.17551, saving model to /content/models/eperiment12_cut_ft_3_blocks.h5
# 200/200 [==============================] - 68s 338ms/step - loss: 0.1122 - accuracy: 0.9579 - val_loss: 0.1755 - val_accuracy: 0.9334
# Epoch 17/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9706
# Epoch 17: val_loss improved from 0.17551 to 0.17087, saving model to /content/models/eperiment12_cut_ft_3_blocks.h5
# 200/200 [==============================] - 68s 338ms/step - loss: 0.0848 - accuracy: 0.9706 - val_loss: 0.1709 - val_accuracy: 0.9362
# Epoch 18/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9701
# Epoch 18: val_loss did not improve from 0.17087
# 200/200 [==============================] - 67s 333ms/step - loss: 0.0831 - accuracy: 0.9701 - val_loss: 0.2443 - val_accuracy: 0.9024
# Epoch 19/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9719
# Epoch 19: val_loss did not improve from 0.17087
# 200/200 [==============================] - 69s 345ms/step - loss: 0.0760 - accuracy: 0.9719 - val_loss: 0.2723 - val_accuracy: 0.8907
# Epoch 20/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9661
# Epoch 20: val_loss did not improve from 0.17087
# 200/200 [==============================] - 67s 334ms/step - loss: 0.0880 - accuracy: 0.9661 - val_loss: 0.1883 - val_accuracy: 0.9339
# Epoch 21/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9789
# Epoch 21: val_loss did not improve from 0.17087
# 200/200 [==============================] - 67s 335ms/step - loss: 0.0624 - accuracy: 0.9789 - val_loss: 0.2811 - val_accuracy: 0.8931
# Epoch 22/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9834
# Epoch 22: val_loss did not improve from 0.17087
# 200/200 [==============================] - 70s 349ms/step - loss: 0.0534 - accuracy: 0.9834 - val_loss: 0.1741 - val_accuracy: 0.9343

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/eperiment12_cut_ft_3_blocks.h5'))
# Out:
# 67/67 [==============================] - 8s 114ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9050    0.8764    0.8905       696
#            1     0.9411    0.9555    0.9482      1437
#
#     accuracy                         0.9297      2133
#    macro avg     0.9231    0.9159    0.9194      2133
# weighted avg     0.9293    0.9297    0.9294      2133

# %% [markdown]
# #### Experiment 12bis: last three blocks RMSProp

# %%
vgg_ft_3_blocks = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment8_cut_feature_extraction_dropout_rms.h5'))

for layer in vgg_ft_3_blocks.get_layer("sequential").layers:
    if layer.name in ('block1_conv2', 'block1_conv1'):
        layer.trainable = False
    else:
        layer.trainable = True

compile_model(vgg_ft_3_blocks, optimizer = "rms", learning_rate=1e-5)

for i, layer in enumerate(vgg_ft_3_blocks.get_layer('sequential').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_4  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_4 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  sequential (Sequential)     (None, 14, 14, 512)       7635264
#
#  global_average_pooling2d_2  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 7766849 (29.63 MB)
# Trainable params: 7728129 (29.48 MB)
# Non-trainable params: 38720 (151.25 KB)
# _________________________________________________________________
# 0 block1_conv1 False
# 1 block1_conv2 False
# 2 block1_pool True
# 3 block2_conv1 True
# 4 block2_conv2 True
# 5 block2_pool True
# 6 block3_conv1 True
# 7 block3_conv2 True
# 8 block3_conv3 True
# 9 block3_pool True
# 10 block4_conv1 True
# 11 block4_conv2 True
# 12 block4_conv3 True
# 13 block4_pool True

# %%
run_model(vgg_ft_3_blocks, 'eperiment12bis_cut_ft_3_blocks', epochs = 100, patience=5, monitor='val_loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-cb70a3a13ddb> in <cell line: 1>()
# ----> 1 run_model(vgg_ft_3_blocks, 'eperiment12bis_cut_ft_3_blocks', epochs = 100, patience=5, monitor='val_loss')
#
# NameError: name 'vgg_ft_3_blocks' is not defined

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/eperiment12bis_cut_ft_3_blocks.h5'))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-df93dadf4212> in <cell line: 1>()
# ----> 1 evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/eperiment12bis_cut_ft_3_blocks.h5'))
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     260
#     261     # Legacy case.
# --> 262     return legacy_sm_saving_lib.load_model(
#     263         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264     )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/legacy/save.py in load_model(filepath, custom_objects, compile, options)
#     232                     if isinstance(filepath_str, str):
#     233                         if not tf.io.gfile.exists(filepath_str):
# --> 234                             raise IOError(
#     235                                 f"No file or directory found at {filepath_str}"
#     236                             )
#
# OSError: No file or directory found at /content/drive/My Drive/Baldi_Cioffo/models/vgg16/eperiment12bis_cut_ft_3_blocks.h5

# %% [markdown]
# #### Experiment 13: all blocks

# %%
vgg_ft_all_blocks = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment7_cut_feature_extraction_dropout.h5'))

for layer in vgg_ft_all_blocks.get_layer("sequential").layers:
    if layer.name in (''):
        layer.trainable = False
    else:
        layer.trainable = True

compile_model(vgg_ft_all_blocks, learning_rate=1e-5)

for i, layer in enumerate(vgg_ft_all_blocks.get_layer('sequential').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_3  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_3 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  sequential (Sequential)     (None, 14, 14, 512)       7635264
#
#  global_average_pooling2d_1  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 7766849 (29.63 MB)
# Trainable params: 7766849 (29.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 0 block1_conv1 True
# 1 block1_conv2 True
# 2 block1_pool True
# 3 block2_conv1 True
# 4 block2_conv2 True
# 5 block2_pool True
# 6 block3_conv1 True
# 7 block3_conv2 True
# 8 block3_conv3 True
# 9 block3_pool True
# 10 block4_conv1 True
# 11 block4_conv2 True
# 12 block4_conv3 True
# 13 block4_pool True

# %%
run_model(vgg_ft_all_blocks, 'eperiment13_cut_ft_all_blocks', epochs = 100, patience=5, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4940 - accuracy: 0.7724
# Epoch 1: val_loss improved from inf to 0.42241, saving model to /content/models/eperiment13_cut_ft_all_blocks.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 140s 566ms/step - loss: 0.4940 - accuracy: 0.7724 - val_loss: 0.4224 - val_accuracy: 0.8011
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4011 - accuracy: 0.8205
# Epoch 2: val_loss improved from 0.42241 to 0.33931, saving model to /content/models/eperiment13_cut_ft_all_blocks.h5
# 200/200 [==============================] - 85s 421ms/step - loss: 0.4011 - accuracy: 0.8205 - val_loss: 0.3393 - val_accuracy: 0.8551
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3481 - accuracy: 0.8462
# Epoch 3: val_loss improved from 0.33931 to 0.28189, saving model to /content/models/eperiment13_cut_ft_all_blocks.h5
# 200/200 [==============================] - 85s 422ms/step - loss: 0.3481 - accuracy: 0.8462 - val_loss: 0.2819 - val_accuracy: 0.8790
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3038 - accuracy: 0.8685
# Epoch 4: val_loss did not improve from 0.28189
# 200/200 [==============================] - 84s 421ms/step - loss: 0.3038 - accuracy: 0.8685 - val_loss: 0.2872 - val_accuracy: 0.8785
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2814 - accuracy: 0.8820
# Epoch 5: val_loss improved from 0.28189 to 0.23587, saving model to /content/models/eperiment13_cut_ft_all_blocks.h5
# 200/200 [==============================] - 85s 423ms/step - loss: 0.2814 - accuracy: 0.8820 - val_loss: 0.2359 - val_accuracy: 0.9029
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2640 - accuracy: 0.8871
# Epoch 6: val_loss did not improve from 0.23587
# 200/200 [==============================] - 84s 420ms/step - loss: 0.2640 - accuracy: 0.8871 - val_loss: 0.2831 - val_accuracy: 0.8776
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2191 - accuracy: 0.9139
# Epoch 7: val_loss did not improve from 0.23587
# 200/200 [==============================] - 84s 420ms/step - loss: 0.2191 - accuracy: 0.9139 - val_loss: 0.2719 - val_accuracy: 0.8856
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2221 - accuracy: 0.9081
# Epoch 8: val_loss did not improve from 0.23587
# 200/200 [==============================] - 83s 415ms/step - loss: 0.2221 - accuracy: 0.9081 - val_loss: 0.3461 - val_accuracy: 0.8438
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9279
# Epoch 9: val_loss improved from 0.23587 to 0.21440, saving model to /content/models/eperiment13_cut_ft_all_blocks.h5
# 200/200 [==============================] - 84s 422ms/step - loss: 0.1821 - accuracy: 0.9279 - val_loss: 0.2144 - val_accuracy: 0.9123
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1647 - accuracy: 0.9365
# Epoch 10: val_loss improved from 0.21440 to 0.19368, saving model to /content/models/eperiment13_cut_ft_all_blocks.h5
# 200/200 [==============================] - 85s 422ms/step - loss: 0.1647 - accuracy: 0.9365 - val_loss: 0.1937 - val_accuracy: 0.9245
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9436
# Epoch 11: val_loss did not improve from 0.19368
# 200/200 [==============================] - 84s 421ms/step - loss: 0.1425 - accuracy: 0.9436 - val_loss: 0.3107 - val_accuracy: 0.8701
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9425
# Epoch 12: val_loss improved from 0.19368 to 0.18433, saving model to /content/models/eperiment13_cut_ft_all_blocks.h5
# 200/200 [==============================] - 87s 434ms/step - loss: 0.1550 - accuracy: 0.9425 - val_loss: 0.1843 - val_accuracy: 0.9278
# Epoch 13/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9533
# Epoch 13: val_loss did not improve from 0.18433
# 200/200 [==============================] - 82s 408ms/step - loss: 0.1231 - accuracy: 0.9533 - val_loss: 0.2020 - val_accuracy: 0.9189
# Epoch 14/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9601
# Epoch 14: val_loss improved from 0.18433 to 0.18180, saving model to /content/models/eperiment13_cut_ft_all_blocks.h5
# 200/200 [==============================] - 83s 415ms/step - loss: 0.1100 - accuracy: 0.9601 - val_loss: 0.1818 - val_accuracy: 0.9268
# Epoch 15/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9661
# Epoch 15: val_loss did not improve from 0.18180
# 200/200 [==============================] - 82s 410ms/step - loss: 0.0923 - accuracy: 0.9661 - val_loss: 0.2298 - val_accuracy: 0.9024
# Epoch 16/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9678
# Epoch 16: val_loss did not improve from 0.18180
# 200/200 [==============================] - 81s 406ms/step - loss: 0.0957 - accuracy: 0.9678 - val_loss: 0.3113 - val_accuracy: 0.8776
# Epoch 17/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1004 - accuracy: 0.9612
# Epoch 17: val_loss did not improve from 0.18180
# 200/200 [==============================] - 83s 412ms/step - loss: 0.1004 - accuracy: 0.9612 - val_loss: 0.1831 - val_accuracy: 0.9301
# Epoch 18/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9769
# Epoch 18: val_loss improved from 0.18180 to 0.18094, saving model to /content/models/eperiment13_cut_ft_all_blocks.h5
# 200/200 [==============================] - 86s 428ms/step - loss: 0.0687 - accuracy: 0.9769 - val_loss: 0.1809 - val_accuracy: 0.9306
# Epoch 19/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9795
# Epoch 19: val_loss did not improve from 0.18094
# 200/200 [==============================] - 83s 415ms/step - loss: 0.0617 - accuracy: 0.9795 - val_loss: 0.1921 - val_accuracy: 0.9245
# Epoch 20/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9808
# Epoch 20: val_loss improved from 0.18094 to 0.17546, saving model to /content/models/eperiment13_cut_ft_all_blocks.h5
# 200/200 [==============================] - 81s 404ms/step - loss: 0.0569 - accuracy: 0.9808 - val_loss: 0.1755 - val_accuracy: 0.9362
# Epoch 21/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0702 - accuracy: 0.9742
# Epoch 21: val_loss did not improve from 0.17546
# 200/200 [==============================] - 82s 409ms/step - loss: 0.0702 - accuracy: 0.9742 - val_loss: 0.1861 - val_accuracy: 0.9296
# Epoch 22/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9917
# Epoch 22: val_loss did not improve from 0.17546
# 200/200 [==============================] - 83s 414ms/step - loss: 0.0356 - accuracy: 0.9917 - val_loss: 0.2014 - val_accuracy: 0.9292
# Epoch 23/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 0.9806
# Epoch 23: val_loss did not improve from 0.17546
# 200/200 [==============================] - 83s 415ms/step - loss: 0.0558 - accuracy: 0.9806 - val_loss: 0.1959 - val_accuracy: 0.9278
# Epoch 24/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9884
# Epoch 24: val_loss did not improve from 0.17546
# 200/200 [==============================] - 84s 417ms/step - loss: 0.0407 - accuracy: 0.9884 - val_loss: 0.2063 - val_accuracy: 0.9259
# Epoch 25/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9906
# Epoch 25: val_loss did not improve from 0.17546
# 200/200 [==============================] - 86s 429ms/step - loss: 0.0319 - accuracy: 0.9906 - val_loss: 0.1905 - val_accuracy: 0.9348

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/eperiment13_cut_ft_all_blocks.h5'))
# Out:
# 67/67 [==============================] - 12s 173ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9174    0.8779    0.8972       696
#            1     0.9421    0.9617    0.9518      1437
#
#     accuracy                         0.9344      2133
#    macro avg     0.9297    0.9198    0.9245      2133
# weighted avg     0.9340    0.9344    0.9340      2133

# %% [markdown]
# ## CLAHE
# Taking the best network on the regular dataset, we evaluate whether or not adding a preprocessing step, i.e., applying CLAHE, improves performance.

# %%
# !unzip -q "/content/drive/My Drive/SplittedDataset_CLAHE.zip" -d "/content"

# %%
DATASET_PATH = "/content/SplittedDataset_CLAHE"
TRAINING_PATH = DATASET_PATH + '/training_set'
TRAINING_ALL_PATH = TRAINING_PATH + '/all'
TRAINING_HEM_PATH = TRAINING_PATH + '/hem'
VALIDATION_PATH = DATASET_PATH + '/validation_set'
TEST_PATH = DATASET_PATH + '/test_set'

# %%
train_dataset = load_training_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
validation_dataset = load_validation_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
test_dataset = load_test_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
# Out:
# Found 6396 files belonging to 2 classes.
# Found 2132 files belonging to 2 classes.
# Found 2133 files belonging to 2 classes.

# %% [markdown]
# ### Experiment 14: Remove Last Block + Fine Tuning of last Three Blocks + CLAHE

# %% [markdown]
# #### Feature Extraction

# %%
model = Sequential()
for layer in conv_base.layers:
  if layer.name in ("block5_conv1"):
    break
  layer.trainable = False
  model.add(layer)

model.summary()
for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
# =================================================================
# Total params: 7635264 (29.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________
# 0 block1_conv1 False
# 1 block1_conv2 False
# 2 block1_pool False
# 3 block2_conv1 False
# 4 block2_conv2 False
# 5 block2_pool False
# 6 block3_conv1 False
# 7 block3_conv2 False
# 8 block3_conv3 False
# 9 block3_pool False
# 10 block4_conv1 False
# 11 block4_conv2 False
# 12 block4_conv3 False
# 13 block4_pool False

# %%
inputs = keras.Input(shape=(224,224,3))
x = keras.applications.vgg16.preprocess_input(inputs)
x = model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
vgg_cut_model_CLAHE = keras.Model(inputs, outputs)
compile_model(vgg_cut_model_CLAHE)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (  (None, 224, 224, 3)       0
#  SlicingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda  (None, 224, 224, 3)       0
#  )
#
#  sequential (Sequential)     (None, 14, 14, 512)       7635264
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 7766849 (29.63 MB)
# Trainable params: 131585 (514.00 KB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %%
run_model(vgg_cut_model_CLAHE, 'experiment14_1_cut_feature_extraction_CLAHE', epochs = 100, patience=5, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 11.8746 - accuracy: 0.6651
# Epoch 1: val_loss improved from inf to 11.43089, saving model to /content/models/experiment14_1_cut_feature_extraction_CLAHE.h5
# 200/200 [==============================] - 31s 149ms/step - loss: 11.8746 - accuracy: 0.6651 - val_loss: 11.4309 - val_accuracy: 0.5047
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - ETA: 0s - loss: 6.6130 - accuracy: 0.6932
# Epoch 2: val_loss improved from 11.43089 to 2.08747, saving model to /content/models/experiment14_1_cut_feature_extraction_CLAHE.h5
# 200/200 [==============================] - 30s 150ms/step - loss: 6.6130 - accuracy: 0.6932 - val_loss: 2.0875 - val_accuracy: 0.8330
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 4.1064 - accuracy: 0.7145
# Epoch 3: val_loss improved from 2.08747 to 1.30044, saving model to /content/models/experiment14_1_cut_feature_extraction_CLAHE.h5
# 200/200 [==============================] - 30s 152ms/step - loss: 4.1064 - accuracy: 0.7145 - val_loss: 1.3004 - val_accuracy: 0.8063
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 2.4425 - accuracy: 0.7183
# Epoch 4: val_loss did not improve from 1.30044
# 200/200 [==============================] - 33s 165ms/step - loss: 2.4425 - accuracy: 0.7183 - val_loss: 2.4509 - val_accuracy: 0.6182
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 1.1730 - accuracy: 0.7464
# Epoch 5: val_loss improved from 1.30044 to 1.00310, saving model to /content/models/experiment14_1_cut_feature_extraction_CLAHE.h5
# 200/200 [==============================] - 31s 152ms/step - loss: 1.1730 - accuracy: 0.7464 - val_loss: 1.0031 - val_accuracy: 0.6562
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6370 - accuracy: 0.7523
# Epoch 6: val_loss improved from 1.00310 to 0.37105, saving model to /content/models/experiment14_1_cut_feature_extraction_CLAHE.h5
# 200/200 [==============================] - 31s 152ms/step - loss: 0.6370 - accuracy: 0.7523 - val_loss: 0.3711 - val_accuracy: 0.8297
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.7794
# Epoch 7: val_loss improved from 0.37105 to 0.35953, saving model to /content/models/experiment14_1_cut_feature_extraction_CLAHE.h5
# 200/200 [==============================] - 31s 151ms/step - loss: 0.4876 - accuracy: 0.7794 - val_loss: 0.3595 - val_accuracy: 0.8410
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4733 - accuracy: 0.7846
# Epoch 8: val_loss did not improve from 0.35953
# 200/200 [==============================] - 31s 153ms/step - loss: 0.4733 - accuracy: 0.7846 - val_loss: 0.4232 - val_accuracy: 0.7941
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4863 - accuracy: 0.7667
# Epoch 9: val_loss did not improve from 0.35953
# 200/200 [==============================] - 31s 153ms/step - loss: 0.4863 - accuracy: 0.7667 - val_loss: 0.3901 - val_accuracy: 0.8189
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4842 - accuracy: 0.7777
# Epoch 10: val_loss did not improve from 0.35953
# 200/200 [==============================] - 33s 165ms/step - loss: 0.4842 - accuracy: 0.7777 - val_loss: 0.3723 - val_accuracy: 0.8321
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4885 - accuracy: 0.7769
# Epoch 11: val_loss did not improve from 0.35953
# 200/200 [==============================] - 31s 152ms/step - loss: 0.4885 - accuracy: 0.7769 - val_loss: 0.3797 - val_accuracy: 0.8293
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4932 - accuracy: 0.7683
# Epoch 12: val_loss did not improve from 0.35953
# 200/200 [==============================] - 31s 153ms/step - loss: 0.4932 - accuracy: 0.7683 - val_loss: 0.5184 - val_accuracy: 0.7462

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment14_1_cut_feature_extraction_CLAHE.h5'))
# Out:
# 67/67 [==============================] - 7s 110ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8179    0.6839    0.7449       696
#            1     0.8582    0.9262    0.8909      1437
#
#     accuracy                         0.8472      2133
#    macro avg     0.8380    0.8051    0.8179      2133
# weighted avg     0.8450    0.8472    0.8433      2133

# %% [markdown]
# #### Fine Tuning

# %%
vgg_ft_3_blocks = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment14_1_cut_feature_extraction_CLAHE.h5'))

for layer in vgg_ft_3_blocks.get_layer("sequential").layers:
    if layer.name in ('block1_conv2', 'block1_conv1'):
        layer.trainable = False
    else:
        layer.trainable = True

compile_model(vgg_ft_3_blocks, learning_rate=1e-5)

for i, layer in enumerate(vgg_ft_3_blocks.get_layer('sequential').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (  (None, 224, 224, 3)       0
#  SlicingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda  (None, 224, 224, 3)       0
#  )
#
#  sequential (Sequential)     (None, 14, 14, 512)       7635264
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 7766849 (29.63 MB)
# Trainable params: 7728129 (29.48 MB)
# Non-trainable params: 38720 (151.25 KB)
# _________________________________________________________________
# 0 block1_conv1 False
# 1 block1_conv2 False
# 2 block1_pool True
# 3 block2_conv1 True
# 4 block2_conv2 True
# 5 block2_pool True
# 6 block3_conv1 True
# 7 block3_conv2 True
# 8 block3_conv3 True
# 9 block3_pool True
# 10 block4_conv1 True
# 11 block4_conv2 True
# 12 block4_conv3 True
# 13 block4_pool True

# %%
run_model(vgg_ft_3_blocks, 'experiment14_2_cut_finetuning_3_blocks_CLAHE', epochs = 100, patience=5, monitor='val_loss')
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4846 - accuracy: 0.7730
# Epoch 1: val_loss improved from inf to 0.43562, saving model to /content/models/experiment14_2_cut_finetuning_3_blocks_CLAHE.h5
# 200/200 [==============================] - 66s 317ms/step - loss: 0.4846 - accuracy: 0.7730 - val_loss: 0.4356 - val_accuracy: 0.7856
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3982 - accuracy: 0.8233
# Epoch 2: val_loss improved from 0.43562 to 0.30978, saving model to /content/models/experiment14_2_cut_finetuning_3_blocks_CLAHE.h5
# 200/200 [==============================] - 65s 323ms/step - loss: 0.3982 - accuracy: 0.8233 - val_loss: 0.3098 - val_accuracy: 0.8677
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3487 - accuracy: 0.8474
# Epoch 3: val_loss did not improve from 0.30978
# 200/200 [==============================] - 64s 320ms/step - loss: 0.3487 - accuracy: 0.8474 - val_loss: 0.3423 - val_accuracy: 0.8644
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3021 - accuracy: 0.8707
# Epoch 4: val_loss improved from 0.30978 to 0.25116, saving model to /content/models/experiment14_2_cut_finetuning_3_blocks_CLAHE.h5
# 200/200 [==============================] - 64s 321ms/step - loss: 0.3021 - accuracy: 0.8707 - val_loss: 0.2512 - val_accuracy: 0.8926
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2728 - accuracy: 0.8812
# Epoch 5: val_loss improved from 0.25116 to 0.22721, saving model to /content/models/experiment14_2_cut_finetuning_3_blocks_CLAHE.h5
# 200/200 [==============================] - 65s 325ms/step - loss: 0.2728 - accuracy: 0.8812 - val_loss: 0.2272 - val_accuracy: 0.9010
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2480 - accuracy: 0.8960
# Epoch 6: val_loss did not improve from 0.22721
# 200/200 [==============================] - 65s 324ms/step - loss: 0.2480 - accuracy: 0.8960 - val_loss: 0.2339 - val_accuracy: 0.9001
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2223 - accuracy: 0.9126
# Epoch 7: val_loss improved from 0.22721 to 0.21555, saving model to /content/models/experiment14_2_cut_finetuning_3_blocks_CLAHE.h5
# 200/200 [==============================] - 65s 323ms/step - loss: 0.2223 - accuracy: 0.9126 - val_loss: 0.2156 - val_accuracy: 0.9099
# Epoch 8/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2047 - accuracy: 0.9160
# Epoch 8: val_loss did not improve from 0.21555
# 200/200 [==============================] - 64s 321ms/step - loss: 0.2047 - accuracy: 0.9160 - val_loss: 0.2223 - val_accuracy: 0.9099
# Epoch 9/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1756 - accuracy: 0.9311
# Epoch 9: val_loss did not improve from 0.21555
# 200/200 [==============================] - 67s 336ms/step - loss: 0.1756 - accuracy: 0.9311 - val_loss: 0.2370 - val_accuracy: 0.9076
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1726 - accuracy: 0.9346
# Epoch 10: val_loss did not improve from 0.21555
# 200/200 [==============================] - 67s 333ms/step - loss: 0.1726 - accuracy: 0.9346 - val_loss: 0.4978 - val_accuracy: 0.7697
# Epoch 11/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9500
# Epoch 11: val_loss improved from 0.21555 to 0.21224, saving model to /content/models/experiment14_2_cut_finetuning_3_blocks_CLAHE.h5
# 200/200 [==============================] - 67s 332ms/step - loss: 0.1399 - accuracy: 0.9500 - val_loss: 0.2122 - val_accuracy: 0.9137
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9554
# Epoch 12: val_loss improved from 0.21224 to 0.19958, saving model to /content/models/experiment14_2_cut_finetuning_3_blocks_CLAHE.h5
# 200/200 [==============================] - 67s 333ms/step - loss: 0.1236 - accuracy: 0.9554 - val_loss: 0.1996 - val_accuracy: 0.9193
# Epoch 13/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9595
# Epoch 13: val_loss did not improve from 0.19958
# 200/200 [==============================] - 67s 332ms/step - loss: 0.1146 - accuracy: 0.9595 - val_loss: 0.2355 - val_accuracy: 0.9085
# Epoch 14/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1087 - accuracy: 0.9597
# Epoch 14: val_loss did not improve from 0.19958
# 200/200 [==============================] - 66s 331ms/step - loss: 0.1087 - accuracy: 0.9597 - val_loss: 0.2041 - val_accuracy: 0.9226
# Epoch 15/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9683
# Epoch 15: val_loss did not improve from 0.19958
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0916 - accuracy: 0.9683 - val_loss: 0.2105 - val_accuracy: 0.9142
# Epoch 16/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9606
# Epoch 16: val_loss did not improve from 0.19958
# 200/200 [==============================] - 67s 335ms/step - loss: 0.1008 - accuracy: 0.9606 - val_loss: 0.2013 - val_accuracy: 0.9235
# Epoch 17/100
# 200/200 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9667
# Epoch 17: val_loss did not improve from 0.19958
# 200/200 [==============================] - 65s 322ms/step - loss: 0.0885 - accuracy: 0.9667 - val_loss: 0.2783 - val_accuracy: 0.8973

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment14_2_cut_finetuning_3_blocks_CLAHE.h5'))
# Out:
# 67/67 [==============================] - 8s 111ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9441    0.8247    0.8804       696
#            1     0.9200    0.9763    0.9473      1437
#
#     accuracy                         0.9269      2133
#    macro avg     0.9320    0.9005    0.9139      2133
# weighted avg     0.9279    0.9269    0.9255      2133

# %% [markdown]
# As shown above, no improvement can be seen with the application of CLAHE. Perhaps all experiments should be repeated from scratch to find the best combination for the images that have been transformed in this way.
