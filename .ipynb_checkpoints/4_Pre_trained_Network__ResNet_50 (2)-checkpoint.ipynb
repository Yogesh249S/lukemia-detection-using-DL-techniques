# %% [markdown]
# # Solve the problem leveraging ResNet-50 architecture
# In this notebook, we will use the ResNet-50 architecture for our classification problem.
#
# First, we'll try a simple **feature extraction**. Since the architecture was trained on a different dataset, we do not expect very good performance, but we can use these results as a baseline for the next step: **fine-tuning**.

# %% [markdown]
# ## Import Libraries
# First of all, let's import all the libraries we will need later.

# %%
from google.colab import drive
import os
import shutil
import numpy as np
import random as rn
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from keras.models import Model
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Load dataset from Google Drive
# The dataset is stored in Google Drive in a zip file, we unzip it locally for better performance.

# %%
drive.mount('/content/drive', force_remount=True)
# !unzip -q "/content/drive/My Drive/SplittedDataset.zip" -d "/content"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Set Parameters

# %%
DATASET_PATH = "/content/SplittedDataset"
TRAINING_PATH = DATASET_PATH + '/training_set'
TRAINING_ALL_PATH = TRAINING_PATH + '/all'
TRAINING_HEM_PATH = TRAINING_PATH + '/hem'
VALIDATION_PATH = DATASET_PATH + '/validation_set'
TEST_PATH = DATASET_PATH + '/test_set'

LOCAL_MODELS_FOLDER = "/content/models"
if not os.path.exists(LOCAL_MODELS_FOLDER):
  os.makedirs(LOCAL_MODELS_FOLDER)
GLOBAL_MODELS_FOLDER = "/content/drive/My Drive/Baldi_Cioffo/models/resnet-50"
if not os.path.exists(GLOBAL_MODELS_FOLDER):
  os.makedirs(GLOBAL_MODELS_FOLDER)

# Default values to load the dataset
BATCH_SIZE = 32
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224

# %% [markdown]
# ## Utility Functions

# %%
def set_seed ():
  '''
  set_seed is used to obtain reproducible results using keras during the development phase
  '''
  seed = 24
  # The below is necessary for reproducible results of certain Python hash-based operations.
  os.environ["PYTHONHASHSEED"]="0"
  # The below is necessary for starting Numpy generated random numbers in a well-defined initial state.
  np.random.seed(seed)
  # The below is necessary for starting core Python generated random numbers in a well-defined state.
  rn.seed(seed)
  # The below tf.random.set_seed will make random number generation in TensorFlow have a well-defined initial state.
  tf.random.set_seed(seed)

def show_training_and_validation_performance(history):
  '''
  show_training_and_validation_performance is used to plot the performances during the training phase
  :param history: object in which are recorded all the events
  '''
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'bo', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

def load_training_set (image_height, image_width, batch_size):
  '''
  load_training_set loads the training set from the "training_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return: the training set
  '''
  return image_dataset_from_directory(
    TRAINING_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def load_validation_set (image_height, image_width, batch_size):
  '''
  load_validation_set loads the validation set from the "validation_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return: the validation set
  '''
  return image_dataset_from_directory(
    VALIDATION_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def load_test_set (image_height, image_width, batch_size):
  '''
  load_test_set loads the test set from the "test_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return: the test set
  '''
  return image_dataset_from_directory(
    TEST_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    shuffle = False,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def compile_model (model, optimizer='adam', learning_rate = 0.001):
  '''
  compile_model is used to compile the current model
  :param model: model to compile
  :param optimizer: optimizer to be used
  :param learning_rate: learning rate parameter for the optimizer
  '''
  if optimizer == 'adam':
    model.compile(loss="binary_crossentropy",
      optimizer=optimizers.Adam(learning_rate=learning_rate),
      metrics=["accuracy"])
  elif optimizer == 'rmsprop':
    model.compile(loss="binary_crossentropy",
                  optimizer = optimizers.RMSprop(learning_rate=learning_rate),
                  metrics=['accuracy'])
  model.summary()

def run_model (model, model_name, epochs = 20, patience=5, monitor='val_loss'):
  '''
  run_model is used to run the current mode
  :param model: model to run
  :param model_name: name given to save the model
  :param epochs: how many epochs to do
  :param patience: patience value for Early Stopping
  :param monitor: what to monitor for Early Stopping and Model Checkpoint
  '''
  # local save path for the models
  save_path = LOCAL_MODELS_FOLDER + '/' + model_name + '.h5'
  callbacks_list = [
                  keras.callbacks.EarlyStopping(monitor=monitor, patience=patience),
                  keras.callbacks.ModelCheckpoint(
                      filepath = save_path,
                      monitor=monitor,
                      verbose=1,
                      save_best_only=True)
                  ]
  history = model.fit(train_dataset,
                    epochs=epochs,
                    validation_data=validation_dataset,
                    callbacks=callbacks_list)
  # save on Drive only the best model
  shutil.copy(save_path, GLOBAL_MODELS_FOLDER + '/' + model_name + '.h5')
  show_training_and_validation_performance(history)

def evaluate_model (model):
  '''
  evaluate_model is used to plot some statistics about the performance on the test set
  :param model: model to consider
  '''
  y_score = model.predict(test_dataset)
  y_pred = np.rint(y_score) # to have 0 or 1
  y_true = tf.concat([labels_batch for data_batch, labels_batch in test_dataset], axis = 0)
  print("Classification report: ")
  print(metrics.classification_report(y_true,y_pred,digits = 4))
  metrics.ConfusionMatrixDisplay.from_predictions(y_true, y_pred)

  # ROC curve
  fpr,tpr,th = metrics.roc_curve(y_true,y_score)
  roc_auc = metrics.roc_auc_score(y_true,y_score)

  plt.figure()
  plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
  plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.0])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('ROC curve')
  plt.legend(loc="lower right")
  plt.show()

# %% [markdown]
# ## Load Dataset
# The dataset, properly preprocessed, is now located in the local machine.

# %%
set_seed()

# %%
train_dataset = load_training_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
validation_dataset = load_validation_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
test_dataset = load_test_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
# Out:
# Found 6396 files belonging to 2 classes.
# Found 2132 files belonging to 2 classes.
# Found 2133 files belonging to 2 classes.

# %% [markdown]
# ## Feature extraction
# Firstly, we use the pretrained network to extract feature and we define our classifiers to classify the images.

# %%
conv_base = keras.applications.resnet.ResNet50(include_top = False, weights='imagenet', input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 56, 56, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 56, 56, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 56, 56, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 28, 28, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 28, 28, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 28, 28, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 28, 28, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 7, 7, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 23587712 (89.98 MB)
# Trainable params: 23534592 (89.78 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
conv_base.trainable = False

# %% [markdown]
# ### Experiment 1: one dense layer with 64 neurons
# In this first experiment we try a simple configuration with a single dense layer before the output layer.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu') (x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model1 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (  (None, 224, 224, 3)       0
#  SlicingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda  (None, 224, 224, 3)       0
#  )
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 64)                6422592
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 30010369 (114.48 MB)
# Trainable params: 6422657 (24.50 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
run_model(model1, 'experiment1_feature_extraction', epochs = 30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 2.7361 - accuracy: 0.6973
# Epoch 1: val_loss improved from inf to 1.77803, saving model to /content/models/experiment1_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 40s 157ms/step - loss: 2.7361 - accuracy: 0.6973 - val_loss: 1.7780 - val_accuracy: 0.7186
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 1.2040 - accuracy: 0.8008
# Epoch 2: val_loss did not improve from 1.77803
# 200/200 [==============================] - 27s 133ms/step - loss: 1.2040 - accuracy: 0.8008 - val_loss: 2.0805 - val_accuracy: 0.7050
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.5530 - accuracy: 0.8787
# Epoch 3: val_loss improved from 1.77803 to 1.08997, saving model to /content/models/experiment1_feature_extraction.h5
# 200/200 [==============================] - 32s 158ms/step - loss: 0.5530 - accuracy: 0.8787 - val_loss: 1.0900 - val_accuracy: 0.7763
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1965 - accuracy: 0.9348
# Epoch 4: val_loss improved from 1.08997 to 0.97265, saving model to /content/models/experiment1_feature_extraction.h5
# 200/200 [==============================] - 28s 137ms/step - loss: 0.1965 - accuracy: 0.9348 - val_loss: 0.9726 - val_accuracy: 0.7922
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1734 - accuracy: 0.9409
# Epoch 5: val_loss improved from 0.97265 to 0.83942, saving model to /content/models/experiment1_feature_extraction.h5
# 200/200 [==============================] - 28s 137ms/step - loss: 0.1734 - accuracy: 0.9409 - val_loss: 0.8394 - val_accuracy: 0.8204
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9581
# Epoch 6: val_loss did not improve from 0.83942
# 200/200 [==============================] - 27s 136ms/step - loss: 0.1210 - accuracy: 0.9581 - val_loss: 1.0904 - val_accuracy: 0.7946
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9637
# Epoch 7: val_loss did not improve from 0.83942
# 200/200 [==============================] - 27s 136ms/step - loss: 0.1071 - accuracy: 0.9637 - val_loss: 1.8663 - val_accuracy: 0.6928
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1992 - accuracy: 0.9364
# Epoch 8: val_loss did not improve from 0.83942
# 200/200 [==============================] - 27s 135ms/step - loss: 0.1992 - accuracy: 0.9364 - val_loss: 1.6514 - val_accuracy: 0.7298
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9653
# Epoch 9: val_loss did not improve from 0.83942
# 200/200 [==============================] - 28s 138ms/step - loss: 0.1082 - accuracy: 0.9653 - val_loss: 1.3146 - val_accuracy: 0.7749
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2952 - accuracy: 0.9334
# Epoch 10: val_loss did not improve from 0.83942
# 200/200 [==============================] - 27s 134ms/step - loss: 0.2952 - accuracy: 0.9334 - val_loss: 1.9027 - val_accuracy: 0.7167

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment1_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 9s 120ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6905    0.7759    0.7307       696
#            1     0.8845    0.8316    0.8572      1437
#
#     accuracy                         0.8134      2133
#    macro avg     0.7875    0.8037    0.7940      2133
# weighted avg     0.8212    0.8134    0.8160      2133

# %% [markdown]
# ### Experiment 2: one dense layer with 32 neurons
# We tried to lower the number of neurons, to fight overfitting

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.Flatten()(x)
x = layers.Dense(32, activation='relu') (x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model2 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model2)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_1  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_1 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  dense_2 (Dense)             (None, 32)                3211296
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 26799041 (102.23 MB)
# Trainable params: 3211329 (12.25 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
run_model(model2, 'experiment2_feature_extraction', epochs = 30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 2.0274 - accuracy: 0.6967
# Epoch 1: val_loss improved from inf to 1.24944, saving model to /content/models/experiment2_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 33s 146ms/step - loss: 2.0274 - accuracy: 0.6967 - val_loss: 1.2494 - val_accuracy: 0.6637
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.6007 - accuracy: 0.8193
# Epoch 2: val_loss improved from 1.24944 to 0.61822, saving model to /content/models/experiment2_feature_extraction.h5
# 200/200 [==============================] - 28s 139ms/step - loss: 0.6007 - accuracy: 0.8193 - val_loss: 0.6182 - val_accuracy: 0.8161
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3326 - accuracy: 0.8831
# Epoch 3: val_loss did not improve from 0.61822
# 200/200 [==============================] - 27s 134ms/step - loss: 0.3326 - accuracy: 0.8831 - val_loss: 0.6231 - val_accuracy: 0.8321
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1687 - accuracy: 0.9357
# Epoch 4: val_loss did not improve from 0.61822
# 200/200 [==============================] - 27s 136ms/step - loss: 0.1687 - accuracy: 0.9357 - val_loss: 1.0002 - val_accuracy: 0.7373
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9679
# Epoch 5: val_loss improved from 0.61822 to 0.60809, saving model to /content/models/experiment2_feature_extraction.h5
# 200/200 [==============================] - 27s 136ms/step - loss: 0.0841 - accuracy: 0.9679 - val_loss: 0.6081 - val_accuracy: 0.8288
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9853
# Epoch 6: val_loss did not improve from 0.60809
# 200/200 [==============================] - 27s 135ms/step - loss: 0.0430 - accuracy: 0.9853 - val_loss: 0.6596 - val_accuracy: 0.8110
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9916
# Epoch 7: val_loss improved from 0.60809 to 0.55893, saving model to /content/models/experiment2_feature_extraction.h5
# 200/200 [==============================] - 28s 138ms/step - loss: 0.0313 - accuracy: 0.9916 - val_loss: 0.5589 - val_accuracy: 0.8410
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9875
# Epoch 8: val_loss did not improve from 0.55893
# 200/200 [==============================] - 27s 134ms/step - loss: 0.0368 - accuracy: 0.9875 - val_loss: 1.6924 - val_accuracy: 0.6313
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2750 - accuracy: 0.9143
# Epoch 9: val_loss did not improve from 0.55893
# 200/200 [==============================] - 27s 134ms/step - loss: 0.2750 - accuracy: 0.9143 - val_loss: 1.3204 - val_accuracy: 0.7566
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2171 - accuracy: 0.9353
# Epoch 10: val_loss did not improve from 0.55893
# 200/200 [==============================] - 31s 155ms/step - loss: 0.2171 - accuracy: 0.9353 - val_loss: 0.9470 - val_accuracy: 0.8053
# Epoch 11/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1463 - accuracy: 0.9575
# Epoch 11: val_loss did not improve from 0.55893
# 200/200 [==============================] - 27s 134ms/step - loss: 0.1463 - accuracy: 0.9575 - val_loss: 0.8865 - val_accuracy: 0.8175
# Epoch 12/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0685 - accuracy: 0.9751
# Epoch 12: val_loss did not improve from 0.55893
# 200/200 [==============================] - 28s 137ms/step - loss: 0.0685 - accuracy: 0.9751 - val_loss: 0.8929 - val_accuracy: 0.8114

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment2_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 8s 94ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7402    0.7859    0.7624       696
#            1     0.8931    0.8664    0.8795      1437
#
#     accuracy                         0.8401      2133
#    macro avg     0.8167    0.8262    0.8210      2133
# weighted avg     0.8432    0.8401    0.8413      2133

# %% [markdown]
# ### Experiment 3: one dense layer with 64 neurons and dropout
# Lowering the capacity of the networks leads us to underfitting, we could try to use Dropout instead.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu') (x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model3 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model3)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_2  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_2 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_2 (Flatten)         (None, 100352)            0
#
#  dense_4 (Dense)             (None, 64)                6422592
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 30010369 (114.48 MB)
# Trainable params: 6422657 (24.50 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
run_model(model3, 'experiment3_feature_extraction', epochs = 50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 1.1223 - accuracy: 0.6551
# Epoch 1: val_loss improved from inf to 0.55918, saving model to /content/models/experiment3_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 34s 144ms/step - loss: 1.1223 - accuracy: 0.6551 - val_loss: 0.5592 - val_accuracy: 0.7636
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5981 - accuracy: 0.7153
# Epoch 2: val_loss improved from 0.55918 to 0.51483, saving model to /content/models/experiment3_feature_extraction.h5
# 200/200 [==============================] - 28s 137ms/step - loss: 0.5981 - accuracy: 0.7153 - val_loss: 0.5148 - val_accuracy: 0.7908
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5600 - accuracy: 0.7325
# Epoch 3: val_loss did not improve from 0.51483
# 200/200 [==============================] - 27s 136ms/step - loss: 0.5600 - accuracy: 0.7325 - val_loss: 0.5858 - val_accuracy: 0.6646
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5308 - accuracy: 0.7572
# Epoch 4: val_loss improved from 0.51483 to 0.45455, saving model to /content/models/experiment3_feature_extraction.h5
# 200/200 [==============================] - 28s 139ms/step - loss: 0.5308 - accuracy: 0.7572 - val_loss: 0.4545 - val_accuracy: 0.8114
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4789 - accuracy: 0.7905
# Epoch 5: val_loss improved from 0.45455 to 0.44278, saving model to /content/models/experiment3_feature_extraction.h5
# 200/200 [==============================] - 28s 139ms/step - loss: 0.4789 - accuracy: 0.7905 - val_loss: 0.4428 - val_accuracy: 0.8241
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4786 - accuracy: 0.7856
# Epoch 6: val_loss improved from 0.44278 to 0.43160, saving model to /content/models/experiment3_feature_extraction.h5
# 200/200 [==============================] - 28s 140ms/step - loss: 0.4786 - accuracy: 0.7856 - val_loss: 0.4316 - val_accuracy: 0.8241
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4137 - accuracy: 0.8286
# Epoch 7: val_loss did not improve from 0.43160
# 200/200 [==============================] - 27s 136ms/step - loss: 0.4137 - accuracy: 0.8286 - val_loss: 0.4338 - val_accuracy: 0.8358
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3921 - accuracy: 0.8386
# Epoch 8: val_loss did not improve from 0.43160
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3921 - accuracy: 0.8386 - val_loss: 0.4471 - val_accuracy: 0.7941
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3877 - accuracy: 0.8347
# Epoch 9: val_loss did not improve from 0.43160
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3877 - accuracy: 0.8347 - val_loss: 0.4502 - val_accuracy: 0.8011
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3677 - accuracy: 0.8465
# Epoch 10: val_loss did not improve from 0.43160
# 200/200 [==============================] - 28s 137ms/step - loss: 0.3677 - accuracy: 0.8465 - val_loss: 0.4583 - val_accuracy: 0.7917
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3419 - accuracy: 0.8632
# Epoch 11: val_loss did not improve from 0.43160
# 200/200 [==============================] - 27s 133ms/step - loss: 0.3419 - accuracy: 0.8632 - val_loss: 0.4771 - val_accuracy: 0.7861

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment3_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 7s 98ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7033    0.7457    0.7238       696
#            1     0.8731    0.8476    0.8602      1437
#
#     accuracy                         0.8143      2133
#    macro avg     0.7882    0.7966    0.7920      2133
# weighted avg     0.8177    0.8143    0.8157      2133

# %% [markdown]
# ### Experiment 4: global average pooling
# Try GlobalAveragePooling instead of fully connected layers, to lower the number of parameters.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.GlobalAveragePooling2D() (x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model4 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model4)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_3  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_3 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 23589761 (89.99 MB)
# Trainable params: 2049 (8.00 KB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
run_model(model4, "experiment4_feature_extraction", epochs=20)
# Out:
# Epoch 1/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5671 - accuracy: 0.7093
# Epoch 1: val_loss improved from inf to 0.52152, saving model to /content/models/experiment4_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 32s 143ms/step - loss: 0.5671 - accuracy: 0.7093 - val_loss: 0.5215 - val_accuracy: 0.7505
# Epoch 2/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4984 - accuracy: 0.7628
# Epoch 2: val_loss improved from 0.52152 to 0.49407, saving model to /content/models/experiment4_feature_extraction.h5
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4984 - accuracy: 0.7628 - val_loss: 0.4941 - val_accuracy: 0.7692
# Epoch 3/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4719 - accuracy: 0.7774
# Epoch 3: val_loss improved from 0.49407 to 0.45501, saving model to /content/models/experiment4_feature_extraction.h5
# 200/200 [==============================] - 27s 134ms/step - loss: 0.4719 - accuracy: 0.7774 - val_loss: 0.4550 - val_accuracy: 0.7941
# Epoch 4/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4568 - accuracy: 0.7899
# Epoch 4: val_loss did not improve from 0.45501
# 200/200 [==============================] - 31s 151ms/step - loss: 0.4568 - accuracy: 0.7899 - val_loss: 0.4881 - val_accuracy: 0.7735
# Epoch 5/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4488 - accuracy: 0.7921
# Epoch 5: val_loss improved from 0.45501 to 0.40038, saving model to /content/models/experiment4_feature_extraction.h5
# 200/200 [==============================] - 28s 137ms/step - loss: 0.4488 - accuracy: 0.7921 - val_loss: 0.4004 - val_accuracy: 0.8232
# Epoch 6/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4375 - accuracy: 0.7999
# Epoch 6: val_loss did not improve from 0.40038
# 200/200 [==============================] - 27s 133ms/step - loss: 0.4375 - accuracy: 0.7999 - val_loss: 0.4038 - val_accuracy: 0.8307
# Epoch 7/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4311 - accuracy: 0.8025
# Epoch 7: val_loss did not improve from 0.40038
# 200/200 [==============================] - 27s 132ms/step - loss: 0.4311 - accuracy: 0.8025 - val_loss: 0.4053 - val_accuracy: 0.8316
# Epoch 8/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4326 - accuracy: 0.8007
# Epoch 8: val_loss improved from 0.40038 to 0.39682, saving model to /content/models/experiment4_feature_extraction.h5
# 200/200 [==============================] - 27s 136ms/step - loss: 0.4326 - accuracy: 0.8007 - val_loss: 0.3968 - val_accuracy: 0.8335
# Epoch 9/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4182 - accuracy: 0.8066
# Epoch 9: val_loss did not improve from 0.39682
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4182 - accuracy: 0.8066 - val_loss: 0.4578 - val_accuracy: 0.7922
# Epoch 10/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4196 - accuracy: 0.8083
# Epoch 10: val_loss did not improve from 0.39682
# 200/200 [==============================] - 27s 136ms/step - loss: 0.4196 - accuracy: 0.8083 - val_loss: 0.4393 - val_accuracy: 0.8002
# Epoch 11/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4081 - accuracy: 0.8122
# Epoch 11: val_loss did not improve from 0.39682
# 200/200 [==============================] - 27s 133ms/step - loss: 0.4081 - accuracy: 0.8122 - val_loss: 0.4132 - val_accuracy: 0.8194
# Epoch 12/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4023 - accuracy: 0.8158
# Epoch 12: val_loss did not improve from 0.39682
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4023 - accuracy: 0.8158 - val_loss: 0.4137 - val_accuracy: 0.8166
# Epoch 13/20
# 200/200 [==============================] - ETA: 0s - loss: 0.3993 - accuracy: 0.8216
# Epoch 13: val_loss did not improve from 0.39682
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3993 - accuracy: 0.8216 - val_loss: 0.4016 - val_accuracy: 0.8260

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment4_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 8s 95ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7120    0.7672    0.7386       696
#            1     0.8829    0.8497    0.8660      1437
#
#     accuracy                         0.8228      2133
#    macro avg     0.7974    0.8085    0.8023      2133
# weighted avg     0.8271    0.8228    0.8244      2133

# %% [markdown]
# ### Experiment 5: global average pooling and two dense layers

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model5 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model5, optimizer='rmsprop')
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_4  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_4 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_7 (Dense)             (None, 512)               1049088
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  dense_9 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 24899969 (94.99 MB)
# Trainable params: 1312257 (5.01 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
run_model(model5, 'Experiment5_feature_extraction', epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.6634 - accuracy: 0.6912
# Epoch 1: val_loss improved from inf to 0.56116, saving model to /content/models/Experiment5_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 33s 140ms/step - loss: 0.6634 - accuracy: 0.6912 - val_loss: 0.5612 - val_accuracy: 0.7584
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.7497
# Epoch 2: val_loss improved from 0.56116 to 0.42688, saving model to /content/models/Experiment5_feature_extraction.h5
# 200/200 [==============================] - 28s 140ms/step - loss: 0.5156 - accuracy: 0.7497 - val_loss: 0.4269 - val_accuracy: 0.8058
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4781 - accuracy: 0.7717
# Epoch 3: val_loss did not improve from 0.42688
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4781 - accuracy: 0.7717 - val_loss: 0.4575 - val_accuracy: 0.8311
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.7808
# Epoch 4: val_loss improved from 0.42688 to 0.39769, saving model to /content/models/Experiment5_feature_extraction.h5
# 200/200 [==============================] - 28s 137ms/step - loss: 0.4622 - accuracy: 0.7808 - val_loss: 0.3977 - val_accuracy: 0.8302
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4475 - accuracy: 0.7908
# Epoch 5: val_loss improved from 0.39769 to 0.39540, saving model to /content/models/Experiment5_feature_extraction.h5
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4475 - accuracy: 0.7908 - val_loss: 0.3954 - val_accuracy: 0.8316
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4271 - accuracy: 0.8011
# Epoch 6: val_loss did not improve from 0.39540
# 200/200 [==============================] - 27s 135ms/step - loss: 0.4271 - accuracy: 0.8011 - val_loss: 0.5779 - val_accuracy: 0.7598
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4129 - accuracy: 0.8080
# Epoch 7: val_loss improved from 0.39540 to 0.37141, saving model to /content/models/Experiment5_feature_extraction.h5
# 200/200 [==============================] - 28s 139ms/step - loss: 0.4129 - accuracy: 0.8080 - val_loss: 0.3714 - val_accuracy: 0.8485
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4015 - accuracy: 0.8116
# Epoch 8: val_loss did not improve from 0.37141
# 200/200 [==============================] - 31s 154ms/step - loss: 0.4015 - accuracy: 0.8116 - val_loss: 0.3798 - val_accuracy: 0.8429
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3890 - accuracy: 0.8175
# Epoch 9: val_loss improved from 0.37141 to 0.35145, saving model to /content/models/Experiment5_feature_extraction.h5
# 200/200 [==============================] - 28s 137ms/step - loss: 0.3890 - accuracy: 0.8175 - val_loss: 0.3514 - val_accuracy: 0.8560
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3701 - accuracy: 0.8301
# Epoch 10: val_loss did not improve from 0.35145
# 200/200 [==============================] - 28s 138ms/step - loss: 0.3701 - accuracy: 0.8301 - val_loss: 0.3883 - val_accuracy: 0.8349
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3647 - accuracy: 0.8352
# Epoch 11: val_loss did not improve from 0.35145
# 200/200 [==============================] - 27s 136ms/step - loss: 0.3647 - accuracy: 0.8352 - val_loss: 0.4064 - val_accuracy: 0.8222
# Epoch 12/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3520 - accuracy: 0.8426
# Epoch 12: val_loss improved from 0.35145 to 0.34258, saving model to /content/models/Experiment5_feature_extraction.h5
# 200/200 [==============================] - 27s 137ms/step - loss: 0.3520 - accuracy: 0.8426 - val_loss: 0.3426 - val_accuracy: 0.8588
# Epoch 13/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3348 - accuracy: 0.8468
# Epoch 13: val_loss did not improve from 0.34258
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3348 - accuracy: 0.8468 - val_loss: 0.4668 - val_accuracy: 0.8518
# Epoch 14/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.8529
# Epoch 14: val_loss did not improve from 0.34258
# 200/200 [==============================] - 27s 136ms/step - loss: 0.3266 - accuracy: 0.8529 - val_loss: 0.3592 - val_accuracy: 0.8490
# Epoch 15/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3153 - accuracy: 0.8558
# Epoch 15: val_loss did not improve from 0.34258
# 200/200 [==============================] - 27s 136ms/step - loss: 0.3153 - accuracy: 0.8558 - val_loss: 0.3910 - val_accuracy: 0.8471
# Epoch 16/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3061 - accuracy: 0.8630
# Epoch 16: val_loss did not improve from 0.34258
# 200/200 [==============================] - 27s 136ms/step - loss: 0.3061 - accuracy: 0.8630 - val_loss: 0.4209 - val_accuracy: 0.8401
# Epoch 17/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.8679
# Epoch 17: val_loss did not improve from 0.34258
# 200/200 [==============================] - 27s 135ms/step - loss: 0.3034 - accuracy: 0.8679 - val_loss: 0.4085 - val_accuracy: 0.8401

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 7s 98ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8215    0.7471    0.7825       696
#            1     0.8827    0.9214    0.9016      1437
#
#     accuracy                         0.8645      2133
#    macro avg     0.8521    0.8342    0.8421      2133
# weighted avg     0.8627    0.8645    0.8628      2133

# %% [markdown]
# ## Fine-tuning

# %% [markdown]
# ### Experiment 1: one dense layer

# %%
model1 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment1_feature_extraction.h5')

set_trainable = False
for layer in model1.get_layer('resnet50').layers:
    if layer.name == 'conv5_block3_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(model1, learning_rate=1e-5)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (  (None, 224, 224, 3)       0
#  SlicingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda  (None, 224, 224, 3)       0
#  )
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 64)                6422592
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 30010369 (114.48 MB)
# Trainable params: 10888321 (41.54 MB)
# Non-trainable params: 19122048 (72.94 MB)
# _________________________________________________________________

# %%
run_model(model1, "experiment1_fine_tuning", epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.2456 - accuracy: 0.9295
# Epoch 1: val_loss improved from inf to 1.13324, saving model to /content/models/experiment1_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 39s 160ms/step - loss: 0.2456 - accuracy: 0.9295 - val_loss: 1.1332 - val_accuracy: 0.8016
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9826
# Epoch 2: val_loss did not improve from 1.13324
# 200/200 [==============================] - 30s 148ms/step - loss: 0.0511 - accuracy: 0.9826 - val_loss: 1.1827 - val_accuracy: 0.7988
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9953
# Epoch 3: val_loss did not improve from 1.13324
# 200/200 [==============================] - 29s 147ms/step - loss: 0.0185 - accuracy: 0.9953 - val_loss: 1.1706 - val_accuracy: 0.8044
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9995
# Epoch 4: val_loss did not improve from 1.13324
# 200/200 [==============================] - 33s 166ms/step - loss: 0.0113 - accuracy: 0.9995 - val_loss: 1.1587 - val_accuracy: 0.8035
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9997
# Epoch 5: val_loss did not improve from 1.13324
# 200/200 [==============================] - 30s 149ms/step - loss: 0.0076 - accuracy: 0.9997 - val_loss: 1.1518 - val_accuracy: 0.8044
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9998
# Epoch 6: val_loss improved from 1.13324 to 1.12855, saving model to /content/models/experiment1_fine_tuning.h5
# 200/200 [==============================] - 30s 151ms/step - loss: 0.0057 - accuracy: 0.9998 - val_loss: 1.1285 - val_accuracy: 0.8082
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 7: val_loss did not improve from 1.12855
# 200/200 [==============================] - 30s 149ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.1598 - val_accuracy: 0.8025
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 8: val_loss did not improve from 1.12855
# 200/200 [==============================] - 30s 147ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.1598 - val_accuracy: 0.8049
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 9: val_loss did not improve from 1.12855
# 200/200 [==============================] - 30s 149ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.1296 - val_accuracy: 0.8100
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 10: val_loss did not improve from 1.12855
# 200/200 [==============================] - 30s 148ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1587 - val_accuracy: 0.8039
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 11: val_loss did not improve from 1.12855
# 200/200 [==============================] - 30s 148ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.1456 - val_accuracy: 0.8082

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment1_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 7s 94ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6698    0.8075    0.7322       696
#            1     0.8964    0.8072    0.8495      1437
#
#     accuracy                         0.8073      2133
#    macro avg     0.7831    0.8074    0.7909      2133
# weighted avg     0.8225    0.8073    0.8112      2133

# %% [markdown]
# ### Experiment 2: global average pooling

# %%
model4 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment4_feature_extraction.h5')

set_trainable = False
# fine-tune the last three elements
for layer in model4.get_layer('resnet50').layers:
    if layer.name == 'conv5_block3_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(model4, learning_rate=1e-5)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_3  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_3 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 23589761 (89.99 MB)
# Trainable params: 4467713 (17.04 MB)
# Non-trainable params: 19122048 (72.94 MB)
# _________________________________________________________________

# %%
run_model(model4, "Experiment2_fine_tuning")
# Out:
# Epoch 1/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4228 - accuracy: 0.8061
# Epoch 1: val_loss improved from inf to 0.42084, saving model to /content/models/Experiment2_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 37s 159ms/step - loss: 0.4228 - accuracy: 0.8061 - val_loss: 0.4208 - val_accuracy: 0.8105
# Epoch 2/20
# 200/200 [==============================] - ETA: 0s - loss: 0.3647 - accuracy: 0.8463
# Epoch 2: val_loss improved from 0.42084 to 0.40705, saving model to /content/models/Experiment2_fine_tuning.h5
# 200/200 [==============================] - 30s 149ms/step - loss: 0.3647 - accuracy: 0.8463 - val_loss: 0.4070 - val_accuracy: 0.8260
# Epoch 3/20
# 200/200 [==============================] - ETA: 0s - loss: 0.3254 - accuracy: 0.8687
# Epoch 3: val_loss did not improve from 0.40705
# 200/200 [==============================] - 29s 146ms/step - loss: 0.3254 - accuracy: 0.8687 - val_loss: 0.4211 - val_accuracy: 0.8096
# Epoch 4/20
# 200/200 [==============================] - ETA: 0s - loss: 0.2873 - accuracy: 0.8910
# Epoch 4: val_loss improved from 0.40705 to 0.37966, saving model to /content/models/Experiment2_fine_tuning.h5
# 200/200 [==============================] - 31s 151ms/step - loss: 0.2873 - accuracy: 0.8910 - val_loss: 0.3797 - val_accuracy: 0.8344
# Epoch 5/20
# 200/200 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.9159
# Epoch 5: val_loss did not improve from 0.37966
# 200/200 [==============================] - 29s 146ms/step - loss: 0.2525 - accuracy: 0.9159 - val_loss: 0.4051 - val_accuracy: 0.8260
# Epoch 6/20
# 200/200 [==============================] - ETA: 0s - loss: 0.2197 - accuracy: 0.9312
# Epoch 6: val_loss improved from 0.37966 to 0.35765, saving model to /content/models/Experiment2_fine_tuning.h5
# 200/200 [==============================] - 29s 147ms/step - loss: 0.2197 - accuracy: 0.9312 - val_loss: 0.3576 - val_accuracy: 0.8419
# Epoch 7/20
# 200/200 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9482
# Epoch 7: val_loss did not improve from 0.35765
# 200/200 [==============================] - 30s 147ms/step - loss: 0.1907 - accuracy: 0.9482 - val_loss: 0.3643 - val_accuracy: 0.8433
# Epoch 8/20
# 200/200 [==============================] - ETA: 0s - loss: 0.1657 - accuracy: 0.9593
# Epoch 8: val_loss did not improve from 0.35765
# 200/200 [==============================] - 30s 148ms/step - loss: 0.1657 - accuracy: 0.9593 - val_loss: 0.3647 - val_accuracy: 0.8415
# Epoch 9/20
# 200/200 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.9690
# Epoch 9: val_loss did not improve from 0.35765
# 200/200 [==============================] - 29s 145ms/step - loss: 0.1412 - accuracy: 0.9690 - val_loss: 0.3674 - val_accuracy: 0.8415
# Epoch 10/20
# 200/200 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9790
# Epoch 10: val_loss did not improve from 0.35765
# 200/200 [==============================] - 30s 147ms/step - loss: 0.1188 - accuracy: 0.9790 - val_loss: 0.3854 - val_accuracy: 0.8326
# Epoch 11/20
# 200/200 [==============================] - ETA: 0s - loss: 0.0966 - accuracy: 0.9847
# Epoch 11: val_loss improved from 0.35765 to 0.35277, saving model to /content/models/Experiment2_fine_tuning.h5
# 200/200 [==============================] - 30s 147ms/step - loss: 0.0966 - accuracy: 0.9847 - val_loss: 0.3528 - val_accuracy: 0.8551
# Epoch 12/20
# 200/200 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9889
# Epoch 12: val_loss did not improve from 0.35277
# 200/200 [==============================] - 33s 164ms/step - loss: 0.0811 - accuracy: 0.9889 - val_loss: 0.3754 - val_accuracy: 0.8424
# Epoch 13/20
# 200/200 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9942
# Epoch 13: val_loss did not improve from 0.35277
# 200/200 [==============================] - 34s 167ms/step - loss: 0.0667 - accuracy: 0.9942 - val_loss: 0.3771 - val_accuracy: 0.8471
# Epoch 14/20
# 200/200 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9967
# Epoch 14: val_loss did not improve from 0.35277
# 200/200 [==============================] - 30s 146ms/step - loss: 0.0523 - accuracy: 0.9967 - val_loss: 0.3767 - val_accuracy: 0.8513
# Epoch 15/20
# 200/200 [==============================] - ETA: 0s - loss: 0.0452 - accuracy: 0.9978
# Epoch 15: val_loss did not improve from 0.35277
# 200/200 [==============================] - 29s 146ms/step - loss: 0.0452 - accuracy: 0.9978 - val_loss: 0.3719 - val_accuracy: 0.8555
# Epoch 16/20
# 200/200 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9986
# Epoch 16: val_loss did not improve from 0.35277
# 200/200 [==============================] - 29s 146ms/step - loss: 0.0389 - accuracy: 0.9986 - val_loss: 0.3917 - val_accuracy: 0.8490

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 7s 98ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7289    0.8305    0.7764       696
#            1     0.9119    0.8504    0.8801      1437
#
#     accuracy                         0.8439      2133
#    macro avg     0.8204    0.8404    0.8282      2133
# weighted avg     0.8522    0.8439    0.8462      2133

# %% [markdown]
# ### Experiment 3: global average pooling and two dense layers

# %%
model5 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_feature_extraction.h5')

set_trainable = False
for layer in model5.get_layer('resnet50').layers:
    if layer.name == 'conv5_block3_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

compile_model(model5, optimizer='rmsprop', learning_rate=1e-5)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_4  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_4 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_7 (Dense)             (None, 512)               1049088
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  dense_9 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 24899969 (94.99 MB)
# Trainable params: 5777921 (22.04 MB)
# Non-trainable params: 19122048 (72.94 MB)
# _________________________________________________________________

# %%
run_model(model5, "Experiment3_fine_tuning", epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3604 - accuracy: 0.8396
# Epoch 1: val_loss improved from inf to 0.40721, saving model to /content/models/Experiment3_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 40s 171ms/step - loss: 0.3604 - accuracy: 0.8396 - val_loss: 0.4072 - val_accuracy: 0.8265
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.2718 - accuracy: 0.8831
# Epoch 2: val_loss improved from 0.40721 to 0.39332, saving model to /content/models/Experiment3_fine_tuning.h5
# 200/200 [==============================] - 30s 147ms/step - loss: 0.2718 - accuracy: 0.8831 - val_loss: 0.3933 - val_accuracy: 0.8358
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9062
# Epoch 3: val_loss improved from 0.39332 to 0.38806, saving model to /content/models/Experiment3_fine_tuning.h5
# 200/200 [==============================] - 30s 148ms/step - loss: 0.2240 - accuracy: 0.9062 - val_loss: 0.3881 - val_accuracy: 0.8410
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.1846 - accuracy: 0.9282
# Epoch 4: val_loss improved from 0.38806 to 0.37907, saving model to /content/models/Experiment3_fine_tuning.h5
# 200/200 [==============================] - 34s 168ms/step - loss: 0.1846 - accuracy: 0.9282 - val_loss: 0.3791 - val_accuracy: 0.8499
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9464
# Epoch 5: val_loss improved from 0.37907 to 0.37215, saving model to /content/models/Experiment3_fine_tuning.h5
# 200/200 [==============================] - 30s 149ms/step - loss: 0.1470 - accuracy: 0.9464 - val_loss: 0.3721 - val_accuracy: 0.8588
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9637
# Epoch 6: val_loss did not improve from 0.37215
# 200/200 [==============================] - 30s 147ms/step - loss: 0.1132 - accuracy: 0.9637 - val_loss: 0.3932 - val_accuracy: 0.8523
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9753
# Epoch 7: val_loss did not improve from 0.37215
# 200/200 [==============================] - 29s 146ms/step - loss: 0.0845 - accuracy: 0.9753 - val_loss: 0.4277 - val_accuracy: 0.8494
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0601 - accuracy: 0.9867
# Epoch 8: val_loss did not improve from 0.37215
# 200/200 [==============================] - 33s 165ms/step - loss: 0.0601 - accuracy: 0.9867 - val_loss: 0.4212 - val_accuracy: 0.8602
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9919
# Epoch 9: val_loss did not improve from 0.37215
# 200/200 [==============================] - 30s 147ms/step - loss: 0.0400 - accuracy: 0.9919 - val_loss: 0.4499 - val_accuracy: 0.8602
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9970
# Epoch 10: val_loss did not improve from 0.37215
# 200/200 [==============================] - 29s 145ms/step - loss: 0.0248 - accuracy: 0.9970 - val_loss: 0.4881 - val_accuracy: 0.8565

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment3_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 8s 99ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7471    0.8233    0.7833       696
#            1     0.9100    0.8650    0.8869      1437
#
#     accuracy                         0.8514      2133
#    macro avg     0.8285    0.8441    0.8351      2133
# weighted avg     0.8568    0.8514    0.8531      2133

# %% [markdown]
# ## Remove final block (5-th block)
# Due to Colab's limitations we only took part of the original dataset, so now our dataset is small and very different from the one the pre-trained network was trained on. In this case it may be good to try to remove some of the final layers of the pre-trained network whose filters deal with finding detailed features. We will use less specific features that we find in previous levels.

# %%
def get_index_by_layer_name(model, layer_name):
  '''
  get_index_by_layer_name is used to retrieve the index of a specific layer
  :param model: model to check
  :param layer_name: name of the layer we want to get the index of
  :return: the index of the layer named as defined in layer_name
  '''
  for index, layer in enumerate(model.layers):
      if layer.name == layer_name:
          return index

# %%
conv_base = keras.applications.resnet.ResNet50(include_top = False, weights='imagenet', input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,3))

# %% [markdown]
# Remove the last convolutionary block of ResNet50.

# %%
base = Model(conv_base.input, conv_base.layers[get_index_by_layer_name(conv_base, 'conv4_block6_out')].output, name='base')
base.trainable = False
base.summary()
# Out:
# Model: "base"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_2[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 56, 56, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 56, 56, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 56, 56, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 28, 28, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 28, 28, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 28, 28, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 28, 28, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 8589184 (32.77 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 8589184 (32.77 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Feature extraction
# Firstly, we will try to use the new base network to extract the features; we will put a classifier on top of the base network. We couldn't afford to use the Flatten, the output of the base network is 14x14x1024, too much. So we decided to use the GlobalAveragePooling2D.

# %% [markdown]
# #### Experiment 1: one dense layer with 256 neurons
# In this first example we use just a Dense layer before the output layer.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(256)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model1 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model1)
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_5  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_5 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_2  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_10 (Dense)            (None, 256)               262400
#
#  dense_11 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8851841 (33.77 MB)
# Trainable params: 262657 (1.00 MB)
# Non-trainable params: 8589184 (32.77 MB)
# _________________________________________________________________

# %%
run_model(model1, "Experiment1_remove_blocks_feature_extraction", epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.6705 - accuracy: 0.6923
# Epoch 1: val_loss improved from inf to 0.44195, saving model to /content/models/Experiment1_remove_blocks_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 28s 124ms/step - loss: 0.6705 - accuracy: 0.6923 - val_loss: 0.4419 - val_accuracy: 0.8035
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.5153 - accuracy: 0.7452
# Epoch 2: val_loss did not improve from 0.44195
# 200/200 [==============================] - 23s 116ms/step - loss: 0.5153 - accuracy: 0.7452 - val_loss: 0.6585 - val_accuracy: 0.6238
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.5212 - accuracy: 0.7448
# Epoch 3: val_loss did not improve from 0.44195
# 200/200 [==============================] - 27s 137ms/step - loss: 0.5212 - accuracy: 0.7448 - val_loss: 0.4715 - val_accuracy: 0.7805
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4862 - accuracy: 0.7630
# Epoch 4: val_loss did not improve from 0.44195
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4862 - accuracy: 0.7630 - val_loss: 0.5559 - val_accuracy: 0.7101
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4707 - accuracy: 0.7770
# Epoch 5: val_loss did not improve from 0.44195
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4707 - accuracy: 0.7770 - val_loss: 1.1361 - val_accuracy: 0.4053
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4747 - accuracy: 0.7758
# Epoch 6: val_loss did not improve from 0.44195
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4747 - accuracy: 0.7758 - val_loss: 0.5350 - val_accuracy: 0.7256

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment1_remove_blocks_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 6s 84ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7577    0.6379    0.6927       696
#            1     0.8371    0.9012    0.8680      1437
#
#     accuracy                         0.8153      2133
#    macro avg     0.7974    0.7696    0.7803      2133
# weighted avg     0.8112    0.8153    0.8108      2133

# %% [markdown]
# #### Experiment 2: one dense layer with 256 neurons and dropout
# Try to use Dropout.

# %%
# define the classifier
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model2 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model2)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_6  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_6 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8851841 (33.77 MB)
# Trainable params: 262657 (1.00 MB)
# Non-trainable params: 8589184 (32.77 MB)
# _________________________________________________________________

# %%
run_model(model2, "Experiment2_remove_blocks_feature_extraction")
# Out:
# Epoch 1/20
# 200/200 [==============================] - ETA: 0s - loss: 0.7852 - accuracy: 0.6681
# Epoch 1: val_loss improved from inf to 0.45063, saving model to /content/models/Experiment2_remove_blocks_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 32s 144ms/step - loss: 0.7852 - accuracy: 0.6681 - val_loss: 0.4506 - val_accuracy: 0.7950
# Epoch 2/20
# 200/200 [==============================] - ETA: 0s - loss: 0.6066 - accuracy: 0.7054
# Epoch 2: val_loss did not improve from 0.45063
# 200/200 [==============================] - 23s 115ms/step - loss: 0.6066 - accuracy: 0.7054 - val_loss: 0.5955 - val_accuracy: 0.6975
# Epoch 3/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5330 - accuracy: 0.7420
# Epoch 3: val_loss did not improve from 0.45063
# 200/200 [==============================] - 23s 116ms/step - loss: 0.5330 - accuracy: 0.7420 - val_loss: 0.4941 - val_accuracy: 0.7636
# Epoch 4/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5212 - accuracy: 0.7461
# Epoch 4: val_loss improved from 0.45063 to 0.42096, saving model to /content/models/Experiment2_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 119ms/step - loss: 0.5212 - accuracy: 0.7461 - val_loss: 0.4210 - val_accuracy: 0.8110
# Epoch 5/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5125 - accuracy: 0.7514
# Epoch 5: val_loss did not improve from 0.42096
# 200/200 [==============================] - 23s 115ms/step - loss: 0.5125 - accuracy: 0.7514 - val_loss: 0.4497 - val_accuracy: 0.7964
# Epoch 6/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5032 - accuracy: 0.7541
# Epoch 6: val_loss improved from 0.42096 to 0.41499, saving model to /content/models/Experiment2_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 119ms/step - loss: 0.5032 - accuracy: 0.7541 - val_loss: 0.4150 - val_accuracy: 0.8157
# Epoch 7/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4953 - accuracy: 0.7645
# Epoch 7: val_loss did not improve from 0.41499
# 200/200 [==============================] - 24s 117ms/step - loss: 0.4953 - accuracy: 0.7645 - val_loss: 0.4463 - val_accuracy: 0.8002
# Epoch 8/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4770 - accuracy: 0.7772
# Epoch 8: val_loss improved from 0.41499 to 0.38263, saving model to /content/models/Experiment2_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 28s 139ms/step - loss: 0.4770 - accuracy: 0.7772 - val_loss: 0.3826 - val_accuracy: 0.8410
# Epoch 9/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4758 - accuracy: 0.7738
# Epoch 9: val_loss did not improve from 0.38263
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4758 - accuracy: 0.7738 - val_loss: 0.4550 - val_accuracy: 0.7950
# Epoch 10/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4821 - accuracy: 0.7736
# Epoch 10: val_loss did not improve from 0.38263
# 200/200 [==============================] - 24s 117ms/step - loss: 0.4821 - accuracy: 0.7736 - val_loss: 0.3965 - val_accuracy: 0.8307
# Epoch 11/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4633 - accuracy: 0.7808
# Epoch 11: val_loss did not improve from 0.38263
# 200/200 [==============================] - 23s 117ms/step - loss: 0.4633 - accuracy: 0.7808 - val_loss: 0.4369 - val_accuracy: 0.8110
# Epoch 12/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.7821
# Epoch 12: val_loss did not improve from 0.38263
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4661 - accuracy: 0.7821 - val_loss: 0.4948 - val_accuracy: 0.7528
# Epoch 13/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4608 - accuracy: 0.7824
# Epoch 13: val_loss did not improve from 0.38263
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4608 - accuracy: 0.7824 - val_loss: 0.4766 - val_accuracy: 0.7655

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 7s 86ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7977    0.7026    0.7471       696
#            1     0.8638    0.9137    0.8881      1437
#
#     accuracy                         0.8448      2133
#    macro avg     0.8308    0.8081    0.8176      2133
# weighted avg     0.8422    0.8448    0.8421      2133

# %% [markdown]
# #### Experiment 3: two dense layers, 256-128 neurons
# Try to make a more complex network, increasing the dense layers.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(256)(x)
x = layers.Dense(128)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model3 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model3)
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_7  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_7 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_4  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_14 (Dense)            (None, 256)               262400
#
#  dense_15 (Dense)            (None, 128)               32896
#
#  dense_16 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 8884609 (33.89 MB)
# Trainable params: 295425 (1.13 MB)
# Non-trainable params: 8589184 (32.77 MB)
# _________________________________________________________________

# %%
run_model(model3, "Experiment3_remove_blocks_feature_extraction")
# Out:
# Epoch 1/20
# 200/200 [==============================] - ETA: 0s - loss: 0.6517 - accuracy: 0.7008
# Epoch 1: val_loss improved from inf to 0.48706, saving model to /content/models/Experiment3_remove_blocks_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 30s 122ms/step - loss: 0.6517 - accuracy: 0.7008 - val_loss: 0.4871 - val_accuracy: 0.7824
# Epoch 2/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5372 - accuracy: 0.7358
# Epoch 2: val_loss improved from 0.48706 to 0.45516, saving model to /content/models/Experiment3_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 117ms/step - loss: 0.5372 - accuracy: 0.7358 - val_loss: 0.4552 - val_accuracy: 0.8072
# Epoch 3/20
# 200/200 [==============================] - ETA: 0s - loss: 0.5092 - accuracy: 0.7516
# Epoch 3: val_loss improved from 0.45516 to 0.41596, saving model to /content/models/Experiment3_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 117ms/step - loss: 0.5092 - accuracy: 0.7516 - val_loss: 0.4160 - val_accuracy: 0.8208
# Epoch 4/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4941 - accuracy: 0.7636
# Epoch 4: val_loss did not improve from 0.41596
# 200/200 [==============================] - 23s 116ms/step - loss: 0.4941 - accuracy: 0.7636 - val_loss: 0.4202 - val_accuracy: 0.8189
# Epoch 5/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4724 - accuracy: 0.7749
# Epoch 5: val_loss did not improve from 0.41596
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4724 - accuracy: 0.7749 - val_loss: 0.4662 - val_accuracy: 0.7847
# Epoch 6/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4711 - accuracy: 0.7755
# Epoch 6: val_loss did not improve from 0.41596
# 200/200 [==============================] - 28s 140ms/step - loss: 0.4711 - accuracy: 0.7755 - val_loss: 0.4681 - val_accuracy: 0.7885
# Epoch 7/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4585 - accuracy: 0.7827
# Epoch 7: val_loss improved from 0.41596 to 0.37367, saving model to /content/models/Experiment3_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 116ms/step - loss: 0.4585 - accuracy: 0.7827 - val_loss: 0.3737 - val_accuracy: 0.8494
# Epoch 8/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4379 - accuracy: 0.7975
# Epoch 8: val_loss improved from 0.37367 to 0.34300, saving model to /content/models/Experiment3_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 28s 141ms/step - loss: 0.4379 - accuracy: 0.7975 - val_loss: 0.3430 - val_accuracy: 0.8588
# Epoch 9/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4364 - accuracy: 0.7999
# Epoch 9: val_loss did not improve from 0.34300
# 200/200 [==============================] - 23s 116ms/step - loss: 0.4364 - accuracy: 0.7999 - val_loss: 0.3672 - val_accuracy: 0.8466
# Epoch 10/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4058 - accuracy: 0.8124
# Epoch 10: val_loss did not improve from 0.34300
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4058 - accuracy: 0.8124 - val_loss: 0.4719 - val_accuracy: 0.7735
# Epoch 11/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4210 - accuracy: 0.8063
# Epoch 11: val_loss did not improve from 0.34300
# 200/200 [==============================] - 23s 116ms/step - loss: 0.4210 - accuracy: 0.8063 - val_loss: 0.4592 - val_accuracy: 0.7781
# Epoch 12/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4123 - accuracy: 0.8147
# Epoch 12: val_loss did not improve from 0.34300
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4123 - accuracy: 0.8147 - val_loss: 0.4029 - val_accuracy: 0.8147
# Epoch 13/20
# 200/200 [==============================] - ETA: 0s - loss: 0.4003 - accuracy: 0.8208
# Epoch 13: val_loss did not improve from 0.34300
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4003 - accuracy: 0.8208 - val_loss: 0.4042 - val_accuracy: 0.8133

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment3_remove_blocks_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 7s 87ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7914    0.7141    0.7508       696
#            1     0.8678    0.9088    0.8878      1437
#
#     accuracy                         0.8453      2133
#    macro avg     0.8296    0.8115    0.8193      2133
# weighted avg     0.8429    0.8453    0.8431      2133

# %% [markdown]
# #### Experiment 4: one dense layer with 512 neurons
# Try to make a more complex networks increasing the neurons of a single Dense layer. We use RMSprop that in this case give us a smoother learning curve.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(512)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model4 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model4, optimizer='rmsprop', learning_rate=5e-5)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_8  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_8 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_5  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_17 (Dense)            (None, 512)               524800
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9114497 (34.77 MB)
# Trainable params: 525313 (2.00 MB)
# Non-trainable params: 8589184 (32.77 MB)
# _________________________________________________________________

# %%
run_model(model4, "Experiment4_remove_blocks_feature_extraction", epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.6133 - accuracy: 0.6654
# Epoch 1: val_loss improved from inf to 0.50184, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 27s 122ms/step - loss: 0.6133 - accuracy: 0.6654 - val_loss: 0.5018 - val_accuracy: 0.7749
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5508 - accuracy: 0.7233
# Epoch 2: val_loss improved from 0.50184 to 0.48877, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 116ms/step - loss: 0.5508 - accuracy: 0.7233 - val_loss: 0.4888 - val_accuracy: 0.7706
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 0.7328
# Epoch 3: val_loss improved from 0.48877 to 0.47562, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 117ms/step - loss: 0.5392 - accuracy: 0.7328 - val_loss: 0.4756 - val_accuracy: 0.7842
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5277 - accuracy: 0.7366
# Epoch 4: val_loss improved from 0.47562 to 0.47336, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 116ms/step - loss: 0.5277 - accuracy: 0.7366 - val_loss: 0.4734 - val_accuracy: 0.7810
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5183 - accuracy: 0.7431
# Epoch 5: val_loss did not improve from 0.47336
# 200/200 [==============================] - 24s 117ms/step - loss: 0.5183 - accuracy: 0.7431 - val_loss: 0.5357 - val_accuracy: 0.7294
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5086 - accuracy: 0.7541
# Epoch 6: val_loss improved from 0.47336 to 0.45445, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 116ms/step - loss: 0.5086 - accuracy: 0.7541 - val_loss: 0.4545 - val_accuracy: 0.7932
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5016 - accuracy: 0.7595
# Epoch 7: val_loss did not improve from 0.45445
# 200/200 [==============================] - 24s 117ms/step - loss: 0.5016 - accuracy: 0.7595 - val_loss: 0.4700 - val_accuracy: 0.7828
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4974 - accuracy: 0.7639
# Epoch 8: val_loss did not improve from 0.45445
# 200/200 [==============================] - 23s 116ms/step - loss: 0.4974 - accuracy: 0.7639 - val_loss: 0.5056 - val_accuracy: 0.7533
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4862 - accuracy: 0.7652
# Epoch 9: val_loss improved from 0.45445 to 0.45170, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 116ms/step - loss: 0.4862 - accuracy: 0.7652 - val_loss: 0.4517 - val_accuracy: 0.8049
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4872 - accuracy: 0.7694
# Epoch 10: val_loss improved from 0.45170 to 0.43031, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4872 - accuracy: 0.7694 - val_loss: 0.4303 - val_accuracy: 0.8077
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4802 - accuracy: 0.7727
# Epoch 11: val_loss did not improve from 0.43031
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4802 - accuracy: 0.7727 - val_loss: 0.4396 - val_accuracy: 0.8053
# Epoch 12/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4753 - accuracy: 0.7741
# Epoch 12: val_loss improved from 0.43031 to 0.41609, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4753 - accuracy: 0.7741 - val_loss: 0.4161 - val_accuracy: 0.8175
# Epoch 13/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4699 - accuracy: 0.7760
# Epoch 13: val_loss did not improve from 0.41609
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4699 - accuracy: 0.7760 - val_loss: 0.5182 - val_accuracy: 0.7444
# Epoch 14/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4633 - accuracy: 0.7819
# Epoch 14: val_loss improved from 0.41609 to 0.39719, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 117ms/step - loss: 0.4633 - accuracy: 0.7819 - val_loss: 0.3972 - val_accuracy: 0.8302
# Epoch 15/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.7811
# Epoch 15: val_loss did not improve from 0.39719
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4638 - accuracy: 0.7811 - val_loss: 0.4235 - val_accuracy: 0.8138
# Epoch 16/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4584 - accuracy: 0.7869
# Epoch 16: val_loss improved from 0.39719 to 0.39638, saving model to /content/models/Experiment4_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 119ms/step - loss: 0.4584 - accuracy: 0.7869 - val_loss: 0.3964 - val_accuracy: 0.8326
# Epoch 17/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4601 - accuracy: 0.7850
# Epoch 17: val_loss did not improve from 0.39638
# 200/200 [==============================] - 24s 116ms/step - loss: 0.4601 - accuracy: 0.7850 - val_loss: 0.4271 - val_accuracy: 0.8119
# Epoch 18/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4559 - accuracy: 0.7913
# Epoch 18: val_loss did not improve from 0.39638
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4559 - accuracy: 0.7913 - val_loss: 0.5200 - val_accuracy: 0.7369
# Epoch 19/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4501 - accuracy: 0.7888
# Epoch 19: val_loss did not improve from 0.39638
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4501 - accuracy: 0.7888 - val_loss: 0.4227 - val_accuracy: 0.8147
# Epoch 20/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4461 - accuracy: 0.7932
# Epoch 20: val_loss did not improve from 0.39638
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4461 - accuracy: 0.7932 - val_loss: 0.4185 - val_accuracy: 0.8189
# Epoch 21/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4461 - accuracy: 0.7939
# Epoch 21: val_loss did not improve from 0.39638
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4461 - accuracy: 0.7939 - val_loss: 0.3980 - val_accuracy: 0.8293

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 6s 84ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7743    0.7198    0.7461       696
#            1     0.8688    0.8984    0.8833      1437
#
#     accuracy                         0.8401      2133
#    macro avg     0.8216    0.8091    0.8147      2133
# weighted avg     0.8380    0.8401    0.8386      2133

# %% [markdown]
# #### Experiment 5: two dense layers of 512 neurons
# Try to make a more complex networks with two fully-connected dense layer of 512 neurons. We use RMSprop that in this case give us a smoother learning curve.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model5 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model5, optimizer='rmsprop')
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_9  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_9 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_6  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_19 (Dense)            (None, 512)               524800
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dense_21 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9377153 (35.77 MB)
# Trainable params: 787969 (3.01 MB)
# Non-trainable params: 8589184 (32.77 MB)
# _________________________________________________________________

# %%
run_model(model5, "Experiment5_remove_blocks_feature_extraction", epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.6475 - accuracy: 0.6699
# Epoch 1: val_loss improved from inf to 0.67474, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 28s 122ms/step - loss: 0.6475 - accuracy: 0.6699 - val_loss: 0.6747 - val_accuracy: 0.6553
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5557 - accuracy: 0.7214
# Epoch 2: val_loss improved from 0.67474 to 0.51206, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 116ms/step - loss: 0.5557 - accuracy: 0.7214 - val_loss: 0.5121 - val_accuracy: 0.7880
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5361 - accuracy: 0.7362
# Epoch 3: val_loss improved from 0.51206 to 0.51036, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 119ms/step - loss: 0.5361 - accuracy: 0.7362 - val_loss: 0.5104 - val_accuracy: 0.7838
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5222 - accuracy: 0.7391
# Epoch 4: val_loss improved from 0.51036 to 0.47549, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 116ms/step - loss: 0.5222 - accuracy: 0.7391 - val_loss: 0.4755 - val_accuracy: 0.7992
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5096 - accuracy: 0.7522
# Epoch 5: val_loss did not improve from 0.47549
# 200/200 [==============================] - 24s 118ms/step - loss: 0.5096 - accuracy: 0.7522 - val_loss: 0.7879 - val_accuracy: 0.5826
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5026 - accuracy: 0.7531
# Epoch 6: val_loss improved from 0.47549 to 0.44459, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 118ms/step - loss: 0.5026 - accuracy: 0.7531 - val_loss: 0.4446 - val_accuracy: 0.8016
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.7594
# Epoch 7: val_loss did not improve from 0.44459
# 200/200 [==============================] - 23s 116ms/step - loss: 0.4976 - accuracy: 0.7594 - val_loss: 0.6010 - val_accuracy: 0.7031
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4893 - accuracy: 0.7644
# Epoch 8: val_loss did not improve from 0.44459
# 200/200 [==============================] - 24s 117ms/step - loss: 0.4893 - accuracy: 0.7644 - val_loss: 0.5009 - val_accuracy: 0.7800
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4768 - accuracy: 0.7705
# Epoch 9: val_loss improved from 0.44459 to 0.44014, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4768 - accuracy: 0.7705 - val_loss: 0.4401 - val_accuracy: 0.8199
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4698 - accuracy: 0.7738
# Epoch 10: val_loss improved from 0.44014 to 0.43056, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 117ms/step - loss: 0.4698 - accuracy: 0.7738 - val_loss: 0.4306 - val_accuracy: 0.8053
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.7744
# Epoch 11: val_loss did not improve from 0.43056
# 200/200 [==============================] - 24s 117ms/step - loss: 0.4637 - accuracy: 0.7744 - val_loss: 0.4468 - val_accuracy: 0.8138
# Epoch 12/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4631 - accuracy: 0.7785
# Epoch 12: val_loss did not improve from 0.43056
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4631 - accuracy: 0.7785 - val_loss: 0.5032 - val_accuracy: 0.7575
# Epoch 13/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4552 - accuracy: 0.7791
# Epoch 13: val_loss did not improve from 0.43056
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4552 - accuracy: 0.7791 - val_loss: 0.6312 - val_accuracy: 0.6904
# Epoch 14/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4510 - accuracy: 0.7867
# Epoch 14: val_loss improved from 0.43056 to 0.36788, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 23s 116ms/step - loss: 0.4510 - accuracy: 0.7867 - val_loss: 0.3679 - val_accuracy: 0.8438
# Epoch 15/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4366 - accuracy: 0.7991
# Epoch 15: val_loss did not improve from 0.36788
# 200/200 [==============================] - 24s 118ms/step - loss: 0.4366 - accuracy: 0.7991 - val_loss: 0.4031 - val_accuracy: 0.8171
# Epoch 16/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4407 - accuracy: 0.7910
# Epoch 16: val_loss did not improve from 0.36788
# 200/200 [==============================] - 24s 117ms/step - loss: 0.4407 - accuracy: 0.7910 - val_loss: 0.5777 - val_accuracy: 0.7312
# Epoch 17/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4311 - accuracy: 0.7921
# Epoch 17: val_loss did not improve from 0.36788
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4311 - accuracy: 0.7921 - val_loss: 0.4082 - val_accuracy: 0.8189
# Epoch 18/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4295 - accuracy: 0.7975
# Epoch 18: val_loss improved from 0.36788 to 0.34755, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 24s 117ms/step - loss: 0.4295 - accuracy: 0.7975 - val_loss: 0.3476 - val_accuracy: 0.8598
# Epoch 19/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4271 - accuracy: 0.8002
# Epoch 19: val_loss did not improve from 0.34755
# 200/200 [==============================] - 28s 140ms/step - loss: 0.4271 - accuracy: 0.8002 - val_loss: 0.3611 - val_accuracy: 0.8588
# Epoch 20/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4209 - accuracy: 0.8022
# Epoch 20: val_loss did not improve from 0.34755
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4209 - accuracy: 0.8022 - val_loss: 0.4398 - val_accuracy: 0.8133
# Epoch 21/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4269 - accuracy: 0.7960
# Epoch 21: val_loss did not improve from 0.34755
# 200/200 [==============================] - 28s 138ms/step - loss: 0.4269 - accuracy: 0.7960 - val_loss: 0.3793 - val_accuracy: 0.8307
# Epoch 22/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4130 - accuracy: 0.8155
# Epoch 22: val_loss did not improve from 0.34755
# 200/200 [==============================] - 24s 117ms/step - loss: 0.4130 - accuracy: 0.8155 - val_loss: 0.4753 - val_accuracy: 0.7889
# Epoch 23/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4098 - accuracy: 0.8083
# Epoch 23: val_loss improved from 0.34755 to 0.31997, saving model to /content/models/Experiment5_remove_blocks_feature_extraction.h5
# 200/200 [==============================] - 28s 140ms/step - loss: 0.4098 - accuracy: 0.8083 - val_loss: 0.3200 - val_accuracy: 0.8696
# Epoch 24/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4050 - accuracy: 0.8135
# Epoch 24: val_loss did not improve from 0.31997
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4050 - accuracy: 0.8135 - val_loss: 0.4457 - val_accuracy: 0.8011
# Epoch 25/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4052 - accuracy: 0.8122
# Epoch 25: val_loss did not improve from 0.31997
# 200/200 [==============================] - 24s 117ms/step - loss: 0.4052 - accuracy: 0.8122 - val_loss: 0.4129 - val_accuracy: 0.8340
# Epoch 26/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4039 - accuracy: 0.8180
# Epoch 26: val_loss did not improve from 0.31997
# 200/200 [==============================] - 24s 117ms/step - loss: 0.4039 - accuracy: 0.8180 - val_loss: 0.3267 - val_accuracy: 0.8743
# Epoch 27/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.8168
# Epoch 27: val_loss did not improve from 0.31997
# 200/200 [==============================] - 23s 114ms/step - loss: 0.3972 - accuracy: 0.8168 - val_loss: 0.4357 - val_accuracy: 0.8133
# Epoch 28/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3961 - accuracy: 0.8196
# Epoch 28: val_loss did not improve from 0.31997
# 200/200 [==============================] - 23s 115ms/step - loss: 0.3961 - accuracy: 0.8196 - val_loss: 0.3330 - val_accuracy: 0.8724

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_remove_blocks_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 6s 82ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8481    0.7141    0.7754       696
#            1     0.8714    0.9381    0.9035      1437
#
#     accuracy                         0.8650      2133
#    macro avg     0.8597    0.8261    0.8394      2133
# weighted avg     0.8638    0.8650    0.8617      2133

# %% [markdown]
# ### Fine tuning
# Now we can fine tune the best models of the previous experiments, unfreezing some of the last layers of the base network.

# %% [markdown]
# #### Unfreeze some layers
# Firstly, we try to unfreeze just some of the last layers of the fourth block.

# %% [markdown]
# ##### Experiment 1: one dense layer with 256 neurons and dropout

# %%
model1 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5')

set_trainable = False
# set trainable from "conv4_block6_1_conv"
for layer in model1.get_layer('base').layers:
    if layer.name == 'conv4_block6_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
model1.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_6  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_6 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8851841 (33.77 MB)
# Trainable params: 1381377 (5.27 MB)
# Non-trainable params: 7470464 (28.50 MB)
# _________________________________________________________________

# %%
compile_model(model1, learning_rate=1e-5)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_6  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_6 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8851841 (33.77 MB)
# Trainable params: 1381377 (5.27 MB)
# Non-trainable params: 7470464 (28.50 MB)
# _________________________________________________________________

# %%
run_model(model1, 'Experiment1_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4453 - accuracy: 0.7957
# Epoch 1: val_loss improved from inf to 0.37112, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 32s 134ms/step - loss: 0.4453 - accuracy: 0.7957 - val_loss: 0.3711 - val_accuracy: 0.8438
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4296 - accuracy: 0.8047
# Epoch 2: val_loss improved from 0.37112 to 0.36046, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.4296 - accuracy: 0.8047 - val_loss: 0.3605 - val_accuracy: 0.8494
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4127 - accuracy: 0.8096
# Epoch 3: val_loss improved from 0.36046 to 0.34916, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 26s 128ms/step - loss: 0.4127 - accuracy: 0.8096 - val_loss: 0.3492 - val_accuracy: 0.8616
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3908 - accuracy: 0.8246
# Epoch 4: val_loss improved from 0.34916 to 0.33756, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 127ms/step - loss: 0.3908 - accuracy: 0.8246 - val_loss: 0.3376 - val_accuracy: 0.8724
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3732 - accuracy: 0.8410
# Epoch 5: val_loss improved from 0.33756 to 0.32164, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 124ms/step - loss: 0.3732 - accuracy: 0.8410 - val_loss: 0.3216 - val_accuracy: 0.8813
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3527 - accuracy: 0.8463
# Epoch 6: val_loss improved from 0.32164 to 0.31301, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.3527 - accuracy: 0.8463 - val_loss: 0.3130 - val_accuracy: 0.8837
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3289 - accuracy: 0.8609
# Epoch 7: val_loss improved from 0.31301 to 0.29979, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 125ms/step - loss: 0.3289 - accuracy: 0.8609 - val_loss: 0.2998 - val_accuracy: 0.8832
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3075 - accuracy: 0.8685
# Epoch 8: val_loss improved from 0.29979 to 0.29295, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 30s 147ms/step - loss: 0.3075 - accuracy: 0.8685 - val_loss: 0.2930 - val_accuracy: 0.8856
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2938 - accuracy: 0.8788
# Epoch 9: val_loss improved from 0.29295 to 0.28788, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 26s 128ms/step - loss: 0.2938 - accuracy: 0.8788 - val_loss: 0.2879 - val_accuracy: 0.8832
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2711 - accuracy: 0.8904
# Epoch 10: val_loss improved from 0.28788 to 0.27598, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.2711 - accuracy: 0.8904 - val_loss: 0.2760 - val_accuracy: 0.8893
# Epoch 11/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2516 - accuracy: 0.8985
# Epoch 11: val_loss improved from 0.27598 to 0.26593, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 125ms/step - loss: 0.2516 - accuracy: 0.8985 - val_loss: 0.2659 - val_accuracy: 0.8959
# Epoch 12/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9059
# Epoch 12: val_loss did not improve from 0.26593
# 200/200 [==============================] - 25s 125ms/step - loss: 0.2354 - accuracy: 0.9059 - val_loss: 0.2703 - val_accuracy: 0.8902
# Epoch 13/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.9159
# Epoch 13: val_loss improved from 0.26593 to 0.25924, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 26s 128ms/step - loss: 0.2183 - accuracy: 0.9159 - val_loss: 0.2592 - val_accuracy: 0.8926
# Epoch 14/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.9260
# Epoch 14: val_loss improved from 0.25924 to 0.25841, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.2054 - accuracy: 0.9260 - val_loss: 0.2584 - val_accuracy: 0.8907
# Epoch 15/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9290
# Epoch 15: val_loss did not improve from 0.25841
# 200/200 [==============================] - 26s 128ms/step - loss: 0.1885 - accuracy: 0.9290 - val_loss: 0.2710 - val_accuracy: 0.8888
# Epoch 16/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1751 - accuracy: 0.9361
# Epoch 16: val_loss improved from 0.25841 to 0.25364, saving model to /content/models/Experiment1_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 30s 149ms/step - loss: 0.1751 - accuracy: 0.9361 - val_loss: 0.2536 - val_accuracy: 0.8973
# Epoch 17/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 0.9439
# Epoch 17: val_loss did not improve from 0.25364
# 200/200 [==============================] - 25s 124ms/step - loss: 0.1632 - accuracy: 0.9439 - val_loss: 0.2610 - val_accuracy: 0.8902
# Epoch 18/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9478
# Epoch 18: val_loss did not improve from 0.25364
# 200/200 [==============================] - 26s 127ms/step - loss: 0.1530 - accuracy: 0.9478 - val_loss: 0.2618 - val_accuracy: 0.8893
# Epoch 19/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9536
# Epoch 19: val_loss did not improve from 0.25364
# 200/200 [==============================] - 25s 127ms/step - loss: 0.1388 - accuracy: 0.9536 - val_loss: 0.2675 - val_accuracy: 0.8884
# Epoch 20/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9592
# Epoch 20: val_loss did not improve from 0.25364
# 200/200 [==============================] - 29s 146ms/step - loss: 0.1245 - accuracy: 0.9592 - val_loss: 0.2563 - val_accuracy: 0.8945
# Epoch 21/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9606
# Epoch 21: val_loss did not improve from 0.25364
# 200/200 [==============================] - 25s 126ms/step - loss: 0.1157 - accuracy: 0.9606 - val_loss: 0.2641 - val_accuracy: 0.8977

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment1_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 6s 83ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8358    0.8190    0.8273       696
#            1     0.9132    0.9221    0.9176      1437
#
#     accuracy                         0.8884      2133
#    macro avg     0.8745    0.8705    0.8724      2133
# weighted avg     0.8879    0.8884    0.8881      2133

# %% [markdown]
# ##### Experiment 2: one dense layer with 512 neurons

# %%
model2 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5')
set_trainable = False
# set trainable from "conv4_block6_1_conv"
for layer in model2.get_layer('base').layers:
    if layer.name == 'conv4_block6_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
model1.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_6  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_6 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8851841 (33.77 MB)
# Trainable params: 1381377 (5.27 MB)
# Non-trainable params: 7470464 (28.50 MB)
# _________________________________________________________________

# %%
compile_model(model2, optimizer='rmsprop', learning_rate=1e-5)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_8  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_8 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_5  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_17 (Dense)            (None, 512)               524800
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9114497 (34.77 MB)
# Trainable params: 1644033 (6.27 MB)
# Non-trainable params: 7470464 (28.50 MB)
# _________________________________________________________________

# %%
run_model(model2, 'Experiment2_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4364 - accuracy: 0.7992
# Epoch 1: val_loss improved from inf to 0.38374, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 30s 129ms/step - loss: 0.4364 - accuracy: 0.7992 - val_loss: 0.3837 - val_accuracy: 0.8419
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4220 - accuracy: 0.8091
# Epoch 2: val_loss improved from 0.38374 to 0.37875, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 26s 128ms/step - loss: 0.4220 - accuracy: 0.8091 - val_loss: 0.3788 - val_accuracy: 0.8471
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4049 - accuracy: 0.8215
# Epoch 3: val_loss improved from 0.37875 to 0.35578, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.4049 - accuracy: 0.8215 - val_loss: 0.3558 - val_accuracy: 0.8569
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3894 - accuracy: 0.8290
# Epoch 4: val_loss improved from 0.35578 to 0.34110, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 26s 127ms/step - loss: 0.3894 - accuracy: 0.8290 - val_loss: 0.3411 - val_accuracy: 0.8626
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3735 - accuracy: 0.8355
# Epoch 5: val_loss improved from 0.34110 to 0.33342, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.3735 - accuracy: 0.8355 - val_loss: 0.3334 - val_accuracy: 0.8757
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3574 - accuracy: 0.8458
# Epoch 6: val_loss improved from 0.33342 to 0.31952, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 125ms/step - loss: 0.3574 - accuracy: 0.8458 - val_loss: 0.3195 - val_accuracy: 0.8734
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3398 - accuracy: 0.8524
# Epoch 7: val_loss improved from 0.31952 to 0.31280, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 26s 129ms/step - loss: 0.3398 - accuracy: 0.8524 - val_loss: 0.3128 - val_accuracy: 0.8795
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3236 - accuracy: 0.8629
# Epoch 8: val_loss improved from 0.31280 to 0.29763, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 26s 127ms/step - loss: 0.3236 - accuracy: 0.8629 - val_loss: 0.2976 - val_accuracy: 0.8837
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3095 - accuracy: 0.8702
# Epoch 9: val_loss did not improve from 0.29763
# 200/200 [==============================] - 25s 124ms/step - loss: 0.3095 - accuracy: 0.8702 - val_loss: 0.2979 - val_accuracy: 0.8832
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2964 - accuracy: 0.8757
# Epoch 10: val_loss improved from 0.29763 to 0.28284, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.2964 - accuracy: 0.8757 - val_loss: 0.2828 - val_accuracy: 0.8870
# Epoch 11/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2816 - accuracy: 0.8831
# Epoch 11: val_loss did not improve from 0.28284
# 200/200 [==============================] - 25s 123ms/step - loss: 0.2816 - accuracy: 0.8831 - val_loss: 0.2920 - val_accuracy: 0.8813
# Epoch 12/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.8924
# Epoch 12: val_loss did not improve from 0.28284
# 200/200 [==============================] - 25s 123ms/step - loss: 0.2657 - accuracy: 0.8924 - val_loss: 0.3046 - val_accuracy: 0.8752
# Epoch 13/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2549 - accuracy: 0.8962
# Epoch 13: val_loss did not improve from 0.28284
# 200/200 [==============================] - 25s 124ms/step - loss: 0.2549 - accuracy: 0.8962 - val_loss: 0.2852 - val_accuracy: 0.8856
# Epoch 14/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2404 - accuracy: 0.9049
# Epoch 14: val_loss improved from 0.28284 to 0.27575, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.2404 - accuracy: 0.9049 - val_loss: 0.2758 - val_accuracy: 0.8888
# Epoch 15/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2262 - accuracy: 0.9114
# Epoch 15: val_loss improved from 0.27575 to 0.27347, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 125ms/step - loss: 0.2262 - accuracy: 0.9114 - val_loss: 0.2735 - val_accuracy: 0.8837
# Epoch 16/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2127 - accuracy: 0.9168
# Epoch 16: val_loss improved from 0.27347 to 0.26000, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.2127 - accuracy: 0.9168 - val_loss: 0.2600 - val_accuracy: 0.8935
# Epoch 17/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9225
# Epoch 17: val_loss did not improve from 0.26000
# 200/200 [==============================] - 25s 124ms/step - loss: 0.1995 - accuracy: 0.9225 - val_loss: 0.2616 - val_accuracy: 0.8879
# Epoch 18/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1916 - accuracy: 0.9307
# Epoch 18: val_loss did not improve from 0.26000
# 200/200 [==============================] - 25s 123ms/step - loss: 0.1916 - accuracy: 0.9307 - val_loss: 0.2601 - val_accuracy: 0.8898
# Epoch 19/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9379
# Epoch 19: val_loss did not improve from 0.26000
# 200/200 [==============================] - 25s 124ms/step - loss: 0.1749 - accuracy: 0.9379 - val_loss: 0.2651 - val_accuracy: 0.8837
# Epoch 20/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.9390
# Epoch 20: val_loss improved from 0.26000 to 0.25725, saving model to /content/models/Experiment2_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 25s 126ms/step - loss: 0.1681 - accuracy: 0.9390 - val_loss: 0.2572 - val_accuracy: 0.8940
# Epoch 21/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 0.9423
# Epoch 21: val_loss did not improve from 0.25725
# 200/200 [==============================] - 25s 125ms/step - loss: 0.1553 - accuracy: 0.9423 - val_loss: 0.2672 - val_accuracy: 0.8827
# Epoch 22/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1473 - accuracy: 0.9506
# Epoch 22: val_loss did not improve from 0.25725
# 200/200 [==============================] - 29s 145ms/step - loss: 0.1473 - accuracy: 0.9506 - val_loss: 0.2596 - val_accuracy: 0.8940
# Epoch 23/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9548
# Epoch 23: val_loss did not improve from 0.25725
# 200/200 [==============================] - 25s 124ms/step - loss: 0.1378 - accuracy: 0.9548 - val_loss: 0.2912 - val_accuracy: 0.8804
# Epoch 24/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9545
# Epoch 24: val_loss did not improve from 0.25725
# 200/200 [==============================] - 25s 123ms/step - loss: 0.1329 - accuracy: 0.9545 - val_loss: 0.2621 - val_accuracy: 0.8973
# Epoch 25/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 0.9636
# Epoch 25: val_loss did not improve from 0.25725
# 200/200 [==============================] - 25s 123ms/step - loss: 0.1168 - accuracy: 0.9636 - val_loss: 0.2700 - val_accuracy: 0.8893

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 6s 85ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8378    0.8089    0.8231       696
#            1     0.9090    0.9241    0.9165      1437
#
#     accuracy                         0.8865      2133
#    macro avg     0.8734    0.8665    0.8698      2133
# weighted avg     0.8857    0.8865    0.8860      2133

# %% [markdown]
# #### Unfreeze all the 4-th block
# We try to unfreeze more layers, more precisely all the fourth block (that is the last block of our base network).

# %% [markdown]
# ##### Experiment 3: one dense layer with 256 neurons and dropout

# %%
model3 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5')

set_trainable = False
# set trainable all conv4 section
for layer in model3.get_layer('base').layers:
    if layer.name == 'conv4_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
compile_model(model3, learning_rate=1e-5)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_6  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_6 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8851841 (33.77 MB)
# Trainable params: 7371265 (28.12 MB)
# Non-trainable params: 1480576 (5.65 MB)
# _________________________________________________________________

# %%
run_model(model3, 'Experiment3_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4244 - accuracy: 0.8053
# Epoch 1: val_loss improved from inf to 0.35725, saving model to /content/models/Experiment3_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 49s 186ms/step - loss: 0.4244 - accuracy: 0.8053 - val_loss: 0.3572 - val_accuracy: 0.8494
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3220 - accuracy: 0.8632
# Epoch 2: val_loss improved from 0.35725 to 0.26574, saving model to /content/models/Experiment3_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 40s 199ms/step - loss: 0.3220 - accuracy: 0.8632 - val_loss: 0.2657 - val_accuracy: 0.8954
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.9104
# Epoch 3: val_loss improved from 0.26574 to 0.21575, saving model to /content/models/Experiment3_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 36s 177ms/step - loss: 0.2312 - accuracy: 0.9104 - val_loss: 0.2157 - val_accuracy: 0.9174
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9487
# Epoch 4: val_loss improved from 0.21575 to 0.20026, saving model to /content/models/Experiment3_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 35s 176ms/step - loss: 0.1445 - accuracy: 0.9487 - val_loss: 0.2003 - val_accuracy: 0.9189
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9744
# Epoch 5: val_loss did not improve from 0.20026
# 200/200 [==============================] - 35s 174ms/step - loss: 0.0845 - accuracy: 0.9744 - val_loss: 0.2114 - val_accuracy: 0.9184
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9892
# Epoch 6: val_loss did not improve from 0.20026
# 200/200 [==============================] - 35s 174ms/step - loss: 0.0466 - accuracy: 0.9892 - val_loss: 0.2162 - val_accuracy: 0.9174
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9950
# Epoch 7: val_loss did not improve from 0.20026
# 200/200 [==============================] - 35s 175ms/step - loss: 0.0264 - accuracy: 0.9950 - val_loss: 0.2271 - val_accuracy: 0.9250
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9953
# Epoch 8: val_loss did not improve from 0.20026
# 200/200 [==============================] - 40s 197ms/step - loss: 0.0214 - accuracy: 0.9953 - val_loss: 0.2447 - val_accuracy: 0.9221
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9981
# Epoch 9: val_loss did not improve from 0.20026
# 200/200 [==============================] - 35s 174ms/step - loss: 0.0113 - accuracy: 0.9981 - val_loss: 0.2475 - val_accuracy: 0.9198

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment3_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 6s 87ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9171    0.8420    0.8779       696
#            1     0.9264    0.9631    0.9444      1437
#
#     accuracy                         0.9236      2133
#    macro avg     0.9217    0.9025    0.9111      2133
# weighted avg     0.9233    0.9236    0.9227      2133

# %% [markdown]
# ##### Experiment 4: one dense layer with 512 neurons

# %%
model4 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5')
set_trainable = False
for layer in model4.get_layer('base').layers:
    if layer.name == 'conv4_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model4, optimizer='rmsprop', learning_rate=1e-5)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_8  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_8 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_5  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_17 (Dense)            (None, 512)               524800
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9114497 (34.77 MB)
# Trainable params: 7633921 (29.12 MB)
# Non-trainable params: 1480576 (5.65 MB)
# _________________________________________________________________

# %%
run_model(model4, 'Experiment4_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4096 - accuracy: 0.8174
# Epoch 1: val_loss improved from inf to 0.35701, saving model to /content/models/Experiment4_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 50s 204ms/step - loss: 0.4096 - accuracy: 0.8174 - val_loss: 0.3570 - val_accuracy: 0.8490
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3039 - accuracy: 0.8785
# Epoch 2: val_loss improved from 0.35701 to 0.27060, saving model to /content/models/Experiment4_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 36s 177ms/step - loss: 0.3039 - accuracy: 0.8785 - val_loss: 0.2706 - val_accuracy: 0.8945
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2259 - accuracy: 0.9174
# Epoch 3: val_loss improved from 0.27060 to 0.22840, saving model to /content/models/Experiment4_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 35s 175ms/step - loss: 0.2259 - accuracy: 0.9174 - val_loss: 0.2284 - val_accuracy: 0.9118
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9440
# Epoch 4: val_loss did not improve from 0.22840
# 200/200 [==============================] - 35s 171ms/step - loss: 0.1576 - accuracy: 0.9440 - val_loss: 0.2426 - val_accuracy: 0.9048
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.9701
# Epoch 5: val_loss did not improve from 0.22840
# 200/200 [==============================] - 35s 173ms/step - loss: 0.0951 - accuracy: 0.9701 - val_loss: 0.2462 - val_accuracy: 0.9099
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9902
# Epoch 6: val_loss did not improve from 0.22840
# 200/200 [==============================] - 35s 173ms/step - loss: 0.0462 - accuracy: 0.9902 - val_loss: 0.2429 - val_accuracy: 0.9203
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9947
# Epoch 7: val_loss did not improve from 0.22840
# 200/200 [==============================] - 40s 197ms/step - loss: 0.0267 - accuracy: 0.9947 - val_loss: 0.2816 - val_accuracy: 0.9170
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9983
# Epoch 8: val_loss did not improve from 0.22840
# 200/200 [==============================] - 35s 174ms/step - loss: 0.0122 - accuracy: 0.9983 - val_loss: 0.2546 - val_accuracy: 0.9203

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 7s 87ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9320    0.7874    0.8536       696
#            1     0.9042    0.9722    0.9370      1437
#
#     accuracy                         0.9119      2133
#    macro avg     0.9181    0.8798    0.8953      2133
# weighted avg     0.9133    0.9119    0.9098      2133

# %% [markdown]
# ##### Experiment 5: two dense layers of 512 neurons

# %%
model5 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_remove_blocks_feature_extraction.h5')
set_trainable = False
for layer in model5.get_layer('base').layers:
    if layer.name == 'conv4_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model5, optimizer='rmsprop', learning_rate=1e-5)
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_9  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_9 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_6  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_19 (Dense)            (None, 512)               524800
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dense_21 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9377153 (35.77 MB)
# Trainable params: 7896577 (30.12 MB)
# Non-trainable params: 1480576 (5.65 MB)
# _________________________________________________________________

# %%
run_model(model5, 'Experiment5_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3744 - accuracy: 0.8293
# Epoch 1: val_loss improved from inf to 0.36228, saving model to /content/models/Experiment5_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 50s 203ms/step - loss: 0.3744 - accuracy: 0.8293 - val_loss: 0.3623 - val_accuracy: 0.8410
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.8891
# Epoch 2: val_loss improved from 0.36228 to 0.23385, saving model to /content/models/Experiment5_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 40s 199ms/step - loss: 0.2668 - accuracy: 0.8891 - val_loss: 0.2338 - val_accuracy: 0.9053
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9231
# Epoch 3: val_loss improved from 0.23385 to 0.22109, saving model to /content/models/Experiment5_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 35s 175ms/step - loss: 0.1936 - accuracy: 0.9231 - val_loss: 0.2211 - val_accuracy: 0.9118
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9559
# Epoch 4: val_loss did not improve from 0.22109
# 200/200 [==============================] - 35s 173ms/step - loss: 0.1284 - accuracy: 0.9559 - val_loss: 0.2219 - val_accuracy: 0.9137
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9765
# Epoch 5: val_loss did not improve from 0.22109
# 200/200 [==============================] - 35s 174ms/step - loss: 0.0794 - accuracy: 0.9765 - val_loss: 0.2382 - val_accuracy: 0.9146
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9870
# Epoch 6: val_loss did not improve from 0.22109
# 200/200 [==============================] - 35s 174ms/step - loss: 0.0466 - accuracy: 0.9870 - val_loss: 0.2445 - val_accuracy: 0.9142
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9955
# Epoch 7: val_loss did not improve from 0.22109
# 200/200 [==============================] - 35s 173ms/step - loss: 0.0234 - accuracy: 0.9955 - val_loss: 0.2637 - val_accuracy: 0.9146
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9978
# Epoch 8: val_loss did not improve from 0.22109
# 200/200 [==============================] - 35s 174ms/step - loss: 0.0128 - accuracy: 0.9978 - val_loss: 0.2794 - val_accuracy: 0.9151

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 6s 83ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9104    0.8032    0.8534       696
#            1     0.9098    0.9617    0.9350      1437
#
#     accuracy                         0.9100      2133
#    macro avg     0.9101    0.8824    0.8942      2133
# weighted avg     0.9100    0.9100    0.9084      2133

# %% [markdown]
# #### Unfreeze also the third block
# We saw an improvement of our models, so we keep to unfreeze more layers. Now we unfreeze also the third block of our base network.

# %% [markdown]
# ##### Experiment 6: one dense layer with 256 neurons and dropout

# %%
model6 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5')

set_trainable = False
for layer in model6.get_layer('base').layers:
    if layer.name == 'conv3_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model6, learning_rate=1e-5)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_6  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_6 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8851841 (33.77 MB)
# Trainable params: 8594433 (32.79 MB)
# Non-trainable params: 257408 (1005.50 KB)
# _________________________________________________________________

# %%
run_model(model6, 'Experiment6_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3993 - accuracy: 0.8291
# Epoch 1: val_loss improved from inf to 0.29044, saving model to /content/models/Experiment6_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 68s 242ms/step - loss: 0.3993 - accuracy: 0.8291 - val_loss: 0.2904 - val_accuracy: 0.8738
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2529 - accuracy: 0.8954
# Epoch 2: val_loss improved from 0.29044 to 0.19951, saving model to /content/models/Experiment6_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 47s 233ms/step - loss: 0.2529 - accuracy: 0.8954 - val_loss: 0.1995 - val_accuracy: 0.9259
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1751 - accuracy: 0.9337
# Epoch 3: val_loss improved from 0.19951 to 0.17097, saving model to /content/models/Experiment6_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 46s 230ms/step - loss: 0.1751 - accuracy: 0.9337 - val_loss: 0.1710 - val_accuracy: 0.9353
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9615
# Epoch 4: val_loss improved from 0.17097 to 0.16059, saving model to /content/models/Experiment6_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 47s 233ms/step - loss: 0.1089 - accuracy: 0.9615 - val_loss: 0.1606 - val_accuracy: 0.9428
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9816
# Epoch 5: val_loss improved from 0.16059 to 0.15805, saving model to /content/models/Experiment6_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 46s 228ms/step - loss: 0.0616 - accuracy: 0.9816 - val_loss: 0.1580 - val_accuracy: 0.9475
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9917
# Epoch 6: val_loss did not improve from 0.15805
# 200/200 [==============================] - 46s 231ms/step - loss: 0.0358 - accuracy: 0.9917 - val_loss: 0.1650 - val_accuracy: 0.9442
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9945
# Epoch 7: val_loss did not improve from 0.15805
# 200/200 [==============================] - 46s 229ms/step - loss: 0.0224 - accuracy: 0.9945 - val_loss: 0.1946 - val_accuracy: 0.9311
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9961
# Epoch 8: val_loss did not improve from 0.15805
# 200/200 [==============================] - 45s 225ms/step - loss: 0.0163 - accuracy: 0.9961 - val_loss: 0.2337 - val_accuracy: 0.9273
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9983
# Epoch 9: val_loss did not improve from 0.15805
# 200/200 [==============================] - 46s 229ms/step - loss: 0.0106 - accuracy: 0.9983 - val_loss: 0.2048 - val_accuracy: 0.9306
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9987
# Epoch 10: val_loss did not improve from 0.15805
# 200/200 [==============================] - 46s 230ms/step - loss: 0.0076 - accuracy: 0.9987 - val_loss: 0.1883 - val_accuracy: 0.9451

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment6_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 6s 82ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9266    0.8894    0.9076       696
#            1     0.9474    0.9659    0.9566      1437
#
#     accuracy                         0.9409      2133
#    macro avg     0.9370    0.9276    0.9321      2133
# weighted avg     0.9407    0.9409    0.9406      2133

# %% [markdown]
# ##### Experiment 7: one dense layer with 512 neurons

# %%
model7 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5')

set_trainable = False
for layer in model7.get_layer('base').layers:
    if layer.name == 'conv3_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model7, optimizer='rmsprop', learning_rate=1e-5)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_8  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_8 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_5  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_17 (Dense)            (None, 512)               524800
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9114497 (34.77 MB)
# Trainable params: 8857089 (33.79 MB)
# Non-trainable params: 257408 (1005.50 KB)
# _________________________________________________________________

# %%
run_model(model7, 'Experiment7_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3794 - accuracy: 0.8397
# Epoch 1: val_loss improved from inf to 0.29438, saving model to /content/models/Experiment7_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 59s 233ms/step - loss: 0.3794 - accuracy: 0.8397 - val_loss: 0.2944 - val_accuracy: 0.8724
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9021
# Epoch 2: val_loss improved from 0.29438 to 0.20167, saving model to /content/models/Experiment7_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 46s 231ms/step - loss: 0.2492 - accuracy: 0.9021 - val_loss: 0.2017 - val_accuracy: 0.9259
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1711 - accuracy: 0.9356
# Epoch 3: val_loss improved from 0.20167 to 0.18223, saving model to /content/models/Experiment7_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 46s 232ms/step - loss: 0.1711 - accuracy: 0.9356 - val_loss: 0.1822 - val_accuracy: 0.9320
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9626
# Epoch 4: val_loss improved from 0.18223 to 0.17183, saving model to /content/models/Experiment7_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 46s 227ms/step - loss: 0.1137 - accuracy: 0.9626 - val_loss: 0.1718 - val_accuracy: 0.9371
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9816
# Epoch 5: val_loss improved from 0.17183 to 0.17165, saving model to /content/models/Experiment7_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 46s 230ms/step - loss: 0.0641 - accuracy: 0.9816 - val_loss: 0.1717 - val_accuracy: 0.9423
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0340 - accuracy: 0.9930
# Epoch 6: val_loss did not improve from 0.17165
# 200/200 [==============================] - 46s 230ms/step - loss: 0.0340 - accuracy: 0.9930 - val_loss: 0.1858 - val_accuracy: 0.9362
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9962
# Epoch 7: val_loss did not improve from 0.17165
# 200/200 [==============================] - 45s 225ms/step - loss: 0.0184 - accuracy: 0.9962 - val_loss: 0.1873 - val_accuracy: 0.9395
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9975
# Epoch 8: val_loss did not improve from 0.17165
# 200/200 [==============================] - 46s 227ms/step - loss: 0.0113 - accuracy: 0.9975 - val_loss: 0.1998 - val_accuracy: 0.9400
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9989
# Epoch 9: val_loss did not improve from 0.17165
# 200/200 [==============================] - 45s 225ms/step - loss: 0.0070 - accuracy: 0.9989 - val_loss: 0.2461 - val_accuracy: 0.9311
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9989
# Epoch 10: val_loss did not improve from 0.17165
# 200/200 [==============================] - 46s 230ms/step - loss: 0.0055 - accuracy: 0.9989 - val_loss: 0.2216 - val_accuracy: 0.9386

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment7_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 7s 80ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9404    0.8621    0.8996       696
#            1     0.9358    0.9736    0.9543      1437
#
#     accuracy                         0.9372      2133
#    macro avg     0.9381    0.9178    0.9269      2133
# weighted avg     0.9373    0.9372    0.9364      2133

# %% [markdown]
# #### Unfreeze also the second block
# We try to unfreeze also the entire second block

# %% [markdown]
# ##### Experiment 8: one dense layer with 256 neurons and dropout

# %%
model8 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5')

set_trainable = False
for layer in model8.get_layer('base').layers:
    if layer.name == 'conv2_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model8, learning_rate=1e-5)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_6  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_6 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8851841 (33.77 MB)
# Trainable params: 8811649 (33.61 MB)
# Non-trainable params: 40192 (157.00 KB)
# _________________________________________________________________

# %%
run_model(model8, 'Experiment8_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3593 - accuracy: 0.8426
# Epoch 1: val_loss improved from inf to 0.45832, saving model to /content/models/Experiment8_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 86s 308ms/step - loss: 0.3593 - accuracy: 0.8426 - val_loss: 0.4583 - val_accuracy: 0.8274
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.9017
# Epoch 2: val_loss improved from 0.45832 to 0.19090, saving model to /content/models/Experiment8_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 60s 296ms/step - loss: 0.2447 - accuracy: 0.9017 - val_loss: 0.1909 - val_accuracy: 0.9278
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9361
# Epoch 3: val_loss improved from 0.19090 to 0.16488, saving model to /content/models/Experiment8_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 59s 295ms/step - loss: 0.1676 - accuracy: 0.9361 - val_loss: 0.1649 - val_accuracy: 0.9362
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9598
# Epoch 4: val_loss did not improve from 0.16488
# 200/200 [==============================] - 59s 292ms/step - loss: 0.1071 - accuracy: 0.9598 - val_loss: 0.1716 - val_accuracy: 0.9348
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9808
# Epoch 5: val_loss improved from 0.16488 to 0.15951, saving model to /content/models/Experiment8_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 60s 299ms/step - loss: 0.0605 - accuracy: 0.9808 - val_loss: 0.1595 - val_accuracy: 0.9428
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9937
# Epoch 6: val_loss improved from 0.15951 to 0.15706, saving model to /content/models/Experiment8_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 60s 299ms/step - loss: 0.0319 - accuracy: 0.9937 - val_loss: 0.1571 - val_accuracy: 0.9484
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9931
# Epoch 7: val_loss did not improve from 0.15706
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0233 - accuracy: 0.9931 - val_loss: 0.1666 - val_accuracy: 0.9437
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9952
# Epoch 8: val_loss did not improve from 0.15706
# 200/200 [==============================] - 58s 292ms/step - loss: 0.0185 - accuracy: 0.9952 - val_loss: 0.2414 - val_accuracy: 0.9203
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9973
# Epoch 9: val_loss did not improve from 0.15706
# 200/200 [==============================] - 58s 292ms/step - loss: 0.0123 - accuracy: 0.9973 - val_loss: 0.1717 - val_accuracy: 0.9508
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9984
# Epoch 10: val_loss did not improve from 0.15706
# 200/200 [==============================] - 58s 291ms/step - loss: 0.0083 - accuracy: 0.9984 - val_loss: 0.1798 - val_accuracy: 0.9451
# Epoch 11/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9995
# Epoch 11: val_loss did not improve from 0.15706
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0047 - accuracy: 0.9995 - val_loss: 0.1993 - val_accuracy: 0.9432

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment8_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 6s 86ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8958    0.9138    0.9047       696
#            1     0.9578    0.9485    0.9531      1437
#
#     accuracy                         0.9372      2133
#    macro avg     0.9268    0.9311    0.9289      2133
# weighted avg     0.9376    0.9372    0.9373      2133

# %% [markdown]
# ##### Experiment 9: one dense layer with 512 neurons

# %%
model9 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5')

set_trainable = False
for layer in model9.get_layer('base').layers:
    if layer.name == 'conv2_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model9, learning_rate=1e-5)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_8  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_8 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_5  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_17 (Dense)            (None, 512)               524800
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9114497 (34.77 MB)
# Trainable params: 9074305 (34.62 MB)
# Non-trainable params: 40192 (157.00 KB)
# _________________________________________________________________

# %%
run_model(model9, 'Experiment9_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3350 - accuracy: 0.8601
# Epoch 1: val_loss improved from inf to 0.44077, saving model to /content/models/Experiment9_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 84s 302ms/step - loss: 0.3350 - accuracy: 0.8601 - val_loss: 0.4408 - val_accuracy: 0.8326
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2170 - accuracy: 0.9146
# Epoch 2: val_loss improved from 0.44077 to 0.20570, saving model to /content/models/Experiment9_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 59s 296ms/step - loss: 0.2170 - accuracy: 0.9146 - val_loss: 0.2057 - val_accuracy: 0.9156
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9439
# Epoch 3: val_loss improved from 0.20570 to 0.16268, saving model to /content/models/Experiment9_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 59s 293ms/step - loss: 0.1468 - accuracy: 0.9439 - val_loss: 0.1627 - val_accuracy: 0.9400
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9728
# Epoch 4: val_loss did not improve from 0.16268
# 200/200 [==============================] - 58s 292ms/step - loss: 0.0860 - accuracy: 0.9728 - val_loss: 0.1687 - val_accuracy: 0.9376
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9911
# Epoch 5: val_loss improved from 0.16268 to 0.16153, saving model to /content/models/Experiment9_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 59s 294ms/step - loss: 0.0432 - accuracy: 0.9911 - val_loss: 0.1615 - val_accuracy: 0.9400
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9942
# Epoch 6: val_loss did not improve from 0.16153
# 200/200 [==============================] - 58s 291ms/step - loss: 0.0290 - accuracy: 0.9942 - val_loss: 0.1625 - val_accuracy: 0.9442
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9980
# Epoch 7: val_loss did not improve from 0.16153
# 200/200 [==============================] - 63s 314ms/step - loss: 0.0146 - accuracy: 0.9980 - val_loss: 0.2042 - val_accuracy: 0.9339
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9972
# Epoch 8: val_loss did not improve from 0.16153
# 200/200 [==============================] - 59s 295ms/step - loss: 0.0149 - accuracy: 0.9972 - val_loss: 0.1769 - val_accuracy: 0.9437
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9986
# Epoch 9: val_loss did not improve from 0.16153
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0086 - accuracy: 0.9986 - val_loss: 0.1906 - val_accuracy: 0.9395
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9983
# Epoch 10: val_loss did not improve from 0.16153
# 200/200 [==============================] - 58s 291ms/step - loss: 0.0100 - accuracy: 0.9983 - val_loss: 0.2019 - val_accuracy: 0.9437

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment9_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 6s 82ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8750    0.9253    0.8994       696
#            1     0.9628    0.9360    0.9492      1437
#
#     accuracy                         0.9325      2133
#    macro avg     0.9189    0.9306    0.9243      2133
# weighted avg     0.9341    0.9325    0.9330      2133

# %% [markdown]
# #### Unfreeze all the base network
# Let's try to unfreeze all the layers of the base network

# %% [markdown]
# ##### Experiment 10: one dense layer with 256 neurons and dropout

# %%
model10 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment2_remove_blocks_feature_extraction.h5')
model10.trainable = True
compile_model(model10, learning_rate=1e-5)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_6  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_6 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_3  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               262400
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 8851841 (33.77 MB)
# Trainable params: 8821249 (33.65 MB)
# Non-trainable params: 30592 (119.50 KB)
# _________________________________________________________________

# %%
run_model(model10, 'Experiment10_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3437 - accuracy: 0.8549
# Epoch 1: val_loss improved from inf to 0.52690, saving model to /content/models/Experiment10_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 87s 315ms/step - loss: 0.3437 - accuracy: 0.8549 - val_loss: 0.5269 - val_accuracy: 0.8354
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2233 - accuracy: 0.9106
# Epoch 2: val_loss improved from 0.52690 to 0.18134, saving model to /content/models/Experiment10_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 61s 307ms/step - loss: 0.2233 - accuracy: 0.9106 - val_loss: 0.1813 - val_accuracy: 0.9306
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1523 - accuracy: 0.9409
# Epoch 3: val_loss improved from 0.18134 to 0.15803, saving model to /content/models/Experiment10_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 66s 329ms/step - loss: 0.1523 - accuracy: 0.9409 - val_loss: 0.1580 - val_accuracy: 0.9381
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9640
# Epoch 4: val_loss did not improve from 0.15803
# 200/200 [==============================] - 62s 308ms/step - loss: 0.0985 - accuracy: 0.9640 - val_loss: 0.1587 - val_accuracy: 0.9447
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9836
# Epoch 5: val_loss did not improve from 0.15803
# 200/200 [==============================] - 61s 302ms/step - loss: 0.0539 - accuracy: 0.9836 - val_loss: 0.1653 - val_accuracy: 0.9442
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9895
# Epoch 6: val_loss did not improve from 0.15803
# 200/200 [==============================] - 62s 307ms/step - loss: 0.0351 - accuracy: 0.9895 - val_loss: 0.1770 - val_accuracy: 0.9423
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9950
# Epoch 7: val_loss did not improve from 0.15803
# 200/200 [==============================] - 61s 303ms/step - loss: 0.0233 - accuracy: 0.9950 - val_loss: 0.1729 - val_accuracy: 0.9461
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9989
# Epoch 8: val_loss did not improve from 0.15803
# 200/200 [==============================] - 61s 304ms/step - loss: 0.0112 - accuracy: 0.9989 - val_loss: 0.1719 - val_accuracy: 0.9442

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment10_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 6s 85ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9041    0.8937    0.8988       696
#            1     0.9488    0.9541    0.9514      1437
#
#     accuracy                         0.9344      2133
#    macro avg     0.9264    0.9239    0.9251      2133
# weighted avg     0.9342    0.9344    0.9343      2133

# %% [markdown]
# ##### Experiment 11: one dense layer with 512 neurons

# %%
model11 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_remove_blocks_feature_extraction.h5')
model11.trainable = True
compile_model(model11, learning_rate=1e-5)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_8  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_8 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_5  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_17 (Dense)            (None, 512)               524800
#
#  dense_18 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9114497 (34.77 MB)
# Trainable params: 9083905 (34.65 MB)
# Non-trainable params: 30592 (119.50 KB)
# _________________________________________________________________

# %%
run_model(model11, 'Experiment11_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.8641
# Epoch 1: val_loss improved from inf to 0.55348, saving model to /content/models/Experiment11_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 91s 339ms/step - loss: 0.3262 - accuracy: 0.8641 - val_loss: 0.5535 - val_accuracy: 0.8241
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2163 - accuracy: 0.9170
# Epoch 2: val_loss improved from 0.55348 to 0.18765, saving model to /content/models/Experiment11_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 62s 309ms/step - loss: 0.2163 - accuracy: 0.9170 - val_loss: 0.1876 - val_accuracy: 0.9254
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9508
# Epoch 3: val_loss improved from 0.18765 to 0.15796, saving model to /content/models/Experiment11_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 62s 308ms/step - loss: 0.1386 - accuracy: 0.9508 - val_loss: 0.1580 - val_accuracy: 0.9414
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0866 - accuracy: 0.9711
# Epoch 4: val_loss improved from 0.15796 to 0.15668, saving model to /content/models/Experiment11_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 62s 308ms/step - loss: 0.0866 - accuracy: 0.9711 - val_loss: 0.1567 - val_accuracy: 0.9423
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0410 - accuracy: 0.9917
# Epoch 5: val_loss improved from 0.15668 to 0.15641, saving model to /content/models/Experiment11_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 62s 309ms/step - loss: 0.0410 - accuracy: 0.9917 - val_loss: 0.1564 - val_accuracy: 0.9484
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9941
# Epoch 6: val_loss did not improve from 0.15641
# 200/200 [==============================] - 62s 308ms/step - loss: 0.0256 - accuracy: 0.9941 - val_loss: 0.1633 - val_accuracy: 0.9470
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9962
# Epoch 7: val_loss did not improve from 0.15641
# 200/200 [==============================] - 62s 308ms/step - loss: 0.0173 - accuracy: 0.9962 - val_loss: 0.1661 - val_accuracy: 0.9475
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9966
# Epoch 8: val_loss did not improve from 0.15641
# 200/200 [==============================] - 61s 303ms/step - loss: 0.0143 - accuracy: 0.9966 - val_loss: 0.1775 - val_accuracy: 0.9484
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9992
# Epoch 9: val_loss did not improve from 0.15641
# 200/200 [==============================] - 61s 306ms/step - loss: 0.0073 - accuracy: 0.9992 - val_loss: 0.1770 - val_accuracy: 0.9456
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9998
# Epoch 10: val_loss did not improve from 0.15641
# 200/200 [==============================] - 66s 330ms/step - loss: 0.0043 - accuracy: 0.9998 - val_loss: 0.1931 - val_accuracy: 0.9432

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment11_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 6s 85ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8813    0.9282    0.9041       696
#            1     0.9643    0.9395    0.9517      1437
#
#     accuracy                         0.9358      2133
#    macro avg     0.9228    0.9338    0.9279      2133
# weighted avg     0.9372    0.9358    0.9362      2133

# %% [markdown]
# ##### Experiment 12: two dense layers of 512 neurons

# %%
model12 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment5_remove_blocks_feature_extraction.h5')
model12.trainable = True
compile_model(model12, learning_rate=1e-5)
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem_9  (None, 224, 224, 3)       0
#   (SlicingOpLambda)
#
#  tf.nn.bias_add_9 (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d_6  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dense_19 (Dense)            (None, 512)               524800
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dense_21 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 9377153 (35.77 MB)
# Trainable params: 9346561 (35.65 MB)
# Non-trainable params: 30592 (119.50 KB)
# _________________________________________________________________

# %%
run_model(model12, 'Experiment12_remove_blocks_fine_tuning', epochs=30)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.8685
# Epoch 1: val_loss improved from inf to 0.58673, saving model to /content/models/Experiment12_remove_blocks_fine_tuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 99s 329ms/step - loss: 0.3119 - accuracy: 0.8685 - val_loss: 0.5867 - val_accuracy: 0.8129
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2038 - accuracy: 0.9221
# Epoch 2: val_loss improved from 0.58673 to 0.20954, saving model to /content/models/Experiment12_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 63s 315ms/step - loss: 0.2038 - accuracy: 0.9221 - val_loss: 0.2095 - val_accuracy: 0.9109
# Epoch 3/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9498
# Epoch 3: val_loss improved from 0.20954 to 0.17444, saving model to /content/models/Experiment12_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 64s 317ms/step - loss: 0.1360 - accuracy: 0.9498 - val_loss: 0.1744 - val_accuracy: 0.9357
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9740
# Epoch 4: val_loss improved from 0.17444 to 0.16696, saving model to /content/models/Experiment12_remove_blocks_fine_tuning.h5
# 200/200 [==============================] - 68s 339ms/step - loss: 0.0792 - accuracy: 0.9740 - val_loss: 0.1670 - val_accuracy: 0.9456
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9897
# Epoch 5: val_loss did not improve from 0.16696
# 200/200 [==============================] - 63s 314ms/step - loss: 0.0374 - accuracy: 0.9897 - val_loss: 0.2217 - val_accuracy: 0.9296
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9939
# Epoch 6: val_loss did not improve from 0.16696
# 200/200 [==============================] - 66s 332ms/step - loss: 0.0251 - accuracy: 0.9939 - val_loss: 0.1867 - val_accuracy: 0.9395
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9953
# Epoch 7: val_loss did not improve from 0.16696
# 200/200 [==============================] - 62s 310ms/step - loss: 0.0175 - accuracy: 0.9953 - val_loss: 0.1931 - val_accuracy: 0.9470
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9945
# Epoch 8: val_loss did not improve from 0.16696
# 200/200 [==============================] - 62s 310ms/step - loss: 0.0180 - accuracy: 0.9945 - val_loss: 0.2309 - val_accuracy: 0.9386
# Epoch 9/30
# 200/200 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9967
# Epoch 9: val_loss did not improve from 0.16696
# 200/200 [==============================] - 62s 312ms/step - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.2598 - val_accuracy: 0.9315

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment12_remove_blocks_fine_tuning.h5'))
# Out:
# 67/67 [==============================] - 8s 105ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8930    0.9109    0.9018       696
#            1     0.9564    0.9471    0.9517      1437
#
#     accuracy                         0.9353      2133
#    macro avg     0.9247    0.9290    0.9268      2133
# weighted avg     0.9357    0.9353    0.9355      2133

# %% [markdown]
# # CLAHE
# We will try now to use the dataset in which the images are preprocesses with CLAHE. We will test the performance with the best network previuosly found and we will compare the results. Unfortunately, no significant improvements were found.

# %% [markdown]
# ## Load dataset from Google Drive
# The dataset is stored in Google Drive in a zip file, we unzip it locally for better performance.

# %%
drive.mount('/content/drive', force_remount=True)
# !unzip -q "/content/drive/My Drive/SplittedDataset_CLAHE.zip" -d "/content"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Set parameters

# %%
DATASET_PATH = "/content/SplittedDataset_CLAHE"
TRAINING_PATH = DATASET_PATH + '/training_set'
TRAINING_ALL_PATH = TRAINING_PATH + '/all'
TRAINING_HEM_PATH = TRAINING_PATH + '/hem'
VALIDATION_PATH = DATASET_PATH + '/validation_set'
TEST_PATH = DATASET_PATH + '/test_set'

# %% [markdown]
# ## Load dataset
# The dataset, properly preprocessed, is now located in the local machine.

# %%
set_seed()

train_dataset = load_training_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
validation_dataset = load_validation_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
test_dataset = load_test_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
# Out:
# Found 6396 files belonging to 2 classes.
# Found 2132 files belonging to 2 classes.
# Found 2133 files belonging to 2 classes.

# %% [markdown]
# ## Remove final block
# As we did for the original dataset, here too we are going to remove the last block that deals with the high-level features of Imagenet

# %%
conv_base = keras.applications.resnet.ResNet50(include_top = False, weights='imagenet', input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,3))

# %%
base = Model(conv_base.input, conv_base.layers[get_index_by_layer_name(conv_base, 'conv4_block6_out')].output, name='base')
base.trainable = False
base.summary()
# Out:
# Model: "base"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_3[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 56, 56, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 56, 56, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 56, 56, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 28, 28, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 28, 28, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 28, 28, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 28, 28, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 8589184 (32.77 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 8589184 (32.77 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Feature extraction
# Firstly, we try the simplest approach in which we use the pretrained network to extract feature and we use our classifier to classify the images.

# %% [markdown]
# ### Experiment 1: one dense layer with 256 neurons and dropout
# This is the first best model found in the previous section with the standard dataset.

# %%
# define the classifier
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = keras.applications.resnet50.preprocess_input(inputs)
x = base(x)
x = layers.GlobalAveragePooling2D() (x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model1 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (  (None, 224, 224, 3)       0
#  SlicingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda  (None, 224, 224, 3)       0
#  )
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               262400
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 8851841 (33.77 MB)
# Trainable params: 262657 (1.00 MB)
# Non-trainable params: 8589184 (32.77 MB)
# _________________________________________________________________

# %%
run_model(model1, "Experiment1_remove_blocks_feature_extraction_CLAHE", epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.7634 - accuracy: 0.6640
# Epoch 1: val_loss improved from inf to 0.52545, saving model to /content/models/Experiment1_remove_blocks_feature_extraction_CLAHE.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 35s 131ms/step - loss: 0.7634 - accuracy: 0.6640 - val_loss: 0.5254 - val_accuracy: 0.7425
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5968 - accuracy: 0.7100
# Epoch 2: val_loss did not improve from 0.52545
# 200/200 [==============================] - 23s 114ms/step - loss: 0.5968 - accuracy: 0.7100 - val_loss: 0.7071 - val_accuracy: 0.6032
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5267 - accuracy: 0.7455
# Epoch 3: val_loss did not improve from 0.52545
# 200/200 [==============================] - 23s 112ms/step - loss: 0.5267 - accuracy: 0.7455 - val_loss: 0.5301 - val_accuracy: 0.7265
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5104 - accuracy: 0.7542
# Epoch 4: val_loss improved from 0.52545 to 0.41668, saving model to /content/models/Experiment1_remove_blocks_feature_extraction_CLAHE.h5
# 200/200 [==============================] - 23s 116ms/step - loss: 0.5104 - accuracy: 0.7542 - val_loss: 0.4167 - val_accuracy: 0.8161
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5211 - accuracy: 0.7475
# Epoch 5: val_loss improved from 0.41668 to 0.40009, saving model to /content/models/Experiment1_remove_blocks_feature_extraction_CLAHE.h5
# 200/200 [==============================] - 23s 114ms/step - loss: 0.5211 - accuracy: 0.7475 - val_loss: 0.4001 - val_accuracy: 0.8255
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5029 - accuracy: 0.7547
# Epoch 6: val_loss did not improve from 0.40009
# 200/200 [==============================] - 27s 136ms/step - loss: 0.5029 - accuracy: 0.7547 - val_loss: 0.4875 - val_accuracy: 0.7627
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.7722
# Epoch 7: val_loss did not improve from 0.40009
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4803 - accuracy: 0.7722 - val_loss: 0.6361 - val_accuracy: 0.6412
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4861 - accuracy: 0.7692
# Epoch 8: val_loss did not improve from 0.40009
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4861 - accuracy: 0.7692 - val_loss: 0.4040 - val_accuracy: 0.8265
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4788 - accuracy: 0.7744
# Epoch 9: val_loss improved from 0.40009 to 0.38453, saving model to /content/models/Experiment1_remove_blocks_feature_extraction_CLAHE.h5
# 200/200 [==============================] - 23s 115ms/step - loss: 0.4788 - accuracy: 0.7744 - val_loss: 0.3845 - val_accuracy: 0.8354
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4657 - accuracy: 0.7869
# Epoch 10: val_loss did not improve from 0.38453
# 200/200 [==============================] - 23s 112ms/step - loss: 0.4657 - accuracy: 0.7869 - val_loss: 0.4052 - val_accuracy: 0.8222
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4611 - accuracy: 0.7831
# Epoch 11: val_loss did not improve from 0.38453
# 200/200 [==============================] - 23s 114ms/step - loss: 0.4611 - accuracy: 0.7831 - val_loss: 0.4399 - val_accuracy: 0.7988
# Epoch 12/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4616 - accuracy: 0.7836
# Epoch 12: val_loss did not improve from 0.38453
# 200/200 [==============================] - 23s 113ms/step - loss: 0.4616 - accuracy: 0.7836 - val_loss: 0.4020 - val_accuracy: 0.8232
# Epoch 13/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4523 - accuracy: 0.7955
# Epoch 13: val_loss did not improve from 0.38453
# 200/200 [==============================] - 23s 112ms/step - loss: 0.4523 - accuracy: 0.7955 - val_loss: 0.4140 - val_accuracy: 0.8189
# Epoch 14/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4522 - accuracy: 0.7907
# Epoch 14: val_loss did not improve from 0.38453
# 200/200 [==============================] - 28s 137ms/step - loss: 0.4522 - accuracy: 0.7907 - val_loss: 0.4487 - val_accuracy: 0.7927

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment1_remove_blocks_feature_extraction_CLAHE.h5'))
# Out:
# 67/67 [==============================] - 7s 100ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8247    0.6624    0.7347       696
#            1     0.8507    0.9318    0.8894      1437
#
#     accuracy                         0.8439      2133
#    macro avg     0.8377    0.7971    0.8120      2133
# weighted avg     0.8422    0.8439    0.8389      2133

# %% [markdown]
# ## Fine Tuning
# Now we can fine-tune the base network to adapt it to extract more useful features in our images.

# %% [markdown]
# ### Unfreeze up to the second block included
# We tried directly to unfreeze up to the second block included, just to compare with the previous results. We can easily see that unfortunately there are no significative improvements, indeed the results are less satisfactory than the same network on the original dataset.

# %% [markdown]
# #### Experiment 1: one dense layer with 256 neurons and dropout

# %%
model1 = tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment1_remove_blocks_feature_extraction_CLAHE.h5')

set_trainable = False
for layer in model1.get_layer('base').layers:
    if layer.name == 'conv2_block1_1_conv':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
compile_model(model1, learning_rate=1e-5)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (  (None, 224, 224, 3)       0
#  SlicingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda  (None, 224, 224, 3)       0
#  )
#
#  base (Functional)           (None, 14, 14, 1024)      8589184
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               262400
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 8851841 (33.77 MB)
# Trainable params: 8811649 (33.61 MB)
# Non-trainable params: 40192 (157.00 KB)
# _________________________________________________________________

# %%
run_model(model1, "Experiment1_remove_blocks_fine_tuning_CLAHE", epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3643 - accuracy: 0.8443
# Epoch 1: val_loss improved from inf to 0.44044, saving model to /content/models/Experiment1_remove_blocks_fine_tuning_CLAHE.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 94s 331ms/step - loss: 0.3643 - accuracy: 0.8443 - val_loss: 0.4404 - val_accuracy: 0.8349
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.2538 - accuracy: 0.8979
# Epoch 2: val_loss improved from 0.44044 to 0.20551, saving model to /content/models/Experiment1_remove_blocks_fine_tuning_CLAHE.h5
# 200/200 [==============================] - 59s 292ms/step - loss: 0.2538 - accuracy: 0.8979 - val_loss: 0.2055 - val_accuracy: 0.9198
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9318
# Epoch 3: val_loss improved from 0.20551 to 0.19204, saving model to /content/models/Experiment1_remove_blocks_fine_tuning_CLAHE.h5
# 200/200 [==============================] - 59s 293ms/step - loss: 0.1746 - accuracy: 0.9318 - val_loss: 0.1920 - val_accuracy: 0.9250
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.1030 - accuracy: 0.9642
# Epoch 4: val_loss did not improve from 0.19204
# 200/200 [==============================] - 58s 287ms/step - loss: 0.1030 - accuracy: 0.9642 - val_loss: 0.2019 - val_accuracy: 0.9273
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9842
# Epoch 5: val_loss did not improve from 0.19204
# 200/200 [==============================] - 58s 288ms/step - loss: 0.0548 - accuracy: 0.9842 - val_loss: 0.2004 - val_accuracy: 0.9353
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9937
# Epoch 6: val_loss did not improve from 0.19204
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0315 - accuracy: 0.9937 - val_loss: 0.2047 - val_accuracy: 0.9353
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9956
# Epoch 7: val_loss did not improve from 0.19204
# 200/200 [==============================] - 58s 288ms/step - loss: 0.0202 - accuracy: 0.9956 - val_loss: 0.2079 - val_accuracy: 0.9329
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9942
# Epoch 8: val_loss did not improve from 0.19204
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0192 - accuracy: 0.9942 - val_loss: 0.2457 - val_accuracy: 0.9264

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment1_remove_blocks_fine_tuning_CLAHE.h5'))
# Out:
# 67/67 [==============================] - 6s 79ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8704    0.8879    0.8791       696
#            1     0.9452    0.9360    0.9406      1437
#
#     accuracy                         0.9203      2133
#    macro avg     0.9078    0.9120    0.9098      2133
# weighted avg     0.9208    0.9203    0.9205      2133
