# %% [markdown]
# # Solve the problem leveraging MobileNet architecture
# In this notebook, we will use the MobileNet architecture for our classification problem.
#
# First, we'll try a simple **feature extraction**. Since the architecture was trained on a different dataset, we do not expect very good performance, but we can use these results as a baseline for the next step: **fine-tuning**.

# %% [markdown]
# ## Import Libraries
# First of all, let's import all the libraries we will need later.

# %%
from google.colab import drive
import os
import shutil
import numpy as np
import random as rn
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from keras.models import Model
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Load dataset from Google Drive

# %%
drive.mount('/content/drive', force_remount=True)
# !unzip -q "/content/drive/My Drive/SplittedDataset.zip" -d "/content"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Set Parameters

# %%
DATASET_PATH = "/content/SplittedDataset"
TRAINING_PATH = DATASET_PATH + '/training_set'
TRAINING_ALL_PATH = TRAINING_PATH + '/all'
TRAINING_HEM_PATH = TRAINING_PATH + '/hem'
VALIDATION_PATH = DATASET_PATH + '/validation_set'
TEST_PATH = DATASET_PATH + '/test_set'

LOCAL_MODELS_FOLDER = "/content/models"
if not os.path.exists(LOCAL_MODELS_FOLDER):
  os.makedirs(LOCAL_MODELS_FOLDER)
GLOBAL_MODELS_FOLDER = "/content/drive/My Drive/Baldi_Cioffo/models/mobilenet"
if not os.path.exists(GLOBAL_MODELS_FOLDER):
  os.makedirs(GLOBAL_MODELS_FOLDER)

# Default values to load the dataset
BATCH_SIZE = 32
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224

# %% [markdown]
# ## Utility Functions

# %%
def set_seed ():
  '''
  set_seed is used to obtain reproducible results using keras during the development phase
  '''
  seed = 24
  # The below is necessary for reproducible results of certain Python hash-based operations.
  os.environ["PYTHONHASHSEED"]="0"
  # The below is necessary for starting Numpy generated random numbers in a well-defined initial state.
  np.random.seed(seed)
  # The below is necessary for starting core Python generated random numbers in a well-defined state.
  rn.seed(seed)
  # The below tf.random.set_seed will make random number generation in TensorFlow have a well-defined initial state.
  tf.random.set_seed(seed)

def show_training_and_validation_performance(history):
  '''
  show_training_and_validation_performance is used to plot the performances during the training phase
  :param history: object in which are recorded all the events
  '''
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'bo', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

def load_training_set (image_height, image_width, batch_size):
  '''
  load_training_set loads the training set from the "training_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return the training set
  '''
  return image_dataset_from_directory(
    TRAINING_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def load_validation_set (image_height, image_width, batch_size):
  '''
  load_validation_set loads the validation set from the "validation_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return the validation set
  '''
  return image_dataset_from_directory(
    VALIDATION_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def load_test_set (image_height, image_width, batch_size):
  '''
  load_test_set loads the test set from the "test_set" folder. The images are resized to height x width
  :param image_height: standard height of the images
  :param image_width: standard width of the images
  :param batch_size: size of each batch
  :return the test set
  '''
  return image_dataset_from_directory(
    TEST_PATH,
    image_size = (image_height, image_width),
    batch_size = batch_size,
    shuffle = False,
    class_names = ['hem', 'all']) # explicit ordering of the labels, 0 for hem, 1 for all

def compile_model (model, optimizer='adam', learning_rate = 0.001):
  '''
  compile_model is used to compile the current model
  :param model: model to compile
  :param optimizer: optimizer to be used
  :param learning_rate: learning rate parameter for the optimizer
  '''
  if optimizer == 'adam':
    model.compile(loss="binary_crossentropy",
      optimizer=optimizers.Adam(learning_rate=learning_rate),
      metrics=["accuracy"])
  elif optimizer == 'rmsprop':
    model.compile(loss="binary_crossentropy",
                  optimizer = optimizers.RMSprop(learning_rate=learning_rate),
                  metrics=['accuracy'])
  model.summary()

def run_model (model, model_name, epochs = 20, patience=5, monitor='val_loss'):
  '''
  run_model is used to run the current mode
  :param model: model to run
  :param model_name: name given to save the model
  :param epochs: how many epochs to do
  :param patience: patience value for Early Stopping
  :param monitor: what to monitor for Early Stopping and Model Checkpoint
  '''
  # local save path for the models
  save_path = LOCAL_MODELS_FOLDER + '/' + model_name + '.h5'
  callbacks_list = [
                  keras.callbacks.EarlyStopping(monitor=monitor, patience=patience),
                  keras.callbacks.ModelCheckpoint(
                      filepath = save_path,
                      monitor=monitor,
                      verbose=1,
                      save_best_only=True)
                  ]
  history = model.fit(train_dataset,
                    epochs=epochs,
                    validation_data=validation_dataset,
                    callbacks=callbacks_list)
  # save on Drive only the best model
  shutil.copy(save_path, GLOBAL_MODELS_FOLDER + '/' + model_name + '.h5')
  show_training_and_validation_performance(history)

def evaluate_model (model):
  '''
  evaluate_model is used to plot some statistics about the performance on the test set
  :param model: model to consider
  '''
  y_score = model.predict(test_dataset)
  y_pred = np.rint(y_score) # to have 0 or 1
  y_true = tf.concat([labels_batch for data_batch, labels_batch in test_dataset], axis = 0)
  print("Classification report: ")
  print(metrics.classification_report(y_true,y_pred,digits = 4))
  metrics.ConfusionMatrixDisplay.from_predictions(y_true, y_pred)

  # ROC curve
  fpr,tpr,th = metrics.roc_curve(y_true,y_score)
  roc_auc = metrics.roc_auc_score(y_true,y_score)

  plt.figure()
  plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
  plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.0])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('ROC curve')
  plt.legend(loc="lower right")
  plt.show()

# %% [markdown]
# ## Load Dataset
# The dataset, properly preprocessed, is now located in the local machine.

# %%
set_seed()

# %% [markdown]
# At this point we need to transform the images we have on disk into preprocessed tensors.
#
# We decided to use the size that ResNet-50 expects as input, which is 224x224, and to use batches of size 32.

# %%
train_dataset = load_training_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
validation_dataset = load_validation_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)
test_dataset = load_test_set(IMAGE_HEIGHT, IMAGE_WIDTH, BATCH_SIZE)

# %% [markdown]
# ## Feature extraction

# %%
conv_base = tf.keras.applications.MobileNetV2(
    input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,3),
    alpha=1,
    include_top= False,
    weights="imagenet",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 112, 112, 32)         864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 112, 112, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 112, 112, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 112, 112, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 112, 112, 32)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 112, 112, 16)         512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 112, 112, 16)         64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 112, 112, 96)         1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 112, 112, 96)         384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 112, 112, 96)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 113, 113, 96)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 56, 56, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 56, 56, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 56, 56, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 56, 56, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 56, 56, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 56, 56, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 56, 56, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 56, 56, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 56, 56, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 57, 57, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 28, 28, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 28, 28, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 28, 28, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 28, 28, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 28, 28, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 28, 28, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 29, 29, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 14, 14, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 14, 14, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 14, 14, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 14, 14, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 14, 14, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 14, 14, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 14, 14, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 14, 14, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 14, 14, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 14, 14, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 14, 14, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 14, 14, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 14, 14, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 14, 14, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 14, 14, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 14, 14, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 14, 14, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 14, 14, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 14, 14, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 15, 15, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 7, 7, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 7, 7, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 7, 7, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 7, 7, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 7, 7, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 7, 7, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 7, 7, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 7, 7, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 7, 7, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 7, 7, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 7, 7, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 7, 7, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 7, 7, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 7, 7, 1280)           0         ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2257984 (8.61 MB)
# Trainable params: 2223872 (8.48 MB)
# Non-trainable params: 34112 (133.25 KB)
# __________________________________________________________________________________________________

# %%
conv_base.trainable = False

# %% [markdown]
# ### Experiment 1
# In this first experiment we try a simple configuration with a single dense layer before the output layer, without regularization techniques.

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = tf.keras.applications.mobilenet.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model1 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv (TFOpLambd  (None, 224, 224, 3)       0
#  a)
#
#  tf.math.subtract (TFOpLamb  (None, 224, 224, 3)       0
#  da)
#
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  flatten (Flatten)           (None, 62720)             0
#
#  dense (Dense)               (None, 1)                 62721
#
# =================================================================
# Total params: 2320705 (8.85 MB)
# Trainable params: 62721 (245.00 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
run_model(model1, 'experiment1_feature_extraction', epochs = 30, patience=5)
# Out:
# Epoch 1/30
# 200/200 [==============================] - ETA: 0s - loss: 1.3209 - accuracy: 0.6923
# Epoch 1: val_loss improved from inf to 0.83859, saving model to /content/models/experiment1_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 22s 73ms/step - loss: 1.3209 - accuracy: 0.6923 - val_loss: 0.8386 - val_accuracy: 0.7706
# Epoch 2/30
# 200/200 [==============================] - ETA: 0s - loss: 0.5568 - accuracy: 0.8139
# Epoch 2: val_loss improved from 0.83859 to 0.63899, saving model to /content/models/experiment1_feature_extraction.h5
# 200/200 [==============================] - 15s 73ms/step - loss: 0.5568 - accuracy: 0.8139 - val_loss: 0.6390 - val_accuracy: 0.8152
# Epoch 3/30
# 199/200 [============================>.] - ETA: 0s - loss: 0.3334 - accuracy: 0.8742
# Epoch 3: val_loss improved from 0.63899 to 0.61082, saving model to /content/models/experiment1_feature_extraction.h5
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3333 - accuracy: 0.8741 - val_loss: 0.6108 - val_accuracy: 0.8086
# Epoch 4/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1861 - accuracy: 0.9256
# Epoch 4: val_loss did not improve from 0.61082
# 200/200 [==============================] - 12s 58ms/step - loss: 0.1861 - accuracy: 0.9256 - val_loss: 0.6259 - val_accuracy: 0.7997
# Epoch 5/30
# 199/200 [============================>.] - ETA: 0s - loss: 0.1872 - accuracy: 0.9207
# Epoch 5: val_loss did not improve from 0.61082
# 200/200 [==============================] - 12s 60ms/step - loss: 0.1869 - accuracy: 0.9209 - val_loss: 0.7439 - val_accuracy: 0.8152
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.2195 - accuracy: 0.9217
# Epoch 6: val_loss did not improve from 0.61082
# 200/200 [==============================] - 12s 60ms/step - loss: 0.2195 - accuracy: 0.9217 - val_loss: 0.8818 - val_accuracy: 0.7889
# Epoch 7/30
# 200/200 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9556
# Epoch 7: val_loss did not improve from 0.61082
# 200/200 [==============================] - 12s 60ms/step - loss: 0.1165 - accuracy: 0.9556 - val_loss: 0.7989 - val_accuracy: 0.7913
# Epoch 8/30
# 199/200 [============================>.] - ETA: 0s - loss: 0.0800 - accuracy: 0.9670
# Epoch 8: val_loss did not improve from 0.61082
# 200/200 [==============================] - 12s 60ms/step - loss: 0.0798 - accuracy: 0.9672 - val_loss: 0.8458 - val_accuracy: 0.7795

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment1_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 5s 55ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6835    0.7759    0.7268       696
#            1     0.8838    0.8260    0.8540      1437
#
#     accuracy                         0.8097      2133
#    macro avg     0.7837    0.8009    0.7904      2133
# weighted avg     0.8185    0.8097    0.8125      2133

# %% [markdown]
# ### Experiment 2

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = tf.keras.applications.mobilenet.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model2 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model2)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_1 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_1 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 2586177 (9.87 MB)
# Trainable params: 328193 (1.25 MB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
run_model(model2, 'experiment2_feature_extraction', epochs = 30, patience=5)
# Out:
# Epoch 1/30
# 199/200 [============================>.] - ETA: 0s - loss: 0.7185 - accuracy: 0.6878
# Epoch 1: val_loss improved from inf to 0.66654, saving model to /content/models/experiment2_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 18s 66ms/step - loss: 0.7190 - accuracy: 0.6873 - val_loss: 0.6665 - val_accuracy: 0.6595
# Epoch 2/30
# 199/200 [============================>.] - ETA: 0s - loss: 0.5792 - accuracy: 0.7263
# Epoch 2: val_loss improved from 0.66654 to 0.55427, saving model to /content/models/experiment2_feature_extraction.h5
# 200/200 [==============================] - 13s 61ms/step - loss: 0.5799 - accuracy: 0.7259 - val_loss: 0.5543 - val_accuracy: 0.7045
# Epoch 3/30
# 199/200 [============================>.] - ETA: 0s - loss: 0.5163 - accuracy: 0.7535
# Epoch 3: val_loss did not improve from 0.55427
# 200/200 [==============================] - 13s 62ms/step - loss: 0.5168 - accuracy: 0.7530 - val_loss: 0.6198 - val_accuracy: 0.6646
# Epoch 4/30
# 199/200 [============================>.] - ETA: 0s - loss: 0.5052 - accuracy: 0.7544
# Epoch 4: val_loss improved from 0.55427 to 0.43391, saving model to /content/models/experiment2_feature_extraction.h5
# 200/200 [==============================] - 13s 62ms/step - loss: 0.5051 - accuracy: 0.7545 - val_loss: 0.4339 - val_accuracy: 0.8082
# Epoch 5/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4712 - accuracy: 0.7767
# Epoch 5: val_loss improved from 0.43391 to 0.41827, saving model to /content/models/experiment2_feature_extraction.h5
# 200/200 [==============================] - 13s 62ms/step - loss: 0.4712 - accuracy: 0.7767 - val_loss: 0.4183 - val_accuracy: 0.8152
# Epoch 6/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4814 - accuracy: 0.7656
# Epoch 6: val_loss improved from 0.41827 to 0.41397, saving model to /content/models/experiment2_feature_extraction.h5
# 200/200 [==============================] - 13s 62ms/step - loss: 0.4814 - accuracy: 0.7656 - val_loss: 0.4140 - val_accuracy: 0.8218
# Epoch 7/30
# 199/200 [============================>.] - ETA: 0s - loss: 0.4589 - accuracy: 0.7805
# Epoch 7: val_loss did not improve from 0.41397
# 200/200 [==============================] - 12s 61ms/step - loss: 0.4597 - accuracy: 0.7803 - val_loss: 0.4188 - val_accuracy: 0.8204
# Epoch 8/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4577 - accuracy: 0.7814
# Epoch 8: val_loss did not improve from 0.41397
# 200/200 [==============================] - 14s 68ms/step - loss: 0.4577 - accuracy: 0.7814 - val_loss: 0.4245 - val_accuracy: 0.8157
# Epoch 9/30
# 199/200 [============================>.] - ETA: 0s - loss: 0.4694 - accuracy: 0.7748
# Epoch 9: val_loss did not improve from 0.41397
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4690 - accuracy: 0.7749 - val_loss: 0.4149 - val_accuracy: 0.8194
# Epoch 10/30
# 200/200 [==============================] - ETA: 0s - loss: 0.4522 - accuracy: 0.7850
# Epoch 10: val_loss did not improve from 0.41397
# 200/200 [==============================] - 13s 62ms/step - loss: 0.4522 - accuracy: 0.7850 - val_loss: 0.5215 - val_accuracy: 0.7317
# Epoch 11/30
# 199/200 [============================>.] - ETA: 0s - loss: 0.4520 - accuracy: 0.7872
# Epoch 11: val_loss did not improve from 0.41397
# 200/200 [==============================] - 12s 61ms/step - loss: 0.4519 - accuracy: 0.7872 - val_loss: 0.4283 - val_accuracy: 0.8030

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment2_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 4s 41ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7893    0.6566    0.7169       696
#            1     0.8462    0.9151    0.8793      1437
#
#     accuracy                         0.8308      2133
#    macro avg     0.8177    0.7859    0.7981      2133
# weighted avg     0.8276    0.8308    0.8263      2133

# %% [markdown]
# ### Experiment 3

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = tf.keras.applications.mobilenet.preprocess_input(inputs)
x = conv_base(x) # feature extraction
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model3 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model3)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_2 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_2 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d_1  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense_3 (Dense)             (None, 1)                 1281
#
# =================================================================
# Total params: 2259265 (8.62 MB)
# Trainable params: 1281 (5.00 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
run_model(model3, 'experiment3_feature_extraction', epochs = 50, patience=5)
# Out:
# Epoch 1/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.6713 - accuracy: 0.6443
# Epoch 1: val_loss improved from inf to 0.50274, saving model to /content/models/experiment3_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 16s 66ms/step - loss: 0.6708 - accuracy: 0.6449 - val_loss: 0.5027 - val_accuracy: 0.7645
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5773 - accuracy: 0.7014
# Epoch 2: val_loss did not improve from 0.50274
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5773 - accuracy: 0.7014 - val_loss: 0.5392 - val_accuracy: 0.7364
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5488 - accuracy: 0.7247
# Epoch 3: val_loss improved from 0.50274 to 0.48573, saving model to /content/models/experiment3_feature_extraction.h5
# 200/200 [==============================] - 13s 62ms/step - loss: 0.5488 - accuracy: 0.7247 - val_loss: 0.4857 - val_accuracy: 0.7739
# Epoch 4/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5364 - accuracy: 0.7301
# Epoch 4: val_loss did not improve from 0.48573
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5365 - accuracy: 0.7301 - val_loss: 0.4933 - val_accuracy: 0.7669
# Epoch 5/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5266 - accuracy: 0.7396
# Epoch 5: val_loss improved from 0.48573 to 0.46955, saving model to /content/models/experiment3_feature_extraction.h5
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5262 - accuracy: 0.7398 - val_loss: 0.4696 - val_accuracy: 0.7903
# Epoch 6/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5214 - accuracy: 0.7442
# Epoch 6: val_loss did not improve from 0.46955
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5216 - accuracy: 0.7439 - val_loss: 0.4873 - val_accuracy: 0.7720
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5204 - accuracy: 0.7444
# Epoch 7: val_loss improved from 0.46955 to 0.46129, saving model to /content/models/experiment3_feature_extraction.h5
# 200/200 [==============================] - 13s 62ms/step - loss: 0.5204 - accuracy: 0.7444 - val_loss: 0.4613 - val_accuracy: 0.7941
# Epoch 8/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5208 - accuracy: 0.7434
# Epoch 8: val_loss did not improve from 0.46129
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5207 - accuracy: 0.7436 - val_loss: 0.5267 - val_accuracy: 0.7420
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5177 - accuracy: 0.7427
# Epoch 9: val_loss did not improve from 0.46129
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5177 - accuracy: 0.7427 - val_loss: 0.4836 - val_accuracy: 0.7711
# Epoch 10/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5198 - accuracy: 0.7418
# Epoch 10: val_loss improved from 0.46129 to 0.44842, saving model to /content/models/experiment3_feature_extraction.h5
# 200/200 [==============================] - 13s 61ms/step - loss: 0.5202 - accuracy: 0.7419 - val_loss: 0.4484 - val_accuracy: 0.8063
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5144 - accuracy: 0.7497
# Epoch 11: val_loss did not improve from 0.44842
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5144 - accuracy: 0.7497 - val_loss: 0.4893 - val_accuracy: 0.7720
# Epoch 12/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5102 - accuracy: 0.7466
# Epoch 12: val_loss did not improve from 0.44842
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5102 - accuracy: 0.7466 - val_loss: 0.4744 - val_accuracy: 0.7786
# Epoch 13/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5149 - accuracy: 0.7395
# Epoch 13: val_loss improved from 0.44842 to 0.44483, saving model to /content/models/experiment3_feature_extraction.h5
# 200/200 [==============================] - 13s 62ms/step - loss: 0.5155 - accuracy: 0.7391 - val_loss: 0.4448 - val_accuracy: 0.8030
# Epoch 14/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5160 - accuracy: 0.7487
# Epoch 14: val_loss did not improve from 0.44483
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5164 - accuracy: 0.7487 - val_loss: 0.4744 - val_accuracy: 0.7871
# Epoch 15/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5064 - accuracy: 0.7561
# Epoch 15: val_loss did not improve from 0.44483
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5064 - accuracy: 0.7561 - val_loss: 0.4805 - val_accuracy: 0.7772
# Epoch 16/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5082 - accuracy: 0.7489
# Epoch 16: val_loss did not improve from 0.44483
# 200/200 [==============================] - 12s 57ms/step - loss: 0.5083 - accuracy: 0.7489 - val_loss: 0.4476 - val_accuracy: 0.8021
# Epoch 17/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5065 - accuracy: 0.7511
# Epoch 17: val_loss did not improve from 0.44483
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5068 - accuracy: 0.7513 - val_loss: 0.4521 - val_accuracy: 0.7988
# Epoch 18/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5007 - accuracy: 0.7610
# Epoch 18: val_loss did not improve from 0.44483
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5012 - accuracy: 0.7605 - val_loss: 0.5158 - val_accuracy: 0.7467

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment3_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 3s 40ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7504    0.6825    0.7148       696
#            1     0.8527    0.8900    0.8710      1437
#
#     accuracy                         0.8223      2133
#    macro avg     0.8015    0.7863    0.7929      2133
# weighted avg     0.8193    0.8223    0.8200      2133

# %% [markdown]
# ### Experiment 4

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = tf.keras.applications.mobilenet.preprocess_input(inputs)
x = conv_base(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(512, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model4 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model4, optimizer='rmsprop')
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_3 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_3 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d_2  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 512)               655872
#
#  dense_5 (Dense)             (None, 512)               262656
#
#  dense_6 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 3177025 (12.12 MB)
# Trainable params: 919041 (3.51 MB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
run_model(model4, "Experiment4_feature_extraction", epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 0.6234 - accuracy: 0.7018
# Epoch 1: val_loss improved from inf to 0.70217, saving model to /content/models/Experiment4_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 20s 74ms/step - loss: 0.6234 - accuracy: 0.7018 - val_loss: 0.7022 - val_accuracy: 0.5507
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5141 - accuracy: 0.7517
# Epoch 2: val_loss improved from 0.70217 to 0.44138, saving model to /content/models/Experiment4_feature_extraction.h5
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5141 - accuracy: 0.7517 - val_loss: 0.4414 - val_accuracy: 0.8143
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4787 - accuracy: 0.7670
# Epoch 3: val_loss improved from 0.44138 to 0.43023, saving model to /content/models/Experiment4_feature_extraction.h5
# 200/200 [==============================] - 13s 64ms/step - loss: 0.4787 - accuracy: 0.7670 - val_loss: 0.4302 - val_accuracy: 0.8096
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4561 - accuracy: 0.7852
# Epoch 4: val_loss did not improve from 0.43023
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4561 - accuracy: 0.7852 - val_loss: 0.5726 - val_accuracy: 0.7322
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4398 - accuracy: 0.7910
# Epoch 5: val_loss improved from 0.43023 to 0.41380, saving model to /content/models/Experiment4_feature_extraction.h5
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4398 - accuracy: 0.7910 - val_loss: 0.4138 - val_accuracy: 0.8307
# Epoch 6/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.4230 - accuracy: 0.7985
# Epoch 6: val_loss did not improve from 0.41380
# 200/200 [==============================] - 13s 62ms/step - loss: 0.4233 - accuracy: 0.7985 - val_loss: 0.4263 - val_accuracy: 0.8236
# Epoch 7/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.4035 - accuracy: 0.8138
# Epoch 7: val_loss did not improve from 0.41380
# 200/200 [==============================] - 12s 59ms/step - loss: 0.4032 - accuracy: 0.8139 - val_loss: 0.4248 - val_accuracy: 0.8194
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3885 - accuracy: 0.8197
# Epoch 8: val_loss did not improve from 0.41380
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3885 - accuracy: 0.8197 - val_loss: 0.6213 - val_accuracy: 0.7022
# Epoch 9/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.3701 - accuracy: 0.8280
# Epoch 9: val_loss did not improve from 0.41380
# 200/200 [==============================] - 12s 60ms/step - loss: 0.3700 - accuracy: 0.8282 - val_loss: 0.4158 - val_accuracy: 0.8354
# Epoch 10/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.3591 - accuracy: 0.8372
# Epoch 10: val_loss did not improve from 0.41380
# 200/200 [==============================] - 13s 62ms/step - loss: 0.3598 - accuracy: 0.8366 - val_loss: 0.5183 - val_accuracy: 0.7645

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/Experiment4_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 4s 44ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7685    0.7011    0.7333       696
#            1     0.8611    0.8977    0.8790      1437
#
#     accuracy                         0.8336      2133
#    macro avg     0.8148    0.7994    0.8062      2133
# weighted avg     0.8309    0.8336    0.8315      2133

# %% [markdown]
# ## Fine tuning

# %% [markdown]
# ### Experiment 5

# %%
fine_tuning = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment3_feature_extraction.h5'))

setTrainable = False
for layer in fine_tuning.get_layer('mobilenetv2_1.00_224').layers:
    if layer.name in ('block_16_expand'):
        setTrainable = True
    if setTrainable == True:
        layer.trainable = True
    else:
      layer.trainable = False

compile_model(fine_tuning, learning_rate=1e-5)

for i, layer in enumerate(fine_tuning.get_layer('mobilenetv2_1.00_224').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_2 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_2 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d_1  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense_3 (Dense)             (None, 1)                 1281
#
# =================================================================
# Total params: 2259265 (8.62 MB)
# Trainable params: 887361 (3.39 MB)
# Non-trainable params: 1371904 (5.23 MB)
# _________________________________________________________________
# 0 input_1 False
# 1 Conv1 False
# 2 bn_Conv1 False
# 3 Conv1_relu False
# 4 expanded_conv_depthwise False
# 5 expanded_conv_depthwise_BN False
# 6 expanded_conv_depthwise_relu False
# 7 expanded_conv_project False
# 8 expanded_conv_project_BN False
# 9 block_1_expand False
# 10 block_1_expand_BN False
# 11 block_1_expand_relu False
# 12 block_1_pad False
# 13 block_1_depthwise False
# 14 block_1_depthwise_BN False
# 15 block_1_depthwise_relu False
# 16 block_1_project False
# 17 block_1_project_BN False
# 18 block_2_expand False
# 19 block_2_expand_BN False
# 20 block_2_expand_relu False
# 21 block_2_depthwise False
# 22 block_2_depthwise_BN False
# 23 block_2_depthwise_relu False
# 24 block_2_project False
# 25 block_2_project_BN False
# 26 block_2_add False
# 27 block_3_expand False
# 28 block_3_expand_BN False
# 29 block_3_expand_relu False
# 30 block_3_pad False
# 31 block_3_depthwise False
# 32 block_3_depthwise_BN False
# 33 block_3_depthwise_relu False
# 34 block_3_project False
# 35 block_3_project_BN False
# 36 block_4_expand False
# 37 block_4_expand_BN False
# 38 block_4_expand_relu False
# 39 block_4_depthwise False
# 40 block_4_depthwise_BN False
# 41 block_4_depthwise_relu False
# 42 block_4_project False
# 43 block_4_project_BN False
# 44 block_4_add False
# 45 block_5_expand False
# 46 block_5_expand_BN False
# 47 block_5_expand_relu False
# 48 block_5_depthwise False
# 49 block_5_depthwise_BN False
# 50 block_5_depthwise_relu False
# 51 block_5_project False
# 52 block_5_project_BN False
# 53 block_5_add False
# 54 block_6_expand False
# 55 block_6_expand_BN False
# 56 block_6_expand_relu False
# 57 block_6_pad False
# 58 block_6_depthwise False
# 59 block_6_depthwise_BN False
# 60 block_6_depthwise_relu False
# 61 block_6_project False
# 62 block_6_project_BN False
# 63 block_7_expand False
# 64 block_7_expand_BN False
# 65 block_7_expand_relu False
# 66 block_7_depthwise False
# 67 block_7_depthwise_BN False
# 68 block_7_depthwise_relu False
# 69 block_7_project False
# 70 block_7_project_BN False
# 71 block_7_add False
# 72 block_8_expand False
# 73 block_8_expand_BN False
# 74 block_8_expand_relu False
# 75 block_8_depthwise False
# 76 block_8_depthwise_BN False
# 77 block_8_depthwise_relu False
# 78 block_8_project False
# 79 block_8_project_BN False
# 80 block_8_add False
# 81 block_9_expand False
# 82 block_9_expand_BN False
# 83 block_9_expand_relu False
# 84 block_9_depthwise False
# 85 block_9_depthwise_BN False
# 86 block_9_depthwise_relu False
# 87 block_9_project False
# 88 block_9_project_BN False
# 89 block_9_add False
# 90 block_10_expand False
# 91 block_10_expand_BN False
# 92 block_10_expand_relu False
# 93 block_10_depthwise False
# 94 block_10_depthwise_BN False
# 95 block_10_depthwise_relu False
# 96 block_10_project False
# 97 block_10_project_BN False
# 98 block_11_expand False
# 99 block_11_expand_BN False
# 100 block_11_expand_relu False
# 101 block_11_depthwise False
# 102 block_11_depthwise_BN False
# 103 block_11_depthwise_relu False
# 104 block_11_project False
# 105 block_11_project_BN False
# 106 block_11_add False
# 107 block_12_expand False
# 108 block_12_expand_BN False
# 109 block_12_expand_relu False
# 110 block_12_depthwise False
# 111 block_12_depthwise_BN False
# 112 block_12_depthwise_relu False
# 113 block_12_project False
# 114 block_12_project_BN False
# 115 block_12_add False
# 116 block_13_expand False
# 117 block_13_expand_BN False
# 118 block_13_expand_relu False
# 119 block_13_pad False
# 120 block_13_depthwise False
# 121 block_13_depthwise_BN False
# 122 block_13_depthwise_relu False
# 123 block_13_project False
# 124 block_13_project_BN False
# 125 block_14_expand False
# 126 block_14_expand_BN False
# 127 block_14_expand_relu False
# 128 block_14_depthwise False
# 129 block_14_depthwise_BN False
# 130 block_14_depthwise_relu False
# 131 block_14_project False
# 132 block_14_project_BN False
# 133 block_14_add False
# 134 block_15_expand False
# 135 block_15_expand_BN False
# 136 block_15_expand_relu False
# 137 block_15_depthwise False
# 138 block_15_depthwise_BN False
# 139 block_15_depthwise_relu False
# 140 block_15_project False
# 141 block_15_project_BN False
# 142 block_15_add False
# 143 block_16_expand True
# 144 block_16_expand_BN True
# 145 block_16_expand_relu True
# 146 block_16_depthwise True
# 147 block_16_depthwise_BN True
# 148 block_16_depthwise_relu True
# 149 block_16_project True
# 150 block_16_project_BN True
# 151 Conv_1 True
# 152 Conv_1_bn True
# 153 out_relu True

# %%
run_model(fine_tuning, 'experiment5_finetuning', epochs = 100, patience=5)
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.7018 - accuracy: 0.6790
# Epoch 1: val_loss improved from inf to 0.44105, saving model to /content/models/experiment5_finetuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 19s 72ms/step - loss: 0.7018 - accuracy: 0.6790 - val_loss: 0.4411 - val_accuracy: 0.8002
# Epoch 2/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5986 - accuracy: 0.7111
# Epoch 2: val_loss did not improve from 0.44105
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6000 - accuracy: 0.7106 - val_loss: 0.4646 - val_accuracy: 0.7889
# Epoch 3/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5513 - accuracy: 0.7362
# Epoch 3: val_loss did not improve from 0.44105
# 200/200 [==============================] - 13s 64ms/step - loss: 0.5513 - accuracy: 0.7358 - val_loss: 0.4668 - val_accuracy: 0.7936
# Epoch 4/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5342 - accuracy: 0.7407
# Epoch 4: val_loss did not improve from 0.44105
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5339 - accuracy: 0.7409 - val_loss: 0.4907 - val_accuracy: 0.7739
# Epoch 5/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5177 - accuracy: 0.7528
# Epoch 5: val_loss did not improve from 0.44105
# 200/200 [==============================] - 13s 64ms/step - loss: 0.5168 - accuracy: 0.7531 - val_loss: 0.5280 - val_accuracy: 0.7481
# Epoch 6/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.4904 - accuracy: 0.7638
# Epoch 6: val_loss did not improve from 0.44105
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4908 - accuracy: 0.7636 - val_loss: 0.5260 - val_accuracy: 0.7514

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment5_finetuning.h5'))
# Out:
# 67/67 [==============================] - 4s 48ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7107    0.6954    0.7030       696
#            1     0.8540    0.8629    0.8584      1437
#
#     accuracy                         0.8083      2133
#    macro avg     0.7824    0.7792    0.7807      2133
# weighted avg     0.8072    0.8083    0.8077      2133

# %% [markdown]
# ### Experiment 6

# %%
fine_tuning = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment2_feature_extraction.h5'))

setTrainable = False
for layer in fine_tuning.get_layer('mobilenetv2_1.00_224').layers:
    if layer.name in ('block_10_expand'):
        setTrainable = True
    if setTrainable == True:
        layer.trainable = True
    else:
      layer.trainable = False

compile_model(fine_tuning, learning_rate=1e-5)

for i, layer in enumerate(fine_tuning.get_layer('mobilenetv2_1.00_224').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_1 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_1 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 2586177 (9.87 MB)
# Trainable params: 2312705 (8.82 MB)
# Non-trainable params: 273472 (1.04 MB)
# _________________________________________________________________
# 0 input_1 False
# 1 Conv1 False
# 2 bn_Conv1 False
# 3 Conv1_relu False
# 4 expanded_conv_depthwise False
# 5 expanded_conv_depthwise_BN False
# 6 expanded_conv_depthwise_relu False
# 7 expanded_conv_project False
# 8 expanded_conv_project_BN False
# 9 block_1_expand False
# 10 block_1_expand_BN False
# 11 block_1_expand_relu False
# 12 block_1_pad False
# 13 block_1_depthwise False
# 14 block_1_depthwise_BN False
# 15 block_1_depthwise_relu False
# 16 block_1_project False
# 17 block_1_project_BN False
# 18 block_2_expand False
# 19 block_2_expand_BN False
# 20 block_2_expand_relu False
# 21 block_2_depthwise False
# 22 block_2_depthwise_BN False
# 23 block_2_depthwise_relu False
# 24 block_2_project False
# 25 block_2_project_BN False
# 26 block_2_add False
# 27 block_3_expand False
# 28 block_3_expand_BN False
# 29 block_3_expand_relu False
# 30 block_3_pad False
# 31 block_3_depthwise False
# 32 block_3_depthwise_BN False
# 33 block_3_depthwise_relu False
# 34 block_3_project False
# 35 block_3_project_BN False
# 36 block_4_expand False
# 37 block_4_expand_BN False
# 38 block_4_expand_relu False
# 39 block_4_depthwise False
# 40 block_4_depthwise_BN False
# 41 block_4_depthwise_relu False
# 42 block_4_project False
# 43 block_4_project_BN False
# 44 block_4_add False
# 45 block_5_expand False
# 46 block_5_expand_BN False
# 47 block_5_expand_relu False
# 48 block_5_depthwise False
# 49 block_5_depthwise_BN False
# 50 block_5_depthwise_relu False
# 51 block_5_project False
# 52 block_5_project_BN False
# 53 block_5_add False
# 54 block_6_expand False
# 55 block_6_expand_BN False
# 56 block_6_expand_relu False
# 57 block_6_pad False
# 58 block_6_depthwise False
# 59 block_6_depthwise_BN False
# 60 block_6_depthwise_relu False
# 61 block_6_project False
# 62 block_6_project_BN False
# 63 block_7_expand False
# 64 block_7_expand_BN False
# 65 block_7_expand_relu False
# 66 block_7_depthwise False
# 67 block_7_depthwise_BN False
# 68 block_7_depthwise_relu False
# 69 block_7_project False
# 70 block_7_project_BN False
# 71 block_7_add False
# 72 block_8_expand False
# 73 block_8_expand_BN False
# 74 block_8_expand_relu False
# 75 block_8_depthwise False
# 76 block_8_depthwise_BN False
# 77 block_8_depthwise_relu False
# 78 block_8_project False
# 79 block_8_project_BN False
# 80 block_8_add False
# 81 block_9_expand False
# 82 block_9_expand_BN False
# 83 block_9_expand_relu False
# 84 block_9_depthwise False
# 85 block_9_depthwise_BN False
# 86 block_9_depthwise_relu False
# 87 block_9_project False
# 88 block_9_project_BN False
# 89 block_9_add False
# 90 block_10_expand True
# 91 block_10_expand_BN True
# 92 block_10_expand_relu True
# 93 block_10_depthwise True
# 94 block_10_depthwise_BN True
# 95 block_10_depthwise_relu True
# 96 block_10_project True
# 97 block_10_project_BN True
# 98 block_11_expand True
# 99 block_11_expand_BN True
# 100 block_11_expand_relu True
# 101 block_11_depthwise True
# 102 block_11_depthwise_BN True
# 103 block_11_depthwise_relu True
# 104 block_11_project True
# 105 block_11_project_BN True
# 106 block_11_add True
# 107 block_12_expand True
# 108 block_12_expand_BN True
# 109 block_12_expand_relu True
# 110 block_12_depthwise True
# 111 block_12_depthwise_BN True
# 112 block_12_depthwise_relu True
# 113 block_12_project True
# 114 block_12_project_BN True
# 115 block_12_add True
# 116 block_13_expand True
# 117 block_13_expand_BN True
# 118 block_13_expand_relu True
# 119 block_13_pad True
# 120 block_13_depthwise True
# 121 block_13_depthwise_BN True
# 122 block_13_depthwise_relu True
# 123 block_13_project True
# 124 block_13_project_BN True
# 125 block_14_expand True
# 126 block_14_expand_BN True
# 127 block_14_expand_relu True
# 128 block_14_depthwise True
# 129 block_14_depthwise_BN True
# 130 block_14_depthwise_relu True
# 131 block_14_project True
# 132 block_14_project_BN True
# 133 block_14_add True
# 134 block_15_expand True
# 135 block_15_expand_BN True
# 136 block_15_expand_relu True
# 137 block_15_depthwise True
# 138 block_15_depthwise_BN True
# 139 block_15_depthwise_relu True
# 140 block_15_project True
# 141 block_15_project_BN True
# 142 block_15_add True
# 143 block_16_expand True
# 144 block_16_expand_BN True
# 145 block_16_expand_relu True
# 146 block_16_depthwise True
# 147 block_16_depthwise_BN True
# 148 block_16_depthwise_relu True
# 149 block_16_project True
# 150 block_16_project_BN True
# 151 Conv_1 True
# 152 Conv_1_bn True
# 153 out_relu True

# %%
run_model(fine_tuning, 'experiment6_finetuning', epochs = 100, patience=5)
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6790 - accuracy: 0.7078
# Epoch 1: val_loss improved from inf to 0.65300, saving model to /content/models/experiment6_finetuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 30s 88ms/step - loss: 0.6790 - accuracy: 0.7078 - val_loss: 0.6530 - val_accuracy: 0.6562
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4606 - accuracy: 0.7872
# Epoch 2: val_loss did not improve from 0.65300
# 200/200 [==============================] - 19s 92ms/step - loss: 0.4606 - accuracy: 0.7872 - val_loss: 0.7349 - val_accuracy: 0.6126
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3620 - accuracy: 0.8399
# Epoch 3: val_loss did not improve from 0.65300
# 200/200 [==============================] - 16s 81ms/step - loss: 0.3620 - accuracy: 0.8399 - val_loss: 0.8938 - val_accuracy: 0.5605
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3012 - accuracy: 0.8691
# Epoch 4: val_loss did not improve from 0.65300
# 200/200 [==============================] - 16s 80ms/step - loss: 0.3012 - accuracy: 0.8691 - val_loss: 0.9699 - val_accuracy: 0.5483
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.2397 - accuracy: 0.9073
# Epoch 5: val_loss did not improve from 0.65300
# 200/200 [==============================] - 16s 80ms/step - loss: 0.2397 - accuracy: 0.9073 - val_loss: 1.1175 - val_accuracy: 0.5164
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.1937 - accuracy: 0.9284
# Epoch 6: val_loss did not improve from 0.65300
# 200/200 [==============================] - 16s 80ms/step - loss: 0.1937 - accuracy: 0.9284 - val_loss: 0.9946 - val_accuracy: 0.5704

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment6_finetuning.h5'))
# Out:
# 67/67 [==============================] - 5s 52ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.4758    0.9195    0.6271       696
#            1     0.9289    0.5094    0.6580      1437
#
#     accuracy                         0.6432      2133
#    macro avg     0.7024    0.7145    0.6426      2133
# weighted avg     0.7811    0.6432    0.6479      2133

# %% [markdown]
# ### Experiment 7

# %%
fine_tuning = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment3_feature_extraction.h5'))

setTrainable = False
for layer in fine_tuning.get_layer('mobilenetv2_1.00_224').layers:
    if layer.name in ('block_10_expand'):
        setTrainable = True
    if setTrainable == True:
        layer.trainable = True
    else:
      layer.trainable = False

compile_model(fine_tuning, learning_rate=1e-5)

for i, layer in enumerate(fine_tuning.get_layer('mobilenetv2_1.00_224').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_2 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_2 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d_1  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  dense_3 (Dense)             (None, 1)                 1281
#
# =================================================================
# Total params: 2259265 (8.62 MB)
# Trainable params: 1985793 (7.58 MB)
# Non-trainable params: 273472 (1.04 MB)
# _________________________________________________________________
# 0 input_1 False
# 1 Conv1 False
# 2 bn_Conv1 False
# 3 Conv1_relu False
# 4 expanded_conv_depthwise False
# 5 expanded_conv_depthwise_BN False
# 6 expanded_conv_depthwise_relu False
# 7 expanded_conv_project False
# 8 expanded_conv_project_BN False
# 9 block_1_expand False
# 10 block_1_expand_BN False
# 11 block_1_expand_relu False
# 12 block_1_pad False
# 13 block_1_depthwise False
# 14 block_1_depthwise_BN False
# 15 block_1_depthwise_relu False
# 16 block_1_project False
# 17 block_1_project_BN False
# 18 block_2_expand False
# 19 block_2_expand_BN False
# 20 block_2_expand_relu False
# 21 block_2_depthwise False
# 22 block_2_depthwise_BN False
# 23 block_2_depthwise_relu False
# 24 block_2_project False
# 25 block_2_project_BN False
# 26 block_2_add False
# 27 block_3_expand False
# 28 block_3_expand_BN False
# 29 block_3_expand_relu False
# 30 block_3_pad False
# 31 block_3_depthwise False
# 32 block_3_depthwise_BN False
# 33 block_3_depthwise_relu False
# 34 block_3_project False
# 35 block_3_project_BN False
# 36 block_4_expand False
# 37 block_4_expand_BN False
# 38 block_4_expand_relu False
# 39 block_4_depthwise False
# 40 block_4_depthwise_BN False
# 41 block_4_depthwise_relu False
# 42 block_4_project False
# 43 block_4_project_BN False
# 44 block_4_add False
# 45 block_5_expand False
# 46 block_5_expand_BN False
# 47 block_5_expand_relu False
# 48 block_5_depthwise False
# 49 block_5_depthwise_BN False
# 50 block_5_depthwise_relu False
# 51 block_5_project False
# 52 block_5_project_BN False
# 53 block_5_add False
# 54 block_6_expand False
# 55 block_6_expand_BN False
# 56 block_6_expand_relu False
# 57 block_6_pad False
# 58 block_6_depthwise False
# 59 block_6_depthwise_BN False
# 60 block_6_depthwise_relu False
# 61 block_6_project False
# 62 block_6_project_BN False
# 63 block_7_expand False
# 64 block_7_expand_BN False
# 65 block_7_expand_relu False
# 66 block_7_depthwise False
# 67 block_7_depthwise_BN False
# 68 block_7_depthwise_relu False
# 69 block_7_project False
# 70 block_7_project_BN False
# 71 block_7_add False
# 72 block_8_expand False
# 73 block_8_expand_BN False
# 74 block_8_expand_relu False
# 75 block_8_depthwise False
# 76 block_8_depthwise_BN False
# 77 block_8_depthwise_relu False
# 78 block_8_project False
# 79 block_8_project_BN False
# 80 block_8_add False
# 81 block_9_expand False
# 82 block_9_expand_BN False
# 83 block_9_expand_relu False
# 84 block_9_depthwise False
# 85 block_9_depthwise_BN False
# 86 block_9_depthwise_relu False
# 87 block_9_project False
# 88 block_9_project_BN False
# 89 block_9_add False
# 90 block_10_expand True
# 91 block_10_expand_BN True
# 92 block_10_expand_relu True
# 93 block_10_depthwise True
# 94 block_10_depthwise_BN True
# 95 block_10_depthwise_relu True
# 96 block_10_project True
# 97 block_10_project_BN True
# 98 block_11_expand True
# 99 block_11_expand_BN True
# 100 block_11_expand_relu True
# 101 block_11_depthwise True
# 102 block_11_depthwise_BN True
# 103 block_11_depthwise_relu True
# 104 block_11_project True
# 105 block_11_project_BN True
# 106 block_11_add True
# 107 block_12_expand True
# 108 block_12_expand_BN True
# 109 block_12_expand_relu True
# 110 block_12_depthwise True
# 111 block_12_depthwise_BN True
# 112 block_12_depthwise_relu True
# 113 block_12_project True
# 114 block_12_project_BN True
# 115 block_12_add True
# 116 block_13_expand True
# 117 block_13_expand_BN True
# 118 block_13_expand_relu True
# 119 block_13_pad True
# 120 block_13_depthwise True
# 121 block_13_depthwise_BN True
# 122 block_13_depthwise_relu True
# 123 block_13_project True
# 124 block_13_project_BN True
# 125 block_14_expand True
# 126 block_14_expand_BN True
# 127 block_14_expand_relu True
# 128 block_14_depthwise True
# 129 block_14_depthwise_BN True
# 130 block_14_depthwise_relu True
# 131 block_14_project True
# 132 block_14_project_BN True
# 133 block_14_add True
# 134 block_15_expand True
# 135 block_15_expand_BN True
# 136 block_15_expand_relu True
# 137 block_15_depthwise True
# 138 block_15_depthwise_BN True
# 139 block_15_depthwise_relu True
# 140 block_15_project True
# 141 block_15_project_BN True
# 142 block_15_add True
# 143 block_16_expand True
# 144 block_16_expand_BN True
# 145 block_16_expand_relu True
# 146 block_16_depthwise True
# 147 block_16_depthwise_BN True
# 148 block_16_depthwise_relu True
# 149 block_16_project True
# 150 block_16_project_BN True
# 151 Conv_1 True
# 152 Conv_1_bn True
# 153 out_relu True

# %%
run_model(fine_tuning, 'experiment7_finetuning', epochs = 100, patience=5)
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.7894 - accuracy: 0.6787
# Epoch 1: val_loss improved from inf to 0.54086, saving model to /content/models/experiment7_finetuning.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 29s 87ms/step - loss: 0.7894 - accuracy: 0.6787 - val_loss: 0.5409 - val_accuracy: 0.7397
# Epoch 2/100
# 200/200 [==============================] - ETA: 0s - loss: 0.6397 - accuracy: 0.7287
# Epoch 2: val_loss did not improve from 0.54086
# 200/200 [==============================] - 16s 80ms/step - loss: 0.6397 - accuracy: 0.7287 - val_loss: 0.6443 - val_accuracy: 0.6914
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5312 - accuracy: 0.7692
# Epoch 3: val_loss did not improve from 0.54086
# 200/200 [==============================] - 16s 80ms/step - loss: 0.5312 - accuracy: 0.7692 - val_loss: 0.6942 - val_accuracy: 0.6773
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4390 - accuracy: 0.8007
# Epoch 4: val_loss did not improve from 0.54086
# 200/200 [==============================] - 16s 80ms/step - loss: 0.4390 - accuracy: 0.8007 - val_loss: 0.7468 - val_accuracy: 0.6642
# Epoch 5/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4156 - accuracy: 0.8100
# Epoch 5: val_loss did not improve from 0.54086
# 200/200 [==============================] - 16s 80ms/step - loss: 0.4156 - accuracy: 0.8100 - val_loss: 0.7737 - val_accuracy: 0.6604
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.3554 - accuracy: 0.8407
# Epoch 6: val_loss did not improve from 0.54086
# 200/200 [==============================] - 16s 80ms/step - loss: 0.3554 - accuracy: 0.8407 - val_loss: 0.6415 - val_accuracy: 0.7111

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment7_finetuning.h5'))
# Out:
# 67/67 [==============================] - 4s 44ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.5609    0.8333    0.6705       696
#            1     0.8944    0.6841    0.7752      1437
#
#     accuracy                         0.7328      2133
#    macro avg     0.7277    0.7587    0.7229      2133
# weighted avg     0.7856    0.7328    0.7411      2133

# %% [markdown]
# ## Remove last block

# %%
def get_index_by_layer_name(model, layer_name):
  '''
  get_index_by_layer_name is used to retrieve the index of a specific layer
  :param model: model to check
  :param layer_name: name of the layer we want to get the index of
  :return: the index of the layer named as defined in layer_name
  '''
  for index, layer in enumerate(model.layers):
      if layer.name == layer_name:
          return index

# %%
conv_base = tf.keras.applications.MobileNetV2(
    input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH,3),
    alpha=1,
    include_top= False,
    weights="imagenet",
)

# %%
base = Model(conv_base.input, conv_base.layers[get_index_by_layer_name(conv_base, 'block_15_add')].output, name='base')
base.trainable = False
base.summary()
# Out:
# Model: "base"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 112, 112, 32)         864       ['input_6[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 112, 112, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 112, 112, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 112, 112, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 112, 112, 32)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 112, 112, 16)         512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 112, 112, 16)         64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 112, 112, 96)         1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 112, 112, 96)         384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 112, 112, 96)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 113, 113, 96)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 56, 56, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 56, 56, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 56, 56, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 56, 56, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 56, 56, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 56, 56, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 56, 56, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 56, 56, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 56, 56, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 56, 56, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 56, 56, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 56, 56, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 56, 56, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 57, 57, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 28, 28, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 28, 28, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 28, 28, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 28, 28, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 28, 28, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 28, 28, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 28, 28, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 28, 28, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 28, 28, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 28, 28, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 28, 28, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 28, 28, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 28, 28, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 28, 28, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 29, 29, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 14, 14, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 14, 14, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 14, 14, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 14, 14, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 14, 14, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 14, 14, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 14, 14, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 14, 14, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 14, 14, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 14, 14, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 14, 14, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 14, 14, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 14, 14, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 14, 14, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 14, 14, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 14, 14, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 14, 14, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 14, 14, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 14, 14, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 14, 14, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 14, 14, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 14, 14, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 14, 14, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 14, 14, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 14, 14, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 14, 14, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 14, 14, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 14, 14, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 14, 14, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 14, 14, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 14, 14, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 14, 14, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 14, 14, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 14, 14, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 15, 15, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 7, 7, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 7, 7, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 7, 7, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 7, 7, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 7, 7, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 7, 7, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 7, 7, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 7, 7, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 7, 7, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 7, 7, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 7, 7, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 7, 7, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 7, 7, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 7, 7, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 7, 7, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 7, 7, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
# ==================================================================================================
# Total params: 1364864 (5.21 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1364864 (5.21 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# #### Experiment 8

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = tf.keras.applications.mobilenet.preprocess_input(inputs)
x = base(x) # feature extraction
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model2 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model2)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_4 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_4 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  base (Functional)           (None, 7, 7, 160)         1364864
#
#  global_average_pooling2d_3  (None, 160)               0
#   (GlobalAveragePooling2D)
#
#  dense_7 (Dense)             (None, 256)               41216
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 1406337 (5.36 MB)
# Trainable params: 41473 (162.00 KB)
# Non-trainable params: 1364864 (5.21 MB)
# _________________________________________________________________

# %%
run_model(model2, 'experiment8_feature_extraction', epochs = 50, patience=5)
# Out:
# Epoch 1/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.6845 - accuracy: 0.6851
# Epoch 1: val_loss improved from inf to 0.78695, saving model to /content/models/experiment8_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 16s 64ms/step - loss: 0.6841 - accuracy: 0.6850 - val_loss: 0.7869 - val_accuracy: 0.5769
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5703 - accuracy: 0.7215
# Epoch 2: val_loss improved from 0.78695 to 0.46995, saving model to /content/models/experiment8_feature_extraction.h5
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5703 - accuracy: 0.7215 - val_loss: 0.4700 - val_accuracy: 0.7913
# Epoch 3/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5494 - accuracy: 0.7318
# Epoch 3: val_loss did not improve from 0.46995
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5493 - accuracy: 0.7320 - val_loss: 0.5483 - val_accuracy: 0.7129
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5385 - accuracy: 0.7442
# Epoch 4: val_loss did not improve from 0.46995
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5385 - accuracy: 0.7442 - val_loss: 0.4878 - val_accuracy: 0.7706
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5230 - accuracy: 0.7481
# Epoch 5: val_loss did not improve from 0.46995
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5230 - accuracy: 0.7481 - val_loss: 0.4766 - val_accuracy: 0.7824
# Epoch 6/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5134 - accuracy: 0.7492
# Epoch 6: val_loss improved from 0.46995 to 0.45439, saving model to /content/models/experiment8_feature_extraction.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5136 - accuracy: 0.7495 - val_loss: 0.4544 - val_accuracy: 0.7969
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5050 - accuracy: 0.7583
# Epoch 7: val_loss did not improve from 0.45439
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5050 - accuracy: 0.7583 - val_loss: 0.5026 - val_accuracy: 0.7538
# Epoch 8/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5110 - accuracy: 0.7531
# Epoch 8: val_loss improved from 0.45439 to 0.44748, saving model to /content/models/experiment8_feature_extraction.h5
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5110 - accuracy: 0.7538 - val_loss: 0.4475 - val_accuracy: 0.8021
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4991 - accuracy: 0.7570
# Epoch 9: val_loss did not improve from 0.44748
# 200/200 [==============================] - 12s 58ms/step - loss: 0.4991 - accuracy: 0.7570 - val_loss: 0.4650 - val_accuracy: 0.7880
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5045 - accuracy: 0.7536
# Epoch 10: val_loss improved from 0.44748 to 0.44686, saving model to /content/models/experiment8_feature_extraction.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5045 - accuracy: 0.7536 - val_loss: 0.4469 - val_accuracy: 0.8002
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5038 - accuracy: 0.7564
# Epoch 11: val_loss did not improve from 0.44686
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5038 - accuracy: 0.7564 - val_loss: 0.4575 - val_accuracy: 0.7917
# Epoch 12/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.4953 - accuracy: 0.7611
# Epoch 12: val_loss did not improve from 0.44686
# 200/200 [==============================] - 14s 67ms/step - loss: 0.4954 - accuracy: 0.7609 - val_loss: 0.5524 - val_accuracy: 0.7083
# Epoch 13/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.4979 - accuracy: 0.7627
# Epoch 13: val_loss did not improve from 0.44686
# 200/200 [==============================] - 13s 61ms/step - loss: 0.4976 - accuracy: 0.7630 - val_loss: 0.5663 - val_accuracy: 0.7003
# Epoch 14/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4947 - accuracy: 0.7631
# Epoch 14: val_loss did not improve from 0.44686
# 200/200 [==============================] - 12s 59ms/step - loss: 0.4947 - accuracy: 0.7631 - val_loss: 0.4832 - val_accuracy: 0.7674
# Epoch 15/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.4965 - accuracy: 0.7590
# Epoch 15: val_loss did not improve from 0.44686
# 200/200 [==============================] - 12s 59ms/step - loss: 0.4966 - accuracy: 0.7588 - val_loss: 0.4781 - val_accuracy: 0.7692

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment8_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 3s 39ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6662    0.7486    0.7050       696
#            1     0.8705    0.8184    0.8436      1437
#
#     accuracy                         0.7956      2133
#    macro avg     0.7684    0.7835    0.7743      2133
# weighted avg     0.8038    0.7956    0.7984      2133

# %% [markdown]
# #### Experiment 9

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = tf.keras.applications.mobilenet.preprocess_input(inputs)
x = base(x) # feature extraction
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model3 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model3)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_8 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_8 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  base (Functional)           (None, 7, 7, 160)         1364864
#
#  global_average_pooling2d_6  (None, 160)               0
#   (GlobalAveragePooling2D)
#
#  dropout_6 (Dropout)         (None, 160)               0
#
#  dense_13 (Dense)            (None, 1)                 161
#
# =================================================================
# Total params: 1365025 (5.21 MB)
# Trainable params: 161 (644.00 Byte)
# Non-trainable params: 1364864 (5.21 MB)
# _________________________________________________________________

# %%
run_model(model3, 'experiment9_feature_extraction', epochs = 50, patience=5)
# Out:
# Epoch 1/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.8794 - accuracy: 0.5961
# Epoch 1: val_loss improved from inf to 0.57682, saving model to /content/models/experiment9_feature_extraction.h5
# 200/200 [==============================] - 15s 63ms/step - loss: 0.8792 - accuracy: 0.5965 - val_loss: 0.5768 - val_accuracy: 0.7054
# Epoch 2/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.7136 - accuracy: 0.6390
# Epoch 2: val_loss improved from 0.57682 to 0.56941, saving model to /content/models/experiment9_feature_extraction.h5
# 200/200 [==============================] - 12s 59ms/step - loss: 0.7127 - accuracy: 0.6391 - val_loss: 0.5694 - val_accuracy: 0.7087
# Epoch 3/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.6403 - accuracy: 0.6734
# Epoch 3: val_loss improved from 0.56941 to 0.54990, saving model to /content/models/experiment9_feature_extraction.h5
# 200/200 [==============================] - 11s 56ms/step - loss: 0.6399 - accuracy: 0.6739 - val_loss: 0.5499 - val_accuracy: 0.7280
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5921 - accuracy: 0.6925
# Epoch 4: val_loss improved from 0.54990 to 0.51112, saving model to /content/models/experiment9_feature_extraction.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5921 - accuracy: 0.6925 - val_loss: 0.5111 - val_accuracy: 0.7575
# Epoch 5/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5855 - accuracy: 0.7018
# Epoch 5: val_loss did not improve from 0.51112
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5856 - accuracy: 0.7009 - val_loss: 0.5157 - val_accuracy: 0.7514
# Epoch 6/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5735 - accuracy: 0.7035
# Epoch 6: val_loss did not improve from 0.51112
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5740 - accuracy: 0.7031 - val_loss: 0.5237 - val_accuracy: 0.7430
# Epoch 7/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5663 - accuracy: 0.7098
# Epoch 7: val_loss did not improve from 0.51112
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5662 - accuracy: 0.7098 - val_loss: 0.5380 - val_accuracy: 0.7275
# Epoch 8/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5683 - accuracy: 0.7136
# Epoch 8: val_loss improved from 0.51112 to 0.49935, saving model to /content/models/experiment9_feature_extraction.h5
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5682 - accuracy: 0.7133 - val_loss: 0.4994 - val_accuracy: 0.7669
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5582 - accuracy: 0.7161
# Epoch 9: val_loss did not improve from 0.49935
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5582 - accuracy: 0.7161 - val_loss: 0.5233 - val_accuracy: 0.7397
# Epoch 10/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5666 - accuracy: 0.7156
# Epoch 10: val_loss did not improve from 0.49935
# 200/200 [==============================] - 13s 64ms/step - loss: 0.5670 - accuracy: 0.7151 - val_loss: 0.5100 - val_accuracy: 0.7556
# Epoch 11/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5632 - accuracy: 0.7175
# Epoch 11: val_loss did not improve from 0.49935
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5631 - accuracy: 0.7173 - val_loss: 0.5287 - val_accuracy: 0.7378
# Epoch 12/50
# 200/200 [==============================] - ETA: 0s - loss: 0.5675 - accuracy: 0.7067
# Epoch 12: val_loss did not improve from 0.49935
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5675 - accuracy: 0.7067 - val_loss: 0.5224 - val_accuracy: 0.7416
# Epoch 13/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.5718 - accuracy: 0.7093
# Epoch 13: val_loss did not improve from 0.49935
# 200/200 [==============================] - 12s 57ms/step - loss: 0.5719 - accuracy: 0.7090 - val_loss: 0.5362 - val_accuracy: 0.7326

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment9_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 3s 39ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6404    0.7241    0.6797       696
#            1     0.8574    0.8031    0.8293      1437
#
#     accuracy                         0.7773      2133
#    macro avg     0.7489    0.7636    0.7545      2133
# weighted avg     0.7866    0.7773    0.7805      2133

# %% [markdown]
# #### Experiment 10

# %%
inputs = keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3))
x = tf.keras.applications.mobilenet.preprocess_input(inputs)
x = base(x) # feature extraction
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model2 = keras.Model(inputs=inputs, outputs=outputs)
compile_model(model2)
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_9 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_9 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  base (Functional)           (None, 7, 7, 160)         1364864
#
#  flatten_2 (Flatten)         (None, 7840)              0
#
#  dense_14 (Dense)            (None, 256)               2007296
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_15 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 3372417 (12.86 MB)
# Trainable params: 2007553 (7.66 MB)
# Non-trainable params: 1364864 (5.21 MB)
# _________________________________________________________________

# %%
run_model(model2, 'experiment10_feature_extraction', epochs = 50, patience=5)
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 11.2698 - accuracy: 0.6645
# Epoch 1: val_loss improved from inf to 2.92388, saving model to /content/models/experiment10_feature_extraction.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 16s 63ms/step - loss: 11.2698 - accuracy: 0.6645 - val_loss: 2.9239 - val_accuracy: 0.7659
# Epoch 2/50
# 199/200 [============================>.] - ETA: 0s - loss: 5.5433 - accuracy: 0.7155
# Epoch 2: val_loss improved from 2.92388 to 1.65540, saving model to /content/models/experiment10_feature_extraction.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 5.5392 - accuracy: 0.7148 - val_loss: 1.6554 - val_accuracy: 0.8016
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 2.1759 - accuracy: 0.7538
# Epoch 3: val_loss improved from 1.65540 to 1.53043, saving model to /content/models/experiment10_feature_extraction.h5
# 200/200 [==============================] - 13s 62ms/step - loss: 2.1759 - accuracy: 0.7538 - val_loss: 1.5304 - val_accuracy: 0.6970
# Epoch 4/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.8341 - accuracy: 0.7882
# Epoch 4: val_loss improved from 1.53043 to 0.49933, saving model to /content/models/experiment10_feature_extraction.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.8333 - accuracy: 0.7886 - val_loss: 0.4993 - val_accuracy: 0.8222
# Epoch 5/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.4761 - accuracy: 0.8075
# Epoch 5: val_loss did not improve from 0.49933
# 200/200 [==============================] - 12s 58ms/step - loss: 0.4769 - accuracy: 0.8072 - val_loss: 0.5020 - val_accuracy: 0.7758
# Epoch 6/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.4042 - accuracy: 0.8194
# Epoch 6: val_loss improved from 0.49933 to 0.40545, saving model to /content/models/experiment10_feature_extraction.h5
# 200/200 [==============================] - 12s 58ms/step - loss: 0.4032 - accuracy: 0.8202 - val_loss: 0.4054 - val_accuracy: 0.8222
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3735 - accuracy: 0.8329
# Epoch 7: val_loss improved from 0.40545 to 0.40285, saving model to /content/models/experiment10_feature_extraction.h5
# 200/200 [==============================] - 12s 58ms/step - loss: 0.3735 - accuracy: 0.8329 - val_loss: 0.4028 - val_accuracy: 0.8260
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 0.3854 - accuracy: 0.8272
# Epoch 8: val_loss did not improve from 0.40285
# 200/200 [==============================] - 12s 57ms/step - loss: 0.3854 - accuracy: 0.8272 - val_loss: 0.4469 - val_accuracy: 0.8053
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 0.4029 - accuracy: 0.8221
# Epoch 9: val_loss did not improve from 0.40285
# 200/200 [==============================] - 12s 58ms/step - loss: 0.4029 - accuracy: 0.8221 - val_loss: 0.6629 - val_accuracy: 0.7144
# Epoch 10/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.3794 - accuracy: 0.8339
# Epoch 10: val_loss did not improve from 0.40285
# 200/200 [==============================] - 12s 58ms/step - loss: 0.3788 - accuracy: 0.8341 - val_loss: 0.4681 - val_accuracy: 0.8002
# Epoch 11/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.3960 - accuracy: 0.8321
# Epoch 11: val_loss did not improve from 0.40285
# 200/200 [==============================] - 12s 59ms/step - loss: 0.3952 - accuracy: 0.8324 - val_loss: 0.4629 - val_accuracy: 0.8171
# Epoch 12/50
# 199/200 [============================>.] - ETA: 0s - loss: 0.3960 - accuracy: 0.8288
# Epoch 12: val_loss did not improve from 0.40285
# 200/200 [==============================] - 14s 71ms/step - loss: 0.3962 - accuracy: 0.8285 - val_loss: 0.4139 - val_accuracy: 0.8255

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment10_feature_extraction.h5'))
# Out:
# 67/67 [==============================] - 3s 41ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7696    0.7342    0.7515       696
#            1     0.8741    0.8935    0.8837      1437
#
#     accuracy                         0.8415      2133
#    macro avg     0.8218    0.8139    0.8176      2133
# weighted avg     0.8400    0.8415    0.8405      2133

# %% [markdown]
# ### Fine tuning

# %% [markdown]
# #### Experiment 11

# %%
fine_tuning = models.load_model(os.path.join(GLOBAL_MODELS_FOLDER, 'experiment9_feature_extraction.h5'))

setTrainable = False
for layer in fine_tuning.get_layer('base').layers:
    if layer.name in ('block_15_depthwise_BN'):
        setTrainable = True
    if setTrainable == True:
        layer.trainable = True
    else:
      layer.trainable = False

compile_model(fine_tuning, learning_rate=1e-5)

for i, layer in enumerate(fine_tuning.get_layer('base').layers):
    print(i, layer.name, layer.trainable)
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_8 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  tf.math.subtract_8 (TFOpLa  (None, 224, 224, 3)       0
#  mbda)
#
#  base (Functional)           (None, 7, 7, 160)         1364864
#
#  global_average_pooling2d_6  (None, 160)               0
#   (GlobalAveragePooling2D)
#
#  dropout_6 (Dropout)         (None, 160)               0
#
#  dense_13 (Dense)            (None, 1)                 161
#
# =================================================================
# Total params: 1365025 (5.21 MB)
# Trainable params: 164641 (643.13 KB)
# Non-trainable params: 1200384 (4.58 MB)
# _________________________________________________________________
# 0 input_6 False
# 1 Conv1 False
# 2 bn_Conv1 False
# 3 Conv1_relu False
# 4 expanded_conv_depthwise False
# 5 expanded_conv_depthwise_BN False
# 6 expanded_conv_depthwise_relu False
# 7 expanded_conv_project False
# 8 expanded_conv_project_BN False
# 9 block_1_expand False
# 10 block_1_expand_BN False
# 11 block_1_expand_relu False
# 12 block_1_pad False
# 13 block_1_depthwise False
# 14 block_1_depthwise_BN False
# 15 block_1_depthwise_relu False
# 16 block_1_project False
# 17 block_1_project_BN False
# 18 block_2_expand False
# 19 block_2_expand_BN False
# 20 block_2_expand_relu False
# 21 block_2_depthwise False
# 22 block_2_depthwise_BN False
# 23 block_2_depthwise_relu False
# 24 block_2_project False
# 25 block_2_project_BN False
# 26 block_2_add False
# 27 block_3_expand False
# 28 block_3_expand_BN False
# 29 block_3_expand_relu False
# 30 block_3_pad False
# 31 block_3_depthwise False
# 32 block_3_depthwise_BN False
# 33 block_3_depthwise_relu False
# 34 block_3_project False
# 35 block_3_project_BN False
# 36 block_4_expand False
# 37 block_4_expand_BN False
# 38 block_4_expand_relu False
# 39 block_4_depthwise False
# 40 block_4_depthwise_BN False
# 41 block_4_depthwise_relu False
# 42 block_4_project False
# 43 block_4_project_BN False
# 44 block_4_add False
# 45 block_5_expand False
# 46 block_5_expand_BN False
# 47 block_5_expand_relu False
# 48 block_5_depthwise False
# 49 block_5_depthwise_BN False
# 50 block_5_depthwise_relu False
# 51 block_5_project False
# 52 block_5_project_BN False
# 53 block_5_add False
# 54 block_6_expand False
# 55 block_6_expand_BN False
# 56 block_6_expand_relu False
# 57 block_6_pad False
# 58 block_6_depthwise False
# 59 block_6_depthwise_BN False
# 60 block_6_depthwise_relu False
# 61 block_6_project False
# 62 block_6_project_BN False
# 63 block_7_expand False
# 64 block_7_expand_BN False
# 65 block_7_expand_relu False
# 66 block_7_depthwise False
# 67 block_7_depthwise_BN False
# 68 block_7_depthwise_relu False
# 69 block_7_project False
# 70 block_7_project_BN False
# 71 block_7_add False
# 72 block_8_expand False
# 73 block_8_expand_BN False
# 74 block_8_expand_relu False
# 75 block_8_depthwise False
# 76 block_8_depthwise_BN False
# 77 block_8_depthwise_relu False
# 78 block_8_project False
# 79 block_8_project_BN False
# 80 block_8_add False
# 81 block_9_expand False
# 82 block_9_expand_BN False
# 83 block_9_expand_relu False
# 84 block_9_depthwise False
# 85 block_9_depthwise_BN False
# 86 block_9_depthwise_relu False
# 87 block_9_project False
# 88 block_9_project_BN False
# 89 block_9_add False
# 90 block_10_expand False
# 91 block_10_expand_BN False
# 92 block_10_expand_relu False
# 93 block_10_depthwise False
# 94 block_10_depthwise_BN False
# 95 block_10_depthwise_relu False
# 96 block_10_project False
# 97 block_10_project_BN False
# 98 block_11_expand False
# 99 block_11_expand_BN False
# 100 block_11_expand_relu False
# 101 block_11_depthwise False
# 102 block_11_depthwise_BN False
# 103 block_11_depthwise_relu False
# 104 block_11_project False
# 105 block_11_project_BN False
# 106 block_11_add False
# 107 block_12_expand False
# 108 block_12_expand_BN False
# 109 block_12_expand_relu False
# 110 block_12_depthwise False
# 111 block_12_depthwise_BN False
# 112 block_12_depthwise_relu False
# 113 block_12_project False
# 114 block_12_project_BN False
# 115 block_12_add False
# 116 block_13_expand False
# 117 block_13_expand_BN False
# 118 block_13_expand_relu False
# 119 block_13_pad False
# 120 block_13_depthwise False
# 121 block_13_depthwise_BN False
# 122 block_13_depthwise_relu False
# 123 block_13_project False
# 124 block_13_project_BN False
# 125 block_14_expand False
# 126 block_14_expand_BN False
# 127 block_14_expand_relu False
# 128 block_14_depthwise False
# 129 block_14_depthwise_BN False
# 130 block_14_depthwise_relu False
# 131 block_14_project False
# 132 block_14_project_BN False
# 133 block_14_add False
# 134 block_15_expand False
# 135 block_15_expand_BN False
# 136 block_15_expand_relu False
# 137 block_15_depthwise True
# 138 block_15_depthwise_BN True
# 139 block_15_depthwise_relu True
# 140 block_15_project True
# 141 block_15_project_BN True
# 142 block_15_add True

# %%
run_model(fine_tuning, 'experiment11_fine_tuning_cut', epochs = 100, patience=5)
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5843 - accuracy: 0.7050
# Epoch 1: val_loss improved from inf to 0.49920, saving model to /content/models/experiment11_fine_tuning_cut.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 200/200 [==============================] - 16s 65ms/step - loss: 0.5843 - accuracy: 0.7050 - val_loss: 0.4992 - val_accuracy: 0.7664
# Epoch 2/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5680 - accuracy: 0.7129
# Epoch 2: val_loss improved from 0.49920 to 0.49578, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 13s 62ms/step - loss: 0.5683 - accuracy: 0.7122 - val_loss: 0.4958 - val_accuracy: 0.7678
# Epoch 3/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5677 - accuracy: 0.7176
# Epoch 3: val_loss improved from 0.49578 to 0.48992, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5677 - accuracy: 0.7176 - val_loss: 0.4899 - val_accuracy: 0.7725
# Epoch 4/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5627 - accuracy: 0.7165
# Epoch 4: val_loss improved from 0.48992 to 0.48321, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5627 - accuracy: 0.7165 - val_loss: 0.4832 - val_accuracy: 0.7800
# Epoch 5/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5542 - accuracy: 0.7249
# Epoch 5: val_loss improved from 0.48321 to 0.47862, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5541 - accuracy: 0.7251 - val_loss: 0.4786 - val_accuracy: 0.7856
# Epoch 6/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5540 - accuracy: 0.7231
# Epoch 6: val_loss improved from 0.47862 to 0.47594, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5540 - accuracy: 0.7231 - val_loss: 0.4759 - val_accuracy: 0.7875
# Epoch 7/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5510 - accuracy: 0.7264
# Epoch 7: val_loss improved from 0.47594 to 0.47197, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5510 - accuracy: 0.7264 - val_loss: 0.4720 - val_accuracy: 0.7899
# Epoch 8/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5525 - accuracy: 0.7213
# Epoch 8: val_loss improved from 0.47197 to 0.46893, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5522 - accuracy: 0.7214 - val_loss: 0.4689 - val_accuracy: 0.7917
# Epoch 9/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5559 - accuracy: 0.7166
# Epoch 9: val_loss improved from 0.46893 to 0.46478, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5554 - accuracy: 0.7170 - val_loss: 0.4648 - val_accuracy: 0.7927
# Epoch 10/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5482 - accuracy: 0.7245
# Epoch 10: val_loss improved from 0.46478 to 0.46222, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 14s 69ms/step - loss: 0.5482 - accuracy: 0.7245 - val_loss: 0.4622 - val_accuracy: 0.7913
# Epoch 11/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5479 - accuracy: 0.7283
# Epoch 11: val_loss improved from 0.46222 to 0.46055, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5480 - accuracy: 0.7284 - val_loss: 0.4605 - val_accuracy: 0.7922
# Epoch 12/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5517 - accuracy: 0.7247
# Epoch 12: val_loss improved from 0.46055 to 0.45872, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5517 - accuracy: 0.7247 - val_loss: 0.4587 - val_accuracy: 0.7899
# Epoch 13/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5396 - accuracy: 0.7294
# Epoch 13: val_loss improved from 0.45872 to 0.45690, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5396 - accuracy: 0.7292 - val_loss: 0.4569 - val_accuracy: 0.7913
# Epoch 14/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5450 - accuracy: 0.7306
# Epoch 14: val_loss improved from 0.45690 to 0.45549, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5450 - accuracy: 0.7306 - val_loss: 0.4555 - val_accuracy: 0.7922
# Epoch 15/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5435 - accuracy: 0.7330
# Epoch 15: val_loss improved from 0.45549 to 0.45375, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5436 - accuracy: 0.7330 - val_loss: 0.4538 - val_accuracy: 0.7932
# Epoch 16/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5380 - accuracy: 0.7326
# Epoch 16: val_loss improved from 0.45375 to 0.45224, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5380 - accuracy: 0.7326 - val_loss: 0.4522 - val_accuracy: 0.7950
# Epoch 17/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5424 - accuracy: 0.7343
# Epoch 17: val_loss improved from 0.45224 to 0.45188, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5429 - accuracy: 0.7337 - val_loss: 0.4519 - val_accuracy: 0.7974
# Epoch 18/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5371 - accuracy: 0.7309
# Epoch 18: val_loss improved from 0.45188 to 0.44994, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5371 - accuracy: 0.7309 - val_loss: 0.4499 - val_accuracy: 0.7997
# Epoch 19/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5359 - accuracy: 0.7316
# Epoch 19: val_loss improved from 0.44994 to 0.44878, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5359 - accuracy: 0.7316 - val_loss: 0.4488 - val_accuracy: 0.7992
# Epoch 20/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5320 - accuracy: 0.7343
# Epoch 20: val_loss improved from 0.44878 to 0.44705, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5325 - accuracy: 0.7337 - val_loss: 0.4470 - val_accuracy: 0.7992
# Epoch 21/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5321 - accuracy: 0.7371
# Epoch 21: val_loss improved from 0.44705 to 0.44543, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5323 - accuracy: 0.7367 - val_loss: 0.4454 - val_accuracy: 0.8025
# Epoch 22/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5320 - accuracy: 0.7401
# Epoch 22: val_loss improved from 0.44543 to 0.44415, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5324 - accuracy: 0.7397 - val_loss: 0.4442 - val_accuracy: 0.8030
# Epoch 23/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5319 - accuracy: 0.7372
# Epoch 23: val_loss did not improve from 0.44415
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5319 - accuracy: 0.7372 - val_loss: 0.4448 - val_accuracy: 0.8030
# Epoch 24/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5274 - accuracy: 0.7405
# Epoch 24: val_loss improved from 0.44415 to 0.44181, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5274 - accuracy: 0.7405 - val_loss: 0.4418 - val_accuracy: 0.8016
# Epoch 25/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5247 - accuracy: 0.7409
# Epoch 25: val_loss improved from 0.44181 to 0.44045, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5249 - accuracy: 0.7409 - val_loss: 0.4404 - val_accuracy: 0.8016
# Epoch 26/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5207 - accuracy: 0.7401
# Epoch 26: val_loss improved from 0.44045 to 0.44023, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 58ms/step - loss: 0.5204 - accuracy: 0.7403 - val_loss: 0.4402 - val_accuracy: 0.8063
# Epoch 27/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5238 - accuracy: 0.7367
# Epoch 27: val_loss improved from 0.44023 to 0.43899, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5238 - accuracy: 0.7367 - val_loss: 0.4390 - val_accuracy: 0.8072
# Epoch 28/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5269 - accuracy: 0.7470
# Epoch 28: val_loss improved from 0.43899 to 0.43764, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5269 - accuracy: 0.7470 - val_loss: 0.4376 - val_accuracy: 0.8068
# Epoch 29/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5229 - accuracy: 0.7426
# Epoch 29: val_loss improved from 0.43764 to 0.43613, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5225 - accuracy: 0.7431 - val_loss: 0.4361 - val_accuracy: 0.8058
# Epoch 30/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5177 - accuracy: 0.7433
# Epoch 30: val_loss improved from 0.43613 to 0.43552, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5177 - accuracy: 0.7433 - val_loss: 0.4355 - val_accuracy: 0.8063
# Epoch 31/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5162 - accuracy: 0.7450
# Epoch 31: val_loss improved from 0.43552 to 0.43538, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 14s 71ms/step - loss: 0.5162 - accuracy: 0.7450 - val_loss: 0.4354 - val_accuracy: 0.8086
# Epoch 32/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5147 - accuracy: 0.7477
# Epoch 32: val_loss improved from 0.43538 to 0.43450, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5147 - accuracy: 0.7477 - val_loss: 0.4345 - val_accuracy: 0.8086
# Epoch 33/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5141 - accuracy: 0.7456
# Epoch 33: val_loss improved from 0.43450 to 0.43259, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5141 - accuracy: 0.7456 - val_loss: 0.4326 - val_accuracy: 0.8058
# Epoch 34/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5131 - accuracy: 0.7484
# Epoch 34: val_loss improved from 0.43259 to 0.43131, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5131 - accuracy: 0.7484 - val_loss: 0.4313 - val_accuracy: 0.8091
# Epoch 35/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.7500
# Epoch 35: val_loss improved from 0.43131 to 0.43101, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 59ms/step - loss: 0.5098 - accuracy: 0.7500 - val_loss: 0.4310 - val_accuracy: 0.8100
# Epoch 36/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5094 - accuracy: 0.7470
# Epoch 36: val_loss improved from 0.43101 to 0.42964, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 13s 62ms/step - loss: 0.5094 - accuracy: 0.7470 - val_loss: 0.4296 - val_accuracy: 0.8086
# Epoch 37/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5122 - accuracy: 0.7448
# Epoch 37: val_loss improved from 0.42964 to 0.42870, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 13s 64ms/step - loss: 0.5125 - accuracy: 0.7448 - val_loss: 0.4287 - val_accuracy: 0.8082
# Epoch 38/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5084 - accuracy: 0.7542
# Epoch 38: val_loss improved from 0.42870 to 0.42773, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5084 - accuracy: 0.7542 - val_loss: 0.4277 - val_accuracy: 0.8105
# Epoch 39/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5054 - accuracy: 0.7561
# Epoch 39: val_loss improved from 0.42773 to 0.42693, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5051 - accuracy: 0.7563 - val_loss: 0.4269 - val_accuracy: 0.8114
# Epoch 40/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5034 - accuracy: 0.7531
# Epoch 40: val_loss improved from 0.42693 to 0.42635, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5034 - accuracy: 0.7531 - val_loss: 0.4263 - val_accuracy: 0.8119
# Epoch 41/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5068 - accuracy: 0.7522
# Epoch 41: val_loss improved from 0.42635 to 0.42538, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5061 - accuracy: 0.7527 - val_loss: 0.4254 - val_accuracy: 0.8138
# Epoch 42/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.7547
# Epoch 42: val_loss improved from 0.42538 to 0.42474, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5073 - accuracy: 0.7547 - val_loss: 0.4247 - val_accuracy: 0.8129
# Epoch 43/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5083 - accuracy: 0.7502
# Epoch 43: val_loss improved from 0.42474 to 0.42402, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.5083 - accuracy: 0.7502 - val_loss: 0.4240 - val_accuracy: 0.8129
# Epoch 44/100
# 200/200 [==============================] - ETA: 0s - loss: 0.5031 - accuracy: 0.7594
# Epoch 44: val_loss improved from 0.42402 to 0.42298, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5031 - accuracy: 0.7594 - val_loss: 0.4230 - val_accuracy: 0.8147
# Epoch 45/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4971 - accuracy: 0.7597
# Epoch 45: val_loss improved from 0.42298 to 0.42235, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 13s 62ms/step - loss: 0.4971 - accuracy: 0.7597 - val_loss: 0.4224 - val_accuracy: 0.8157
# Epoch 46/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5069 - accuracy: 0.7533
# Epoch 46: val_loss improved from 0.42235 to 0.42191, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.5072 - accuracy: 0.7530 - val_loss: 0.4219 - val_accuracy: 0.8129
# Epoch 47/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4990 - accuracy: 0.7594
# Epoch 47: val_loss improved from 0.42191 to 0.42131, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 61ms/step - loss: 0.4990 - accuracy: 0.7594 - val_loss: 0.4213 - val_accuracy: 0.8152
# Epoch 48/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.4987 - accuracy: 0.7564
# Epoch 48: val_loss did not improve from 0.42131
# 200/200 [==============================] - 13s 62ms/step - loss: 0.4991 - accuracy: 0.7559 - val_loss: 0.4217 - val_accuracy: 0.8166
# Epoch 49/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4989 - accuracy: 0.7569
# Epoch 49: val_loss did not improve from 0.42131
# 200/200 [==============================] - 12s 61ms/step - loss: 0.4989 - accuracy: 0.7569 - val_loss: 0.4220 - val_accuracy: 0.8166
# Epoch 50/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4967 - accuracy: 0.7613
# Epoch 50: val_loss did not improve from 0.42131
# 200/200 [==============================] - 12s 59ms/step - loss: 0.4967 - accuracy: 0.7613 - val_loss: 0.4219 - val_accuracy: 0.8171
# Epoch 51/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.5027 - accuracy: 0.7536
# Epoch 51: val_loss did not improve from 0.42131
# 200/200 [==============================] - 14s 67ms/step - loss: 0.5023 - accuracy: 0.7541 - val_loss: 0.4216 - val_accuracy: 0.8175
# Epoch 52/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4956 - accuracy: 0.7608
# Epoch 52: val_loss improved from 0.42131 to 0.41994, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.4956 - accuracy: 0.7608 - val_loss: 0.4199 - val_accuracy: 0.8166
# Epoch 53/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4930 - accuracy: 0.7588
# Epoch 53: val_loss improved from 0.41994 to 0.41909, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 59ms/step - loss: 0.4930 - accuracy: 0.7588 - val_loss: 0.4191 - val_accuracy: 0.8166
# Epoch 54/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.4933 - accuracy: 0.7544
# Epoch 54: val_loss did not improve from 0.41909
# 200/200 [==============================] - 12s 60ms/step - loss: 0.4933 - accuracy: 0.7547 - val_loss: 0.4192 - val_accuracy: 0.8180
# Epoch 55/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4915 - accuracy: 0.7613
# Epoch 55: val_loss improved from 0.41909 to 0.41866, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 13s 61ms/step - loss: 0.4915 - accuracy: 0.7613 - val_loss: 0.4187 - val_accuracy: 0.8185
# Epoch 56/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.4939 - accuracy: 0.7594
# Epoch 56: val_loss improved from 0.41866 to 0.41786, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 12s 60ms/step - loss: 0.4939 - accuracy: 0.7595 - val_loss: 0.4179 - val_accuracy: 0.8185
# Epoch 57/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.4990 - accuracy: 0.7593
# Epoch 57: val_loss did not improve from 0.41786
# 200/200 [==============================] - 14s 68ms/step - loss: 0.4986 - accuracy: 0.7592 - val_loss: 0.4208 - val_accuracy: 0.8194
# Epoch 58/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.4891 - accuracy: 0.7624
# Epoch 58: val_loss improved from 0.41786 to 0.41551, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4895 - accuracy: 0.7614 - val_loss: 0.4155 - val_accuracy: 0.8194
# Epoch 59/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.4899 - accuracy: 0.7596
# Epoch 59: val_loss improved from 0.41551 to 0.41527, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 14s 70ms/step - loss: 0.4907 - accuracy: 0.7592 - val_loss: 0.4153 - val_accuracy: 0.8204
# Epoch 60/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4880 - accuracy: 0.7655
# Epoch 60: val_loss did not improve from 0.41527
# 200/200 [==============================] - 13s 62ms/step - loss: 0.4880 - accuracy: 0.7655 - val_loss: 0.4178 - val_accuracy: 0.8218
# Epoch 61/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4882 - accuracy: 0.7639
# Epoch 61: val_loss improved from 0.41527 to 0.41373, saving model to /content/models/experiment11_fine_tuning_cut.h5
# 200/200 [==============================] - 13s 62ms/step - loss: 0.4882 - accuracy: 0.7639 - val_loss: 0.4137 - val_accuracy: 0.8204
# Epoch 62/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.4849 - accuracy: 0.7619
# Epoch 62: val_loss did not improve from 0.41373
# 200/200 [==============================] - 12s 60ms/step - loss: 0.4850 - accuracy: 0.7622 - val_loss: 0.4145 - val_accuracy: 0.8236
# Epoch 63/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4882 - accuracy: 0.7620
# Epoch 63: val_loss did not improve from 0.41373
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4882 - accuracy: 0.7620 - val_loss: 0.4173 - val_accuracy: 0.8189
# Epoch 64/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.4867 - accuracy: 0.7629
# Epoch 64: val_loss did not improve from 0.41373
# 200/200 [==============================] - 12s 59ms/step - loss: 0.4868 - accuracy: 0.7628 - val_loss: 0.4149 - val_accuracy: 0.8222
# Epoch 65/100
# 200/200 [==============================] - ETA: 0s - loss: 0.4843 - accuracy: 0.7680
# Epoch 65: val_loss did not improve from 0.41373
# 200/200 [==============================] - 14s 68ms/step - loss: 0.4843 - accuracy: 0.7680 - val_loss: 0.4163 - val_accuracy: 0.8204
# Epoch 66/100
# 199/200 [============================>.] - ETA: 0s - loss: 0.4810 - accuracy: 0.7692
# Epoch 66: val_loss did not improve from 0.41373
# 200/200 [==============================] - 12s 61ms/step - loss: 0.4813 - accuracy: 0.7688 - val_loss: 0.4148 - val_accuracy: 0.8208

# %%
evaluate_model(tf.keras.models.load_model(GLOBAL_MODELS_FOLDER + '/experiment11_fine_tuning_cut.h5'))
# Out:
# 67/67 [==============================] - 3s 39ms/step
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7313    0.7744    0.7523       696
#            1     0.8875    0.8622    0.8747      1437
#
#     accuracy                         0.8336      2133
#    macro avg     0.8094    0.8183    0.8135      2133
# weighted avg     0.8366    0.8336    0.8347      2133
